# %%
import requests
import random
import numpy as np
import pandas as pd
import string #Required for generating random stock tickers

# %% [markdown]
# # 1. Retrieving Real Stock Data with API

# %% [markdown]
# To start off, we obtain the Top 200 stocks by market capitalization (named as price in the code) from US-listed exchanges.
#
# We also include a try-except block to ensure that any errors during requests are caught and reported.

# %%
stock_url = "https://financialmodelingprep.com/api/v3/stock/list?apikey=NSD2m35XyjrwOoYdtKbq1JPOHlABl8CW"

try:
    stock_response = requests.get(stock_url)
    stock_response.raise_for_status()
    stock_data = stock_response.json()

    # Check API response structure
    print("Sample API Response:")
    print(stock_data[:5])

    # Filter US-listed stocks only
    us_exchanges = ['NYSE', 'NASDAQ', 'AMEX']

    valid_stocks = [
        stock for stock in stock_data
        if stock.get('exchangeShortName') in us_exchanges  # US-listed exchanges
        and stock.get('type') == 'stock'  # Only include stocks
        and stock.get('price') is not None  # Ensure price is not None
    ]

    print(f"Total valid stocks: {len(valid_stocks)}")
    print("Sample valid stocks:", valid_stocks[:5])

    # Sort by price, handling None values safely
    sorted_stocks = sorted(valid_stocks, key=lambda x: x.get('price', 0), reverse=True)

    # Get the top 200 stocks
    top_200_stocks = sorted_stocks[:200]
    stock_symbols = [stock['symbol'] for stock in top_200_stocks]

    print("Top 200 Stocks by Price (Placeholder for Market Cap):")
    print(stock_symbols)

except Exception as e:
    print(f"Error: {e}")
# Out:
# Sample API Response:
# [{'symbol': 'NPOF.ME', 'name': 'FIZIKA Scientific and Production Association Open Joint-Stock Company', 'price': 11850, 'exchange': 'Moscow Stock Exchange', 'exchangeShortName': 'MCX', 'type': 'stock'}, {'symbol': 'TERRAREAL.BO', 'name': 'Terraform Realstate Limited', 'price': 6.5, 'exchange': 'Bombay Stock Exchange', 'exchangeShortName': 'BSE', 'type': 'stock'}, {'symbol': 'KCPSUGIND.NS', 'name': 'K.C.P. Sugar and Industries Corporation Limited', 'price': 46.97, 'exchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'type': 'stock'}, {'symbol': 'RKEC.NS', 'name': 'RKEC Projects Limited', 'price': 99.79, 'exchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'type': 'stock'}, {'symbol': 'PMGOLD.AX', 'name': 'Perth Mint Gold', 'price': 17.94, 'exchange': 'Australian Securities Exchange', 'exchangeShortName': 'ASX', 'type': 'etf'}]
# Total valid stocks: 11005
# Sample valid stocks: [{'symbol': 'BUPXX', 'name': 'BlackRock Liquidity Funds - FedFund', 'price': 1, 'exchange': 'Nasdaq', 'exchangeShortName': 'NASDAQ', 'type': 'stock'}, {'symbol': 'AEAXX', 'name': 'AB Government Exchange Reserves', 'price': 1, 'exchange': 'Nasdaq', 'exchangeShortName': 'NASDAQ', 'type': 'stock'}, {'symbol': 'DTC', 'name': 'Solo Brands, Inc.', 'price': 1.12, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}, {'symbol': 'CMG', 'name': 'Chipotle Mexican Grill, Inc.', 'price': 64.29, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}, {'symbol': 'PRM', 'name': 'Perimeter Solutions, SA', 'price': 13.02, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}]
# Top 200 Stocks by Price (Placeholder for Market Cap):
# ['BRK-A', 'NVR', 'BKNG', 'AZO', 'SEB', 'FICO', 'FCNCA', 'WTM', 'DHR-PA', 'MELI', 'MKL', 'AVGOP', 'BH-A', 'TDG', 'DHR-PB', 'BAC-PL', 'COKE', 'MTD', 'ORLY', 'WFC-PL', 'TPL', 'GWW', 'NOW', 'BLK', 'FTV-PA', 'COST', 'EQIX', 'NFLX', 'GHC', 'USB-PA', 'Y', 'LLY', 'URI', 'HUBS', 'REGN', 'ASML', 'INTU', 'PH', 'LII', 'KLAC', 'ARGX', 'AXON', 'MPWR', 'META', 'MSCI', 'TYL', 'GS', 'DJCO', 'MCK', 'ISRG', 'MLM', 'AMP', 'MUSA', 'NEU', 'ROP', 'WSO-B', 'SAIA', 'MA', 'TMO', 'CHE', 'SNPS', 'WSO', 'SPGI', 'NWLI', 'IT', 'KNSL', 'CACC', 'LMT', 'FDS', 'MCO', 'UNH', 'ANTM', 'NOC', 'TSLA', 'EME', 'SPOT', 'CVCO', 'TDY', 'VRTX', 'MSI', 'ATRI', 'BRK-B', 'ADBE', 'FIX', 'MSFT', 'DPZ', 'DE', 'HUBB', 'DDS', 'RACE', 'LIN', 'IDXX', 'ERIE', 'ULTA', 'GPI', 'CASY', 'CACI', 'RH', 'HD', 'WINA', 'CSL', 'ZBRA', 'TT', 'LULU', 'MSTR', 'ABMD', 'CSWI', 'UTHR', 'CRWD', 'CAT', 'WAT', 'CHTR', 'SYK', 'LAD', 'ELV', 'CABO', 'CW', 'SHW', 'CMI', 'AON', 'POOL', 'ACN', 'EG', 'KAI', 'DUOL', 'CPAY', 'RE', 'CRM', 'CRVL', 'MORN', 'SNA', 'MEDP', 'ETN', 'ANSS', 'UI', 'BLD', 'APP', 'BIO', 'BIO-B', 'PWR', 'SWAV', 'WST', 'KRTX', 'LPLA', 'GEV', 'VMI', 'ESGR', 'RBC', 'V', 'CYBR', 'SEZL', 'PSA', 'AYI', 'PIPR', 'COIN', 'CDNS', 'WTW', 'STZ-B', 'SAM', 'HCA', 'MDGL', 'APD', 'FLT', 'ADSK', 'AXP', 'MCD', 'WING', 'ADP', 'MANH', 'ESS', 'KSU', 'ROK', 'MOH', 'BURL', 'EVR', 'WIRE', 'MAR', 'AJG', 'VRSK', 'RS', 'WDAY', 'FDX', 'CB', 'PRI', 'TSCO', 'EFX', 'ASR', 'FLUT', 'VMC', 'HIFS', 'TEAM', 'PXD', 'JLL', 'ITW', 'EXP', 'AMGN', 'CI', 'GD', 'MDB', 'WDFC']

# %% [markdown]
# For each of these Top 200 stocks, we will then retrieve its annual income statement data with an API request.
#
# The API response is stored in a list of dictionary to extract relevant metrics like Year, Revenue and Net Income.
#
# Hence, each record corresponds to a specific stock and year, with detailed financial metrics.
#
# Again, error handling during API requests is included and reported.

# %%
data = []

# For each valid stock, fetch income data and store it
for stock in stock_symbols:
    try:
        # Build the API URL for income statement
        income_url = f"https://financialmodelingprep.com/api/v3/income-statement/{stock}?period=annual&apikey=NSD2m35XyjrwOoYdtKbq1JPOHlABl8CW"
        
        # Fetch data from the API
        response = requests.get(income_url, timeout=10)  # Added timeout
        
        # Check for a successful response
        if response.status_code != 200:
            print(f"Failed to fetch data for {stock}: HTTP {response.status_code}")
            continue
        
        # Parse JSON response
        income_response = response.json()

        # Check if data is available and is in the expected format (a list of dictionaries)
        if isinstance(income_response, list) and income_response:
            for report in income_response:  # Loop over each year
                # Extract the year safely
                year = report.get('date', '')
                year = year.split('-')[0] if '-' in year else year

                # Create a dictionary for the stock report
                row = {
                    'Stock': stock,
                    'Year': year,
                    'Revenue': report.get('revenue'),
                    'Revenue Growth': report.get('revenueGrowth'),
                    'Operating Income': report.get('operatingIncome'),
                    'Net Income': report.get('netIncome'),
                    'Net Income Ratio': report.get('netIncomeRatio'),
                    'Gross Profit': report.get('grossProfit'),
                    'Gross Profit Ratio': report.get('grossProfitRatio'),
                    'Operating Expenses': report.get('operatingExpenses'),
                    'Cost of Revenue': report.get('costOfRevenue'),
                    'EBITDA': report.get('ebitda'),
                    'Interest Expense': report.get('interestExpense'),
                    'Depreciation & Amortization': report.get('depreciationAndAmortization')
                }
                # Append the row to the data list
                data.append(row)
        else:
            print(f"No income data available for {stock}.")
    except Exception as e:
        print(f"Error fetching data for {stock}: {e}")

# Output the data to check
print(f"Fetched data for {len(data)} records.")
# Out:
# Failed to fetch data for MCK: HTTP 429
# Failed to fetch data for ISRG: HTTP 429
# Failed to fetch data for MLM: HTTP 429
# Failed to fetch data for AMP: HTTP 429
# Failed to fetch data for MUSA: HTTP 429
# Failed to fetch data for NEU: HTTP 429
# Failed to fetch data for ROP: HTTP 429
# Failed to fetch data for WSO-B: HTTP 429
# Failed to fetch data for SAIA: HTTP 429
# Failed to fetch data for MA: HTTP 429
# Failed to fetch data for TMO: HTTP 429
# Failed to fetch data for CHE: HTTP 429
# Failed to fetch data for SNPS: HTTP 429
# Failed to fetch data for WSO: HTTP 429
# Failed to fetch data for SPGI: HTTP 429
# Failed to fetch data for NWLI: HTTP 429
# Failed to fetch data for IT: HTTP 429
# Failed to fetch data for KNSL: HTTP 429
# Failed to fetch data for CACC: HTTP 429
# Failed to fetch data for LMT: HTTP 429
# Failed to fetch data for FDS: HTTP 429
# Failed to fetch data for MCO: HTTP 429
# Failed to fetch data for UNH: HTTP 429
# Failed to fetch data for ANTM: HTTP 429
# Failed to fetch data for NOC: HTTP 429
# Failed to fetch data for TSLA: HTTP 429
# Failed to fetch data for EME: HTTP 429
# Failed to fetch data for SPOT: HTTP 429
# Failed to fetch data for CVCO: HTTP 429
# Failed to fetch data for TDY: HTTP 429
# Failed to fetch data for VRTX: HTTP 429
# Failed to fetch data for MSI: HTTP 429
# Failed to fetch data for ATRI: HTTP 429
# Failed to fetch data for BRK-B: HTTP 429
# Failed to fetch data for ADBE: HTTP 429
# Failed to fetch data for FIX: HTTP 429
# Failed to fetch data for MSFT: HTTP 429
# Failed to fetch data for DPZ: HTTP 429
# Failed to fetch data for DE: HTTP 429
# Failed to fetch data for HUBB: HTTP 429
# Failed to fetch data for DDS: HTTP 429
# Failed to fetch data for RACE: HTTP 429
# Failed to fetch data for LIN: HTTP 429
# Failed to fetch data for IDXX: HTTP 429
# Failed to fetch data for ERIE: HTTP 429
# Failed to fetch data for ULTA: HTTP 429
# Failed to fetch data for GPI: HTTP 429
# Failed to fetch data for CASY: HTTP 429
# Failed to fetch data for CACI: HTTP 429
# Failed to fetch data for RH: HTTP 429
# Failed to fetch data for HD: HTTP 429
# Failed to fetch data for WINA: HTTP 429
# Failed to fetch data for CSL: HTTP 429
# Failed to fetch data for ZBRA: HTTP 429
# Failed to fetch data for TT: HTTP 429
# Failed to fetch data for LULU: HTTP 429
# Failed to fetch data for MSTR: HTTP 429
# Failed to fetch data for ABMD: HTTP 429
# Failed to fetch data for CSWI: HTTP 429
# Failed to fetch data for UTHR: HTTP 429
# Failed to fetch data for CRWD: HTTP 429
# Failed to fetch data for CAT: HTTP 429
# Failed to fetch data for WAT: HTTP 429
# Failed to fetch data for CHTR: HTTP 429
# Failed to fetch data for SYK: HTTP 429
# Failed to fetch data for LAD: HTTP 429
# Failed to fetch data for ELV: HTTP 429
# Failed to fetch data for CABO: HTTP 429
# Failed to fetch data for CW: HTTP 429
# Failed to fetch data for SHW: HTTP 429
# Failed to fetch data for CMI: HTTP 429
# Failed to fetch data for AON: HTTP 429
# Failed to fetch data for POOL: HTTP 429
# Failed to fetch data for ACN: HTTP 429
# Failed to fetch data for EG: HTTP 429
# Failed to fetch data for KAI: HTTP 429
# Failed to fetch data for DUOL: HTTP 429
# Failed to fetch data for CPAY: HTTP 429
# Failed to fetch data for RE: HTTP 429
# Failed to fetch data for CRM: HTTP 429
# Failed to fetch data for CRVL: HTTP 429
# Failed to fetch data for MORN: HTTP 429
# Failed to fetch data for SNA: HTTP 429
# Failed to fetch data for MEDP: HTTP 429
# Failed to fetch data for ETN: HTTP 429
# Failed to fetch data for ANSS: HTTP 429
# Failed to fetch data for UI: HTTP 429
# Failed to fetch data for BLD: HTTP 429
# Failed to fetch data for APP: HTTP 429
# Failed to fetch data for BIO: HTTP 429
# Failed to fetch data for BIO-B: HTTP 429
# Failed to fetch data for PWR: HTTP 429
# Failed to fetch data for SWAV: HTTP 429
# Failed to fetch data for WST: HTTP 429
# Failed to fetch data for KRTX: HTTP 429
# Failed to fetch data for LPLA: HTTP 429
# Failed to fetch data for GEV: HTTP 429
# Failed to fetch data for VMI: HTTP 429
# Failed to fetch data for ESGR: HTTP 429
# Failed to fetch data for RBC: HTTP 429
# Failed to fetch data for V: HTTP 429
# Failed to fetch data for CYBR: HTTP 429
# Failed to fetch data for SEZL: HTTP 429
# Failed to fetch data for PSA: HTTP 429
# Failed to fetch data for AYI: HTTP 429
# Failed to fetch data for PIPR: HTTP 429
# Failed to fetch data for COIN: HTTP 429
# Failed to fetch data for CDNS: HTTP 429
# Failed to fetch data for WTW: HTTP 429
# Failed to fetch data for STZ-B: HTTP 429
# Failed to fetch data for SAM: HTTP 429
# Failed to fetch data for HCA: HTTP 429
# Failed to fetch data for MDGL: HTTP 429
# Failed to fetch data for APD: HTTP 429
# Failed to fetch data for FLT: HTTP 429
# Failed to fetch data for ADSK: HTTP 429
# Failed to fetch data for AXP: HTTP 429
# Failed to fetch data for MCD: HTTP 429
# Failed to fetch data for WING: HTTP 429
# Failed to fetch data for ADP: HTTP 429
# Failed to fetch data for MANH: HTTP 429
# Failed to fetch data for ESS: HTTP 429
# Failed to fetch data for KSU: HTTP 429
# Failed to fetch data for ROK: HTTP 429
# Failed to fetch data for MOH: HTTP 429
# Failed to fetch data for BURL: HTTP 429
# Failed to fetch data for EVR: HTTP 429
# Failed to fetch data for WIRE: HTTP 429
# Failed to fetch data for MAR: HTTP 429
# Failed to fetch data for AJG: HTTP 429
# Failed to fetch data for VRSK: HTTP 429
# Failed to fetch data for RS: HTTP 429
# Failed to fetch data for WDAY: HTTP 429
# Failed to fetch data for FDX: HTTP 429
# Failed to fetch data for CB: HTTP 429
# Failed to fetch data for PRI: HTTP 429
# Failed to fetch data for TSCO: HTTP 429
# Failed to fetch data for EFX: HTTP 429
# Failed to fetch data for ASR: HTTP 429
# Failed to fetch data for FLUT: HTTP 429
# Failed to fetch data for VMC: HTTP 429
# Failed to fetch data for HIFS: HTTP 429
# Failed to fetch data for TEAM: HTTP 429
# Failed to fetch data for PXD: HTTP 429
# Failed to fetch data for JLL: HTTP 429
# Failed to fetch data for ITW: HTTP 429
# Failed to fetch data for EXP: HTTP 429
# Failed to fetch data for AMGN: HTTP 429
# Failed to fetch data for CI: HTTP 429
# Failed to fetch data for GD: HTTP 429
# Failed to fetch data for MDB: HTTP 429
# Failed to fetch data for WDFC: HTTP 429
# Fetched data for 240 records.

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (240, 14)

# %%
# Checking all stocks requested are inside df
df['Stock'].nunique()
# Out:
# 48

# %% [markdown]
# # 2. Obtaining Base, Partial, Historical & Sparse Datasets

# %% [markdown]
# ### Base Dataset

# %% [markdown]
# We create a synthetic dataset of 100,000 rows containing simulated financial metrics for various stocks across year 2000 to 2024.
#
# Using generate_random_tickers, we create unique stocks of random lengths and create stock-year combinations. We then simulate the other financial metrics proportionally based on the revenue. For example, cost of revenue is 40-70% of revenue.
#
# We then verified the data integrity by checking no duplicate stock-year combination exists.

# %%
# Define parameters for simulation
# Define parameters
n_desired_rows = 100000  # Target number of unique rows
years = list(range(2000, 2025))  # Expand the range of years (e.g., 2000-2024)
n_unique_stocks_needed = n_desired_rows // len(years) + 1  # Number of unique stocks needed

# Generate fake stock tickers
def generate_random_tickers(n, length_range=(4, 6)):
    tickers = set()  # Use a set to ensure uniqueness
    while len(tickers) < n:
        length = random.randint(*length_range)  # Random length between 4 and 6
        ticker = ''.join(random.choices(string.ascii_uppercase, k=length))
        tickers.add(ticker)
    return list(tickers)

# Define the number of unique stock tickers needed
n_unique_stocks_needed = n_desired_rows // len(years) + 1

# Generate random stock tickers
base_stocks = generate_random_tickers(n_unique_stocks_needed)

# Generate all possible stock-year combinations
stock_year_combinations = [(stock, year) for stock in base_stocks for year in years]

# Shuffle the combinations to randomize the order
np.random.seed(42)  # Ensure reproducibility
random.shuffle(stock_year_combinations)

# Select exactly 100,000 rows
stock_year_combinations = stock_year_combinations[:n_desired_rows]

# Initialize an empty list to store simulated data
simulated_data = []

# Simulate data for unique stock-year combinations
for i, (stock, year) in enumerate(stock_year_combinations):
    # Use previous year's revenue for this stock (if available)
    if i > 0 and simulated_data[-1]['Stock'] == stock:
        previous_revenue = simulated_data[-1]['Revenue']
    else:
        previous_revenue = np.random.randint(1e6, 2.1e9)  # Random initial revenue if no previous data

    # Calculate revenue based on growth
    revenue_growth = np.random.uniform(-0.1, 0.2)  # Random growth rate (-10% to 20%)
    revenue = previous_revenue * (1 + revenue_growth)
    
    # Simulate financial metrics
    cost_of_revenue = revenue * np.random.uniform(0.4, 0.7)
    gross_profit = revenue - cost_of_revenue
    operating_expenses = np.random.uniform(0.2, 0.4) * revenue
    operating_income = gross_profit - operating_expenses
    depreciation_and_amortization = np.random.randint(1e5, 1e7)
    ebitda = operating_income + depreciation_and_amortization
    interest_expense = np.random.randint(1e5, 1e6)
    net_income = operating_income - interest_expense
    net_income_ratio = net_income / revenue if revenue != 0 else 0
    gross_profit_ratio = gross_profit / revenue if revenue != 0 else 0

    # Append to simulated data
    simulated_data.append({
        'Stock': stock,
        'Year': year,
        'Revenue': revenue,
        'Revenue Growth': revenue_growth,
        'Operating Income': operating_income,
        'Net Income': net_income,
        'Net Income Ratio': net_income_ratio,
        'Gross Profit': gross_profit,
        'Gross Profit Ratio': gross_profit_ratio,
        'Operating Expenses': operating_expenses,
        'Cost of Revenue': cost_of_revenue,
        'EBITDA': ebitda,
        'Interest Expense': interest_expense,
        'Depreciation & Amortization': depreciation_and_amortization,
    })

# Convert to a DataFrame
simulated_df = pd.DataFrame(simulated_data)

# Verify duplicates
duplicates = simulated_df.duplicated(subset=['Stock', 'Year'], keep=False)
print(f"Number of duplicates: {duplicates.sum()}")

# Display the first rows
print(simulated_df.head())
# Out:
# Number of duplicates: 0
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 0  QZJZTU  2021  1.833317e+09        0.138963      3.465545e+08  3.459331e+08
# 1  AURIJB  2000  2.599285e+08        0.037775      7.052226e+07  7.035744e+07
# 2   GXUAV  2006  2.254691e+09        0.116600      2.666813e+08  2.663455e+08
# 3  ZQDDFB  2017  5.011669e+08       -0.008727      7.827428e+07  7.767409e+07
# 4    ETEY  2004  4.910126e+08        0.019958      9.390576e+07  9.374003e+07
#
#    Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 0          0.188692  9.991022e+08            0.544970        6.525477e+08
# 1          0.270680  1.299350e+08            0.499887        5.941274e+07
# 2          0.118130  7.179707e+08            0.318434        4.512894e+08
# 3          0.154986  2.218030e+08            0.442573        1.435287e+08
# 4          0.190912  2.877335e+08            0.586000        1.938277e+08
#
#    Cost of Revenue        EBITDA  Interest Expense  \
# 0     8.342152e+08  3.488890e+08            621430
# 1     1.299935e+08  7.514593e+07            164820
# 2     1.536720e+09  2.668847e+08            335796
# 3     2.793639e+08  8.767993e+07            600186
# 4     2.032790e+08  1.038953e+08            165725
#
#    Depreciation & Amortization
# 0                      2334489
# 1                      4623669
# 2                       203355
# 3                      9405648
# 4                      9989550

# %% [markdown]
# Importantly, we concatenate the simulated_df with the initial df containing the real stocks to generate the base dataset.

# %%
expanded_df = pd.concat([df, simulated_df], ignore_index=True)

# %%
expanded_df.to_csv('expanded_dataset.csv', index=False)

# %%
print(f"Expanded dataset has {len(expanded_df)} rows.")
# Out:
# Expanded dataset has 100240 rows.

# %% [markdown]
# ### Partial Dataset

# %% [markdown]
# The partial dataset overlaps with the base dataset, but has missing values in some columns.
#
# The year range is limited to 2022 to 2023.

# %%
# Create a deep copy of expanded_df, with filters by 2022, 2023
partial_df = expanded_df[expanded_df['Year'].isin([2022,2023])].copy()

#Introduce missing data in 'Revenue', 'Net Income' and 'Operating Expenses'
partial_df.loc[partial_df.sample(frac=0.2).index, 'Revenue'] = np.nan #Within revenue, introduce 20% of missing data
partial_df.loc[partial_df.sample(frac=0.1).index, 'Net Income'] = np.nan #Within net income, introduce 10% of missing data
partial_df.loc[partial_df.sample(frac=0.3).index, 'Operating Expenses'] = np.nan #Within operating expenses, introduce 30% of missing data

# %%
partial_df.to_csv('partial_dataset.csv', index=False)

# %%
partial_df.head()
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 0   BRK-A  2023  3.644820e+11             NaN      1.231960e+11           NaN
# 1   BRK-A  2022           NaN             NaN     -2.698500e+10 -2.281900e+10
# 5     NVR  2023  9.534889e+09             NaN      1.822455e+09  1.591611e+09
# 6     NVR  2022  1.053829e+10             NaN      2.169184e+09  1.725575e+09
# 10   BKNG  2023  2.136500e+10             NaN      5.835000e+09  4.289000e+09
#
#     Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 0           0.263999  1.231960e+11            0.338003        1.985750e+11
# 1          -0.097438  1.098710e+11            0.469153                 NaN
# 5           0.166925  2.483691e+09            0.260485                 NaN
# 6           0.163743  2.876016e+09            0.272911                 NaN
# 10          0.200749  2.136000e+10            0.999766                 NaN
#
#     Cost of Revenue        EBITDA  Interest Expense  \
# 0      2.412860e+11  1.376550e+11      5.003000e+09
# 1      1.243190e+11 -1.524900e+10      4.352000e+09
# 5      7.051198e+09  1.973029e+09      2.774000e+07
# 6      7.662271e+09  2.310114e+09      3.952400e+07
# 10     5.000000e+06  7.043000e+09      8.970000e+08
#
#     Depreciation & Amortization
# 0                  1.248600e+10
# 1                  1.089900e+10
# 5                  1.691600e+07
# 6                  1.739600e+07
# 10                 6.650000e+08

# %% [markdown]
# ### Historical Dataset

# %% [markdown]
# The historical dataset introduces a larger range of years (but randomized), with mismatched data and duplicate records.
#
# Stocks in this dataset are referenced from the stocks in the base dataset.

# %%
historical_data = []
historical_years = range(2010, 2021) # Year 2010 to 2021
historical_stocks = expanded_df['Stock']

# %%
#Simulate 10000 rows of historical data
for row in range(10000):
    stock = np.random.choice(historical_stocks)
    year = np.random.choice(historical_years)

    revenue = np.random.randint(1e6, 2.1e9) if np.random.rand() > 0.2 else None  # 20% missing revenue
    
    # Introduce some unrealistic (invalid) values for revenue
    if np.random.rand() < 0.05:  # 5% chance to introduce an unrealistic value
        revenue = np.random.randint(-1e9, -1e6)  # Negative revenue (invalid)

    # Introduce mismatched values for 'Cost of Revenue' by using None instead of NaN
    cost_of_revenue = revenue * np.random.uniform(0.3, 0.8) if revenue else None

    # Introduce stock name mismatch randomly
    if np.random.rand() < 0.05:
        stock = stock + ' .end'

    # Introduce missing values in 'Cost of Revenue'
    if np.random.rand() < 0.1:
        cost_of_revenue = None

    # Add fewer financial metrics (to create schema differences)
    if revenue and cost_of_revenue:
        gross_profit = revenue - cost_of_revenue
    else:
        gross_profit = None

    # Introduce random years outside of range
    if np.random.rand() > 0.05:
        year = np.random.randint(2130, 2200)

    historical_data.append({
        'Stock': stock,
        'Year': year,
        'Revenue': revenue,
        'Cost of Revenue': cost_of_revenue,
        'Gross Profit': gross_profit
    })

# %%
historical_df = pd.DataFrame(historical_data)

# %% [markdown]
# ### Sparse Dataset

# %% [markdown]
# Finally, the sparse dataset only contains 100 random stocks, with year and revenue as their only metrics.
#
# Like the Historical dataset, stocks are refrenced from those in the base dataset.
#
# 50% of the revenue column will be empty.

# %%
sparse_data = []
sparse_years = range(2000, 2009)
sparse_stocks = expanded_df['Stock']

# %%
for stock in np.random.choice(sparse_stocks, size=100, replace=False): #Select 100 random stocks
    for year in sparse_years:
        if np.random.rand() > 0.5: #For 50% of the year column, assign a random revenue. The other 50% will be uninitialized
            revenue = np.random.randint(1e6, 2.1e9)
            
            sparse_data.append({
                'Stock': stock,
                'Year': year,
                'Revenue': revenue
            })

# %%
sparse_df = pd.DataFrame(sparse_data)

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ### Check whether every stock-year pair is unique

# %%
def check_unique_stock_year_pairs(df, stock_col='Stock', year_col='Year'):
    # Create a combined column to check for duplicates
    unique_combinations = df[[stock_col, year_col]].drop_duplicates()

    # Compare the length of unique combinations with the original DataFrame
    if len(unique_combinations) == len(df):
        print("All stock-year pairs are unique.")
        return True
    else:
        print("There are duplicate stock-year pairs.")
        # Keep no duplicates to ensure only rows with unique Stock-Year pairs remain
        duplicates = df[df.duplicated(subset=[stock_col, year_col], keep=False)]
        print("Duplicate entries:")
        print(duplicates)
        print(duplicates.shape)
        return False

# %%
check_unique_stock_year_pairs(expanded_df)
# Out:
# All stock-year pairs are unique.
# True

# %%
check_unique_stock_year_pairs(partial_df)
# Out:
# All stock-year pairs are unique.
# True

# %%
# 1217 duplicate pairs
check_unique_stock_year_pairs(historical_df)
# Out:
# There are duplicate stock-year pairs.
# Duplicate entries:
#         Stock  Year       Revenue  Cost of Revenue  Gross_Profit  Gross Profit
# 4       DUBLF  2149  1.564826e+09              NaN           NaN           NaN
# 20     MGNABA  2134  1.880840e+09     1.030426e+09  8.504137e+08           NaN
# 32     FMTVPY  2178  6.908849e+08     3.754662e+08  3.154187e+08           NaN
# 38       MCNC  2140  4.908585e+08     3.340902e+08  1.567683e+08           NaN
# 64       HYNB  2161           NaN              NaN           NaN           NaN
# ...       ...   ...           ...              ...           ...           ...
# 19943    PIXU  2169  1.183188e+09     5.678716e+08           NaN  6.153159e+08
# 19973   TYSAP  2171  3.227322e+07     1.418402e+07           NaN  1.808920e+07
# 19974  DMCKPU  2140  1.735987e+09     1.050246e+09           NaN  6.857412e+08
# 19979  VDVEWR  2152  1.082795e+09     5.963902e+08           NaN  4.864046e+08
# 19988  SNBDXN  2196  3.257110e+08              NaN           NaN           NaN
#
# [1217 rows x 6 columns]
# (1217, 6)
# False

# %%
# 4 duplicate pairs
check_unique_stock_year_pairs(sparse_df)
# Out:
# There are duplicate stock-year pairs.
# Duplicate entries:
#     Stock  Year     Revenue
# 263  LALI  2005   176762369
# 264  LALI  2007   661785285
# 288  LALI  2005  1596116051
# 290  LALI  2007  1004175337
# (4, 3)
# False

# %% [markdown]
# ### Dropping duplicate stock-year pairs

# %%
def drop_duplicate_stock_year_pairs(df, stock_col='Stock', year_col='Year'):
    print("DataFrame after dropping all duplicates:")
    return df[~df.duplicated(subset=['Stock', 'Year'], keep=False)]

# %%
historical_df = drop_duplicate_stock_year_pairs(historical_df)
print(historical_df)
# Out:
# DataFrame after dropping all duplicates:
#         Stock  Year       Revenue  Cost of Revenue  Gross_Profit  Gross Profit
# 0       GOLXD  2184  9.680579e+08     6.308393e+08  3.372186e+08           NaN
# 1       OKDZW  2192  4.770210e+08     2.977351e+08  1.792859e+08           NaN
# 2       PGOPC  2168  9.445676e+08     6.795297e+08  2.650379e+08           NaN
# 3        FSPF  2151  1.623014e+08     1.034746e+08  5.882680e+07           NaN
# 5       KDMTE  2198  6.519775e+08     4.517509e+08  2.002266e+08           NaN
# ...       ...   ...           ...              ...           ...           ...
# 19995  DUOJBW  2162  1.739624e+09     5.799098e+08           NaN  1.159714e+09
# 19996   RZYXV  2194  2.511675e+08     1.142958e+08           NaN  1.368718e+08
# 19997   MXKTG  2138           NaN              NaN           NaN           NaN
# 19998   XGMTN  2136           NaN              NaN           NaN           NaN
# 19999   XEZIM  2160           NaN              NaN           NaN           NaN
#
# [18783 rows x 6 columns]

# %%
sparse_df = drop_duplicate_stock_year_pairs(sparse_df)
print(sparse_df)
# Out:
# DataFrame after dropping all duplicates:
#       Stock  Year     Revenue
# 0      JGPF  2002   533645067
# 1      JGPF  2003   191962652
# 2     HSCGS  2001   300527108
# 3     HSCGS  2002  1486372237
# 4     HSCGS  2005  1350321861
# ..      ...   ...         ...
# 442  ZTMXAP  2001  1360600396
# 443  ZTMXAP  2003   257623495
# 444  ZTMXAP  2005   483787674
# 445  ZTMXAP  2006   793009584
# 446  ZTMXAP  2008  1808217019
#
# [443 rows x 3 columns]

# %% [markdown]
# ### Check for duplicates

# %%
# Base dataset
print(f"Duplicate entries (Base Dataset): {expanded_df.duplicated().sum()}")
print(f"{round((expanded_df.duplicated().sum() / partial_df.shape[0]) * 100, 2)}% rows are duplicate.")

# Partial dataset
print(f"Duplicate entries (Partial Dataset): {partial_df.duplicated().sum()}")
print(f"{round((partial_df.duplicated().sum() / partial_df.shape[0]) * 100, 2)}% rows are duplicate.")

# Historical dataset
print(f"Duplicate entries (Historical Dataset): {historical_df.duplicated().sum()}")
print(f"{round((historical_df.duplicated().sum() / historical_df.shape[0]) * 100, 2)}% rows are duplicate.")

# Sparse dataset
print(f"Duplicate entries (Sparse Dataset): {sparse_df.duplicated().sum()}")
print(f"{round((sparse_df.duplicated().sum() / sparse_df.shape[0]) * 100, 2)}% rows are duplicate.")
# Out:
# Duplicate entries (Base Dataset): 0
# 0.0% rows are duplicate.
# Duplicate entries (Partial Dataset): 0
# 0.0% rows are duplicate.
# Duplicate entries (Historical Dataset): 0
# 0.0% rows are duplicate.
# Duplicate entries (Sparse Dataset): 0
# 0.0% rows are duplicate.

# %% [markdown]
# ### Check for inconsistencies

# %% [markdown]
# This function prints the number of unique values per column. From the unique values, we can also tell any inconsistencies such as impossible negatives in revenue that we need to manage.

# %%
# Loop through all columns and print unique values
def no_of_unique_values(df):
    for col in df.columns:
        print(f"Column Name (Base Dataset): {col}")
        print(f"Unique Values: {df[col].unique()}")
        print(f"Number of Unique Values: {df[col].nunique()}")
        print('-' * 60) # To demarcate columns

# %%
no_of_unique_values(expanded_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['BRK-A' 'NVR' 'BKNG' ... 'AEZUE' 'RJLN' 'TTCZLN']
# Number of Unique Values: 4049
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: [2023 2022 2021 2020 2019 2024 2018 2017 2000 2006 2004 2002 2014 2001
#  2007 2012 2010 2008 2016 2013 2015 2003 2005 2009 2011]
# Number of Unique Values: 25
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [3.64482000e+11 2.34190000e+11 3.54636000e+11 ... 1.33376586e+09
#  1.54838758e+09 4.91265446e+08]
# Number of Unique Values: 100235
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue Growth
# Unique Values: [        nan  0.1389629   0.03777467 ... -0.08242593  0.14503091
#   0.17837523]
# Number of Unique Values: 100000
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Income
# Unique Values: [ 1.23196000e+11 -2.69850000e+10 -8.24250000e+10 ...  2.33408720e+08
#   2.10674763e+08  6.71323111e+07]
# Number of Unique Values: 100234
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income
# Unique Values: [ 9.62230000e+10 -2.28190000e+10  8.99370000e+10 ...  2.32894034e+08
#   2.09868208e+08  6.66666631e+07]
# Number of Unique Values: 100234
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income Ratio
# Unique Values: [ 0.26399932 -0.09743798  0.2536037  ...  0.17461388  0.13553984
#   0.13570395]
# Number of Unique Values: 100235
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit
# Unique Values: [1.23196000e+11 1.09871000e+11 1.33706000e+11 ... 6.81125307e+08
#  5.82403625e+08 2.54976513e+08]
# Number of Unique Values: 100232
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit Ratio
# Unique Values: [0.33800297 0.46915325 0.3770232  ... 0.51067832 0.37613556 0.51901984]
# Number of Unique Values: 100220
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Expenses
# Unique Values: [ 1.98575000e+11  1.42310000e+11 -4.37061000e+11 ...  4.47716587e+08
#   3.71728862e+08  1.87844202e+08]
# Number of Unique Values: 100235
# ------------------------------------------------------------
# Column Name (Base Dataset): Cost of Revenue
# Unique Values: [2.41286000e+11 1.24319000e+11 2.20930000e+11 ... 6.52640558e+08
#  9.65983951e+08 2.36288934e+08]
# Number of Unique Values: 100219
# ------------------------------------------------------------
# Column Name (Base Dataset): EBITDA
# Unique Values: [ 1.37655000e+11 -1.52490000e+10  1.26576000e+11 ...  2.40057128e+08
#   2.15454472e+08  6.86180431e+07]
# Number of Unique Values: 100233
# ------------------------------------------------------------
# Column Name (Base Dataset): Interest Expense
# Unique Values: [5.00300e+09 4.35200e+09 4.17200e+09 ... 5.14686e+05 8.06555e+05
#  4.65648e+05]
# Number of Unique Values: 94790
# ------------------------------------------------------------
# Column Name (Base Dataset): Depreciation & Amortization
# Unique Values: [1.248600e+10 1.089900e+10 1.071800e+10 ... 6.648408e+06 4.779709e+06
#  1.485732e+06]
# Number of Unique Values: 99743
# ------------------------------------------------------------

# %%
no_of_unique_values(partial_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['BRK-A' 'NVR' 'BKNG' ... 'ATJUK' 'NJCE' 'RIORFE']
# Number of Unique Values: 4048
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: [2023 2022]
# Number of Unique Values: 2
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [3.64482000e+11            nan 9.53488900e+09 ... 2.75076875e+08
#  4.15520636e+08 1.54838758e+09]
# Number of Unique Values: 6476
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue Growth
# Unique Values: [       nan 0.03180095 0.05889517 ... 0.02069398 0.00177194 0.14503091]
# Number of Unique Values: 8002
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Income
# Unique Values: [ 1.23196000e+11 -2.69850000e+10  1.82245500e+09 ...  3.27766620e+06
#   5.36752494e+07  2.10674763e+08]
# Number of Unique Values: 8093
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income
# Unique Values: [            nan -2.28190000e+10  1.59161100e+09 ...  1.81939940e+08
#   2.86571320e+06  2.09868208e+08]
# Number of Unique Values: 7285
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income Ratio
# Unique Values: [ 0.26399932 -0.09743798  0.16692496 ...  0.01041786  0.12826422
#   0.13553984]
# Number of Unique Values: 8094
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit
# Unique Values: [1.23196000e+11 1.09871000e+11 2.48369100e+09 ... 1.10289609e+08
#  1.83765112e+08 5.82403625e+08]
# Number of Unique Values: 8094
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit Ratio
# Unique Values: [0.33800297 0.46915325 0.26048452 ... 0.40094104 0.44225267 0.37613556]
# Number of Unique Values: 8092
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Expenses
# Unique Values: [1.98575000e+11            nan 4.03000000e+08 ... 3.17016873e+08
#  1.07011943e+08 1.30089863e+08]
# Number of Unique Values: 5665
# ------------------------------------------------------------
# Column Name (Base Dataset): Cost of Revenue
# Unique Values: [2.41286000e+11 1.24319000e+11 7.05119800e+09 ... 1.64787266e+08
#  2.31755524e+08 9.65983951e+08]
# Number of Unique Values: 8091
# ------------------------------------------------------------
# Column Name (Base Dataset): EBITDA
# Unique Values: [ 1.37655000e+11 -1.52490000e+10  1.97302900e+09 ...  5.90238020e+06
#   5.93300584e+07  2.15454472e+08]
# Number of Unique Values: 8094
# ------------------------------------------------------------
# Column Name (Base Dataset): Interest Expense
# Unique Values: [5.00300e+09 4.35200e+09 2.77400e+07 ... 4.11953e+05 3.78818e+05
#  8.06555e+05]
# Number of Unique Values: 8055
# ------------------------------------------------------------
# Column Name (Base Dataset): Depreciation & Amortization
# Unique Values: [1.248600e+10 1.089900e+10 1.691600e+07 ... 2.624714e+06 5.654809e+06
#  4.779709e+06]
# Number of Unique Values: 8093
# ------------------------------------------------------------

# %% [markdown]
# Significant inconsistencies in the Historical dataset include:
# 1. Impossible negatives
# 2. Impossible years (.e.g 2177)
# 3. Stock names with '.end'

# %%
no_of_unique_values(historical_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['GOLXD' 'OKDZW' 'PGOPC' ... 'NKZRR .end' 'TFWAN .end' 'NSYB .end']
# Number of Unique Values: 4883
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: [2184 2192 2168 2151 2198 2154 2197 2014 2185 2165 2182 2171 2195 2017
#  2177 2141 2199 2163 2131 2146 2132 2183 2011 2137 2178 2149 2190 2173
#  2162 2159 2161 2166 2015 2179 2181 2152 2191 2193 2156 2135 2169 2133
#  2157 2145 2148 2167 2138 2016 2147 2136 2140 2018 2180 2130 2175 2144
#  2020 2134 2196 2164 2019 2194 2012 2189 2176 2170 2172 2174 2158 2160
#  2143 2155 2187 2139 2013 2188 2153 2150 2010 2186 2142]
# Number of Unique Values: 81
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [9.68057898e+08 4.77020998e+08 9.44567602e+08 ... 4.27379260e+08
#  1.73962391e+09 2.51167538e+08]
# Number of Unique Values: 15217
# ------------------------------------------------------------
# Column Name (Base Dataset): Cost of Revenue
# Unique Values: [6.30839271e+08 2.97735124e+08 6.79529699e+08 ... 2.88116475e+08
#  5.79909805e+08 1.14295786e+08]
# Number of Unique Values: 13659
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross_Profit
# Unique Values: [ 3.37218627e+08  1.79285874e+08  2.65037903e+08 ...  3.99410303e+08
#  -1.13473456e+08  5.44876454e+08]
# Number of Unique Values: 6880
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit
# Unique Values: [           nan 1.90958656e+08 1.78644373e+08 ... 4.41269230e+08
#  1.15971411e+09 1.36871752e+08]
# Number of Unique Values: 6779
# ------------------------------------------------------------

# %%
no_of_unique_values(sparse_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['JGPF' 'HSCGS' 'LUWJK' 'JTLCVH' 'LZZC' 'MWSS' 'MRPLYG' 'CWDAN' 'HZLRUE'
#  'WRZLM' 'XFPB' 'OIPJTN' 'GMUIRW' 'OFXJW' 'VXBRR' 'QYQWK' 'TCFKRN' 'BRCA'
#  'ZPYYZ' 'AKST' 'DDDVA' 'WKNKX' 'UEEFE' 'VIYELP' 'UUQYV' 'DNVDJ' 'HKGAD'
#  'BILXVJ' 'WLXAXZ' 'NJOZ' 'FRBCIS' 'RZYXV' 'PIVFKR' 'DONBI' 'EIBIXF'
#  'LJQTY' 'JKHS' 'YEJA' 'MRGA' 'IBWX' 'TVSZY' 'QCVFL' 'YUJYCD' 'AKQIW'
#  'DKAOAD' 'IYRY' 'IAYS' 'WADDHX' 'PVEZUI' 'RLHBXG' 'ESWP' 'FNAGW' 'NILZVW'
#  'HQWC' 'GSTU' 'WLVCSU' 'URVDB' 'MPZVM' 'OIQBP' 'LYLV' 'LALI' 'PVTD'
#  'YNBFK' 'HMBZZ' 'VBHMK' 'PJTU' 'JQDDKQ' 'YEHHW' 'GIKR' 'AHSBJZ' 'OWKXL'
#  'UKDBVP' 'YFEWQ' 'MUBU' 'CPDIV' 'ACKMX' 'XLNCQ' 'GXZVB' 'OYHNF' 'BBQJR'
#  'WCLDW' 'WXOZR' 'JYGE' 'WREJO' 'RYXNHM' 'MZFOY' 'RSTPL' 'MKDRCL' 'JJPICI'
#  'QIWX' 'QJCDKV' 'DBPFE' 'BFPVXC' 'LSUJ' 'GDHC' 'EIZCGW' 'LVAB' 'AWNVTB'
#  'ZTMXAP']
# Number of Unique Values: 99
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: [2002 2003 2001 2005 2006 2008 2000 2007 2004]
# Number of Unique Values: 9
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [ 533645067  191962652  300527108 1486372237 1350321861 1690467909
#  1155493210  587623804 1209970433   56275440 1341538340 1069752461
#   488145524  767233971 1933716215  708227707  669009794 2033512818
#  1615863000  147176424  333242793 1894473219 1877664625 2048269988
#   273556852 1632874224  974889969 1184373784 1409987886 1822628440
#   914787253  461928425 1615665014  580547533  695257158 1966909108
#  1891942782   79999727  441385005  245290925   80793021 1333253416
#   885907489 1310647131 1198124468  797731368  392570811 1200557563
#  1454584055 1543002567  551427552  787110897 1640016571 1247728347
#   518335321 1038915797 1412853497 1391852906   17558387 1428158545
#  1915475786  322145378 2069131462 2000468422  551449202  324952877
#   983185595  540688548  614875035  919430957  947662928 1668078378
#  2078190963  535931715  683994796 1004711631 1512622566 1877247722
#  1374560087 1472707031 1040366579   48836365 1545908479 1733757960
#  2095525606 1582385035 1504664148   70242697 1839146027 1848409355
#    19577417 1556905120 1987797451 1528570403  231970529 1946311068
#  1010461474  594673623    5499997  330784204  766941514  839638427
#   568746201  168281522   82554457  517285556 1898593398 1276636154
#   986779913 1823323596 1466941064 1267464293  758588392 1026412931
#   503821446  140305124 1517549726 1295146079   15187826 2060918692
#  1915647955  211919225 2009731817 2053966780  689606359 1349512389
#  1180475795 1525980191 1408056180  808298898  332406440  918206289
#   185496353 2069164522 1767945864 1841706820  530059207   73025063
#  1272284773   90881757 1842941483 2052028150  285731419  883631031
#   823081221 1109809274 1162445506  993703548   13077767  787028231
#   814614012 1452092847 1020809134  254344007 1791383414 1967502016
#  1487952592  135444067 1618231059  950024669 1786603661  894235066
#   859490561  366537306 1695880030  132574040  467380515 1307452047
#  1046331079  648900320 1645453662  364510634 1610698392 1904910651
#   826271919 2042599533 1691856550  855217606  472713233 1007988721
#    96876920 1797438381   62752537  731094891 1491883400 1221652502
#   101951585  277426125 2021377488  583304195 1459362085  358183193
#   368135460  636490376  475852168  859594756 1912498031 1052040100
#   149856871 1452526618 1806045901   67878295  192228751   69765125
#   549528881  626121634 1950955718 1624838645  677587520  912923317
#  1672217627 1082784019 1711835696 1168654094 2064672695  789552975
#  1541216507 1492476490  334434298 2079435568  901512115  153205523
#  1180451020 1948901847   83230565 1667752927 1639703994  321926622
#  1661075692   28671497  705646259 2046141865 2031086605 1713852722
#   237730046  177322205 1317040940 1004991086 1031959995 1519381195
#  1119705546  905933319  244477233  369021926  654489566 1729989635
#  1061587819 1623403814 1827184869   50303150  457180474 1065160395
#   266899724 1957247038 1231256219  870429277  182485403  816159547
#  2072479204 1238721038  563904575 1124672125  268533819 1439181355
#   531467012 1439972525  142371981 1674825802 1383379672  119833114
#  1886700062   35676451  623334627 2015366007  753401673  251952251
#   974109563 1617172511 1754677273 1999125199 2097665537 1800174338
#  1881645414  811800922 1261533971 1814722682 1034857179  348254414
#  1601583944 1175044018  113639916  713286869  708064467  127011775
#  1150272111  921338810 1852437037 1885191914  636583651  562883658
#  1408443528 1965624474    8804775 1585173763 1201469532  284254389
#  1686419581  665378955  205212300  358439169   92772139  785671374
#  1437131642 1356558109 1609653550 1790712384  447493659 1157662485
#  1624599491 1857485308 1823109813  352377031 1167445575  955966382
#  1315816996  573895423 1639670424  829091518 1698297079 2036929962
#   124716766 1080123945 1840125009 1956584742  999358602 1285218574
#  1677256277  927415515  594186672 1837971450 1155746864 1774971429
#     5826720 1956517781 1571520092  716144341 1071273188 1723175704
#   874475370  831288023  559680645 1921071968  704280684 1835041397
#  1982747910    3126697 1613477688 2044065577  263204238 1393862698
#  1746528259 1798947097   61999681  895301907 1288211920 1309605511
#   659711410 1475414200 1058324954 1066131377  276499264 1213334527
#  1134290847 1696480204 1112744514  128357902 1147279632 1807511963
#   559734231    7632513 1177675094 1481091175  439339156  534294295
#   784449619 1146319884 1328028026 1460363174 1364607224   84472911
#   517450776  599785470  629900601 1343428480 1030720286  969191630
#  1346370295  326710820  898909409 2099690733 1577920250  555194957
#  1987866069 1247528729  135040778  618525838 1430933324 2068749402
#  2065480571  400739433 1839373168 1280417241 1794328335  963247756
#   641747607  466386110 1659050625 1951851465  408908240  462175621
#  1234194628 1974566605  659312566  728295255 1188438996  294119616
#  1718313061  411053453 1664750074 1752734924 1022529132  555158797
#   123185720  204945946 1561037472 1037911356  839017067 1614498703
#  1360600396  257623495  483787674  793009584 1808217019]
# Number of Unique Values: 443
# ------------------------------------------------------------

# %% [markdown]
# We also check the dtypes and basic info of each column for any null columns.

# %%
print('Base Dataset') #Check revenue growth for null
print(expanded_df.dtypes)
print(expanded_df.info())
print('-' * 60)

print('Partial Dataset') #Check revenue, revenue growth, net income, operating expenses for null
print(partial_df.dtypes)
print(partial_df.info())
print('-' * 60)

print('Historical Dataset') #Check revenue, cost of revenue, gross profit for null
print(historical_df.dtypes) 
print(historical_df.info())
print('-' * 60)

print('Sparse Dataset')
print(sparse_df.dtypes)
print(sparse_df.info())
print('-' * 60)
# Out:
# Base Dataset
# Stock                           object
# Year                             int64
# Revenue                        float64
# Revenue Growth                 float64
# Operating Income               float64
# Net Income                     float64
# Net Income Ratio               float64
# Gross Profit                   float64
# Gross Profit Ratio             float64
# Operating Expenses             float64
# Cost of Revenue                float64
# EBITDA                         float64
# Interest Expense               float64
# Depreciation & Amortization    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100240 entries, 0 to 100239
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Stock                        100240 non-null  object
#  1   Year                         100240 non-null  int64
#  2   Revenue                      100240 non-null  float64
#  3   Revenue Growth               100000 non-null  float64
#  4   Operating Income             100240 non-null  float64
#  5   Net Income                   100240 non-null  float64
#  6   Net Income Ratio             100240 non-null  float64
#  7   Gross Profit                 100240 non-null  float64
#  8   Gross Profit Ratio           100240 non-null  float64
#  9   Operating Expenses           100240 non-null  float64
#  10  Cost of Revenue              100240 non-null  float64
#  11  EBITDA                       100240 non-null  float64
#  12  Interest Expense             100240 non-null  float64
#  13  Depreciation & Amortization  100240 non-null  float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 10.7+ MB
# None
# ------------------------------------------------------------
# Partial Dataset
# Stock                           object
# Year                             int64
# Revenue                        float64
# Revenue Growth                 float64
# Operating Income               float64
# Net Income                     float64
# Net Income Ratio               float64
# Gross Profit                   float64
# Gross Profit Ratio             float64
# Operating Expenses             float64
# Cost of Revenue                float64
# EBITDA                         float64
# Interest Expense               float64
# Depreciation & Amortization    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 8096 entries, 0 to 100238
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Stock                        8096 non-null   object
#  1   Year                         8096 non-null   int64
#  2   Revenue                      6477 non-null   float64
#  3   Revenue Growth               8002 non-null   float64
#  4   Operating Income             8096 non-null   float64
#  5   Net Income                   7286 non-null   float64
#  6   Net Income Ratio             8096 non-null   float64
#  7   Gross Profit                 8096 non-null   float64
#  8   Gross Profit Ratio           8096 non-null   float64
#  9   Operating Expenses           5667 non-null   float64
#  10  Cost of Revenue              8096 non-null   float64
#  11  EBITDA                       8096 non-null   float64
#  12  Interest Expense             8096 non-null   float64
#  13  Depreciation & Amortization  8096 non-null   float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 1.2+ MB
# None
# ------------------------------------------------------------
# Historical Dataset
# Stock               object
# Year                 int64
# Revenue            float64
# Cost of Revenue    float64
# Gross_Profit       float64
# Gross Profit       float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 18783 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Stock            18783 non-null  object
#  1   Year             18783 non-null  int64
#  2   Revenue          15218 non-null  float64
#  3   Cost of Revenue  13659 non-null  float64
#  4   Gross_Profit     6880 non-null   float64
#  5   Gross Profit     6779 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.0+ MB
# None
# ------------------------------------------------------------
# Sparse Dataset
# Stock      object
# Year        int64
# Revenue     int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 443 entries, 0 to 446
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Stock    443 non-null    object
#  1   Year     443 non-null    int64
#  2   Revenue  443 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 13.8+ KB
# None
# ------------------------------------------------------------

# %% [markdown]
# ### Check and filter out impossible years

# %% [markdown]
# This function checks whether years in the 'year' column are greater than a maximum year.
#
# The 'year_column' is a keyword argument that fits the 'year' column. 'max_year' is also a keyword argument that represents the max year.
#
# In this case, we find out whether any column exceeds year 2024.

# %%
def check_years(df, year_column, max_year):
    
    # Flag rows where the year is out of range
    df['is_out_of_range'] = df[year_column] > max_year

    # out_of_range represents years that exceed max_year
    # valid_rows represents years before year max_year
    out_of_range = df[df['is_out_of_range']]
    valid_rows = df[~df['is_out_of_range']]
    
    return {
        "out_of_range": out_of_range,
        "valid_rows": valid_rows,
        "flagged_df": df
    }

# %%
expanded_df_years = check_years(expanded_df, year_column='Year', max_year=2024)
print("Out-of-range rows:")
print(expanded_df_years["out_of_range"])

print("\nValid rows:")
print(expanded_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(expanded_df_years["flagged_df"])
# Out:
# Out-of-range rows:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, is_out_of_range]
# Index: []
#
# Valid rows:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        BRK-A  2023  3.644820e+11             NaN      1.231960e+11
# 1        BRK-A  2022  2.341900e+11             NaN     -2.698500e+10
# 2        BRK-A  2021  3.546360e+11             NaN     -8.242500e+10
# 3        BRK-A  2020  2.862560e+11             NaN     -1.135820e+11
# 4        BRK-A  2019  3.272230e+11             NaN     -7.723400e+10
# ...        ...   ...           ...             ...               ...
# 100235  FMKJRM  2017  1.669641e+09       -0.033992      4.244411e+08
# 100236    IWCM  2024  2.011885e+08       -0.052957      2.713820e+07
# 100237   FBBAT  2003  1.333766e+09       -0.082426      2.334087e+08
# 100238    NJCE  2023  1.548388e+09        0.145031      2.106748e+08
# 100239  UHQIWS  2020  4.912654e+08        0.178375      6.713231e+07
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       9.622300e+10          0.263999  1.231960e+11            0.338003
# 1      -2.281900e+10         -0.097438  1.098710e+11            0.469153
# 2       8.993700e+10          0.253604  1.337060e+11            0.377023
# 3       4.252100e+10          0.148542  8.953000e+10            0.312762
# 4       8.141700e+10          0.248812  1.248030e+11            0.381400
# ...              ...               ...           ...                 ...
# 100235  4.237558e+08          0.253801  7.949797e+08            0.476138
# 100236  2.616266e+07          0.130041  7.740314e+07            0.384729
# 100237  2.328940e+08          0.174614  6.811253e+08            0.510678
# 100238  2.098682e+08          0.135540  5.824036e+08            0.376136
# 100239  6.666666e+07          0.135704  2.549765e+08            0.519020
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 0             1.985750e+11     2.412860e+11  1.376550e+11      5.003000e+09
# 1             1.423100e+11     1.243190e+11 -1.524900e+10      4.352000e+09
# 2            -4.370610e+11     2.209300e+11  1.265760e+11      4.172000e+09
# 3            -3.998380e+11     1.967260e+11  8.038600e+10      4.083000e+09
# 4            -4.044570e+11     2.024200e+11  1.156410e+11      3.961000e+09
# ...                    ...              ...           ...               ...
# 100235        3.705387e+08     8.746609e+08  4.284005e+08      6.852870e+05
# 100236        5.026494e+07     1.237854e+08  3.227004e+07      9.755480e+05
# 100237        4.477166e+08     6.526406e+08  2.400571e+08      5.146860e+05
# 100238        3.717289e+08     9.659840e+08  2.154545e+08      8.065550e+05
# 100239        1.878442e+08     2.362889e+08  6.861804e+07      4.656480e+05
#
#         Depreciation & Amortization  is_out_of_range
# 0                      1.248600e+10            False
# 1                      1.089900e+10            False
# 2                      1.071800e+10            False
# 3                      1.059600e+10            False
# 4                      1.006400e+10            False
# ...                             ...              ...
# 100235                 3.959418e+06            False
# 100236                 5.131834e+06            False
# 100237                 6.648408e+06            False
# 100238                 4.779709e+06            False
# 100239                 1.485732e+06            False
#
# [100240 rows x 15 columns]
#
# Dataframe with flagged column:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        BRK-A  2023  3.644820e+11             NaN      1.231960e+11
# 1        BRK-A  2022  2.341900e+11             NaN     -2.698500e+10
# 2        BRK-A  2021  3.546360e+11             NaN     -8.242500e+10
# 3        BRK-A  2020  2.862560e+11             NaN     -1.135820e+11
# 4        BRK-A  2019  3.272230e+11             NaN     -7.723400e+10
# ...        ...   ...           ...             ...               ...
# 100235  FMKJRM  2017  1.669641e+09       -0.033992      4.244411e+08
# 100236    IWCM  2024  2.011885e+08       -0.052957      2.713820e+07
# 100237   FBBAT  2003  1.333766e+09       -0.082426      2.334087e+08
# 100238    NJCE  2023  1.548388e+09        0.145031      2.106748e+08
# 100239  UHQIWS  2020  4.912654e+08        0.178375      6.713231e+07
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       9.622300e+10          0.263999  1.231960e+11            0.338003
# 1      -2.281900e+10         -0.097438  1.098710e+11            0.469153
# 2       8.993700e+10          0.253604  1.337060e+11            0.377023
# 3       4.252100e+10          0.148542  8.953000e+10            0.312762
# 4       8.141700e+10          0.248812  1.248030e+11            0.381400
# ...              ...               ...           ...                 ...
# 100235  4.237558e+08          0.253801  7.949797e+08            0.476138
# 100236  2.616266e+07          0.130041  7.740314e+07            0.384729
# 100237  2.328940e+08          0.174614  6.811253e+08            0.510678
# 100238  2.098682e+08          0.135540  5.824036e+08            0.376136
# 100239  6.666666e+07          0.135704  2.549765e+08            0.519020
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 0             1.985750e+11     2.412860e+11  1.376550e+11      5.003000e+09
# 1             1.423100e+11     1.243190e+11 -1.524900e+10      4.352000e+09
# 2            -4.370610e+11     2.209300e+11  1.265760e+11      4.172000e+09
# 3            -3.998380e+11     1.967260e+11  8.038600e+10      4.083000e+09
# 4            -4.044570e+11     2.024200e+11  1.156410e+11      3.961000e+09
# ...                    ...              ...           ...               ...
# 100235        3.705387e+08     8.746609e+08  4.284005e+08      6.852870e+05
# 100236        5.026494e+07     1.237854e+08  3.227004e+07      9.755480e+05
# 100237        4.477166e+08     6.526406e+08  2.400571e+08      5.146860e+05
# 100238        3.717289e+08     9.659840e+08  2.154545e+08      8.065550e+05
# 100239        1.878442e+08     2.362889e+08  6.861804e+07      4.656480e+05
#
#         Depreciation & Amortization  is_out_of_range
# 0                      1.248600e+10            False
# 1                      1.089900e+10            False
# 2                      1.071800e+10            False
# 3                      1.059600e+10            False
# 4                      1.006400e+10            False
# ...                             ...              ...
# 100235                 3.959418e+06            False
# 100236                 5.131834e+06            False
# 100237                 6.648408e+06            False
# 100238                 4.779709e+06            False
# 100239                 1.485732e+06            False
#
# [100240 rows x 15 columns]

# %%
partial_df_years = check_years(partial_df, year_column='Year', max_year=2024)
print("Out-of-range rows:")
print(partial_df_years["out_of_range"])

print("\nValid rows:")
print(partial_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(partial_df_years["flagged_df"])
# Out:
# Out-of-range rows:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, is_out_of_range]
# Index: []
#
# Valid rows:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        BRK-A  2023  3.644820e+11             NaN      1.231960e+11
# 1        BRK-A  2022           NaN             NaN     -2.698500e+10
# 5          NVR  2023  9.534889e+09             NaN      1.822455e+09
# 6          NVR  2022  1.053829e+10             NaN      2.169184e+09
# 10        BKNG  2023  2.136500e+10             NaN      5.835000e+09
# ...        ...   ...           ...             ...               ...
# 100156    CMMY  2022  2.239456e+09        0.099316      1.254194e+08
# 100163    MUMO  2023  1.037629e+09        0.181497      1.823199e+08
# 100165  PGVKAG  2023  2.750769e+08        0.020694      3.277666e+06
# 100177    HYYJ  2023  4.155206e+08        0.001772      5.367525e+07
# 100238    NJCE  2023  1.548388e+09        0.145031      2.106748e+08
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0                NaN          0.263999  1.231960e+11            0.338003
# 1      -2.281900e+10         -0.097438  1.098710e+11            0.469153
# 5       1.591611e+09          0.166925  2.483691e+09            0.260485
# 6       1.725575e+09          0.163743  2.876016e+09            0.272911
# 10      4.289000e+09          0.200749  2.136000e+10            0.999766
# ...              ...               ...           ...                 ...
# 100156  1.250442e+08          0.055837  9.927977e+08            0.443321
# 100163  1.819399e+08          0.175342  4.993368e+08            0.481229
# 100165  2.865713e+06          0.010418  1.102896e+08            0.400941
# 100177           NaN          0.128264  1.837651e+08            0.442253
# 100238  2.098682e+08          0.135540  5.824036e+08            0.376136
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 0             1.985750e+11     2.412860e+11  1.376550e+11      5.003000e+09
# 1                      NaN     1.243190e+11 -1.524900e+10      4.352000e+09
# 5                      NaN     7.051198e+09  1.973029e+09      2.774000e+07
# 6                      NaN     7.662271e+09  2.310114e+09      3.952400e+07
# 10                     NaN     5.000000e+06  7.043000e+09      8.970000e+08
# ...                    ...              ...           ...               ...
# 100156        8.673782e+08     1.246658e+09  1.332592e+08      3.752040e+05
# 100163        3.170169e+08     5.382918e+08  1.918209e+08      3.799450e+05
# 100165        1.070119e+08     1.647873e+08  5.902380e+06      4.119530e+05
# 100177        1.300899e+08     2.317555e+08  5.933006e+07      3.788180e+05
# 100238                 NaN     9.659840e+08  2.154545e+08      8.065550e+05
#
#         Depreciation & Amortization  is_out_of_range
# 0                      1.248600e+10            False
# 1                      1.089900e+10            False
# 5                      1.691600e+07            False
# 6                      1.739600e+07            False
# 10                     6.650000e+08            False
# ...                             ...              ...
# 100156                 7.839776e+06            False
# 100163                 9.501007e+06            False
# 100165                 2.624714e+06            False
# 100177                 5.654809e+06            False
# 100238                 4.779709e+06            False
#
# [8096 rows x 15 columns]
#
# Dataframe with flagged column:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        BRK-A  2023  3.644820e+11             NaN      1.231960e+11
# 1        BRK-A  2022           NaN             NaN     -2.698500e+10
# 5          NVR  2023  9.534889e+09             NaN      1.822455e+09
# 6          NVR  2022  1.053829e+10             NaN      2.169184e+09
# 10        BKNG  2023  2.136500e+10             NaN      5.835000e+09
# ...        ...   ...           ...             ...               ...
# 100156    CMMY  2022  2.239456e+09        0.099316      1.254194e+08
# 100163    MUMO  2023  1.037629e+09        0.181497      1.823199e+08
# 100165  PGVKAG  2023  2.750769e+08        0.020694      3.277666e+06
# 100177    HYYJ  2023  4.155206e+08        0.001772      5.367525e+07
# 100238    NJCE  2023  1.548388e+09        0.145031      2.106748e+08
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0                NaN          0.263999  1.231960e+11            0.338003
# 1      -2.281900e+10         -0.097438  1.098710e+11            0.469153
# 5       1.591611e+09          0.166925  2.483691e+09            0.260485
# 6       1.725575e+09          0.163743  2.876016e+09            0.272911
# 10      4.289000e+09          0.200749  2.136000e+10            0.999766
# ...              ...               ...           ...                 ...
# 100156  1.250442e+08          0.055837  9.927977e+08            0.443321
# 100163  1.819399e+08          0.175342  4.993368e+08            0.481229
# 100165  2.865713e+06          0.010418  1.102896e+08            0.400941
# 100177           NaN          0.128264  1.837651e+08            0.442253
# 100238  2.098682e+08          0.135540  5.824036e+08            0.376136
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 0             1.985750e+11     2.412860e+11  1.376550e+11      5.003000e+09
# 1                      NaN     1.243190e+11 -1.524900e+10      4.352000e+09
# 5                      NaN     7.051198e+09  1.973029e+09      2.774000e+07
# 6                      NaN     7.662271e+09  2.310114e+09      3.952400e+07
# 10                     NaN     5.000000e+06  7.043000e+09      8.970000e+08
# ...                    ...              ...           ...               ...
# 100156        8.673782e+08     1.246658e+09  1.332592e+08      3.752040e+05
# 100163        3.170169e+08     5.382918e+08  1.918209e+08      3.799450e+05
# 100165        1.070119e+08     1.647873e+08  5.902380e+06      4.119530e+05
# 100177        1.300899e+08     2.317555e+08  5.933006e+07      3.788180e+05
# 100238                 NaN     9.659840e+08  2.154545e+08      8.065550e+05
#
#         Depreciation & Amortization  is_out_of_range
# 0                      1.248600e+10            False
# 1                      1.089900e+10            False
# 5                      1.691600e+07            False
# 6                      1.739600e+07            False
# 10                     6.650000e+08            False
# ...                             ...              ...
# 100156                 7.839776e+06            False
# 100163                 9.501007e+06            False
# 100165                 2.624714e+06            False
# 100177                 5.654809e+06            False
# 100238                 4.779709e+06            False
#
# [8096 rows x 15 columns]

# %% [markdown]
# 17822 rows in Historical Dataset are out of range.

# %%
historical_df_years = check_years(historical_df, year_column='Year', max_year=2024)
print("Out-of-range rows:")
print(historical_df_years["out_of_range"])

print("\nValid rows:")
print(historical_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(historical_df_years["flagged_df"])
# Out:
# Out-of-range rows:
#         Stock  Year       Revenue  Cost of Revenue  Gross_Profit  \
# 0       GOLXD  2184  9.680579e+08     6.308393e+08  3.372186e+08
# 1       OKDZW  2192  4.770210e+08     2.977351e+08  1.792859e+08
# 2       PGOPC  2168  9.445676e+08     6.795297e+08  2.650379e+08
# 3        FSPF  2151  1.623014e+08     1.034746e+08  5.882680e+07
# 5       KDMTE  2198  6.519775e+08     4.517509e+08  2.002266e+08
# ...       ...   ...           ...              ...           ...
# 19995  DUOJBW  2162  1.739624e+09     5.799098e+08           NaN
# 19996   RZYXV  2194  2.511675e+08     1.142958e+08           NaN
# 19997   MXKTG  2138           NaN              NaN           NaN
# 19998   XGMTN  2136           NaN              NaN           NaN
# 19999   XEZIM  2160           NaN              NaN           NaN
#
#        Gross Profit  is_out_of_range
# 0               NaN             True
# 1               NaN             True
# 2               NaN             True
# 3               NaN             True
# 5               NaN             True
# ...             ...              ...
# 19995  1.159714e+09             True
# 19996  1.368718e+08             True
# 19997           NaN             True
# 19998           NaN             True
# 19999           NaN             True
#
# [17822 rows x 7 columns]
#
# Valid rows:
#         Stock  Year       Revenue  Cost of Revenue  Gross_Profit  \
# 9       TBION  2014  1.721602e+09     5.691370e+08  1.152465e+09
# 16      HMUXK  2017  4.020641e+08     1.227038e+08  2.793604e+08
# 29     UWYVPZ  2011  1.289311e+09     7.509919e+08  5.383186e+08
# 30     SEOBWL  2017 -9.045562e+08              NaN           NaN
# 41      KHNKA  2011  1.270224e+09     6.075390e+08  6.626846e+08
# ...       ...   ...           ...              ...           ...
# 19903    HFUZ  2018  6.898412e+08     2.960274e+08           NaN
# 19910   SDGZA  2011  3.311051e+08     1.853702e+08           NaN
# 19959    QLNE  2012  1.654806e+09     8.629593e+08           NaN
# 19966    AMVT  2018  8.167094e+08     4.438317e+08           NaN
# 19986   UCJCO  2017  5.206276e+08     1.947702e+08           NaN
#
#        Gross Profit  is_out_of_range
# 9               NaN            False
# 16              NaN            False
# 29              NaN            False
# 30              NaN            False
# 41              NaN            False
# ...             ...              ...
# 19903  3.938138e+08            False
# 19910  1.457350e+08            False
# 19959  7.918462e+08            False
# 19966  3.728776e+08            False
# 19986  3.258574e+08            False
#
# [961 rows x 7 columns]
#
# Dataframe with flagged column:
#         Stock  Year       Revenue  Cost of Revenue  Gross_Profit  \
# 0       GOLXD  2184  9.680579e+08     6.308393e+08  3.372186e+08
# 1       OKDZW  2192  4.770210e+08     2.977351e+08  1.792859e+08
# 2       PGOPC  2168  9.445676e+08     6.795297e+08  2.650379e+08
# 3        FSPF  2151  1.623014e+08     1.034746e+08  5.882680e+07
# 5       KDMTE  2198  6.519775e+08     4.517509e+08  2.002266e+08
# ...       ...   ...           ...              ...           ...
# 19995  DUOJBW  2162  1.739624e+09     5.799098e+08           NaN
# 19996   RZYXV  2194  2.511675e+08     1.142958e+08           NaN
# 19997   MXKTG  2138           NaN              NaN           NaN
# 19998   XGMTN  2136           NaN              NaN           NaN
# 19999   XEZIM  2160           NaN              NaN           NaN
#
#        Gross Profit  is_out_of_range
# 0               NaN             True
# 1               NaN             True
# 2               NaN             True
# 3               NaN             True
# 5               NaN             True
# ...             ...              ...
# 19995  1.159714e+09             True
# 19996  1.368718e+08             True
# 19997           NaN             True
# 19998           NaN             True
# 19999           NaN             True
#
# [18783 rows x 7 columns]

# %% [markdown]
# We filter out rows that are out of range, and keep only rows within the valid range of until 2024.
#
# Unique values in the 'Year' column are checked again.

# %%
historical_df = historical_df.loc[historical_df_years['valid_rows'].index]

# %%
historical_df['Year'].unique()
# Out:
# array([2014, 2017, 2011, 2015, 2016, 2018, 2020, 2019, 2012, 2013, 2010],
#       dtype=int64)

# %%
sparse_df_years = check_years(sparse_df, year_column='Year', max_year=2099)
print("Out-of-range rows:")
print(sparse_df_years["out_of_range"])

print("\nValid rows:")
print(sparse_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(sparse_df_years["flagged_df"])
# Out:
# Out-of-range rows:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, is_out_of_range]
# Index: []
#
# Valid rows:
#       Stock  Year     Revenue  is_out_of_range
# 0      JGPF  2002   533645067            False
# 1      JGPF  2003   191962652            False
# 2     HSCGS  2001   300527108            False
# 3     HSCGS  2002  1486372237            False
# 4     HSCGS  2005  1350321861            False
# ..      ...   ...         ...              ...
# 442  ZTMXAP  2001  1360600396            False
# 443  ZTMXAP  2003   257623495            False
# 444  ZTMXAP  2005   483787674            False
# 445  ZTMXAP  2006   793009584            False
# 446  ZTMXAP  2008  1808217019            False
#
# [443 rows x 4 columns]
#
# Dataframe with flagged column:
#       Stock  Year     Revenue  is_out_of_range
# 0      JGPF  2002   533645067            False
# 1      JGPF  2003   191962652            False
# 2     HSCGS  2001   300527108            False
# 3     HSCGS  2002  1486372237            False
# 4     HSCGS  2005  1350321861            False
# ..      ...   ...         ...              ...
# 442  ZTMXAP  2001  1360600396            False
# 443  ZTMXAP  2003   257623495            False
# 444  ZTMXAP  2005   483787674            False
# 445  ZTMXAP  2006   793009584            False
# 446  ZTMXAP  2008  1808217019            False
#
# [443 rows x 4 columns]

# %% [markdown]
# ### Rename values in 'Stock' column that end with ' .end' in Historical Dataset

# %% [markdown]
# We replace both '.end' and ' .end' at the end of the string using regex.
#
# After that, we print out the stock names to see whether they are all named correctly.

# %%
historical_df['Stock'] = historical_df['Stock'].str.replace(r'\s?\.end$', '', regex=True)

# %%
historical_df['Stock'].unique()
# Out:
# array(['TBION', 'HMUXK', 'UWYVPZ', 'SEOBWL', 'KHNKA', 'ZONI', 'TQWB',
#        'SYART', 'XCWI', 'DKFS', 'AHOLHZ', 'SNSWR', 'ESZU', 'CBENTE',
#        'BAET', 'WUAPX', 'MJJJT', 'RHWJ', 'GEQJW', 'LJVL', 'MHTQR',
#        'UVOIB', 'PMUY', 'QRDU', 'TUWQO', 'HPZUZ', 'BODXS', 'TBLHW',
#        'BOOGWT', 'MSLC', 'CSXRFF', 'IGLP', 'CFRQ', 'BGCVR', 'DBOZU',
#        'GQESMN', 'IMLWA', 'ZIGNSP', 'ZMNUXG', 'NBQK', 'CKHS', 'KBTPAN',
#        'NIQTOM', 'MJVLN', 'PCOSBN', 'MTTH', 'AVNCI', 'HWEVQX', 'XGYW',
#        'QOCDZY', 'INZP', 'NOVZI', 'PGEFK', 'FWSPZB', 'BMGM', 'JXREJ',
#        'OTRHID', 'XDCHVO', 'ADLLZX', 'QDZH', 'XRZQ', 'XNMM', 'AEXZMU',
#        'FFRAVF', 'YFIZ', 'WRLLF', 'PDLVXN', 'FDWEU', 'NTZQO', 'JBQBJ',
#        'MQBHG', 'MQPN', 'AMVT', 'DOQGLN', 'MLWODF', 'MHKEQ', 'WBAC',
#        'XRGJ', 'NKBF', 'UUTDFC', 'EODSLX', 'QMWW', 'VDXZN', 'OXNZ',
#        'EYPA', 'XBSY', 'CKZS', 'WOYU', 'XPHLDB', 'XNEG', 'LGIGR', 'RRGZ',
#        'UXRNLG', 'KBAKCF', 'PJUGAF', 'BJQIZN', 'IMBWSH', 'YEHR', 'IELVMR',
#        'TMEB', 'IMZD', 'OMQLGO', 'YYHGE', 'MCKXK', 'XPETH', 'TGLPW',
#        'ORDIF', 'UHSJ', 'YAGTO', 'SBJAWK', 'XIDBCB', 'WNUYLW', 'EHMTYT',
#        'EHQPA', 'AEPHNR', 'LGSD', 'TBLY', 'UGBW', 'XOEW', 'YHMTZ',
#        'GMZVBT', 'HZKX', 'BKVU', 'XAVFEC', 'JBJV', 'YWMUJ', 'TOEC',
#        'JQEVEZ', 'LGVUA', 'SFDKND', 'GARJPH', 'YAMAU', 'QPJR', 'KDTL',
#        'VAURIY', 'HWIOMX', 'DHOYI', 'VFYYU', 'MVJZJR', 'JJPICI', 'GZPGYT',
#        'QEYPMT', 'PVNF', 'FNMY', 'QXNG', 'NGFRO', 'BFPVXC', 'MVSO',
#        'QBZFYV', 'AYCOM', 'MSEHK', 'YXBEDH', 'JEZA', 'VHXAW', 'BJFY',
#        'YBIC', 'BSNU', 'AWESC', 'QTNVK', 'ROUUU', 'ZTEU', 'JSLJ',
#        'TSQKGR', 'BHYJAU', 'DHTFUV', 'HNTKM', 'GQLZD', 'PHGJ', 'LYLV',
#        'JIJLF', 'CWFLBY', 'JFWPGR', 'QWAGTL', 'AHYBP', 'HSQTZ', 'VKRQM',
#        'DHQTB', 'NNBWV', 'GOHF', 'ZXTF', 'IVKH', 'SWDIG', 'FEDYR',
#        'FXOSB', 'LWFR', 'LBGTDQ', 'LHBDXS', 'QGPM', 'LBOP', 'FGDEPH',
#        'YTMEQA', 'HXKRMV', 'ZPHX', 'UCVDFV', 'OQRAYL', 'AUYG', 'ESWU',
#        'HCCQ', 'LYCHB', 'FAELI', 'YBUBTG', 'HPUTV', 'HXPFDN', 'OGGZ',
#        'HOEV', 'ARBCCJ', 'FFOO', 'QIMBFV', 'VQPFQ', 'YDEQGH', 'HCZO',
#        'PDNMH', 'XHFD', 'GMYYB', 'TXDJGM', 'ZOBITN', 'VEDZJL', 'TXOJI',
#        'DBCNBY', 'OFXJW', 'ULPJLC', 'SBKJK', 'FCMIS', 'SCCLS', 'RICWS',
#        'JHRWR', 'KQOZ', 'XGOQN', 'NADPM', 'DEEETO', 'SIOEXP', 'ERSM',
#        'YFBISX', 'CNCGFE', 'ZKSE', 'AVUKN', 'RHQUOJ', 'DVOKU', 'PXIVML',
#        'MGTYKW', 'GFIGIW', 'XESR', 'ZESF', 'WSWBEB', 'ABZUQ', 'DBGKWF',
#        'SJXLCA', 'OGWAK', 'PWZKGN', 'RSWV', 'ESWP', 'ABVG', 'CYIX',
#        'TWAMIO', 'IBEVY', 'ERRDF', 'IXKKP', 'FYBDB', 'GEOD', 'HJUX',
#        'BKJUI', 'KGTDM', 'OMBBZC', 'EGGTH', 'IHKBU', 'KTYFPQ', 'PJELN',
#        'MNWTOR', 'MEKTI', 'OBXZ', 'RJVD', 'FVQQH', 'NYPNY', 'TYBJI',
#        'WXUKNI', 'AWEE', 'ZBGG', 'PGVKAG', 'XIYUAQ', 'UYIC', 'NYEA',
#        'FWJRLZ', 'CNSKEE', 'XPMGE', 'MMEI', 'FJREC', 'EADP', 'GVNWZ',
#        'UOWUK', 'HYXS', 'OAFRCA', 'QBNUT', 'XMDXWB', 'CXGGM', 'FIXL',
#        'ZHHUXD', 'ULDUGA', 'FEZQ', 'WXPFKX', 'GABAG', 'KIFRM', 'VIBFYP',
#        'KQVZS', 'EAUKF', 'PLRN', 'MDMSC', 'UFMTSJ', 'UCRL', 'JKJQGN',
#        'OEXPNH', 'NFUB', 'HFLQUR', 'EOZSX', 'QBNN', 'USBO', 'MNBS',
#        'USDBW', 'KXCXV', 'IDIJ', 'SSAT', 'ACAOH', 'JBXNVA', 'GYBO',
#        'EDSWZG', 'SRGNK', 'KMASG', 'EYTYC', 'QURR', 'BUDL', 'GJONUM',
#        'MJWOJU', 'TTCZLN', 'BODEFP', 'GCTDS', 'VNCJG', 'ZSCUBT', 'MNYAWA',
#        'RXYEKN', 'DUYFMA', 'HPBER', 'GNEEK', 'XVOV', 'XDSIE', 'BLFWU',
#        'WLZJR', 'FYXUDS', 'ZYUC', 'GXSBCL', 'WHLMDU', 'DMVRKJ', 'QFFQ',
#        'KJAUIT', 'UHPOH', 'UWTD', 'BEKYKU', 'XSKCTD', 'BGMFXT', 'CUXTZ',
#        'FIZPBA', 'TUUQDL', 'WXVSS', 'REHVDH', 'IQHJTY', 'RKLHMU', 'UATDI',
#        'NHYPX', 'UMLHI', 'UDZA', 'DEEQW', 'CJDIFQ', 'YXGXBD', 'YKUM',
#        'ZCKDK', 'FCVC', 'NPQDD', 'JIRP', 'LLWVT', 'HDAAU', 'MXENBP',
#        'REFXE', 'SLTFZN', 'YKUGMZ', 'LVJP', 'XRGWHY', 'EWDSF', 'AOFWGE',
#        'VICTU', 'BWTXBP', 'TGFPKM', 'TTIL', 'OXAG', 'AUOHNH', 'XQMO',
#        'FQLZMZ', 'CVWMPB', 'SLKCGM', 'UUOLS', 'BCSEX', 'XWOG', 'VRINEJ',
#        'SHULKP', 'EICVA', 'YHLCZ', 'ITJB', 'PHSZIX', 'LSJDY', 'JMCGQG',
#        'ZBIUB', 'MXRHW', 'SWIZO', 'TMOQ', 'YAUP', 'OBBVWE', 'TMXREP',
#        'VUKOP', 'BJQW', 'NIWNC', 'RVFO', 'CIQHOL', 'MVORS', 'OFOMR',
#        'QQKNSC', 'FOJY', 'HPUXS', 'NNYKMD', 'BFTTG', 'XRYFI', 'MMPLA',
#        'VFONOW', 'TKNFC', 'LLXF', 'ZZGCPK', 'HQMEQ', 'YOEWMC', 'UVSBDX',
#        'THKFL', 'NAXE', 'RIQYM', 'VEKY', 'WPLKQ', 'TIOP', 'RYAZSN',
#        'EWCSE', 'KMKL', 'KBFXJ', 'HKPIB', 'YJQD', 'MXCKC', 'BPJK', 'KHJX',
#        'CFQGKS', 'XNBZ', 'LRDEIW', 'ESREJ', 'KJTPC', 'AUIJ', 'IQGO',
#        'APPHI', 'BMMVB', 'UIDUOU', 'YNCRP', 'CGQFF', 'PMNMDZ', 'LJGW',
#        'ETSV', 'KAVUFE', 'PTCDVE', 'SXSF', 'RBBHV', 'HAWAI', 'KKTV',
#        'CRQA', 'TQMOO', 'FBMSGE', 'EYGV', 'TWWBA', 'ACKMX', 'ANIFNR',
#        'SMHQ', 'FABKF', 'YGSMC', 'FLVX', 'YHNF', 'XOJHZ', 'CJSO',
#        'AMSNTB', 'LLQI', 'FQCJ', 'ZEHKH', 'HESJ', 'DIGSWH', 'MTKPV',
#        'RJOJST', 'OZOCB', 'ZNEKXC', 'KEKC', 'UVNDMM', 'ZPJNHT', 'YXBNQ',
#        'BJTD', 'AQSE', 'PXPBY', 'PRNZVO', 'BENF', 'WXXUXG', 'RBPNO',
#        'DYAF', 'BKHF', 'ILSIL', 'QIJU', 'ZHDJJX', 'LQMTFR', 'ZRPHJU',
#        'FYVTY', 'NCMLJ', 'MUBU', 'QXWF', 'INXIRU', 'BLK', 'SDHPP', 'HGWD',
#        'HDLAPA', 'PONQ', 'KLMCIQ', 'GZKDK', 'CBUKFZ', 'AEXM', 'YCFD',
#        'FMXAY', 'TZCQE', 'RQTA', 'BQXYUH', 'ONMZ', 'MDKZM', 'HYZU',
#        'EFDFK', 'WSGC', 'BHVKVT', 'RMVWN', 'QSCLJJ', 'QUGB', 'WAUWOY',
#        'KAVM', 'HCFC', 'RSRR', 'XTIFU', 'FEHZ', 'TFFHIX', 'IKKTW',
#        'CNKFXX', 'JCBFVB', 'IURUPJ', 'YJUYHT', 'EAFI', 'YYAHA', 'LEEM',
#        'OMBQK', 'BJJHB', 'AVGOP', 'LHJTTC', 'AKTCH', 'HERVQA', 'TZMITS',
#        'YCUPOA', 'YLCXNI', 'MCCU', 'JVVC', 'EDFVEO', 'PYIX', 'YZNCLW',
#        'TBFE', 'CPOWCB', 'IIXL', 'GXUAV', 'VBGEVC', 'EJXYM', 'ALGZOZ',
#        'HESQ', 'LSXWM', 'KOKD', 'MIYNYG', 'IESNGY', 'KOHYQ', 'NDLFT',
#        'LEYZHF', 'LKOM', 'IFQCY', 'NKLUQ', 'ITNH', 'GJPVG', 'VEWSH',
#        'AAVGZ', 'SLQOIX', 'LFJLDV', 'AHJRAQ', 'COCGV', 'PNSFJ', 'MDXN',
#        'ZTMXAP', 'KWQS', 'IOHE', 'CNVQ', 'EVKRG', 'CYGEDB', 'EMJGZ',
#        'MYWR', 'XIWOX', 'HVRHP', 'XDPK', 'DMQR', 'HYWXC', 'EEBJPX',
#        'GXRAJB', 'XJIUCY', 'CHTNBH', 'TPWXO', 'PVVA', 'CKGE', 'VXAGF',
#        'EGPUY', 'ITITR', 'QHTDS', 'JQASI', 'IGVLE', 'PMJVIU', 'NEQTLG',
#        'QGBC', 'UFCTYK', 'MIBP', 'TJLX', 'DKTB', 'XDNBZ', 'JZLKEO',
#        'PVYMR', 'UKRK', 'KSKKH', 'IGMUKH', 'JTVHUM', 'WBAO', 'JOGJLK',
#        'PSNCWE', 'FYUSTM', 'DOGRN', 'FBBAT', 'BQHJK', 'WSQLSO', 'TVHQN',
#        'UMYVT', 'ZWJUH', 'SEIEO', 'QRATUL', 'ZHMHO', 'EUYH', 'NKEH',
#        'RGSQ', 'OWVM', 'YIET', 'JYRD', 'UJAXJ', 'NATAGU', 'WXYNEA',
#        'FVYBNT', 'YKOUY', 'WOTY', 'HCUJK', 'TCSNEN', 'SQRBGE', 'BHCYI',
#        'MMPTCX', 'UIFA', 'ZNJIOX', 'GFNLX', 'ZQNFU', 'GFBJW', 'ZKEX',
#        'BCSS', 'HMFOSC', 'CDJGVI', 'QXQCS', 'UYJJ', 'VWVR', 'FHXHO',
#        'LYANK', 'IPPL', 'BWDUHB', 'QWJTJ', 'CSGBJ', 'OLYZSR', 'UMJT',
#        'FYVOX', 'IZDAEJ', 'JXDCQN', 'LRSW', 'BNKW', 'YLJW', 'BFEK',
#        'RMID', 'AYJM', 'FCGWM', 'KXXJIE', 'UOGLZY', 'URQYXX', 'AOJFJ',
#        'XJKN', 'QUDHN', 'BZGMSE', 'HVMD', 'JXMSMO', 'AEGEZB', 'RDVP',
#        'WPCH', 'YFFFTL', 'WHAIZ', 'TGUU', 'OKEUQ', 'EMONB', 'IMTB',
#        'PLQW', 'RGBZ', 'LVAB', 'LODTMH', 'MCGL', 'SWMYX', 'FFAKWT',
#        'MADJUT', 'EWSHE', 'YLBTQC', 'NFOCJ', 'JNOKP', 'VOPFJX', 'FDGQ',
#        'YCAP', 'UEQYX', 'TXGR', 'EMOII', 'HONUL', 'BUSNW', 'TKKA',
#        'CPAAF', 'FYUPBE', 'DUPDNO', 'RWGTOG', 'XFPB', 'CONL', 'UIDW',
#        'VEMJFL', 'MKBU', 'ECXO', 'CTSD', 'XIWDFD', 'DGOZX', 'UQXN',
#        'AYIOJ', 'KVNS', 'FMEQI', 'FNAGW', 'SIYEM', 'XDFCFE', 'KVPL',
#        'YNRRYM', 'XVPUNN', 'DSDLDU', 'SNUBU', 'PGHUNC', 'GOUTB', 'NECOC',
#        'DGMDXO', 'NJBN', 'MFJEW', 'PVXWT', 'GSAO', 'MHXZQ', 'XMKKHQ',
#        'VMNGD', 'JDZGW', 'KQVHPS', 'YIRN', 'VKLZ', 'FHVJJA', 'FPKQ',
#        'FUIEKC', 'DQNOHS', 'NAHAQ', 'NGUJAB', 'FCNCA', 'PXPO', 'KORPZ',
#        'AFWUF', 'AFRB', 'JKHS', 'SAFYIT', 'OTTRI', 'APOKY', 'CFSGKH',
#        'QTYHZ', 'WIKAQ', 'DPMY', 'UHYBDN', 'BGTEPS', 'DOFUWJ', 'VLIKHP',
#        'EIZCGW', 'FXRV', 'MRPLYG', 'UBEBX', 'VLJFC', 'NADF', 'KLMUU',
#        'OTQI', 'VAZVVG', 'VTSGTI', 'HCHG', 'ZVKD', 'SPPV', 'AEZBY',
#        'UELAOI', 'FRDUP', 'AZNZ', 'OZIH', 'YVHK', 'VZAF', 'MDBZCA', 'NVR',
#        'MUMO', 'BBFQ', 'SJWKCT', 'QJJPTU', 'SNGWWU', 'BPAUK', 'BEAY',
#        'RZZLH', 'ADKVY', 'KZURPA', 'RSTPL', 'TTCDL', 'SQOFZ', 'RGWU',
#        'OWOV', 'PNST', 'OKKOB', 'MCVLL', 'YUJYCD', 'UHMQH', 'RNXSN',
#        'ZZZBKF', 'JTFVV', 'RRZCHO', 'DUSLN', 'TDQS', 'NVNAM', 'NPBAYV',
#        'ZVUP', 'TKEY', 'TLLH', 'OZHGL', 'UUKHAK', 'CIGDDQ', 'XFLFG',
#        'FNTZH', 'ONBOT', 'HFUZ', 'SDGZA', 'QLNE', 'UCJCO'], dtype=object)

# %% [markdown]
# ### Check for impossible negative values

# %% [markdown]
# We know that the following columns cannot have negative values:
# **Revenue, Operating Expenses, Cost of Revenue, Interest Expense, Depreciation & Amortization**
#
# We iterate this function over each column to check for any impossible negative values.
#
# We then create a valid_columns list to only keep rows with no impossible negative values.

# %%
def drop_rows_with_negatives(df):
    columns_to_check = ['Revenue', 'Operating Expenses', 'Cost of Revenue', 'Interest Expense', 'Depreciation & Amortization']

    # For each column within columns that are not supposed to have negative values
    for column in columns_to_check:
        if column in df.columns: # Check first if the column exist in the datasset
            # Check for negative values in the column
            has_negative = df[column].lt(0).any()
            if has_negative:
                print(f"Column '{column}' contains negative values.")
            else:
                print(f"Column '{column} does not contain any negative values.'")
        else: # If the column is not present in the dataset, we skip it
            print(f"Column '{column}' is not present in the DataFrame. Skipping.")
            
    # Only keep rows with no impossible negative values
    valid_columns = [col for col in columns_to_check if col in df.columns]
    rows_with_negatives = df[df[valid_columns].lt(0).any(axis=1)]
    return df.drop(rows_with_negatives.index)

# %%
expanded_df = drop_rows_with_negatives(expanded_df)
# Out:
# Column 'Revenue does not contain any negative values.'
# Column 'Operating Expenses' contains negative values.
# Column 'Cost of Revenue' contains negative values.
# Column 'Interest Expense' contains negative values.
# Column 'Depreciation & Amortization' contains negative values.

# %%
partial_df = drop_rows_with_negatives(partial_df)
# Out:
# Column 'Revenue does not contain any negative values.'
# Column 'Operating Expenses' contains negative values.
# Column 'Cost of Revenue' contains negative values.
# Column 'Interest Expense does not contain any negative values.'
# Column 'Depreciation & Amortization' contains negative values.

# %%
historical_df = drop_rows_with_negatives(historical_df)
# Out:
# Column 'Revenue' contains negative values.
# Column 'Operating Expenses' is not present in the DataFrame. Skipping.
# Column 'Cost of Revenue' contains negative values.
# Column 'Interest Expense' is not present in the DataFrame. Skipping.
# Column 'Depreciation & Amortization' is not present in the DataFrame. Skipping.

# %%
sparse_df = drop_rows_with_negatives(sparse_df)
# Out:
# Column 'Revenue does not contain any negative values.'
# Column 'Operating Expenses' is not present in the DataFrame. Skipping.
# Column 'Cost of Revenue' is not present in the DataFrame. Skipping.
# Column 'Interest Expense' is not present in the DataFrame. Skipping.
# Column 'Depreciation & Amortization' is not present in the DataFrame. Skipping.

# %% [markdown]
# ### Dealing with missing values

# %%
# Calculate the percentage of missing values
def missing_values_check(df):
    missing_values = df.isnull().sum()
    percent = (missing_values * 100) / len(df)
    
    # Create a DataFrame to display missing values information
    missing_df = pd.DataFrame({
        'Column': df.columns,
        'No. of Missing Values': missing_values.values,
        'Percentage': percent.values
    }).sort_values(by='Percentage', ascending=False)

    return missing_df

# %%
print(missing_values_check(expanded_df))
print('-'*80)
print(missing_values_check(partial_df))
print('-'*80)
print(missing_values_check(historical_df))
print('-'*80)
print(missing_values_check(sparse_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 3                Revenue Growth                    213    0.212547
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 2                       Revenue                      0    0.000000
# 4              Operating Income                      0    0.000000
# 5                    Net Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000
# --------------------------------------------------------------------------------
#                          Column  No. of Missing Values  Percentage
# 9            Operating Expenses                   2427   29.988879
# 2                       Revenue                   1619   20.004943
# 5                    Net Income                    810   10.008649
# 3                Revenue Growth                     91    1.124429
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 4              Operating Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000
# --------------------------------------------------------------------------------
#             Column  No. of Missing Values  Percentage
# 4     Gross_Profit                    599   65.250545
# 5     Gross Profit                    580   63.180828
# 3  Cost of Revenue                    261   28.431373
# 2          Revenue                    185   20.152505
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 6  is_out_of_range                      0    0.000000
# --------------------------------------------------------------------------------
#             Column  No. of Missing Values  Percentage
# 0            Stock                      0         0.0
# 1             Year                      0         0.0
# 2          Revenue                      0         0.0
# 3  is_out_of_range                      0         0.0

# %% [markdown]
# The number of missing values in the Partial and Historical dataset hold a significant percentage of the datasets, which affects analysis later on.
#
# We will try to fill in the missing values as best as we can, based on previous year revenues or calculations between columns.

# %% [markdown]
# ### Managing Missing Values

# %% [markdown]
# ### Expanded Dataset: Revenue Growth

# %%
# For each stock, fill in revenue growth NaN based on revenue in the previous year
# Ensure 'Year' column is in integer format
expanded_df['Year'] = expanded_df['Year'].astype(int)

# Sort by stock and year
expanded_df = expanded_df.sort_values(by=['Stock', 'Year'])

# Calculate revenue growth where it is NaN
expanded_df['Revenue Growth'] = expanded_df.groupby('Stock')['Revenue'].apply(
    lambda x: x.pct_change(fill_method=None).fillna(0)
).reset_index(drop=True)

# %%
# Confirm that the only NaN left are stocks with no prior revenues
expanded_df_NaN = expanded_df[expanded_df['Revenue Growth'].isna()]

# %%
expanded_df_NaN
# Out:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 100217   AODFB  2004  1.780660e+09             NaN      4.687504e+08
# 100232  AOFZYV  2016  2.750267e+08             NaN      9.370307e+07
# 100226    BMQJ  2020  8.431168e+08             NaN      2.452183e+08
# 100237   FBBAT  2003  1.333766e+09             NaN      2.334087e+08
# 100235  FMKJRM  2017  1.669641e+09             NaN      4.244411e+08
# 100223   GXXAE  2018  4.399244e+08             NaN      1.043316e+08
# 100227  HDOIIU  2024  1.180558e+09             NaN      2.119589e+08
# 100228  HNECUE  2007  1.789047e+09             NaN      1.230134e+08
# 100231  HXFIYE  2020  4.303517e+08             NaN      1.228597e+08
# 100234   IBOIC  2014  6.335495e+08             NaN      6.407981e+07
# 100236    IWCM  2024  2.011885e+08             NaN      2.713820e+07
# 100229    JKQT  2004  3.675429e+07             NaN      5.015120e+06
# 100224   MFYYA  2014  2.081575e+09             NaN      2.210648e+08
# 100222   MKRUX  2013  3.069180e+08             NaN      1.990756e+07
# 100233    MYWR  2004  1.907948e+09             NaN      2.052163e+08
# 100219   NARXV  2009  2.108123e+09             NaN      5.114961e+08
# 100215   NECOC  2008  2.123852e+09             NaN      2.386519e+08
# 100238    NJCE  2023  1.548388e+09             NaN      2.106748e+08
# 100225    NYKN  2012  2.843117e+08             NaN      4.533858e+07
# 100216    PUVW  2017  1.005798e+09             NaN      9.517866e+07
# 100230  QDFXYI  2019  6.815540e+08             NaN      9.123404e+07
# 100220  RIOWXA  2001  2.128028e+08             NaN     -1.367332e+06
# 100218    TEHM  2008  2.193145e+09             NaN      6.433787e+08
# 100221  TKNSEP  2017  1.853166e+09             NaN      1.261148e+08
# 100214    TTIL  2024  1.124392e+06             NaN      3.881855e+05
# 100213    UBQQ  2015  1.720394e+09             NaN      5.739772e+08
# 100239  UHQIWS  2020  4.912654e+08             NaN      6.713231e+07
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 100217  4.684636e+08          0.263084  9.369216e+08            0.526165
# 100232  9.270996e+07          0.337094  1.508744e+08            0.548581
# 100226  2.448926e+08          0.290461  4.980760e+08            0.590756
# 100237  2.328940e+08          0.174614  6.811253e+08            0.510678
# 100235  4.237558e+08          0.253801  7.949797e+08            0.476138
# 100223  1.042150e+08          0.236893  2.560161e+08            0.581955
# 100227  2.111904e+08          0.178890  6.219169e+08            0.526799
# 100228  1.228087e+08          0.068645  6.007443e+08            0.335790
# 100231  1.223439e+08          0.284288  2.447124e+08            0.568634
# 100234  6.366110e+07          0.100483  3.004009e+08            0.474155
# 100236  2.616266e+07          0.130041  7.740314e+07            0.384729
# 100229  4.391812e+06          0.119491  1.553394e+07            0.422643
# 100224  2.207602e+08          0.106054  8.948207e+08            0.429877
# 100222  1.930178e+07          0.062889  9.702830e+07            0.316138
# 100233  2.043375e+08          0.107098  7.487988e+08            0.392463
# 100219  5.111623e+08          0.242473  1.000883e+09            0.474774
# 100215  2.383285e+08          0.112215  7.138076e+08            0.336091
# 100238  2.098682e+08          0.135540  5.824036e+08            0.376136
# 100225  4.435542e+07          0.156010  1.486509e+08            0.522845
# 100216  9.444352e+07          0.093899  3.246667e+08            0.322795
# 100230  9.055099e+07          0.132860  2.525246e+08            0.370513
# 100220 -1.987969e+06         -0.009342  8.098952e+07            0.380585
# 100218  6.427152e+08          0.293056  1.254352e+09            0.571942
# 100221  1.256069e+08          0.067780  8.196565e+08            0.442301
# 100214 -2.819675e+05         -0.250773  6.204868e+05            0.551842
# 100213  5.737168e+08          0.333480  9.904594e+08            0.575717
# 100239  6.666666e+07          0.135704  2.549765e+08            0.519020
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 100217        4.681712e+08     8.437386e+08  4.770844e+08          286758.0
# 100232        5.717134e+07     1.241523e+08  1.005936e+08          993114.0
# 100226        2.528577e+08     3.450408e+08  2.517345e+08          325753.0
# 100237        4.477166e+08     6.526406e+08  2.400571e+08          514686.0
# 100235        3.705387e+08     8.746609e+08  4.284005e+08          685287.0
# 100223        1.516844e+08     1.839083e+08  1.105029e+08          116655.0
# 100227        4.099581e+08     5.586409e+08  2.197298e+08          768468.0
# 100228        4.777309e+08     1.188303e+09  1.263938e+08          204687.0
# 100231        1.218527e+08     1.856393e+08  1.293109e+08          515872.0
# 100234        2.363211e+08     3.331486e+08  6.926207e+07          418713.0
# 100236        5.026494e+07     1.237854e+08  3.227004e+07          975548.0
# 100229        1.051882e+07     2.122035e+07  6.192322e+06          623308.0
# 100224        6.737559e+08     1.186754e+09  2.229155e+08          304637.0
# 100222        7.712073e+07     2.098897e+08  2.861522e+07          605788.0
# 100233        5.435825e+08     1.159150e+09  2.144383e+08          878771.0
# 100219        4.893866e+08     1.107240e+09  5.187035e+08          333708.0
# 100215        4.751557e+08     1.410045e+09  2.395454e+08          323450.0
# 100238        3.717289e+08     9.659840e+08  2.154545e+08          806555.0
# 100225        1.033123e+08     1.356608e+08  5.212200e+07          983166.0
# 100216        2.294881e+08     6.811314e+08  9.613299e+07          735139.0
# 100230        1.612906e+08     4.290293e+08  9.950987e+07          683050.0
# 100220        8.235685e+07     1.318132e+08  1.547172e+06          620637.0
# 100218        6.109732e+08     9.387930e+08  6.486510e+08          663444.0
# 100221        6.935417e+08     1.033510e+09  1.325331e+08          507962.0
# 100214        2.323012e+05     5.039052e+05  7.652416e+06          670153.0
# 100213        4.164822e+08     7.299344e+08  5.775975e+08          260382.0
# 100239        1.878442e+08     2.362889e+08  6.861804e+07          465648.0
#
#         Depreciation & Amortization  is_out_of_range
# 100217                    8333984.0            False
# 100232                    6890492.0            False
# 100226                    6516184.0            False
# 100237                    6648408.0            False
# 100235                    3959418.0            False
# 100223                    6171271.0            False
# 100227                    7770933.0            False
# 100228                    3380443.0            False
# 100231                    6451176.0            False
# 100234                    5182259.0            False
# 100236                    5131834.0            False
# 100229                    1177202.0            False
# 100224                    1850740.0            False
# 100222                    8707658.0            False
# 100233                    9222014.0            False
# 100219                    7207447.0            False
# 100215                     893469.0            False
# 100238                    4779709.0            False
# 100225                    6783417.0            False
# 100216                     954332.0            False
# 100230                    8275823.0            False
# 100220                    2914504.0            False
# 100218                    5272380.0            False
# 100221                    6418243.0            False
# 100214                    7264230.0            False
# 100213                    3620277.0            False
# 100239                    1485732.0            False

# %% [markdown]
# ### Partial Dataset: Operating Expenses, Revenue, Net Income, Revenue Growth

# %%
partial_df.columns
# Out:
# Index(['Stock', 'Year', 'Revenue', 'Revenue Growth', 'Operating Income',
#        'Net Income', 'Net Income Ratio', 'Gross Profit', 'Gross Profit Ratio',
#        'Operating Expenses', 'Cost of Revenue', 'EBITDA', 'Interest Expense',
#        'Depreciation & Amortization', 'is_out_of_range'],
#       dtype='object')

# %%
partial_df[['Operating Expenses', 'Interest Expense', 'Net Income', 'Revenue Growth']]
# Out:
#       Operating Expenses  Interest Expense    Net Income  Revenue Growth
# 0           1.985750e+11      5.003000e+09           NaN             NaN
# 1                    NaN      4.352000e+09 -2.281900e+10             NaN
# 2                    NaN      2.774000e+07  1.591611e+09             NaN
# 3                    NaN      3.952400e+07  1.725575e+09             NaN
# 4                    NaN      8.970000e+08  4.289000e+09             NaN
# ...                  ...               ...           ...             ...
# 8091        8.673782e+08      3.752040e+05  1.250442e+08        0.099316
# 8092        3.170169e+08      3.799450e+05  1.819399e+08        0.181497
# 8093        1.070119e+08      4.119530e+05  2.865713e+06        0.020694
# 8094        1.300899e+08      3.788180e+05           NaN        0.001772
# 8095                 NaN      8.065550e+05  2.098682e+08        0.145031
#
# [8093 rows x 4 columns]

# %% [markdown]
# #### Operating Expenses = Gross Profit - Operating Income

# %%
# Fill NaN in 'Operating Expenses' only if both 'Gross Profit' and 'Operating Income' are available
partial_df['Operating Expenses'] = partial_df.apply(
    lambda row: row['Gross Profit'] - row['Operating Income']
    if pd.isna(row['Operating Expenses']) and pd.notna(row['Gross Profit']) and pd.notna(row['Operating Income'])
    else row['Operating Expenses'], axis=1
)

# %%
partial_df[['Operating Expenses', 'Gross Profit', 'Operating Income']]
# Out:
#       Operating Expenses  Gross Profit  Operating Income
# 0           1.985750e+11  1.231960e+11      1.231960e+11
# 1           1.368560e+11  1.098710e+11     -2.698500e+10
# 2           6.612360e+08  2.483691e+09      1.822455e+09
# 3           7.068320e+08  2.876016e+09      2.169184e+09
# 4           1.552500e+10  2.136000e+10      5.835000e+09
# ...                  ...           ...               ...
# 8091        8.673782e+08  9.927977e+08      1.254194e+08
# 8092        3.170169e+08  4.993368e+08      1.823199e+08
# 8093        1.070119e+08  1.102896e+08      3.277666e+06
# 8094        1.300899e+08  1.837651e+08      5.367525e+07
# 8095        3.717289e+08  5.824036e+08      2.106748e+08
#
# [8093 rows x 3 columns]

# %%
# Check if Operating Expenses still has NaN
if partial_df['Operating Expenses'].isna().any():
    print("Yes, there are still NaN values.")
    print(partial_df[partial_df['Operating Expenses'].isna()])
else:
    print("No more NaN values")
# Out:
# No more NaN values

# %%
print(missing_values_check(partial_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 2                       Revenue                   1619   20.004943
# 5                    Net Income                    810   10.008649
# 3                Revenue Growth                     91    1.124429
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 4              Operating Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000

# %% [markdown]
# #### Net Income = Operating Income - Interest Expense

# %%
# Fill NaN in 'Net Income' only when Operating Income, Interest Expense are available
partial_df['Net Income'] = partial_df.apply(
    lambda row: row['Operating Income'] - row['Interest Expense']
    if pd.isna(row['Net Income']) and pd.notna(row['Operating Income']) and pd.notna(row['Interest Expense'])
    else row['Net Income'],
    axis=1
)

# %%
partial_df[['Net Income', 'Operating Income', 'Interest Expense']]
# Out:
#         Net Income  Operating Income  Interest Expense
# 0     1.181930e+11      1.231960e+11      5.003000e+09
# 1    -2.281900e+10     -2.698500e+10      4.352000e+09
# 2     1.591611e+09      1.822455e+09      2.774000e+07
# 3     1.725575e+09      2.169184e+09      3.952400e+07
# 4     4.289000e+09      5.835000e+09      8.970000e+08
# ...            ...               ...               ...
# 8091  1.250442e+08      1.254194e+08      3.752040e+05
# 8092  1.819399e+08      1.823199e+08      3.799450e+05
# 8093  2.865713e+06      3.277666e+06      4.119530e+05
# 8094  5.329643e+07      5.367525e+07      3.788180e+05
# 8095  2.098682e+08      2.106748e+08      8.065550e+05
#
# [8093 rows x 3 columns]

# %%
# Check if Net Income still has NaN
if partial_df['Net Income'].isna().any():
    print("Yes, there are still NaN values.")
    print(partial_df[partial_df['Net Income'].isna()])
else:
    print("No more NaN values")
# Out:
# No more NaN values

# %%
print(missing_values_check(partial_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 2                       Revenue                   1619   20.004943
# 3                Revenue Growth                     91    1.124429
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 4              Operating Income                      0    0.000000
# 5                    Net Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000

# %% [markdown]
# #### Revenue = Gross Profit + Cost of Revenue

# %%
# Fill NaN in 'Revenue' only when Gross Profit and Cost of Revenue are available
partial_df['Revenue'] = partial_df.apply(
    lambda row: row['Gross Profit'] + row['Cost of Revenue']
    if pd.isna(row['Revenue']) and pd.notna(row['Gross Profit']) and pd.notna(row['Cost of Revenue'])
    else row['Revenue'],
    axis=1
)

# %%
partial_df[['Revenue', 'Gross Profit', 'Cost of Revenue']]
# Out:
#            Revenue  Gross Profit  Cost of Revenue
# 0     3.644820e+11  1.231960e+11     2.412860e+11
# 1     2.341900e+11  1.098710e+11     1.243190e+11
# 2     9.534889e+09  2.483691e+09     7.051198e+09
# 3     1.053829e+10  2.876016e+09     7.662271e+09
# 4     2.136500e+10  2.136000e+10     5.000000e+06
# ...            ...           ...              ...
# 8091  2.239456e+09  9.927977e+08     1.246658e+09
# 8092  1.037629e+09  4.993368e+08     5.382918e+08
# 8093  2.750769e+08  1.102896e+08     1.647873e+08
# 8094  4.155206e+08  1.837651e+08     2.317555e+08
# 8095  1.548388e+09  5.824036e+08     9.659840e+08
#
# [8093 rows x 3 columns]

# %%
# Check if Revenue still has NaN values
if partial_df['Revenue'].isna().any():
    print("Yes, there are still NaN values.")
    print(partial_df[partial_df['Revenue'].isna()])
else:
    print("No more NaN values")
# Out:
# No more NaN values

# %%
print(missing_values_check(partial_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 3                Revenue Growth                     91    1.124429
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 2                       Revenue                      0    0.000000
# 4              Operating Income                      0    0.000000
# 5                    Net Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000

# %% [markdown]
# #### Revenue Growth = % Change in Revenue from Previous Year

# %%
# For each stock, fill in revenue growth NaN based on revenue in the previous year
# Ensure 'Year' column is in integer format
partial_df['Year'] = partial_df['Year'].astype(int)

# Sort by stock and year
partial_df = partial_df.sort_values(by=['Stock', 'Year'])

# Calculate revenue growth where it is NaN
partial_df['Revenue Growth'] = partial_df.groupby('Stock')['Revenue'].apply(
    lambda x: x.pct_change().fillna(0)
).reset_index(level=0, drop=True)  # Reset the group index, drop the group level

# %%
partial_df[['Stock', 'Year', 'Revenue', 'Revenue Growth']]
# Out:
#        Stock  Year       Revenue  Revenue Growth
# 5007   AAFRW  2022  7.097898e+08        0.000000
# 130    AAFRW  2023  2.947645e+07       -0.958472
# 1077  AAHFBX  2022  1.148219e+09        0.000000
# 2326  AAHFBX  2023  1.223013e+09        0.065139
# 2447    AALB  2022  1.012524e+09        0.000000
# ...      ...   ...           ...             ...
# 2011    ZZWA  2023  1.292421e+09       -0.302745
# 5625  ZZZBKF  2022  2.321441e+08        0.000000
# 753   ZZZBKF  2023  3.261039e+08        0.404748
# 6105   ZZZBQ  2022  1.128191e+09        0.000000
# 269    ZZZBQ  2023  8.445354e+08       -0.251425
#
# [8093 rows x 4 columns]

# %% [markdown]
# ### Historical Dataset: Gross Profit, Cost of Revenue, Revenue

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 4     Gross_Profit                    599   65.250545
# 5     Gross Profit                    580   63.180828
# 3  Cost of Revenue                    261   28.431373
# 2          Revenue                    185   20.152505
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 6  is_out_of_range                      0    0.000000

# %% [markdown]
# At this point, we also drop the 'Gross_Profit' column as it is a duplicate to the actual 'Gross Profit'.

# %%
historical_df = historical_df.drop(columns=['Gross_Profit'])

# %% [markdown]
# #### Gross Profit = Revenue - Cost of Revenue

# %%
# Fill NaN in 'Gross Profit' only when Revenue and Cost of Revenue are available
historical_df['Gross Profit'] = historical_df.apply(
    lambda row: row['Revenue'] - row['Cost of Revenue']
    if pd.isna(row['Gross Profit']) and pd.notna(row['Revenue']) and pd.notna(row['Cost of Revenue'])
    else row['Gross Profit'],
    axis=1
)

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    261   28.431373
# 4     Gross Profit                    261   28.431373
# 2          Revenue                    185   20.152505
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000

# %% [markdown]
# #### Cost of Revenue = Revenue - Gross Profit

# %%
# Fill NaN in 'Cost of Revenue' only when Revenue and Gross Profit are available
historical_df['Cost of Revenue'] = historical_df.apply(
    lambda row: row['Revenue'] - row['Gross Profit']
    if pd.isna(row['Cost of Revenue']) and pd.notna(row['Revenue']) and pd.notna(row['Gross Profit'])
    else row['Cost of Revenue'],
    axis=1
)

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    261   28.431373
# 4     Gross Profit                    261   28.431373
# 2          Revenue                    185   20.152505
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000

# %% [markdown]
# #### Revenue = Cost of Revenue + Gross Profit

# %%
# Fill NaN in 'Revenue' only when Cost of Revenue and Gross Profit are available
historical_df['Revenue'] = historical_df.apply(
    lambda row: row['Cost of Revenue'] + row['Gross Profit']
    if pd.isna(row['Revenue']) and pd.notna(row['Cost of Revenue']) and pd.notna(row['Gross Profit'])
    else row['Revenue'],
    axis=1
)

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    261   28.431373
# 4     Gross Profit                    261   28.431373
# 2          Revenue                    185   20.152505
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000

# %%
# Check the shape of Historical Dataset
historical_df.shape
# Out:
# (918, 6)

# %%
# Remove rows with no Revenue
historical_df = historical_df.drop(historical_df[historical_df['Revenue'].isna()].index)

# %% [markdown]
# #### Drop helper columns

# %%
expanded_df = expanded_df.drop(columns=['is_out_of_range'])

# %%
partial_df = partial_df.drop(columns=['is_out_of_range'])

# %%
historical_df = historical_df.drop(columns=['is_out_of_range'])

# %%
sparse_df = sparse_df.drop(columns=['is_out_of_range'])

# %%
print(missing_values_check(sparse_df))
# Out:
#     Column  No. of Missing Values  Percentage
# 0    Stock                      0         0.0
# 1     Year                      0         0.0
# 2  Revenue                      0         0.0

# %% [markdown]
# ### Checking Actual vs Expected value of columns

# %% [markdown]
# For each financial metric, the actual values might not follow the expected values.
#
# For example, if EBITDA = Operating Income - Depreciation & Amortization, the actual value might not follow this formula.
#
# This could be because there are adjustments in real-world reporting or human error from inputting the incorrect value, which can result in them to be there by default.
#
# Depending on how many rows are mismatched for each financial metric, we will decide whether to retain these mismatched rows for analysis later on.

# %% [markdown]
# #### Checking EBITDA (Operating Income - D&A)

# %%
def ebitda_calculation(df):
    # Calculate expected EBITDA
    df['expected_EBITDA'] = df['Operating Income'] + df['Depreciation & Amortization']
    # Compare expected EBITDA with the actual EBITDA, also considering small floating-point differences
    df['EBITDA_match'] = np.isclose(df['expected_EBITDA'], df['EBITDA'])

# %%
ebitda_calculation(expanded_df)

# %%
ebitda_calculation(partial_df)

# %%
# 181 out of 100213 rows in Expanded Dataset still do not match the expected EBITDA formula.
expanded_df[expanded_df['EBITDA_match'] == False]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 181 out of 100213 rows in Expanded Dataset still do not match the expected EBITDA formula.
# ----> 2 expanded_df[expanded_df['EBITDA_match'] == False]
#
# NameError: name 'expanded_df' is not defined

# %%
# 79 out of 8093 rows in Partial Dataset still do not match the expected EBITDA formula
partial_df[partial_df['EBITDA_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 216     ARGX  2022  4.107460e+08        0.000000     -7.196630e+08
# 217     ARGX  2023  1.226316e+09        1.985582     -4.250490e+08
# 232     ASML  2022  2.117340e+10        0.000000      7.321000e+09
# 276    AVGOP  2022  3.320300e+10        0.000000      1.422500e+10
# 277    AVGOP  2023  3.581900e+10        0.078788      1.620700e+10
# ...      ...   ...           ...             ...               ...
# 6468     URI  2022  1.164200e+10        0.000000      3.232000e+09
# 6469     URI  2023  1.433200e+10        0.231060      3.827000e+09
# 6478  USB-PA  2023  2.801300e+10        0.000000      7.846000e+09
# 6899  WFC-PL  2022  7.378500e+10        0.000000      1.497000e+10
# 7080     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 216  -7.095940e+08         -1.727574  3.813150e+08            0.928347
# 217  -2.950530e+08         -0.240601  1.108481e+09            0.903911
# 232   5.624200e+09          0.265626  1.051270e+10            0.496505
# 276   1.149500e+10          0.346204  2.209500e+10            0.665452
# 277   1.458500e+10          0.393143  2.469000e+10            0.689299
# ...            ...               ...           ...                 ...
# 6468  2.787000e+09          0.180811  4.996000e+09            0.429136
# 6469  2.424000e+09          0.169132  5.813000e+09            0.405596
# 6478  5.429000e+09          0.193803  2.801300e+10            1.000000
# 6899  1.367700e+10          0.185363  7.378500e+10            1.000000
# 7080 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#       Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 216         1.100978e+09     2.943100e+07 -5.820093e+08      3.906000e+06
# 217         1.533530e+09     1.178350e+08 -2.160230e+08      9.040000e+05
# 232         3.191700e+09     1.066070e+10  6.997600e+09      6.080000e+07
# 276         7.813000e+09     1.110800e+10  1.915500e+10      1.737000e+09
# 277         8.483000e+09     1.112900e+10  2.055400e+10      1.622000e+09
# ...                  ...              ...           ...               ...
# 6468        1.764000e+09     6.646000e+09  5.464000e+09      4.450000e+08
# 6469        2.094000e+09     8.519000e+09  6.627000e+09      6.350000e+08
# 6478        2.801300e+10     0.000000e+00  7.855000e+09      1.261100e+10
# 6899        5.881500e+10     0.000000e+00  2.227800e+10      9.074000e+09
# 7080        1.760000e+08     9.860000e+07 -1.039000e+08      4.030000e+07
#
#       Depreciation & Amortization  expected_EBITDA  EBITDA_match
# 216                  1.043420e+08    -6.153210e+08         False
# 217                  1.114794e+08    -3.135696e+08         False
# 232                  6.407000e+08     7.961700e+09         False
# 276                  4.984000e+09     1.920900e+10         False
# 277                  3.835000e+09     2.004200e+10         False
# ...                           ...              ...           ...
# 6468                 2.217000e+09     5.449000e+09         False
# 6469                 2.781000e+09     6.608000e+09         False
# 6478                 1.018000e+09     8.864000e+09         False
# 6899                 7.309000e+09     2.227900e+10         False
# 7080                 5.200000e+06     8.797000e+08         False
#
# [79 rows x 16 columns]

# %% [markdown]
# #### Checking Net Income (Operating Income - Interest Expense)

# %%
def netincome_calculation(df):
    # Calculate expected net income
    df['expected_netincome'] = df['Operating Income'] - df['Interest Expense']
    # Compare expected net income with the actual net income, also considering small floating-point differences
    df['netincome_match'] = np.isclose(df['expected_netincome'], df['Net Income'])

# %%
netincome_calculation(expanded_df)

# %%
expanded_df.columns
# Out:
# Index(['Stock', 'Year', 'Revenue', 'Revenue Growth', 'Operating Income',
#        'Net Income', 'Net Income Ratio', 'Gross Profit', 'Gross Profit Ratio',
#        'Operating Expenses', 'Cost of Revenue', 'EBITDA', 'Interest Expense',
#        'Depreciation & Amortization', 'expected_EBITDA', 'EBITDA_match',
#        'expected_netincome', 'netincome_match', 'expected_netincome_ratio',
#        'netincomeratio_match', 'expected_grossprofit_ratio',
#        'grossprofitratio_match', 'expected_grossprofit', 'grossprofit_match',
#        'expected_revenue', 'revenue_match', 'expected_revenuegrowth',
#        'revenuegrowth_match', 'expected_costofrevenue', 'costofrevenue_match',
#        'expected_operatingincome', 'operatingincome_match',
#        'expected_operatingexpenses', 'operatingexpenses_match',
#        'expected_depreciationamortization', 'depreciationamortization_match'],
#       dtype='object')

# %%
netincome_calculation(partial_df)

# %%
# 213 out of 100213 rows in Expanded Dataset still do not match the expected Net Income formula
expanded_df[expanded_df['netincome_match'] == False]
# Out:
#         Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 2699     ARGX  2019  7.811609e+07       -0.469980     -1.998759e+08
# 2700     ARGX  2020  4.484817e+07        2.949865     -5.143769e+08
# 2701     ARGX  2021  4.972770e+08        0.120119     -3.487460e+08
# 2702     ARGX  2022  4.107460e+08        0.138077     -7.196630e+08
# 2703     ARGX  2023  1.226316e+09        0.000000     -4.250490e+08
# ...       ...   ...           ...             ...               ...
# 85312  WFC-PL  2019  8.506300e+10       -0.441807      2.596700e+10
# 85313  WFC-PL  2020  7.234000e+10       -0.666893      4.041000e+09
# 85314  WFC-PL  2021  7.849200e+10       -0.496299      2.885100e+10
# 85315  WFC-PL  2022  7.378500e+10       -0.178047      1.497000e+10
# 87566     WTM  2022  1.157900e+09       16.772178      8.745000e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 2699  -1.824254e+08         -2.335311 -1.185681e+08           -1.517845
# 2700  -6.512349e+08        -14.520879 -2.590780e+08           -5.776780
# 2701  -4.082650e+08         -0.821001 -1.276787e+07           -0.025676
# 2702  -7.095940e+08         -1.727574  3.813150e+08            0.928347
# 2703  -2.950530e+08         -0.240601  1.108481e+09            0.903911
# ...             ...               ...           ...                 ...
# 85312  1.971500e+10          0.231769  8.506300e+10            1.000000
# 85313  1.786000e+09          0.024689  7.234000e+10            1.000000
# 85314  2.210900e+10          0.281672  7.849200e+10            1.000000
# 85315  1.367700e+10          0.185363  7.378500e+10            1.000000
# 87566 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#        Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 2699         2.792189e+08      196684207.0 -1.776956e+08      1.388070e+05
# 2700         5.623561e+08      303926197.0 -6.016670e+08      1.740983e+06
# 2701         8.460230e+08      510044872.0 -3.144211e+08      1.096000e+06
# 2702         1.100978e+09       29431000.0 -5.820093e+08      3.906000e+06
# 2703         1.533530e+09      117835000.0 -2.160230e+08      9.040000e+05
# ...                   ...              ...           ...               ...
# 85312        5.826000e+10              0.0  0.000000e+00      1.885200e+10
# 85313        5.766700e+10              0.0  0.000000e+00      7.963000e+09
# 85314        5.379000e+10              0.0  3.731000e+10      3.915000e+09
# 85315        5.727800e+10              0.0  2.227800e+10      9.074000e+09
# 87566        1.760000e+08       98600000.0 -1.039000e+08      4.030000e+07
#
#        Depreciation & Amortization  expected_EBITDA  EBITDA_match  \
# 2699                  2.424651e+06    -1.974513e+08         False
# 2700                  4.221946e+06    -5.101549e+08         False
# 2701                  5.867000e+06    -3.428790e+08         False
# 2702                  1.043420e+08    -6.153210e+08         False
# 2703                  1.114794e+08    -3.135696e+08         False
# ...                            ...              ...           ...
# 85312                 7.923000e+09     3.389000e+10         False
# 85313                 8.974000e+09     1.301500e+10         False
# 85314                 8.494000e+09     3.734500e+10         False
# 85315                 7.309000e+09     2.227900e+10         False
# 87566                 5.200000e+06     8.797000e+08         False
#
#        expected_netincome  netincome_match
# 2699        -2.000147e+08            False
# 2700        -5.161178e+08            False
# 2701        -3.498420e+08            False
# 2702        -7.235690e+08            False
# 2703        -4.259530e+08            False
# ...                   ...              ...
# 85312        7.115000e+09            False
# 85313       -3.922000e+09            False
# 85314        2.493600e+10            False
# 85315        5.896000e+09            False
# 87566        8.342000e+08            False
#
# [213 rows x 18 columns]

# %%
# 81 out of 8093 rows in Partial Dataset still do not match the expected Net Income formula
partial_df[partial_df['netincome_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 216     ARGX  2022  4.107460e+08        0.000000     -7.196630e+08
# 217     ARGX  2023  1.226316e+09        1.985582     -4.250490e+08
# 232     ASML  2022  2.117340e+10        0.000000      7.321000e+09
# 233     ASML  2023  2.755850e+10        0.301562      9.042300e+09
# 276    AVGOP  2022  3.320300e+10        0.000000      1.422500e+10
# ...      ...   ...           ...             ...               ...
# 6211     TYL  2023  1.951751e+09        0.054884      2.185370e+08
# 6469     URI  2023  1.433200e+10        0.231060      3.827000e+09
# 6478  USB-PA  2023  2.801300e+10        0.000000      7.846000e+09
# 6899  WFC-PL  2022  7.378500e+10        0.000000      1.497000e+10
# 7080     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 216  -7.095940e+08         -1.727574  3.813150e+08            0.928347
# 217  -2.950530e+08         -0.240601  1.108481e+09            0.903911
# 232   5.624200e+09          0.265626  1.051270e+10            0.496505
# 233   7.839000e+09          0.284449  1.413610e+10            0.512949
# 276   1.149500e+10          0.346204  2.209500e+10            0.665452
# ...            ...               ...           ...                 ...
# 6211  1.659190e+08          0.085010  7.864670e+08            0.402955
# 6469  2.424000e+09          0.169132  5.813000e+09            0.405596
# 6478  5.429000e+09          0.193803  2.801300e+10            1.000000
# 6899  1.367700e+10          0.185363  7.378500e+10            1.000000
# 7080 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#       Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 216         1.100978e+09     2.943100e+07 -5.820093e+08      3.906000e+06
# 217         1.533530e+09     1.178350e+08 -2.160230e+08      9.040000e+05
# 232         3.191700e+09     1.066070e+10  6.997600e+09      6.080000e+07
# 233         5.093800e+09     1.342240e+10  9.698700e+09      1.527000e+08
# 276         7.813000e+09     1.110800e+10  1.915500e+10      1.737000e+09
# ...                  ...              ...           ...               ...
# 6211        5.679300e+08     1.165284e+09  3.926320e+08      2.362900e+07
# 6469        2.094000e+09     8.519000e+09  6.627000e+09      6.350000e+08
# 6478        2.801300e+10     0.000000e+00  7.855000e+09      1.261100e+10
# 6899        5.881500e+10     0.000000e+00  2.227800e+10      9.074000e+09
# 7080        1.760000e+08     9.860000e+07 -1.039000e+08      4.030000e+07
#
#       Depreciation & Amortization  expected_EBITDA  EBITDA_match  \
# 216                  1.043420e+08    -6.153210e+08         False
# 217                  1.114794e+08    -3.135696e+08         False
# 232                  6.407000e+08     7.961700e+09         False
# 233                  6.564000e+08     9.698700e+09          True
# 276                  4.984000e+09     1.920900e+10         False
# ...                           ...              ...           ...
# 6211                 1.707670e+08     3.893040e+08         False
# 6469                 2.781000e+09     6.608000e+09         False
# 6478                 1.018000e+09     8.864000e+09         False
# 6899                 7.309000e+09     2.227900e+10         False
# 7080                 5.200000e+06     8.797000e+08         False
#
#       expected_netincome  netincome_match
# 216        -7.235690e+08            False
# 217        -4.259530e+08            False
# 232         7.260200e+09            False
# 233         8.889600e+09            False
# 276         1.248800e+10            False
# ...                  ...              ...
# 6211        1.949080e+08            False
# 6469        3.192000e+09            False
# 6478       -4.765000e+09            False
# 6899        5.896000e+09            False
# 7080        8.342000e+08            False
#
# [81 rows x 18 columns]

# %% [markdown]
# #### Checking Gross Profit (Revenue - Cost of Revenue)

# %%
def grossprofit_calculation(df):
    # Calculate expected gross profit
    df['expected_grossprofit'] = df['Revenue'] - df['Cost of Revenue']
    
    # Compare expected gross profit with the actual gross profit, considering small floating-point differences
    df['grossprofit_match'] = np.isclose(df['expected_grossprofit'], df['Gross Profit'])

# %%
grossprofit_calculation(expanded_df)

# %%
grossprofit_calculation(partial_df)

# %%
# 4 out of 100213 rows in Expanded Dataset still do not match the expected Gross Profit formula
expanded_df[expanded_df['grossprofit_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 4273  BAC-PL  2019  8.558200e+10       -0.764196      3.884000e+10
# 4274  BAC-PL  2020  7.420800e+10        9.220948      2.572500e+10
# 4275  BAC-PL  2021  9.370700e+10       -0.894823      4.094600e+10
# 4276  BAC-PL  2022  9.240700e+10        0.243336      3.864300e+10
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 4273  2.743000e+10          0.320511           0.0                 0.0
# 4274  1.789400e+10          0.241133           0.0                 0.0
# 4275  3.197800e+10          0.341255           0.0                 0.0
# 4276  2.752800e+10          0.297900           0.0                 0.0
#
#       Operating Expenses  ...  expected_EBITDA  EBITDA_match  \
# 4273        4.674200e+10  ...     4.056900e+10         False
# 4274        4.848300e+10  ...     2.756800e+10         False
# 4275        5.276100e+10  ...     4.284400e+10         False
# 4276        5.376400e+10  ...     4.062100e+10         False
#
#       expected_netincome  netincome_match  expected_netincome_ratio  \
# 4273        1.649500e+10            False                  0.320511
# 4274        1.750000e+10            False                  0.241133
# 4275        3.620800e+10            False                  0.341255
# 4276        1.854000e+10            False                  0.297900
#
#       netincomeratio_match  expected_grossprofit_ratio  \
# 4273                  True                         0.0
# 4274                  True                         0.0
# 4275                  True                         0.0
# 4276                  True                         0.0
#
#       grossprofitratio_match  expected_grossprofit  grossprofit_match
# 4273                    True          8.558200e+10              False
# 4274                    True          7.420800e+10              False
# 4275                    True          9.370700e+10              False
# 4276                    True          9.240700e+10              False
#
# [4 rows x 24 columns]

# %%
# Only 1 row in Partial Dataset does not match
partial_df[partial_df['grossprofit_match'] == False]
# Out:
#       Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 350  BAC-PL  2022  9.240700e+10             0.0      3.864300e+10
#
#        Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 350  1.854000e+10            0.2979           0.0                 0.0
#
#      Operating Expenses  ...  expected_EBITDA  EBITDA_match  \
# 350       -3.864300e+10  ...     4.062100e+10         False
#
#      expected_netincome  netincome_match  expected_netincome_ratio  \
# 350        1.854000e+10             True                  0.200634
#
#      netincomeratio_match  expected_grossprofit_ratio  grossprofitratio_match  \
# 350                 False                         0.0                    True
#
#      expected_grossprofit  grossprofit_match
# 350          9.240700e+10              False
#
# [1 rows x 24 columns]

# %% [markdown]
# #### Checking Net Income Ratio (Net Income / Revenue)

# %%
def netincomeratio_calculation(df):
    # Calculate expected net income ratio
    df['expected_netincome_ratio'] = df['Net Income'] / df['Revenue']
    
    # Handle the case where Revenue is zero to avoid division by zero
    df['expected_netincome_ratio'] = df['expected_netincome_ratio'].where(df['Revenue'] != 0, 0)
    
    # Compare expected net income ratio with the actual net income ratio, considering small floating-point differences
    df['netincomeratio_match'] = np.isclose(df['expected_netincome_ratio'], df['Net Income Ratio'])

# %%
netincomeratio_calculation(expanded_df)

# %%
netincomeratio_calculation(partial_df)

# %%
# All rows in Expanded Dataset match
expanded_df[expanded_df['netincomeratio_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_grossprofit, grossprofit_match, expected_operatingincome, operatingincome_match]
# Index: []
#
# [0 rows x 26 columns]

# %%
# 10 out of 8093 rows in Partial Dataset still do not match the expected Net Income Ratio formula
partial_df[partial_df['netincomeratio_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 277    AVGOP  2023  3.581900e+10        0.078788      1.620700e+10
# 315     AXON  2023  1.563391e+09        0.313846      1.547890e+08
# 341      AZO  2023  1.745721e+10        0.074142      3.473986e+09
# 350   BAC-PL  2022  9.240700e+10        0.000000      3.864300e+10
# 591    BRK-A  2023  3.644820e+11        0.556352      1.231960e+11
# 1080  DHR-PA  2022  3.147100e+10        0.000000      8.688000e+09
# 1704    FICO  2022  1.377270e+09        0.000000      5.424140e+08
# 5340    REGN  2022  1.217290e+10        0.000000      4.738900e+09
# 6097     TPL  2023  6.315950e+08       -0.053680      4.860530e+08
# 6468     URI  2022  1.164200e+10        0.000000      3.232000e+09
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 277   1.458500e+10          0.393143  2.469000e+10            0.689299
# 315   1.477940e+08          0.111442  9.553820e+08            0.611096
# 341   3.167614e+09          0.144836  9.070422e+09            0.519580
# 350   1.854000e+10          0.297900  0.000000e+00            0.000000
# 591   1.181930e+11          0.263999  1.231960e+11            0.338003
# 1080  8.477000e+09          0.229068  1.894900e+10            0.602110
# 1704  4.734470e+08          0.271218  1.075096e+09            0.780599
# 5340  4.679500e+09          0.356398  1.061250e+10            0.871814
# 6097  4.860530e+08          0.642255  5.832720e+08            0.923491
# 6468  2.787000e+09          0.180811  4.996000e+09            0.429136
#
#       Operating Expenses  ...  expected_netincome  netincome_match  \
# 277         8.483000e+09  ...        1.458500e+10             True
# 315         8.005930e+08  ...        1.477940e+08             True
# 341         5.596436e+09  ...        3.167614e+09             True
# 350        -3.864300e+10  ...        1.854000e+10             True
# 591         1.985750e+11  ...        1.181930e+11             True
# 1080        1.026100e+10  ...        8.477000e+09             True
# 1704        5.326820e+08  ...        4.734470e+08             True
# 5340        5.618500e+09  ...        4.679500e+09             True
# 6097        9.721900e+07  ...        4.860530e+08             True
# 6468        1.764000e+09  ...        2.787000e+09             True
#
#       expected_netincome_ratio  netincomeratio_match  \
# 277                   0.407186                 False
# 315                   0.094534                 False
# 341                   0.181450                 False
# 350                   0.200634                 False
# 591                   0.324277                 False
# 1080                  0.269359                 False
# 1704                  0.343758                 False
# 5340                  0.384419                 False
# 6097                  0.769564                 False
# 6468                  0.239392                 False
#
#       expected_grossprofit_ratio  grossprofitratio_match  \
# 277                     0.689299                    True
# 315                     0.611096                    True
# 341                     0.519580                    True
# 350                     0.000000                    True
# 591                     0.338003                    True
# 1080                    0.602110                    True
# 1704                    0.780599                    True
# 5340                    0.871814                    True
# 6097                    0.923491                    True
# 6468                    0.429136                    True
#
#       expected_grossprofit  grossprofit_match  expected_operatingincome  \
# 277           2.469000e+10               True              1.620700e+10
# 315           9.553820e+08               True              1.547890e+08
# 341           9.070422e+09               True              3.473986e+09
# 350           9.240700e+10              False              3.864300e+10
# 591           1.231960e+11               True             -7.537900e+10
# 1080          1.894900e+10               True              8.688000e+09
# 1704          1.075096e+09               True              5.424140e+08
# 5340          1.061250e+10               True              4.994000e+09
# 6097          5.832720e+08               True              4.860530e+08
# 6468          4.996000e+09               True              3.232000e+09
#
#       operatingincome_match
# 277                    True
# 315                    True
# 341                    True
# 350                    True
# 591                   False
# 1080                   True
# 1704                   True
# 5340                  False
# 6097                   True
# 6468                   True
#
# [10 rows x 26 columns]

# %% [markdown]
# #### Checking Gross Profit Ratio (Gross Profit / Revenue)

# %%
def grossprofitratio_calculation(df):
    # Calculate expected gross profit ratio
    df['expected_grossprofit_ratio'] = df['Gross Profit'] / df['Revenue']
    
    # Handle the case where Revenue is zero to avoid division by zero
    df['expected_grossprofit_ratio'] = df['expected_grossprofit_ratio'].where(df['Revenue'] != 0, 0)
    
    # Compare expected gross profit ratio with the actual gross profit ratio, considering small floating-point differences
    df['grossprofitratio_match'] = np.isclose(df['expected_grossprofit_ratio'], df['Gross Profit Ratio'])

# %%
grossprofitratio_calculation(expanded_df)

# %%
grossprofitratio_calculation(partial_df)

# %%
# All rows in Expanded Dataset match
expanded_df[expanded_df['grossprofitratio_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match]
# Index: []
#
# [0 rows x 22 columns]

# %%
# All rows in Partial Dataset match
partial_df[partial_df['grossprofitratio_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# #### Checking Revenue (Gross Profit + Cost of Revenue)

# %%
def revenue_calculation(df):
    # Calculate expected revenue
    df['expected_revenue'] = df['Gross Profit'] + df['Cost of Revenue']

    # Compare expected revenue with the actual revenue, considering small floating-point differences
    df['revenue_match'] = np.isclose(df['expected_revenue'], df['Revenue'])

# %%
revenue_calculation(expanded_df)

# %%
revenue_calculation(partial_df)

# %%
revenue_calculation(historical_df)

# %%
# 4 out of 100213 rows in Expanded Dataset still do not match
expanded_df[expanded_df['revenue_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 4273  BAC-PL  2019  8.558200e+10       -0.764196      3.884000e+10
# 4274  BAC-PL  2020  7.420800e+10        9.220948      2.572500e+10
# 4275  BAC-PL  2021  9.370700e+10       -0.894823      4.094600e+10
# 4276  BAC-PL  2022  9.240700e+10        0.243336      3.864300e+10
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 4273  2.743000e+10          0.320511           0.0                 0.0
# 4274  1.789400e+10          0.241133           0.0                 0.0
# 4275  3.197800e+10          0.341255           0.0                 0.0
# 4276  2.752800e+10          0.297900           0.0                 0.0
#
#       Operating Expenses  ...  expected_netincome  netincome_match  \
# 4273        4.674200e+10  ...        1.649500e+10            False
# 4274        4.848300e+10  ...        1.750000e+10            False
# 4275        5.276100e+10  ...        3.620800e+10            False
# 4276        5.376400e+10  ...        1.854000e+10            False
#
#       expected_netincome_ratio  netincomeratio_match  \
# 4273                  0.320511                  True
# 4274                  0.241133                  True
# 4275                  0.341255                  True
# 4276                  0.297900                  True
#
#       expected_grossprofit_ratio  grossprofitratio_match  \
# 4273                         0.0                    True
# 4274                         0.0                    True
# 4275                         0.0                    True
# 4276                         0.0                    True
#
#       expected_grossprofit  grossprofit_match  expected_revenue  revenue_match
# 4273          8.558200e+10              False               0.0          False
# 4274          7.420800e+10              False               0.0          False
# 4275          9.370700e+10              False               0.0          False
# 4276          9.240700e+10              False               0.0          False
#
# [4 rows x 26 columns]

# %%
# 1 out of 8093 rows in Partial Dataset still does not match
partial_df[partial_df['revenue_match'] == False]
# Out:
#       Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 350  BAC-PL  2022  9.240700e+10             0.0      3.864300e+10
#
#        Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 350  1.854000e+10            0.2979           0.0                 0.0
#
#      Operating Expenses  ...  expected_netincome  netincome_match  \
# 350       -3.864300e+10  ...        1.854000e+10             True
#
#      expected_netincome_ratio  netincomeratio_match  \
# 350                  0.200634                 False
#
#      expected_grossprofit_ratio  grossprofitratio_match  expected_grossprofit  \
# 350                         0.0                    True          9.240700e+10
#
#      grossprofit_match  expected_revenue  revenue_match
# 350              False               0.0          False
#
# [1 rows x 26 columns]

# %%
false_rows = historical_df[historical_df['revenue_match'] == False]

all_nan = false_rows[['Cost of Revenue', 'Gross Profit']].isna().all().all()

# %%
# 76 out of 733 rows in Historical Dataset still do not match
# But we keep the 76 rows anyway because the mismatch is actually caused by NaN in the other columns
if all_nan:
    print("All rows of Cost of Revenue & Gross Profit are NaN")
else:
    print("Not all rows are NaN")
# Out:
# All rows of Cost of Revenue & Gross Profit are NaN

# %% [markdown]
# #### Checking Revenue Growth (% Change in Revenue from Previous Year)

# %%
def revenuegrowth_calculation(df):
    # Sort Stock and Year first
    df = df.sort_values(by=['Stock', 'Year'])
    
    # Calculate expected revenue growth
    df['expected_revenuegrowth'] = df.groupby('Stock')['Revenue'].pct_change()

    # Fill NaN values in expected_revenuegrowth (e.g., first year or missing data)
    df['expected_revenuegrowth'] = df['expected_revenuegrowth'].fillna(0)

    # Compare expected revenue growth with the actual revenue growth, considering small floating-point differences
    df['revenuegrowth_match'] = np.isclose(df['expected_revenuegrowth'], df['Revenue Growth'], atol=1e-2)

    return df

# %%
expanded_df = revenuegrowth_calculation(expanded_df)

# %%
partial_df = revenuegrowth_calculation(partial_df)

# %%
# Almost all rows in Expanded Dataset still do not match
expanded_df[expanded_df['revenuegrowth_match'] == False]

# We keep these rows but replace the original Revenue Growth with the expected numbers
expanded_df['Revenue Growth'] = expanded_df['expected_revenuegrowth']

# %%
# All rows in Partial Dataset match
partial_df[partial_df['revenuegrowth_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_grossprofit, grossprofit_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# #### Checking Cost of Revenue (Revenue - Gross Profit)

# %%
def costofrevenue_calculation(df):
    # Calculate expected cost of revenue
    df['expected_costofrevenue'] = df['Revenue'] - df['Gross Profit']

    # Compare expected cost of revenue with the actual cost of revenue, considering small floating-point differences
    df['costofrevenue_match'] = np.isclose(df['expected_costofrevenue'], df['Cost of Revenue'])

# %%
costofrevenue_calculation(expanded_df)

# %%
costofrevenue_calculation(partial_df)

# %%
# 4 out of 100213 rows in Expanded Dataset still do not match
expanded_df[expanded_df['costofrevenue_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 4273  BAC-PL  2019  8.558200e+10        0.000000      3.884000e+10
# 4274  BAC-PL  2020  7.420800e+10       -0.132902      2.572500e+10
# 4275  BAC-PL  2021  9.370700e+10        0.262761      4.094600e+10
# 4276  BAC-PL  2022  9.240700e+10       -0.013873      3.864300e+10
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 4273  2.743000e+10          0.320511           0.0                 0.0
# 4274  1.789400e+10          0.241133           0.0                 0.0
# 4275  3.197800e+10          0.341255           0.0                 0.0
# 4276  2.752800e+10          0.297900           0.0                 0.0
#
#       Operating Expenses  ...  expected_grossprofit_ratio  \
# 4273        4.674200e+10  ...                         0.0
# 4274        4.848300e+10  ...                         0.0
# 4275        5.276100e+10  ...                         0.0
# 4276        5.376400e+10  ...                         0.0
#
#       grossprofitratio_match  expected_grossprofit  grossprofit_match  \
# 4273                    True          8.558200e+10              False
# 4274                    True          7.420800e+10              False
# 4275                    True          9.370700e+10              False
# 4276                    True          9.240700e+10              False
#
#       expected_revenue  revenue_match  expected_revenuegrowth  \
# 4273               0.0          False                0.000000
# 4274               0.0          False               -0.132902
# 4275               0.0          False                0.262761
# 4276               0.0          False               -0.013873
#
#       revenuegrowth_match  expected_costofrevenue  costofrevenue_match
# 4273                False            8.558200e+10                False
# 4274                False            7.420800e+10                False
# 4275                False            9.370700e+10                False
# 4276                False            9.240700e+10                False
#
# [4 rows x 30 columns]

# %%
# 1 out of 8093 rows in Partial Dataset does not match
partial_df[partial_df['costofrevenue_match'] == False]
# Out:
#       Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 350  BAC-PL  2022  9.240700e+10             0.0      3.864300e+10
#
#        Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 350  1.854000e+10            0.2979           0.0                 0.0
#
#      Operating Expenses  ...  expected_grossprofit_ratio  \
# 350       -3.864300e+10  ...                         0.0
#
#      grossprofitratio_match  expected_grossprofit  grossprofit_match  \
# 350                    True          9.240700e+10              False
#
#      expected_revenue  revenue_match  expected_revenuegrowth  \
# 350               0.0          False                     0.0
#
#      revenuegrowth_match  expected_costofrevenue  costofrevenue_match
# 350                 True            9.240700e+10                False
#
# [1 rows x 30 columns]

# %% [markdown]
# #### Checking Operating Income (Gross Profit - Operating Expense)

# %%
def operatingincome_calculation(df):
    # Calculate expected operating income
    df['expected_operatingincome'] = df['Gross Profit'] - df['Operating Expenses']
    
    # Compare expected operating income with the actual operating income, considering small floating-point differences
    df['operatingincome_match'] = np.isclose(df['expected_operatingincome'], df['Operating Income'])

# %%
operatingincome_calculation(expanded_df)

# %%
operatingincome_calculation(partial_df)

# %%
# 99 out of 100213 rows in Expanded Dataset still do not match
expanded_df[expanded_df['operatingincome_match'] == False]
# Out:
#         Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 2699     ARGX  2019  7.811609e+07        0.000000     -1.998759e+08
# 2700     ARGX  2020  4.484817e+07       -0.425878     -5.143769e+08
# 2701     ARGX  2021  4.972770e+08       10.088010     -3.487460e+08
# 2881     ASML  2021  1.861100e+10        0.331402      6.750100e+09
# 3409    AVGOP  2020  2.388800e+10        0.000000      4.014000e+09
# ...       ...   ...           ...             ...               ...
# 85312  WFC-PL  2019  8.506300e+10        0.000000      2.596700e+10
# 85313  WFC-PL  2020  7.234000e+10       -0.149571      4.041000e+09
# 85314  WFC-PL  2021  7.849200e+10        0.085043      2.885100e+10
# 85315  WFC-PL  2022  7.378500e+10       -0.059968      1.497000e+10
# 87566     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 2699  -1.824254e+08         -2.335311 -1.185681e+08           -1.517845
# 2700  -6.512349e+08        -14.520879 -2.590780e+08           -5.776780
# 2701  -4.082650e+08         -0.821001 -1.276787e+07           -0.025676
# 2881   5.883200e+09          0.316114  9.809000e+09            0.527054
# 3409   2.960000e+09          0.123912  1.351600e+10            0.565807
# ...             ...               ...           ...                 ...
# 85312  1.971500e+10          0.231769  8.506300e+10            1.000000
# 85313  1.786000e+09          0.024689  7.234000e+10            1.000000
# 85314  2.210900e+10          0.281672  7.849200e+10            1.000000
# 85315  1.367700e+10          0.185363  7.378500e+10            1.000000
# 87566 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#        Operating Expenses  ...  expected_grossprofit  grossprofit_match  \
# 2699         2.792189e+08  ...         -1.185681e+08               True
# 2700         5.623561e+08  ...         -2.590780e+08               True
# 2701         8.460230e+08  ...         -1.276787e+07               True
# 2881         3.272600e+09  ...          9.809000e+09               True
# 3409         9.304000e+09  ...          1.351600e+10               True
# ...                   ...  ...                   ...                ...
# 85312        5.826000e+10  ...          8.506300e+10               True
# 85313        5.766700e+10  ...          7.234000e+10               True
# 85314        5.379000e+10  ...          7.849200e+10               True
# 85315        5.727800e+10  ...          7.378500e+10               True
# 87566        1.760000e+08  ...          1.059300e+09               True
#
#        expected_revenue  revenue_match  expected_revenuegrowth  \
# 2699       7.811609e+07           True                0.000000
# 2700       4.484817e+07           True               -0.425878
# 2701       4.972770e+08           True               10.088010
# 2881       1.861100e+10           True                0.331402
# 3409       2.388800e+10           True                0.000000
# ...                 ...            ...                     ...
# 85312      8.506300e+10           True                0.000000
# 85313      7.234000e+10           True               -0.149571
# 85314      7.849200e+10           True                0.085043
# 85315      7.378500e+10           True               -0.059968
# 87566      1.157900e+09           True                0.000000
#
#        revenuegrowth_match  expected_costofrevenue  costofrevenue_match  \
# 2699                 False            1.966842e+08                 True
# 2700                 False            3.039262e+08                 True
# 2701                 False            5.100449e+08                 True
# 2881                 False            8.802000e+09                 True
# 3409                 False            1.037200e+10                 True
# ...                    ...                     ...                  ...
# 85312                False            0.000000e+00                 True
# 85313                False            0.000000e+00                 True
# 85314                False            0.000000e+00                 True
# 85315                False            0.000000e+00                 True
# 87566                False            9.860000e+07                 True
#
#        expected_operatingincome  operatingincome_match
# 2699              -3.977870e+08                  False
# 2700              -8.214341e+08                  False
# 2701              -8.587909e+08                  False
# 2881               6.536400e+09                  False
# 3409               4.212000e+09                  False
# ...                         ...                    ...
# 85312              2.680300e+10                  False
# 85313              1.467300e+10                  False
# 85314              2.470200e+10                  False
# 85315              1.650700e+10                  False
# 87566              8.833000e+08                  False
#
# [99 rows x 32 columns]

# %%
# 23 out of 8093 rows in Partial Dataset still do not match
partial_df[partial_df['operatingincome_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 276    AVGOP  2022  3.320300e+10        0.000000      1.422500e+10
# 591    BRK-A  2023  3.644820e+11        0.556352      1.231960e+11
# 1092    DJCO  2022  5.400900e+07        0.000000      7.440000e+06
# 1476    EQIX  2022  7.263105e+09        0.000000      1.200528e+09
# 1625   FCNCA  2023  7.604000e+09        0.674521      3.331000e+09
# 1852  FTV-PA  2022  5.825700e+09        0.000000      9.874000e+08
# 2040     GHC  2022  3.924493e+09        0.000000      4.447160e+08
# 2152      GS  2022  4.736500e+10        0.000000      3.483200e+10
# 2153      GS  2023  4.625400e+10       -0.023456      2.642200e+10
# 2467    HUBS  2023  2.170230e+09        0.253766     -2.080560e+08
# 3262    KLAC  2022  9.211883e+09        0.000000      3.649576e+09
# 3512     LII  2022  4.718400e+09        0.000000      6.562000e+08
# 3560     LLY  2022  2.854140e+10        0.000000      7.127300e+09
# 3778    META  2022  1.166090e+11        0.000000      3.355500e+10
# 3862     MKL  2022  1.181554e+10        0.000000      8.786290e+08
# 3926    MPWR  2022  1.794148e+09        0.000000      5.267850e+08
# 3982     MTD  2022  3.919709e+09        0.000000      1.135540e+09
# 4782      PH  2022  1.586161e+10        0.000000      1.869478e+09
# 4783      PH  2023  1.906519e+10        0.201971      1.614226e+09
# 5340    REGN  2022  1.217290e+10        0.000000      4.738900e+09
# 6469     URI  2023  1.433200e+10        0.231060      3.827000e+09
# 6478  USB-PA  2023  2.801300e+10        0.000000      7.846000e+09
# 7080     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 276   1.149500e+10          0.346204  2.209500e+10            0.665452
# 591   1.181930e+11          0.263999  1.231960e+11            0.338003
# 1092 -7.562400e+07         -1.400211  1.166600e+07            0.216001
# 1476  7.043450e+08          0.096976  3.511604e+09            0.483485
# 1625  1.146600e+10          1.507891  4.080000e+09            0.536560
# 1852  7.552000e+08          0.129632  3.363400e+09            0.577338
# 2040  6.707900e+07          0.017092  1.266775e+09            0.322787
# 2152  1.126100e+10          0.237749  3.119100e+10            0.658524
# 2153  8.516000e+09          0.184114  2.970200e+10            0.642150
# 2467 -1.762950e+08         -0.081233  1.824741e+09            0.840805
# 3262  3.321807e+09          0.360600  5.619442e+09            0.610021
# 3512  4.971000e+08          0.105354  1.284700e+09            0.272274
# 3560  6.244800e+09          0.218798  2.191160e+10            0.767713
# 3778  2.320000e+10          0.198955  9.136000e+10            0.783473
# 3862 -1.012030e+08         -0.008565  1.163677e+10            0.984869
# 3926  4.376720e+08          0.243944  1.048552e+09            0.584429
# 3982  8.725020e+08          0.222594  2.308042e+09            0.588830
# 4782  1.315605e+09          0.082943  4.474341e+09            0.282086
# 4783  2.082936e+09          0.109253  6.429302e+09            0.337227
# 5340  4.679500e+09          0.356398  1.061250e+10            0.871814
# 6469  2.424000e+09          0.169132  5.813000e+09            0.405596
# 6478  5.429000e+09          0.193803  2.801300e+10            1.000000
# 7080 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#       Operating Expenses  ...  expected_netincome  netincome_match  \
# 276         7.813000e+09  ...        1.248800e+10            False
# 591         1.985750e+11  ...        1.181930e+11             True
# 1092        8.432000e+06  ...        6.331000e+06            False
# 1476        2.285261e+09  ...        8.441910e+08            False
# 1625        4.273000e+09  ...       -3.480000e+08            False
# 1852        2.358100e+09  ...        8.891000e+08            False
# 2040        3.711605e+09  ...        3.903130e+08            False
# 2152        3.116400e+10  ...        1.348600e+10            False
# 2153        4.625400e+10  ...       -3.574200e+10            False
# 2467        1.935954e+09  ...       -2.118570e+08            False
# 3262        1.965261e+09  ...        3.489237e+09            False
# 3512        6.262000e+08  ...        6.175000e+08            False
# 3560        1.363120e+10  ...        6.795700e+09            False
# 3778        6.241600e+10  ...        3.327900e+10            False
# 3862        1.176832e+10  ...        6.825670e+08            False
# 3926        5.137660e+08  ...        5.124160e+08            False
# 3982        1.181822e+09  ...        1.080148e+09            False
# 4782        1.627116e+09  ...        1.614226e+09            False
# 4783        3.354103e+09  ...        1.040332e+09            False
# 5340        5.618500e+09  ...        4.679500e+09             True
# 6469        2.094000e+09  ...        3.192000e+09            False
# 6478        2.801300e+10  ...       -4.765000e+09            False
# 7080        1.760000e+08  ...        8.342000e+08            False
#
#       expected_netincome_ratio  netincomeratio_match  \
# 276                   0.346204                  True
# 591                   0.324277                 False
# 1092                 -1.400211                  True
# 1476                  0.096976                  True
# 1625                  1.507891                  True
# 1852                  0.129632                  True
# 2040                  0.017092                  True
# 2152                  0.237749                  True
# 2153                  0.184114                  True
# 2467                 -0.081233                  True
# 3262                  0.360600                  True
# 3512                  0.105354                  True
# 3560                  0.218798                  True
# 3778                  0.198955                  True
# 3862                 -0.008565                  True
# 3926                  0.243944                  True
# 3982                  0.222594                  True
# 4782                  0.082943                  True
# 4783                  0.109253                  True
# 5340                  0.384419                 False
# 6469                  0.169132                  True
# 6478                  0.193803                  True
# 7080                 -0.164781                  True
#
#       expected_grossprofit_ratio  grossprofitratio_match  \
# 276                     0.665452                    True
# 591                     0.338003                    True
# 1092                    0.216001                    True
# 1476                    0.483485                    True
# 1625                    0.536560                    True
# 1852                    0.577338                    True
# 2040                    0.322787                    True
# 2152                    0.658524                    True
# 2153                    0.642150                    True
# 2467                    0.840805                    True
# 3262                    0.610021                    True
# 3512                    0.272274                    True
# 3560                    0.767713                    True
# 3778                    0.783473                    True
# 3862                    0.984869                    True
# 3926                    0.584429                    True
# 3982                    0.588830                    True
# 4782                    0.282086                    True
# 4783                    0.337227                    True
# 5340                    0.871814                    True
# 6469                    0.405596                    True
# 6478                    1.000000                    True
# 7080                    0.914846                    True
#
#       expected_grossprofit  grossprofit_match  expected_operatingincome  \
# 276           2.209500e+10               True              1.428200e+10
# 591           1.231960e+11               True             -7.537900e+10
# 1092          1.166600e+07               True              3.234000e+06
# 1476          3.511604e+09               True              1.226343e+09
# 1625          4.080000e+09               True             -1.930000e+08
# 1852          3.363400e+09               True              1.005300e+09
# 2040          1.266775e+09               True             -2.444830e+09
# 2152          3.119100e+10               True              2.700000e+07
# 2153          2.970200e+10               True             -1.655200e+10
# 2467          1.824741e+09               True             -1.112130e+08
# 3262          5.619442e+09               True              3.654181e+09
# 3512          1.284700e+09               True              6.585000e+08
# 3560          2.191160e+10               True              8.280400e+09
# 3778          9.136000e+10               True              2.894400e+10
# 3862          1.163677e+10               True             -1.315550e+08
# 3926          1.048552e+09               True              5.347860e+08
# 3982          2.308042e+09               True              1.126220e+09
# 4782          4.474341e+09               True              2.847225e+09
# 4783          6.429302e+09               True              3.075199e+09
# 5340          1.061250e+10               True              4.994000e+09
# 6469          5.813000e+09               True              3.719000e+09
# 6478          2.801300e+10               True              0.000000e+00
# 7080          1.059300e+09               True              8.833000e+08
#
#       operatingincome_match
# 276                   False
# 591                   False
# 1092                  False
# 1476                  False
# 1625                  False
# 1852                  False
# 2040                  False
# 2152                  False
# 2153                  False
# 2467                  False
# 3262                  False
# 3512                  False
# 3560                  False
# 3778                  False
# 3862                  False
# 3926                  False
# 3982                  False
# 4782                  False
# 4783                  False
# 5340                  False
# 6469                  False
# 6478                  False
# 7080                  False
#
# [23 rows x 26 columns]

# %% [markdown]
# #### Checking Operating Expenses (Gross Profit - Operating Income)

# %%
def operatingexpenses_calculation(df):
    # Calculate expected operating expenses
    df['expected_operatingexpenses'] = df['Gross Profit'] - df['Operating Income']
    
    # Compare expected operating expenses with the actual operating expense, considering small floating-point differences
    df['operatingexpenses_match'] = np.isclose(df['expected_operatingexpenses'], df['Operating Expenses'])

# %%
operatingexpenses_calculation(expanded_df)

# %%
operatingexpenses_calculation(partial_df)

# %%
# 99 out of 100213 in Expanded Dataset match
expanded_df[expanded_df['operatingexpenses_match'] == False]
# Out:
#         Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 2699     ARGX  2019  7.811609e+07        0.000000     -1.998759e+08
# 2700     ARGX  2020  4.484817e+07       -0.425878     -5.143769e+08
# 2701     ARGX  2021  4.972770e+08       10.088010     -3.487460e+08
# 2881     ASML  2021  1.861100e+10        0.331402      6.750100e+09
# 3409    AVGOP  2020  2.388800e+10        0.000000      4.014000e+09
# ...       ...   ...           ...             ...               ...
# 85312  WFC-PL  2019  8.506300e+10        0.000000      2.596700e+10
# 85313  WFC-PL  2020  7.234000e+10       -0.149571      4.041000e+09
# 85314  WFC-PL  2021  7.849200e+10        0.085043      2.885100e+10
# 85315  WFC-PL  2022  7.378500e+10       -0.059968      1.497000e+10
# 87566     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 2699  -1.824254e+08         -2.335311 -1.185681e+08           -1.517845
# 2700  -6.512349e+08        -14.520879 -2.590780e+08           -5.776780
# 2701  -4.082650e+08         -0.821001 -1.276787e+07           -0.025676
# 2881   5.883200e+09          0.316114  9.809000e+09            0.527054
# 3409   2.960000e+09          0.123912  1.351600e+10            0.565807
# ...             ...               ...           ...                 ...
# 85312  1.971500e+10          0.231769  8.506300e+10            1.000000
# 85313  1.786000e+09          0.024689  7.234000e+10            1.000000
# 85314  2.210900e+10          0.281672  7.849200e+10            1.000000
# 85315  1.367700e+10          0.185363  7.378500e+10            1.000000
# 87566 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#        Operating Expenses  ...  expected_revenue  revenue_match  \
# 2699         2.792189e+08  ...      7.811609e+07           True
# 2700         5.623561e+08  ...      4.484817e+07           True
# 2701         8.460230e+08  ...      4.972770e+08           True
# 2881         3.272600e+09  ...      1.861100e+10           True
# 3409         9.304000e+09  ...      2.388800e+10           True
# ...                   ...  ...               ...            ...
# 85312        5.826000e+10  ...      8.506300e+10           True
# 85313        5.766700e+10  ...      7.234000e+10           True
# 85314        5.379000e+10  ...      7.849200e+10           True
# 85315        5.727800e+10  ...      7.378500e+10           True
# 87566        1.760000e+08  ...      1.157900e+09           True
#
#        expected_revenuegrowth  revenuegrowth_match  expected_costofrevenue  \
# 2699                 0.000000                False            1.966842e+08
# 2700                -0.425878                False            3.039262e+08
# 2701                10.088010                False            5.100449e+08
# 2881                 0.331402                False            8.802000e+09
# 3409                 0.000000                False            1.037200e+10
# ...                       ...                  ...                     ...
# 85312                0.000000                False            0.000000e+00
# 85313               -0.149571                False            0.000000e+00
# 85314                0.085043                False            0.000000e+00
# 85315               -0.059968                False            0.000000e+00
# 87566                0.000000                False            9.860000e+07
#
#        costofrevenue_match  expected_operatingincome  operatingincome_match  \
# 2699                  True             -3.977870e+08                  False
# 2700                  True             -8.214341e+08                  False
# 2701                  True             -8.587909e+08                  False
# 2881                  True              6.536400e+09                  False
# 3409                  True              4.212000e+09                  False
# ...                    ...                       ...                    ...
# 85312                 True              2.680300e+10                  False
# 85313                 True              1.467300e+10                  False
# 85314                 True              2.470200e+10                  False
# 85315                 True              1.650700e+10                  False
# 87566                 True              8.833000e+08                  False
#
#        expected_operatingexpenses  operatingexpenses_match
# 2699                 8.130778e+07                    False
# 2700                 2.552988e+08                    False
# 2701                 3.359781e+08                    False
# 2881                 3.058900e+09                    False
# 3409                 9.502000e+09                    False
# ...                           ...                      ...
# 85312                5.909600e+10                    False
# 85313                6.829900e+10                    False
# 85314                4.964100e+10                    False
# 85315                5.881500e+10                    False
# 87566                1.848000e+08                    False
#
# [99 rows x 34 columns]

# %%
# 23 out of 8093 rows in Partial Dataset still do not match
partial_df[partial_df['operatingexpenses_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 276    AVGOP  2022  3.320300e+10        0.000000      1.422500e+10
# 591    BRK-A  2023  3.644820e+11        0.556352      1.231960e+11
# 1092    DJCO  2022  5.400900e+07        0.000000      7.440000e+06
# 1476    EQIX  2022  7.263105e+09        0.000000      1.200528e+09
# 1625   FCNCA  2023  7.604000e+09        0.674521      3.331000e+09
# 1852  FTV-PA  2022  5.825700e+09        0.000000      9.874000e+08
# 2040     GHC  2022  3.924493e+09        0.000000      4.447160e+08
# 2152      GS  2022  4.736500e+10        0.000000      3.483200e+10
# 2153      GS  2023  4.625400e+10       -0.023456      2.642200e+10
# 2467    HUBS  2023  2.170230e+09        0.253766     -2.080560e+08
# 3262    KLAC  2022  9.211883e+09        0.000000      3.649576e+09
# 3512     LII  2022  4.718400e+09        0.000000      6.562000e+08
# 3560     LLY  2022  2.854140e+10        0.000000      7.127300e+09
# 3778    META  2022  1.166090e+11        0.000000      3.355500e+10
# 3862     MKL  2022  1.181554e+10        0.000000      8.786290e+08
# 3926    MPWR  2022  1.794148e+09        0.000000      5.267850e+08
# 3982     MTD  2022  3.919709e+09        0.000000      1.135540e+09
# 4782      PH  2022  1.586161e+10        0.000000      1.869478e+09
# 4783      PH  2023  1.906519e+10        0.201971      1.614226e+09
# 5340    REGN  2022  1.217290e+10        0.000000      4.738900e+09
# 6469     URI  2023  1.433200e+10        0.231060      3.827000e+09
# 6478  USB-PA  2023  2.801300e+10        0.000000      7.846000e+09
# 7080     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 276   1.149500e+10          0.346204  2.209500e+10            0.665452
# 591   1.181930e+11          0.263999  1.231960e+11            0.338003
# 1092 -7.562400e+07         -1.400211  1.166600e+07            0.216001
# 1476  7.043450e+08          0.096976  3.511604e+09            0.483485
# 1625  1.146600e+10          1.507891  4.080000e+09            0.536560
# 1852  7.552000e+08          0.129632  3.363400e+09            0.577338
# 2040  6.707900e+07          0.017092  1.266775e+09            0.322787
# 2152  1.126100e+10          0.237749  3.119100e+10            0.658524
# 2153  8.516000e+09          0.184114  2.970200e+10            0.642150
# 2467 -1.762950e+08         -0.081233  1.824741e+09            0.840805
# 3262  3.321807e+09          0.360600  5.619442e+09            0.610021
# 3512  4.971000e+08          0.105354  1.284700e+09            0.272274
# 3560  6.244800e+09          0.218798  2.191160e+10            0.767713
# 3778  2.320000e+10          0.198955  9.136000e+10            0.783473
# 3862 -1.012030e+08         -0.008565  1.163677e+10            0.984869
# 3926  4.376720e+08          0.243944  1.048552e+09            0.584429
# 3982  8.725020e+08          0.222594  2.308042e+09            0.588830
# 4782  1.315605e+09          0.082943  4.474341e+09            0.282086
# 4783  2.082936e+09          0.109253  6.429302e+09            0.337227
# 5340  4.679500e+09          0.356398  1.061250e+10            0.871814
# 6469  2.424000e+09          0.169132  5.813000e+09            0.405596
# 6478  5.429000e+09          0.193803  2.801300e+10            1.000000
# 7080 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#       Operating Expenses  ...  expected_revenue  revenue_match  \
# 276         7.813000e+09  ...      3.320300e+10           True
# 591         1.985750e+11  ...      3.644820e+11           True
# 1092        8.432000e+06  ...      5.400900e+07           True
# 1476        2.285261e+09  ...      7.263105e+09           True
# 1625        4.273000e+09  ...      7.604000e+09           True
# 1852        2.358100e+09  ...      5.825700e+09           True
# 2040        3.711605e+09  ...      3.924493e+09           True
# 2152        3.116400e+10  ...      4.736500e+10           True
# 2153        4.625400e+10  ...      4.625400e+10           True
# 2467        1.935954e+09  ...      2.170230e+09           True
# 3262        1.965261e+09  ...      9.211883e+09           True
# 3512        6.262000e+08  ...      4.718400e+09           True
# 3560        1.363120e+10  ...      2.854140e+10           True
# 3778        6.241600e+10  ...      1.166090e+11           True
# 3862        1.176832e+10  ...      1.181554e+10           True
# 3926        5.137660e+08  ...      1.794148e+09           True
# 3982        1.181822e+09  ...      3.919709e+09           True
# 4782        1.627116e+09  ...      1.586161e+10           True
# 4783        3.354103e+09  ...      1.906519e+10           True
# 5340        5.618500e+09  ...      1.217290e+10           True
# 6469        2.094000e+09  ...      1.433200e+10           True
# 6478        2.801300e+10  ...      2.801300e+10           True
# 7080        1.760000e+08  ...      1.157900e+09           True
#
#       expected_revenuegrowth  revenuegrowth_match  expected_costofrevenue  \
# 276                 0.000000                 True            1.110800e+10
# 591                 0.556352                 True            2.412860e+11
# 1092                0.000000                 True            4.234300e+07
# 1476                0.000000                 True            3.751501e+09
# 1625                0.674521                 True            3.524000e+09
# 1852                0.000000                 True            2.462300e+09
# 2040                0.000000                 True            2.657718e+09
# 2152                0.000000                 True            1.617400e+10
# 2153               -0.023456                 True            1.655200e+10
# 2467                0.253766                 True            3.454890e+08
# 3262                0.000000                 True            3.592441e+09
# 3512                0.000000                 True            3.433700e+09
# 3560                0.000000                 True            6.629800e+09
# 3778                0.000000                 True            2.524900e+10
# 3862                0.000000                 True            1.787780e+08
# 3926                0.000000                 True            7.455960e+08
# 3982                0.000000                 True            1.611667e+09
# 4782                0.000000                 True            1.138727e+10
# 4783                0.201971                 True            1.263589e+10
# 5340                0.000000                 True            1.560400e+09
# 6469                0.231060                 True            8.519000e+09
# 6478                0.000000                 True            0.000000e+00
# 7080                0.000000                 True            9.860000e+07
#
#       costofrevenue_match  expected_operatingincome  operatingincome_match  \
# 276                  True              1.428200e+10                  False
# 591                  True             -7.537900e+10                  False
# 1092                 True              3.234000e+06                  False
# 1476                 True              1.226343e+09                  False
# 1625                 True             -1.930000e+08                  False
# 1852                 True              1.005300e+09                  False
# 2040                 True             -2.444830e+09                  False
# 2152                 True              2.700000e+07                  False
# 2153                 True             -1.655200e+10                  False
# 2467                 True             -1.112130e+08                  False
# 3262                 True              3.654181e+09                  False
# 3512                 True              6.585000e+08                  False
# 3560                 True              8.280400e+09                  False
# 3778                 True              2.894400e+10                  False
# 3862                 True             -1.315550e+08                  False
# 3926                 True              5.347860e+08                  False
# 3982                 True              1.126220e+09                  False
# 4782                 True              2.847225e+09                  False
# 4783                 True              3.075199e+09                  False
# 5340                 True              4.994000e+09                  False
# 6469                 True              3.719000e+09                  False
# 6478                 True              0.000000e+00                  False
# 7080                 True              8.833000e+08                  False
#
#       expected_operatingexpenses  operatingexpenses_match
# 276                 7.870000e+09                    False
# 591                 0.000000e+00                    False
# 1092                4.226000e+06                    False
# 1476                2.311076e+09                    False
# 1625                7.490000e+08                    False
# 1852                2.376000e+09                    False
# 2040                8.220590e+08                    False
# 2152               -3.641000e+09                    False
# 2153                3.280000e+09                    False
# 2467                2.032797e+09                    False
# 3262                1.969866e+09                    False
# 3512                6.285000e+08                    False
# 3560                1.478430e+10                    False
# 3778                5.780500e+10                    False
# 3862                1.075814e+10                    False
# 3926                5.217670e+08                    False
# 3982                1.172502e+09                    False
# 4782                2.604863e+09                    False
# 4783                4.815076e+09                    False
# 5340                5.873600e+09                    False
# 6469                1.986000e+09                    False
# 6478                2.016700e+10                    False
# 7080                1.848000e+08                    False
#
# [23 rows x 34 columns]

# %% [markdown]
# #### Checking Depreciation & Amortization (EBITDA - Operating Income)

# %%
def depreciationamortization_calculation(df):
    # Calculate expected D&A
    df['expected_depreciationamortization'] = df['EBITDA'] - df['Operating Income']
    
    # Compare expected D&A with the actual D&A, considering small floating-point differences
    df['depreciationamortization_match'] = np.isclose(df['expected_depreciationamortization'], df['Depreciation & Amortization'])

# %%
depreciationamortization_calculation(expanded_df)

# %%
depreciationamortization_calculation(partial_df)

# %%
# 181 rows out of 100213 in Expanded Dataset still do not match
expanded_df[expanded_df['depreciationamortization_match'] == False]
# Out:
#         Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 2699     ARGX  2019  7.811609e+07        0.000000     -1.998759e+08
# 2700     ARGX  2020  4.484817e+07       -0.425878     -5.143769e+08
# 2701     ARGX  2021  4.972770e+08       10.088010     -3.487460e+08
# 2702     ARGX  2022  4.107460e+08       -0.174010     -7.196630e+08
# 2703     ARGX  2023  1.226316e+09        1.985582     -4.250490e+08
# ...       ...   ...           ...             ...               ...
# 85312  WFC-PL  2019  8.506300e+10        0.000000      2.596700e+10
# 85313  WFC-PL  2020  7.234000e+10       -0.149571      4.041000e+09
# 85314  WFC-PL  2021  7.849200e+10        0.085043      2.885100e+10
# 85315  WFC-PL  2022  7.378500e+10       -0.059968      1.497000e+10
# 87566     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 2699  -1.824254e+08         -2.335311 -1.185681e+08           -1.517845
# 2700  -6.512349e+08        -14.520879 -2.590780e+08           -5.776780
# 2701  -4.082650e+08         -0.821001 -1.276787e+07           -0.025676
# 2702  -7.095940e+08         -1.727574  3.813150e+08            0.928347
# 2703  -2.950530e+08         -0.240601  1.108481e+09            0.903911
# ...             ...               ...           ...                 ...
# 85312  1.971500e+10          0.231769  8.506300e+10            1.000000
# 85313  1.786000e+09          0.024689  7.234000e+10            1.000000
# 85314  2.210900e+10          0.281672  7.849200e+10            1.000000
# 85315  1.367700e+10          0.185363  7.378500e+10            1.000000
# 87566 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#        Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 2699         2.792189e+08  ...                0.000000                False
# 2700         5.623561e+08  ...               -0.425878                False
# 2701         8.460230e+08  ...               10.088010                False
# 2702         1.100978e+09  ...               -0.174010                False
# 2703         1.533530e+09  ...                1.985582                False
# ...                   ...  ...                     ...                  ...
# 85312        5.826000e+10  ...                0.000000                False
# 85313        5.766700e+10  ...               -0.149571                False
# 85314        5.379000e+10  ...                0.085043                False
# 85315        5.727800e+10  ...               -0.059968                False
# 87566        1.760000e+08  ...                0.000000                False
#
#        expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 2699              196684206.0                 True             -3.977870e+08
# 2700              303926196.0                 True             -8.214341e+08
# 2701              510044872.0                 True             -8.587909e+08
# 2702               29431000.0                 True             -7.196630e+08
# 2703              117835000.0                 True             -4.250490e+08
# ...                       ...                  ...                       ...
# 85312                     0.0                 True              2.680300e+10
# 85313                     0.0                 True              1.467300e+10
# 85314                     0.0                 True              2.470200e+10
# 85315                     0.0                 True              1.650700e+10
# 87566              98600000.0                 True              8.833000e+08
#
#        operatingincome_match  expected_operatingexpenses  \
# 2699                   False                8.130778e+07
# 2700                   False                2.552988e+08
# 2701                   False                3.359781e+08
# 2702                    True                1.100978e+09
# 2703                    True                1.533530e+09
# ...                      ...                         ...
# 85312                  False                5.909600e+10
# 85313                  False                6.829900e+10
# 85314                  False                4.964100e+10
# 85315                  False                5.881500e+10
# 87566                  False                1.848000e+08
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 2699                     False                       2.218027e+07
# 2700                     False                      -8.729010e+07
# 2701                     False                       3.432493e+07
# 2702                      True                       1.376537e+08
# 2703                      True                       2.090260e+08
# ...                        ...                                ...
# 85312                    False                      -2.596700e+10
# 85313                    False                      -4.041000e+09
# 85314                    False                       8.459000e+09
# 85315                    False                       7.308000e+09
# 87566                    False                      -9.784000e+08
#
#        depreciationamortization_match
# 2699                            False
# 2700                            False
# 2701                            False
# 2702                            False
# 2703                            False
# ...                               ...
# 85312                           False
# 85313                           False
# 85314                           False
# 85315                           False
# 87566                           False
#
# [181 rows x 36 columns]

# %%
# 79 rows out of 8093 rows in Partial Dataset still do not match
partial_df[partial_df['depreciationamortization_match'] == False]
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 216     ARGX  2022  4.107460e+08        0.000000     -7.196630e+08
# 217     ARGX  2023  1.226316e+09        1.985582     -4.250490e+08
# 232     ASML  2022  2.117340e+10        0.000000      7.321000e+09
# 276    AVGOP  2022  3.320300e+10        0.000000      1.422500e+10
# 277    AVGOP  2023  3.581900e+10        0.078788      1.620700e+10
# ...      ...   ...           ...             ...               ...
# 6468     URI  2022  1.164200e+10        0.000000      3.232000e+09
# 6469     URI  2023  1.433200e+10        0.231060      3.827000e+09
# 6478  USB-PA  2023  2.801300e+10        0.000000      7.846000e+09
# 6899  WFC-PL  2022  7.378500e+10        0.000000      1.497000e+10
# 7080     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 216  -7.095940e+08         -1.727574  3.813150e+08            0.928347
# 217  -2.950530e+08         -0.240601  1.108481e+09            0.903911
# 232   5.624200e+09          0.265626  1.051270e+10            0.496505
# 276   1.149500e+10          0.346204  2.209500e+10            0.665452
# 277   1.458500e+10          0.393143  2.469000e+10            0.689299
# ...            ...               ...           ...                 ...
# 6468  2.787000e+09          0.180811  4.996000e+09            0.429136
# 6469  2.424000e+09          0.169132  5.813000e+09            0.405596
# 6478  5.429000e+09          0.193803  2.801300e+10            1.000000
# 6899  1.367700e+10          0.185363  7.378500e+10            1.000000
# 7080 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#       Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 216         1.100978e+09  ...                0.000000                 True
# 217         1.533530e+09  ...                1.985582                 True
# 232         3.191700e+09  ...                0.000000                 True
# 276         7.813000e+09  ...                0.000000                 True
# 277         8.483000e+09  ...                0.078788                 True
# ...                  ...  ...                     ...                  ...
# 6468        1.764000e+09  ...                0.000000                 True
# 6469        2.094000e+09  ...                0.231060                 True
# 6478        2.801300e+10  ...                0.000000                 True
# 6899        5.881500e+10  ...                0.000000                 True
# 7080        1.760000e+08  ...                0.000000                 True
#
#       expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 216             2.943100e+07                 True             -7.196630e+08
# 217             1.178350e+08                 True             -4.250490e+08
# 232             1.066070e+10                 True              7.321000e+09
# 276             1.110800e+10                 True              1.428200e+10
# 277             1.112900e+10                 True              1.620700e+10
# ...                      ...                  ...                       ...
# 6468            6.646000e+09                 True              3.232000e+09
# 6469            8.519000e+09                 True              3.719000e+09
# 6478            0.000000e+00                 True              0.000000e+00
# 6899            0.000000e+00                 True              1.497000e+10
# 7080            9.860000e+07                 True              8.833000e+08
#
#       operatingincome_match  expected_operatingexpenses  \
# 216                    True                1.100978e+09
# 217                    True                1.533530e+09
# 232                    True                3.191700e+09
# 276                   False                7.870000e+09
# 277                    True                8.483000e+09
# ...                     ...                         ...
# 6468                   True                1.764000e+09
# 6469                  False                1.986000e+09
# 6478                  False                2.016700e+10
# 6899                   True                5.881500e+10
# 7080                  False                1.848000e+08
#
#       operatingexpenses_match  expected_depreciationamortization  \
# 216                      True                       1.376537e+08
# 217                      True                       2.090260e+08
# 232                      True                      -3.234000e+08
# 276                     False                       4.930000e+09
# 277                      True                       4.347000e+09
# ...                       ...                                ...
# 6468                     True                       2.232000e+09
# 6469                    False                       2.800000e+09
# 6478                    False                       9.000000e+06
# 6899                     True                       7.308000e+09
# 7080                    False                      -9.784000e+08
#
#       depreciationamortization_match
# 216                            False
# 217                            False
# 232                            False
# 276                            False
# 277                            False
# ...                              ...
# 6468                           False
# 6469                           False
# 6478                           False
# 6899                           False
# 7080                           False
#
# [79 rows x 36 columns]

# %% [markdown]
# #### Dropping rows with 'False' in any of Match columns

# %%
# Expanded Dataset - All match columns except for expected revenue growth match
expanded_df_match_columns = [col for col in expanded_df.columns if 'match' in col and col != 'revenuegrowth_match']

# Filter rows where any of the match columns have False values - 213 rows
expanded_df_rows_with_false = expanded_df[~expanded_df[expanded_df_match_columns].all(axis=1)]

expanded_df_rows_with_false
# Out:
#         Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 2699     ARGX  2019  7.811609e+07        0.000000     -1.998759e+08
# 2700     ARGX  2020  4.484817e+07       -0.425878     -5.143769e+08
# 2701     ARGX  2021  4.972770e+08       10.088010     -3.487460e+08
# 2702     ARGX  2022  4.107460e+08       -0.174010     -7.196630e+08
# 2703     ARGX  2023  1.226316e+09        1.985582     -4.250490e+08
# ...       ...   ...           ...             ...               ...
# 85312  WFC-PL  2019  8.506300e+10        0.000000      2.596700e+10
# 85313  WFC-PL  2020  7.234000e+10       -0.149571      4.041000e+09
# 85314  WFC-PL  2021  7.849200e+10        0.085043      2.885100e+10
# 85315  WFC-PL  2022  7.378500e+10       -0.059968      1.497000e+10
# 87566     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 2699  -1.824254e+08         -2.335311 -1.185681e+08           -1.517845
# 2700  -6.512349e+08        -14.520879 -2.590780e+08           -5.776780
# 2701  -4.082650e+08         -0.821001 -1.276787e+07           -0.025676
# 2702  -7.095940e+08         -1.727574  3.813150e+08            0.928347
# 2703  -2.950530e+08         -0.240601  1.108481e+09            0.903911
# ...             ...               ...           ...                 ...
# 85312  1.971500e+10          0.231769  8.506300e+10            1.000000
# 85313  1.786000e+09          0.024689  7.234000e+10            1.000000
# 85314  2.210900e+10          0.281672  7.849200e+10            1.000000
# 85315  1.367700e+10          0.185363  7.378500e+10            1.000000
# 87566 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#        Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 2699         2.792189e+08  ...                0.000000                False
# 2700         5.623561e+08  ...               -0.425878                False
# 2701         8.460230e+08  ...               10.088010                False
# 2702         1.100978e+09  ...               -0.174010                False
# 2703         1.533530e+09  ...                1.985582                False
# ...                   ...  ...                     ...                  ...
# 85312        5.826000e+10  ...                0.000000                False
# 85313        5.766700e+10  ...               -0.149571                False
# 85314        5.379000e+10  ...                0.085043                False
# 85315        5.727800e+10  ...               -0.059968                False
# 87566        1.760000e+08  ...                0.000000                False
#
#        expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 2699              196684206.0                 True             -3.977870e+08
# 2700              303926196.0                 True             -8.214341e+08
# 2701              510044872.0                 True             -8.587909e+08
# 2702               29431000.0                 True             -7.196630e+08
# 2703              117835000.0                 True             -4.250490e+08
# ...                       ...                  ...                       ...
# 85312                     0.0                 True              2.680300e+10
# 85313                     0.0                 True              1.467300e+10
# 85314                     0.0                 True              2.470200e+10
# 85315                     0.0                 True              1.650700e+10
# 87566              98600000.0                 True              8.833000e+08
#
#        operatingincome_match  expected_operatingexpenses  \
# 2699                   False                8.130778e+07
# 2700                   False                2.552988e+08
# 2701                   False                3.359781e+08
# 2702                    True                1.100978e+09
# 2703                    True                1.533530e+09
# ...                      ...                         ...
# 85312                  False                5.909600e+10
# 85313                  False                6.829900e+10
# 85314                  False                4.964100e+10
# 85315                  False                5.881500e+10
# 87566                  False                1.848000e+08
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 2699                     False                       2.218027e+07
# 2700                     False                      -8.729010e+07
# 2701                     False                       3.432493e+07
# 2702                      True                       1.376537e+08
# 2703                      True                       2.090260e+08
# ...                        ...                                ...
# 85312                    False                      -2.596700e+10
# 85313                    False                      -4.041000e+09
# 85314                    False                       8.459000e+09
# 85315                    False                       7.308000e+09
# 87566                    False                      -9.784000e+08
#
#        depreciationamortization_match
# 2699                            False
# 2700                            False
# 2701                            False
# 2702                            False
# 2703                            False
# ...                               ...
# 85312                           False
# 85313                           False
# 85314                           False
# 85315                           False
# 87566                           False
#
# [213 rows x 36 columns]

# %%
# Drop these rows
expanded_df = expanded_df.drop(index=expanded_df_rows_with_false.index)

# %%
expanded_df
# Out:
#         Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0       AAFRW  2000  1.103142e+09        0.000000      2.918478e+08
# 1       AAFRW  2001  3.984834e+07       -0.963877      4.527289e+05
# 2       AAFRW  2002  9.519782e+08       22.890035      1.890946e+08
# 3       AAFRW  2003  1.283757e+09        0.348515      4.323393e+08
# 4       AAFRW  2004  1.503795e+08       -0.882860      1.974637e+07
# ...       ...   ...           ...             ...               ...
# 100208  ZZZBQ  2020  3.781246e+08        1.140794      7.029086e+07
# 100209  ZZZBQ  2021  1.300227e+09        2.438621      1.191204e+08
# 100210  ZZZBQ  2022  1.128191e+09       -0.132313      2.433491e+08
# 100211  ZZZBQ  2023  8.445354e+08       -0.251425      3.927662e+07
# 100212  ZZZBQ  2024  1.039218e+09        0.230521      2.637286e+08
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       2.915345e+08          0.264276  6.296658e+08            0.570793
# 1      -6.468705e+04         -0.001623  1.213086e+07            0.304426
# 2       1.887653e+08          0.198287  3.978879e+08            0.417959
# 3       4.314507e+08          0.336084  7.196193e+08            0.560557
# 4       1.931370e+07          0.128433  6.864248e+07            0.456462
# ...              ...               ...           ...                 ...
# 100208  6.974936e+07          0.184461  1.586118e+08            0.419470
# 100209  1.181734e+08          0.090887  5.562011e+08            0.427772
# 100210  2.431163e+08          0.215492  6.427123e+08            0.569684
# 100211  3.905789e+07          0.046248  2.832449e+08            0.335386
# 100212  2.632932e+08          0.253357  5.977993e+08            0.575239
#
#         Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 0             3.378181e+08  ...                0.000000                False
# 1             1.167813e+07  ...               -0.963877                False
# 2             2.087934e+08  ...               22.890035                False
# 3             2.872800e+08  ...                0.348515                False
# 4             4.889611e+07  ...               -0.882860                False
# ...                    ...  ...                     ...                  ...
# 100208        8.832091e+07  ...                1.140794                False
# 100209        4.370807e+08  ...                2.438621                False
# 100210        3.993631e+08  ...               -0.132313                False
# 100211        2.439683e+08  ...               -0.251425                False
# 100212        3.340707e+08  ...                0.230521                False
#
#         expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 0                 4.734762e+08                 True              2.918478e+08
# 1                 2.771748e+07                 True              4.527289e+05
# 2                 5.540903e+08                 True              1.890946e+08
# 3                 5.641375e+08                 True              4.323393e+08
# 4                 8.173707e+07                 True              1.974637e+07
# ...                        ...                  ...                       ...
# 100208            2.195128e+08                 True              7.029086e+07
# 100209            7.440260e+08                 True              1.191204e+08
# 100210            4.854785e+08                 True              2.433491e+08
# 100211            5.612904e+08                 True              3.927662e+07
# 100212            4.414188e+08                 True              2.637286e+08
#
#         operatingincome_match  expected_operatingexpenses  \
# 0                        True                3.378181e+08
# 1                        True                1.167813e+07
# 2                        True                2.087934e+08
# 3                        True                2.872800e+08
# 4                        True                4.889611e+07
# ...                       ...                         ...
# 100208                   True                8.832091e+07
# 100209                   True                4.370807e+08
# 100210                   True                3.993631e+08
# 100211                   True                2.439683e+08
# 100212                   True                3.340707e+08
#
#         operatingexpenses_match  expected_depreciationamortization  \
# 0                          True                          7821411.0
# 1                          True                           529931.0
# 2                          True                          4493034.0
# 3                          True                          2228554.0
# 4                          True                          5271247.0
# ...                         ...                                ...
# 100208                     True                          6679235.0
# 100209                     True                          5861457.0
# 100210                     True                           886906.0
# 100211                     True                          3587258.0
# 100212                     True                          5733889.0
#
#         depreciationamortization_match
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True
# ...                                ...
# 100208                            True
# 100209                            True
# 100210                            True
# 100211                            True
# 100212                            True
#
# [100000 rows x 36 columns]

# %%
# Partial Dataset - All match columns except for expected revenue growth match
partial_df_match_columns = [col for col in partial_df.columns if 'match' in col and col != 'revenuegrowth_match']

# Filter rows where any of the match columns have False values - 91 rows
partial_df_rows_with_false = partial_df[~partial_df[partial_df_match_columns].all(axis=1)]

partial_df_rows_with_false
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 216     ARGX  2022  4.107460e+08        0.000000     -7.196630e+08
# 217     ARGX  2023  1.226316e+09        1.985582     -4.250490e+08
# 232     ASML  2022  2.117340e+10        0.000000      7.321000e+09
# 233     ASML  2023  2.755850e+10        0.301562      9.042300e+09
# 276    AVGOP  2022  3.320300e+10        0.000000      1.422500e+10
# ...      ...   ...           ...             ...               ...
# 6468     URI  2022  1.164200e+10        0.000000      3.232000e+09
# 6469     URI  2023  1.433200e+10        0.231060      3.827000e+09
# 6478  USB-PA  2023  2.801300e+10        0.000000      7.846000e+09
# 6899  WFC-PL  2022  7.378500e+10        0.000000      1.497000e+10
# 7080     WTM  2022  1.157900e+09        0.000000      8.745000e+08
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 216  -7.095940e+08         -1.727574  3.813150e+08            0.928347
# 217  -2.950530e+08         -0.240601  1.108481e+09            0.903911
# 232   5.624200e+09          0.265626  1.051270e+10            0.496505
# 233   7.839000e+09          0.284449  1.413610e+10            0.512949
# 276   1.149500e+10          0.346204  2.209500e+10            0.665452
# ...            ...               ...           ...                 ...
# 6468  2.787000e+09          0.180811  4.996000e+09            0.429136
# 6469  2.424000e+09          0.169132  5.813000e+09            0.405596
# 6478  5.429000e+09          0.193803  2.801300e+10            1.000000
# 6899  1.367700e+10          0.185363  7.378500e+10            1.000000
# 7080 -1.908000e+08         -0.164781  1.059300e+09            0.914846
#
#       Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 216         1.100978e+09  ...                0.000000                 True
# 217         1.533530e+09  ...                1.985582                 True
# 232         3.191700e+09  ...                0.000000                 True
# 233         5.093800e+09  ...                0.301562                 True
# 276         7.813000e+09  ...                0.000000                 True
# ...                  ...  ...                     ...                  ...
# 6468        1.764000e+09  ...                0.000000                 True
# 6469        2.094000e+09  ...                0.231060                 True
# 6478        2.801300e+10  ...                0.000000                 True
# 6899        5.881500e+10  ...                0.000000                 True
# 7080        1.760000e+08  ...                0.000000                 True
#
#       expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 216             2.943100e+07                 True             -7.196630e+08
# 217             1.178350e+08                 True             -4.250490e+08
# 232             1.066070e+10                 True              7.321000e+09
# 233             1.342240e+10                 True              9.042300e+09
# 276             1.110800e+10                 True              1.428200e+10
# ...                      ...                  ...                       ...
# 6468            6.646000e+09                 True              3.232000e+09
# 6469            8.519000e+09                 True              3.719000e+09
# 6478            0.000000e+00                 True              0.000000e+00
# 6899            0.000000e+00                 True              1.497000e+10
# 7080            9.860000e+07                 True              8.833000e+08
#
#       operatingincome_match  expected_operatingexpenses  \
# 216                    True                1.100978e+09
# 217                    True                1.533530e+09
# 232                    True                3.191700e+09
# 233                    True                5.093800e+09
# 276                   False                7.870000e+09
# ...                     ...                         ...
# 6468                   True                1.764000e+09
# 6469                  False                1.986000e+09
# 6478                  False                2.016700e+10
# 6899                   True                5.881500e+10
# 7080                  False                1.848000e+08
#
#       operatingexpenses_match  expected_depreciationamortization  \
# 216                      True                       1.376537e+08
# 217                      True                       2.090260e+08
# 232                      True                      -3.234000e+08
# 233                      True                       6.564000e+08
# 276                     False                       4.930000e+09
# ...                       ...                                ...
# 6468                     True                       2.232000e+09
# 6469                    False                       2.800000e+09
# 6478                    False                       9.000000e+06
# 6899                     True                       7.308000e+09
# 7080                    False                      -9.784000e+08
#
#       depreciationamortization_match
# 216                            False
# 217                            False
# 232                            False
# 233                             True
# 276                            False
# ...                              ...
# 6468                           False
# 6469                           False
# 6478                           False
# 6899                           False
# 7080                           False
#
# [91 rows x 36 columns]

# %%
# Drop these rows
partial_df = partial_df.drop(index=partial_df_rows_with_false.index)

# %%
partial_df
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0      AAFRW  2022  7.097898e+08        0.000000      4.695101e+07
# 1      AAFRW  2023  2.947645e+07       -0.958472      8.918110e+06
# 2     AAHFBX  2022  1.148219e+09        0.000000      1.709324e+08
# 3     AAHFBX  2023  1.223013e+09        0.065139      1.857744e+08
# 4       AALB  2022  1.012524e+09        0.000000      3.690259e+08
# ...      ...   ...           ...             ...               ...
# 8088    ZZWA  2023  1.292421e+09       -0.302745      1.379075e+08
# 8089  ZZZBKF  2022  2.321441e+08        0.000000      3.857396e+07
# 8090  ZZZBKF  2023  3.261039e+08        0.404748      9.026569e+07
# 8091   ZZZBQ  2022  1.128191e+09        0.000000      2.433491e+08
# 8092   ZZZBQ  2023  8.445354e+08       -0.251425      3.927662e+07
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0     4.609527e+07          0.064942  2.968603e+08            0.418237
# 1     8.538895e+06          0.289685  1.589946e+07            0.539395
# 2     1.703448e+08          0.148356  5.159221e+08            0.449324
# 3     1.853291e+08          0.151535  5.378012e+08            0.439735
# 4     3.680859e+08          0.363533  5.820688e+08            0.574869
# ...            ...               ...           ...                 ...
# 8088  1.374613e+08          0.106360  5.670301e+08            0.438735
# 8089  3.766445e+07          0.162246  1.222414e+08            0.526575
# 8090  8.937578e+07          0.274072  1.924950e+08            0.590287
# 8091  2.431163e+08          0.215492  6.427123e+08            0.569684
# 8092  3.905789e+07          0.046248  2.832449e+08            0.335386
#
#       Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 0           2.499093e+08  ...                0.000000                 True
# 1           6.981349e+06  ...               -0.958472                 True
# 2           3.449897e+08  ...                0.000000                 True
# 3           3.520268e+08  ...                0.065139                 True
# 4           2.130430e+08  ...                0.000000                 True
# ...                  ...  ...                     ...                  ...
# 8088        4.291226e+08  ...               -0.302745                 True
# 8089        8.366739e+07  ...                0.000000                 True
# 8090        1.022293e+08  ...                0.404748                 True
# 8091        3.993631e+08  ...                0.000000                 True
# 8092        2.439683e+08  ...               -0.251425                 True
#
#       expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 0               4.129296e+08                 True              4.695101e+07
# 1               1.357699e+07                 True              8.918110e+06
# 2               6.322969e+08                 True              1.709324e+08
# 3               6.852117e+08                 True              1.857744e+08
# 4               4.304557e+08                 True              3.690259e+08
# ...                      ...                  ...                       ...
# 8088            7.253911e+08                 True              1.379075e+08
# 8089            1.099028e+08                 True              3.857396e+07
# 8090            1.336089e+08                 True              9.026569e+07
# 8091            4.854785e+08                 True              2.433491e+08
# 8092            5.612904e+08                 True              3.927662e+07
#
#       operatingincome_match  expected_operatingexpenses  \
# 0                      True                2.499093e+08
# 1                      True                6.981349e+06
# 2                      True                3.449897e+08
# 3                      True                3.520268e+08
# 4                      True                2.130430e+08
# ...                     ...                         ...
# 8088                   True                4.291226e+08
# 8089                   True                8.366739e+07
# 8090                   True                1.022293e+08
# 8091                   True                3.993631e+08
# 8092                   True                2.439683e+08
#
#       operatingexpenses_match  expected_depreciationamortization  \
# 0                        True                          8154792.0
# 1                        True                          9404991.0
# 2                        True                          4301712.0
# 3                        True                          8930222.0
# 4                        True                          9738310.0
# ...                       ...                                ...
# 8088                     True                          2544710.0
# 8089                     True                          5241496.0
# 8090                     True                          2123737.0
# 8091                     True                           886906.0
# 8092                     True                          3587258.0
#
#       depreciationamortization_match
# 0                               True
# 1                               True
# 2                               True
# 3                               True
# 4                               True
# ...                              ...
# 8088                            True
# 8089                            True
# 8090                            True
# 8091                            True
# 8092                            True
#
# [8002 rows x 36 columns]

# %%
# expanded_df.to_csv('expanded_df_v4.csv', index=False)
# partial_df.to_csv('partial_df_v4.csv', index=False)
# historical_df.to_csv('historical_df_v3.csv', index=False)
# sparse_df.to_csv('sparse_df_v3.csv', index=False)

# %%
expanded_df.shape
# Out:
# (100000, 36)

# %%
partial_df.shape
# Out:
# (8002, 36)

# %%
historical_df.shape
# Out:
# (733, 7)

# %%
sparse_df.shape
# Out:
# (443, 3)

# %% [markdown]
# # 4. Merge all datasets into one

# %% [markdown]
# Now that the datasets have been cleaned, we merge all 4 datasets into one.
#
# We use concat to join since the datasets have the same structure, and we only want to combine rows.

# %%
merged_df = pd.concat([expanded_df, partial_df], axis=0, ignore_index=True).drop_duplicates()

# %%
merged_df = pd.concat([merged_df, historical_df, sparse_df], axis=0, ignore_index=True).drop_duplicates()

# %%
merged_df
# Out:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        AAFRW  2000  1.103142e+09        0.000000      2.918478e+08
# 1        AAFRW  2001  3.984834e+07       -0.963877      4.527289e+05
# 2        AAFRW  2002  9.519782e+08       22.890035      1.890946e+08
# 3        AAFRW  2003  1.283757e+09        0.348515      4.323393e+08
# 4        AAFRW  2004  1.503795e+08       -0.882860      1.974637e+07
# ...        ...   ...           ...             ...               ...
# 109157  ZTMXAP  2001  1.360600e+09             NaN               NaN
# 109158  ZTMXAP  2003  2.576235e+08             NaN               NaN
# 109159  ZTMXAP  2005  4.837877e+08             NaN               NaN
# 109160  ZTMXAP  2006  7.930096e+08             NaN               NaN
# 109161  ZTMXAP  2008  1.808217e+09             NaN               NaN
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       2.915345e+08          0.264276  6.296658e+08            0.570793
# 1      -6.468705e+04         -0.001623  1.213086e+07            0.304426
# 2       1.887653e+08          0.198287  3.978879e+08            0.417959
# 3       4.314507e+08          0.336084  7.196193e+08            0.560557
# 4       1.931370e+07          0.128433  6.864248e+07            0.456462
# ...              ...               ...           ...                 ...
# 109157           NaN               NaN           NaN                 NaN
# 109158           NaN               NaN           NaN                 NaN
# 109159           NaN               NaN           NaN                 NaN
# 109160           NaN               NaN           NaN                 NaN
# 109161           NaN               NaN           NaN                 NaN
#
#         Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 0             3.378181e+08  ...                0.000000                False
# 1             1.167813e+07  ...               -0.963877                False
# 2             2.087934e+08  ...               22.890035                False
# 3             2.872800e+08  ...                0.348515                False
# 4             4.889611e+07  ...               -0.882860                False
# ...                    ...  ...                     ...                  ...
# 109157                 NaN  ...                     NaN                  NaN
# 109158                 NaN  ...                     NaN                  NaN
# 109159                 NaN  ...                     NaN                  NaN
# 109160                 NaN  ...                     NaN                  NaN
# 109161                 NaN  ...                     NaN                  NaN
#
#         expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 0                 4.734762e+08                 True              2.918478e+08
# 1                 2.771748e+07                 True              4.527289e+05
# 2                 5.540903e+08                 True              1.890946e+08
# 3                 5.641375e+08                 True              4.323393e+08
# 4                 8.173707e+07                 True              1.974637e+07
# ...                        ...                  ...                       ...
# 109157                     NaN                  NaN                       NaN
# 109158                     NaN                  NaN                       NaN
# 109159                     NaN                  NaN                       NaN
# 109160                     NaN                  NaN                       NaN
# 109161                     NaN                  NaN                       NaN
#
#        operatingincome_match  expected_operatingexpenses  \
# 0                       True                3.378181e+08
# 1                       True                1.167813e+07
# 2                       True                2.087934e+08
# 3                       True                2.872800e+08
# 4                       True                4.889611e+07
# ...                      ...                         ...
# 109157                   NaN                         NaN
# 109158                   NaN                         NaN
# 109159                   NaN                         NaN
# 109160                   NaN                         NaN
# 109161                   NaN                         NaN
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 0                         True                          7821411.0
# 1                         True                           529931.0
# 2                         True                          4493034.0
# 3                         True                          2228554.0
# 4                         True                          5271247.0
# ...                        ...                                ...
# 109157                     NaN                                NaN
# 109158                     NaN                                NaN
# 109159                     NaN                                NaN
# 109160                     NaN                                NaN
# 109161                     NaN                                NaN
#
#        depreciationamortization_match
# 0                                True
# 1                                True
# 2                                True
# 3                                True
# 4                                True
# ...                               ...
# 109157                            NaN
# 109158                            NaN
# 109159                            NaN
# 109160                            NaN
# 109161                            NaN
#
# [109162 rows x 36 columns]

# %% [markdown]
# #### Checking Merged Dataset

# %%
# Checking shape of merged dataset
merged_df.shape
# Out:
# (109162, 36)

# %%
# Ensure no more duplicate rows
duplicate_rows = merged_df[merged_df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_grossprofit, grossprofit_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match, expected_costofrevenue, costofrevenue_match, expected_operatingincome, operatingincome_match, expected_operatingexpenses, operatingexpenses_match, expected_depreciationamortization, depreciationamortization_match]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# There will be NaN values from merging other datasets.
#
# We need to ensure that there are no completely null rows.

# %%
merged_df = merged_df.dropna(how='all')

if merged_df.isnull().all(axis=1).any():
    print("There are rows where all values are null.")
else:
    print("No completely null rows.")
# Out:
# No completely null rows.

# %%
# Check data types
merged_df.dtypes
# Out:
# Stock                                 object
# Year                                   int64
# Revenue                              float64
# Revenue Growth                       float64
# Operating Income                     float64
# Net Income                           float64
# Net Income Ratio                     float64
# Gross Profit                         float64
# Gross Profit Ratio                   float64
# Operating Expenses                   float64
# Cost of Revenue                      float64
# EBITDA                               float64
# Interest Expense                     float64
# Depreciation & Amortization          float64
# expected_EBITDA                      float64
# EBITDA_match                          object
# expected_netincome                   float64
# netincome_match                       object
# expected_netincome_ratio             float64
# netincomeratio_match                  object
# expected_grossprofit_ratio           float64
# grossprofitratio_match                object
# expected_grossprofit                 float64
# grossprofit_match                     object
# expected_revenue                     float64
# revenue_match                         object
# expected_revenuegrowth               float64
# revenuegrowth_match                   object
# expected_costofrevenue               float64
# costofrevenue_match                   object
# expected_operatingincome             float64
# operatingincome_match                 object
# expected_operatingexpenses           float64
# operatingexpenses_match               object
# expected_depreciationamortization    float64
# depreciationamortization_match        object
# dtype: object

# %%
# Summary of merged dataset
merged_df.describe()
# Out:
#                 Year       Revenue  Revenue Growth  Operating Income  \
# count  109162.000000  1.091620e+05   107986.000000      1.079860e+05
# mean     2012.755327  1.098778e+09        2.717415      1.651019e+08
# std         7.455022  6.444464e+08       25.478039      1.644769e+08
# min      2000.000000  1.023372e+06       -0.999527     -2.317177e+08
# 25%      2006.000000  5.448704e+08       -0.462931      3.694524e+07
# 50%      2013.000000  1.090496e+09        0.000000      1.229605e+08
# 75%      2020.000000  1.636822e+09        0.865614      2.570472e+08
# max      2024.000000  2.551488e+09     1635.022705      9.520607e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# count  1.079860e+05     107986.000000  1.086430e+05       107986.000000
# mean   1.645518e+08          0.148117  4.946681e+08            0.450134
# std    1.644765e+08          0.105009  3.104808e+08            0.086670
# min   -2.324647e+08         -0.917878  3.394100e+05            0.300000
# 25%    3.639651e+07          0.071335  2.361958e+08            0.375300
# 50%    1.223375e+08          0.148567  4.717303e+08            0.450051
# 75%    2.564731e+08          0.225439  7.166411e+08            0.525012
# max    9.510885e+08          0.396542  1.486397e+09            0.599999
#
#        Operating Expenses  Cost of Revenue  ...  expected_netincome  \
# count        1.079860e+05     1.086430e+05  ...        1.079860e+05
# mean         3.297301e+08     6.042552e+08  ...        1.645518e+08
# std          2.068611e+08     3.714500e+08  ...        1.644765e+08
# min          2.323012e+05     4.784573e+05  ...       -2.324647e+08
# 25%          1.570939e+08     2.918796e+08  ...        3.639651e+07
# 50%          3.148631e+08     5.859132e+08  ...        1.223375e+08
# 75%          4.778916e+08     8.796323e+08  ...        2.564731e+08
# max          9.819004e+08     1.769863e+09  ...        9.510885e+08
#
#        expected_netincome_ratio  expected_grossprofit_ratio  \
# count             107986.000000               107986.000000
# mean                   0.148117                    0.450134
# std                    0.105009                    0.086670
# min                   -0.917878                    0.300000
# 25%                    0.071335                    0.375300
# 50%                    0.148567                    0.450051
# 75%                    0.225439                    0.525012
# max                    0.396542                    0.599999
#
#        expected_grossprofit  expected_revenue  expected_revenuegrowth  \
# count          1.079860e+05      1.086430e+05           107986.000000
# mean           4.948320e+08      1.098923e+09                2.717415
# std            3.104070e+08      6.445462e+08               25.478039
# min            3.394100e+05      1.023372e+06               -0.999527
# 25%            2.363636e+08      5.448758e+08               -0.462931
# 50%            4.720612e+08      1.090677e+09                0.000000
# 75%            7.167518e+08      1.636859e+09                0.865614
# max            1.486397e+09      2.551488e+09             1635.022705
#
#        expected_costofrevenue  expected_operatingincome  \
# count            1.079860e+05              1.079860e+05
# mean             6.045317e+08              1.651019e+08
# std              3.714708e+08              1.644769e+08
# min              4.784573e+05             -2.317177e+08
# 25%              2.921763e+08              3.694524e+07
# 50%              5.862100e+08              1.229605e+08
# 75%              8.801034e+08              2.570472e+08
# max              1.769863e+09              9.520607e+08
#
#        expected_operatingexpenses  expected_depreciationamortization
# count                1.079860e+05                       1.079860e+05
# mean                 3.297301e+08                       5.053486e+06
# std                  2.068611e+08                       2.856925e+06
# min                  2.323012e+05                       1.001190e+05
# 25%                  1.570939e+08                       2.590665e+06
# 50%                  3.148631e+08                       5.050248e+06
# 75%                  4.778916e+08                       7.526053e+06
# max                  9.819004e+08                       9.999999e+06
#
# [8 rows x 24 columns]

# %% [markdown]
# **Year**:
#
# Min year is 2000, Max year is 2024. Median year is 2013. The mean year 2012 suggests a midpoint near the median, indicating that the years are evenly distributed and not heavily skewed.
#
# **Revenue Growth**:
#
# Need to explore Max Revenue Growth (1635.02) as it might represent outliers.
#
# **Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses**:
#
# The negative min values may need to be investigated for accuracy or treated by replacing or refining.
#
# **Cost of Revenue**:
#
# The large standard deviation (3.714500e+08) suggests outliers or extreme cases.

# %%
# 9468 rows still have rows with impossible negative values
negative_rows = merged_df[
    (merged_df[['Operating Income', 'Net Income', 'Net Income Ratio', 
                'Gross Profit', 'Gross Profit Ratio', 'Operating Expenses']] < 0).any(axis=1)
]

print(negative_rows)
# Out:
#         Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 1       AAFRW  2001  3.984834e+07       -0.963877      4.527289e+05
# 56       AALB  2006  3.147740e+08       -0.783685     -8.011229e+06
# 64       AALB  2014  3.983703e+08       -0.622511     -6.636414e+06
# 68       AALB  2018  6.185085e+07       -0.920547      5.859314e+04
# 91      AANLW  2016  1.413008e+09        1.164323     -3.477968e+07
# ...       ...   ...           ...             ...               ...
# 107923  ZUTIJ  2023  3.088237e+08       -0.616497     -2.843915e+06
# 107929   ZVID  2023  2.281706e+08       -0.874989     -1.362404e+07
# 107963  ZYOTO  2023  1.993264e+08       -0.880139     -2.628906e+06
# 107969   ZYWP  2023  6.725761e+08       -0.596408     -4.256370e+07
# 107972  ZZHJF  2022  1.934900e+09        0.000000     -5.301251e+07
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 1      -6.468705e+04         -0.001623  1.213086e+07            0.304426
# 56     -9.008283e+06         -0.028618  1.022987e+08            0.324991
# 64     -6.747240e+06         -0.016937  1.416177e+08            0.355493
# 68     -4.887729e+05         -0.007902  1.950175e+07            0.315303
# 91     -3.537407e+07         -0.025035  4.430263e+08            0.313534
# ...              ...               ...           ...                 ...
# 107923 -3.603820e+06         -0.011670  9.529655e+07            0.308579
# 107929 -1.418975e+07         -0.062189  7.483015e+07            0.327957
# 107963 -3.087053e+06         -0.015487  6.411937e+07            0.321680
# 107969 -4.273928e+07         -0.063546  2.190517e+08            0.325691
# 107972 -5.345171e+07         -0.027625  6.586360e+08            0.340398
#
#         Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 1             1.167813e+07  ...               -0.963877                False
# 56            1.103099e+08  ...               -0.783685                False
# 64            1.482541e+08  ...               -0.622511                False
# 68            1.944316e+07  ...               -0.920547                False
# 91            4.778060e+08  ...                1.164323                False
# ...                    ...  ...                     ...                  ...
# 107923        9.814046e+07  ...               -0.616497                 True
# 107929        8.845419e+07  ...               -0.874989                 True
# 107963        6.674828e+07  ...               -0.880139                 True
# 107969        2.616154e+08  ...               -0.596408                 True
# 107972        7.116485e+08  ...                0.000000                 True
#
#         expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 1                 2.771748e+07                 True              4.527289e+05
# 56                2.124753e+08                 True             -8.011229e+06
# 64                2.567526e+08                 True             -6.636414e+06
# 68                4.234910e+07                 True              5.859314e+04
# 91                9.699820e+08                 True             -3.477968e+07
# ...                        ...                  ...                       ...
# 107923            2.135271e+08                 True             -2.843915e+06
# 107929            1.533404e+08                 True             -1.362404e+07
# 107963            1.352070e+08                 True             -2.628906e+06
# 107969            4.535244e+08                 True             -4.256370e+07
# 107972            1.276264e+09                 True             -5.301251e+07
#
#        operatingincome_match  expected_operatingexpenses  \
# 1                       True                1.167813e+07
# 56                      True                1.103099e+08
# 64                      True                1.482541e+08
# 68                      True                1.944316e+07
# 91                      True                4.778060e+08
# ...                      ...                         ...
# 107923                  True                9.814046e+07
# 107929                  True                8.845419e+07
# 107963                  True                6.674828e+07
# 107969                  True                2.616154e+08
# 107972                  True                7.116485e+08
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 1                         True                           529931.0
# 56                        True                          2237529.0
# 64                        True                          8750397.0
# 68                        True                          6126043.0
# 91                        True                          2655357.0
# ...                        ...                                ...
# 107923                    True                          5066956.0
# 107929                    True                          1406404.0
# 107963                    True                          9347801.0
# 107969                    True                          9322780.0
# 107972                    True                          9226979.0
#
#        depreciationamortization_match
# 1                                True
# 56                               True
# 64                               True
# 68                               True
# 91                               True
# ...                               ...
# 107923                           True
# 107929                           True
# 107963                           True
# 107969                           True
# 107972                           True
#
# [9478 rows x 36 columns]

# %%
# Remove rows with impossible negative values
merged_df = merged_df[~(
    (merged_df[['Operating Income', 'Net Income', 'Net Income Ratio', 
                'Gross Profit', 'Gross Profit Ratio', 'Operating Expenses']] < 0).any(axis=1)
)]

# %%
merged_df
# Out:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        AAFRW  2000  1.103142e+09        0.000000      2.918478e+08
# 2        AAFRW  2002  9.519782e+08       22.890035      1.890946e+08
# 3        AAFRW  2003  1.283757e+09        0.348515      4.323393e+08
# 4        AAFRW  2004  1.503795e+08       -0.882860      1.974637e+07
# 5        AAFRW  2005  2.193423e+09       13.585912      4.247539e+07
# ...        ...   ...           ...             ...               ...
# 109157  ZTMXAP  2001  1.360600e+09             NaN               NaN
# 109158  ZTMXAP  2003  2.576235e+08             NaN               NaN
# 109159  ZTMXAP  2005  4.837877e+08             NaN               NaN
# 109160  ZTMXAP  2006  7.930096e+08             NaN               NaN
# 109161  ZTMXAP  2008  1.808217e+09             NaN               NaN
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       2.915345e+08          0.264276  6.296658e+08            0.570793
# 2       1.887653e+08          0.198287  3.978879e+08            0.417959
# 3       4.314507e+08          0.336084  7.196193e+08            0.560557
# 4       1.931370e+07          0.128433  6.864248e+07            0.456462
# 5       4.176383e+07          0.019040  7.088561e+08            0.323173
# ...              ...               ...           ...                 ...
# 109157           NaN               NaN           NaN                 NaN
# 109158           NaN               NaN           NaN                 NaN
# 109159           NaN               NaN           NaN                 NaN
# 109160           NaN               NaN           NaN                 NaN
# 109161           NaN               NaN           NaN                 NaN
#
#         Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 0             3.378181e+08  ...                0.000000                False
# 2             2.087934e+08  ...               22.890035                False
# 3             2.872800e+08  ...                0.348515                False
# 4             4.889611e+07  ...               -0.882860                False
# 5             6.663807e+08  ...               13.585912                False
# ...                    ...  ...                     ...                  ...
# 109157                 NaN  ...                     NaN                  NaN
# 109158                 NaN  ...                     NaN                  NaN
# 109159                 NaN  ...                     NaN                  NaN
# 109160                 NaN  ...                     NaN                  NaN
# 109161                 NaN  ...                     NaN                  NaN
#
#         expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 0                 4.734762e+08                 True              2.918478e+08
# 2                 5.540903e+08                 True              1.890946e+08
# 3                 5.641375e+08                 True              4.323393e+08
# 4                 8.173707e+07                 True              1.974637e+07
# 5                 1.484567e+09                 True              4.247539e+07
# ...                        ...                  ...                       ...
# 109157                     NaN                  NaN                       NaN
# 109158                     NaN                  NaN                       NaN
# 109159                     NaN                  NaN                       NaN
# 109160                     NaN                  NaN                       NaN
# 109161                     NaN                  NaN                       NaN
#
#        operatingincome_match  expected_operatingexpenses  \
# 0                       True                3.378181e+08
# 2                       True                2.087934e+08
# 3                       True                2.872800e+08
# 4                       True                4.889611e+07
# 5                       True                6.663807e+08
# ...                      ...                         ...
# 109157                   NaN                         NaN
# 109158                   NaN                         NaN
# 109159                   NaN                         NaN
# 109160                   NaN                         NaN
# 109161                   NaN                         NaN
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 0                         True                          7821411.0
# 2                         True                          4493034.0
# 3                         True                          2228554.0
# 4                         True                          5271247.0
# 5                         True                          9412834.0
# ...                        ...                                ...
# 109157                     NaN                                NaN
# 109158                     NaN                                NaN
# 109159                     NaN                                NaN
# 109160                     NaN                                NaN
# 109161                     NaN                                NaN
#
#        depreciationamortization_match
# 0                                True
# 2                                True
# 3                                True
# 4                                True
# 5                                True
# ...                               ...
# 109157                            NaN
# 109158                            NaN
# 109159                            NaN
# 109160                            NaN
# 109161                            NaN
#
# [99684 rows x 36 columns]

# %%
merged_df.describe()
# Out:
#                Year       Revenue  Revenue Growth  Operating Income  \
# count  99684.000000  9.968400e+04    98508.000000      9.850800e+04
# mean    2012.749980  1.102225e+09        2.723434      1.843641e+08
# std        7.458296  6.424239e+08       25.186756      1.590442e+08
# min     2000.000000  1.249005e+06       -0.999131      1.326189e+05
# 25%     2006.000000  5.506577e+08       -0.456824      5.641282e+07
# 50%     2013.000000  1.094675e+09        0.000000      1.419928e+08
# 75%     2020.000000  1.637873e+09        0.871727      2.733886e+08
# max     2024.000000  2.551488e+09     1635.022705      9.520607e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# count  9.850800e+04      98508.000000  9.916500e+04        98508.000000
# mean   1.838147e+08          0.165839  5.080734e+08            0.461223
# std    1.590430e+08          0.091630  3.142898e+08            0.082220
# min    4.415663e+02          0.000002  5.030428e+05            0.300000
# 25%    5.582250e+07          0.092728  2.462394e+08            0.394586
# 50%    1.414293e+08          0.161750  4.863062e+08            0.463395
# 75%    2.728563e+08          0.233243  7.382905e+08            0.531653
# max    9.510885e+08          0.396542  1.486397e+09            0.599999
#
#        Operating Expenses  Cost of Revenue  ...  expected_netincome  \
# count        9.850800e+04     9.916500e+04  ...        9.850800e+04
# mean         3.239783e+08     5.943290e+08  ...        1.838147e+08
# std          2.018362e+08     3.622300e+08  ...        1.590430e+08
# min          3.667232e+05     5.481921e+05  ...        4.415663e+02
# 25%          1.559077e+08     2.899245e+08  ...        5.582250e+07
# 50%          3.098174e+08     5.778838e+08  ...        1.414293e+08
# 75%          4.682072e+08     8.633439e+08  ...        2.728563e+08
# max          9.788143e+08     1.769863e+09  ...        9.510885e+08
#
#        expected_netincome_ratio  expected_grossprofit_ratio  \
# count              98508.000000                98508.000000
# mean                   0.165839                    0.461223
# std                    0.091630                    0.082220
# min                    0.000002                    0.300000
# 25%                    0.092728                    0.394586
# 50%                    0.161750                    0.463395
# 75%                    0.233243                    0.531653
# max                    0.396542                    0.599999
#
#        expected_grossprofit  expected_revenue  expected_revenuegrowth  \
# count          9.850800e+04      9.916500e+04            98508.000000
# mean           5.083424e+08      1.102402e+09                2.723434
# std            3.142255e+08      6.425221e+08               25.186756
# min            5.030428e+05      1.249005e+06               -0.999131
# 25%            2.465416e+08      5.506737e+08               -0.456824
# 50%            4.869337e+08      1.094765e+09                0.000000
# 75%            7.385511e+08      1.637902e+09                0.871727
# max            1.486397e+09      2.551488e+09             1635.022705
#
#        expected_costofrevenue  expected_operatingincome  \
# count            9.850800e+04              9.850800e+04
# mean             5.945659e+08              1.843641e+08
# std              3.621986e+08              1.590442e+08
# min              5.481921e+05              1.326189e+05
# 25%              2.900895e+08              5.641282e+07
# 50%              5.781479e+08              1.419928e+08
# 75%              8.636343e+08              2.733886e+08
# max              1.769863e+09              9.520607e+08
#
#        expected_operatingexpenses  expected_depreciationamortization
# count                9.850800e+04                       9.850800e+04
# mean                 3.239783e+08                       5.055885e+06
# std                  2.018362e+08                       2.857988e+06
# min                  3.667232e+05                       1.001190e+05
# 25%                  1.559077e+08                       2.592128e+06
# 50%                  3.098174e+08                       5.055082e+06
# 75%                  4.682072e+08                       7.529402e+06
# max                  9.788143e+08                       9.999999e+06
#
# [8 rows x 24 columns]

# %%
# merged_df.to_csv('merged_df_v2.csv', index=False)
