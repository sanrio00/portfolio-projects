# %%
import requests
import random
import numpy as np
import pandas as pd
import string #Required for generating random stock tickers

# %% [markdown]
# # 1. Retrieving Real Stock Data with API

# %% [markdown]
# To start off, we obtain the Top 200 stocks by market capitalization (named as price in the code) from US-listed exchanges.
#
# We also include a try-except block to ensure that any errors during requests are caught and reported.

# %%
stock_url = "https://financialmodelingprep.com/api/v3/stock/list?apikey=NSD2m35XyjrwOoYdtKbq1JPOHlABl8CW"

try:
    stock_response = requests.get(stock_url)
    stock_response.raise_for_status()
    stock_data = stock_response.json()

    # Check API response structure
    print("Sample API Response:")
    print(stock_data[:5])

    # Filter US-listed stocks only
    us_exchanges = ['NYSE', 'NASDAQ', 'AMEX']

    valid_stocks = [
        stock for stock in stock_data
        if stock.get('exchangeShortName') in us_exchanges  # US-listed exchanges
        and stock.get('type') == 'stock'  # Only include stocks
        and stock.get('price') is not None  # Ensure price is not None
    ]

    print(f"Total valid stocks: {len(valid_stocks)}")
    print("Sample valid stocks:", valid_stocks[:5])

    # Sort by price, handling None values safely
    sorted_stocks = sorted(valid_stocks, key=lambda x: x.get('price', 0), reverse=True)

    # Get the top 200 stocks
    top_200_stocks = sorted_stocks[:200]
    stock_symbols = [stock['symbol'] for stock in top_200_stocks]

    print("Top 200 Stocks by Price (Placeholder for Market Cap):")
    print(stock_symbols)

except Exception as e:
    print(f"Error: {e}")
# Out:
# Sample API Response:
# [{'symbol': 'NPOF.ME', 'name': 'FIZIKA Scientific and Production Association Open Joint-Stock Company', 'price': 11850, 'exchange': 'Moscow Stock Exchange', 'exchangeShortName': 'MCX', 'type': 'stock'}, {'symbol': 'TERRAREAL.BO', 'name': 'Terraform Realstate Limited', 'price': 6.5, 'exchange': 'Bombay Stock Exchange', 'exchangeShortName': 'BSE', 'type': 'stock'}, {'symbol': 'PMGOLD.AX', 'name': 'Perth Mint Gold', 'price': 17.94, 'exchange': 'Australian Securities Exchange', 'exchangeShortName': 'ASX', 'type': 'etf'}, {'symbol': 'KZMS.ME', 'name': 'The Open Joint Stock Company Krasnokamsk Metal Mesh Works', 'price': 226, 'exchange': 'Moscow Stock Exchange', 'exchangeShortName': 'MCX', 'type': 'stock'}, {'symbol': 'BAHN-B.ST', 'name': 'Bahnhof AB (publ)', 'price': 53.4, 'exchange': 'Stockholm Stock Exchange', 'exchangeShortName': 'STO', 'type': 'stock'}]
# Total valid stocks: 11062
# Sample valid stocks: [{'symbol': 'NSC', 'name': 'Norfolk Southern Corporation', 'price': 256.14, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}, {'symbol': 'NVR', 'name': 'NVR, Inc.', 'price': 8345.35, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}, {'symbol': 'AAMI', 'name': 'Acadian Asset Management', 'price': 25.66, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}, {'symbol': 'DELL', 'name': 'Dell Technologies Inc.', 'price': 114.22, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}, {'symbol': 'HOUS', 'name': 'Anywhere Real Estate Inc.', 'price': 3.84, 'exchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'type': 'stock'}]
# Top 200 Stocks by Price (Placeholder for Market Cap):
# ['BRK-A', 'NVR', 'BKNG', 'AZO', 'SEB', 'FCNCA', 'WTM', 'FICO', 'DHR-PA', 'MELI', 'MKL', 'AVGOP', 'TPL', 'TDG', 'MTD', 'COKE', 'ORLY', 'DHR-PB', 'BAC-PL', 'WFC-PL', 'NOW', 'GWW', 'BH-A', 'BLK', 'NFLX', 'FTV-PA', 'COST', 'EQIX', 'GHC', 'USB-PA', 'Y', 'URI', 'LLY', 'KLAC', 'ASML', 'HUBS', 'MPWR', 'REGN', 'PH', 'LII', 'ARGX', 'GS', 'META', 'MSCI', 'AXON', 'ISRG', 'INTU', 'MCK', 'TYL', 'TMO', 'AMP', 'SNPS', 'MLM', 'FIX', 'CHE', 'MA', 'ROP', 'EME', 'UNH', 'IT', 'CACC', 'TDY', 'SPGI', 'SAIA', 'SPOT', 'NWLI', 'NOC', 'WSO', 'NEU', 'LMT', 'MCO', 'ANTM', 'MUSA', 'MSI', 'CVCO', 'DDS', 'DE', 'DJCO', 'WSO-B', 'FDS', 'ATRI', 'BRK-B', 'HUBB', 'GPI', 'DPZ', 'MSFT', 'LIN', 'VRTX', 'GEV', 'ADBE', 'RH', 'KNSL', 'IDXX', 'UI', 'RACE', 'CACI', 'ZBRA', 'ULTA', 'HD', 'WAT', 'TSLA', 'CASY', 'CAT', 'CSL', 'ELV', 'TT', 'WINA', 'SYK', 'LULU', 'CW', 'ABMD', 'CSWI', 'KAI', 'CRWD', 'ERIE', 'CPAY', 'MSTR', 'UTHR', 'ETN', 'CMI', 'AON', 'ACN', 'EG', 'APP', 'POOL', 'SHW', 'ANSS', 'CHTR', 'CYBR', 'LPLA', 'BLD', 'PWR', 'BIO', 'RE', 'SNA', 'BIO-B', 'MEDP', 'LAD', 'CEG', 'WST', 'VMI', 'MDGL', 'CABO', 'AYI', 'DUOL', 'SWAV', 'CRM', 'KRTX', 'V', 'ESGR', 'MORN', 'AXP', 'HCA', 'CDNS', 'APD', 'WTW', 'RBC', 'STZ-B', 'MOH', 'PIPR', 'IESC', 'FLT', 'ADSK', 'ESLT', 'COIN', 'ADP', 'CI', 'HUM', 'KSU', 'BURL', 'PRI', 'PSA', 'ROK', 'POWL', 'WIRE', 'WING', 'AJG', 'RS', 'MAR', 'MANH', 'EVR', 'MCD', 'VRSK', 'AMGN', 'ESS', 'PODD', 'ASR', 'ALNY', 'SAP', 'VMC', 'JLL', 'PEN', 'FFIV', 'FDX', 'PXD', 'EFX', 'GD', 'FLUT', 'CB', 'JPM']

# %% [markdown]
# For each of these Top 200 stocks, we will then retrieve its annual income statement data with an API request.
#
# The API response is stored in a list of dictionary to extract relevant metrics like Year, Revenue and Net Income.
#
# Hence, each record corresponds to a specific stock and year, with detailed financial metrics.
#
# Again, error handling during API requests is included and reported.

# %%
data = []

# For each valid stock, fetch income data and store it
for stock in stock_symbols:
    try:
        # Build the API URL for income statement
        income_url = f"https://financialmodelingprep.com/api/v3/income-statement/{stock}?period=annual&apikey=NSD2m35XyjrwOoYdtKbq1JPOHlABl8CW"
        
        # Fetch data from the API
        response = requests.get(income_url, timeout=10)  # Added timeout
        
        # Check for a successful response
        if response.status_code != 200:
            print(f"Failed to fetch data for {stock}: HTTP {response.status_code}")
            continue
        
        # Parse JSON response
        income_response = response.json()

        # Check if the income response is a non-empty list
        if isinstance(income_response, list) and income_response:
            for report in income_response:  # Loop over each year
                # Extract the year safely
                year = report.get('date', '')
                year = year.split('-')[0] if '-' in year else year

                # Create a dictionary for the stock report
                row = {
                    'Stock': stock,
                    'Year': year,
                    'Revenue': report.get('revenue'),
                    'Revenue Growth': report.get('revenueGrowth'),
                    'Operating Income': report.get('operatingIncome'),
                    'Net Income': report.get('netIncome'),
                    'Net Income Ratio': report.get('netIncomeRatio'),
                    'Gross Profit': report.get('grossProfit'),
                    'Gross Profit Ratio': report.get('grossProfitRatio'),
                    'Operating Expenses': report.get('operatingExpenses'),
                    'Cost of Revenue': report.get('costOfRevenue'),
                    'EBITDA': report.get('ebitda'),
                    'Interest Expense': report.get('interestExpense'),
                    'Depreciation & Amortization': report.get('depreciationAndAmortization')
                }
                # Append the row to the data list
                data.append(row)
        else:
            print(f"No income data available for {stock}.")
    except Exception as e:
        print(f"Error fetching data for {stock}: {e}")

# %%
# Output the data to check
print(f"Fetched data for {len(data)} records.")
# Out:
# Fetched data for 999 records.

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (999, 14)

# %%
# Checking all stocks requested are inside df
df['Stock'].nunique()
# Out:
# 200

# %%
# df.to_csv('api_stock.csv')

# %% [markdown]
# # 2. Obtaining Base, Partial, Historical & Sparse Datasets

# %% [markdown]
# ### Base Dataset

# %% [markdown]
# We create a synthetic dataset of 100,000 rows containing simulated financial metrics for various stocks across year 2000 to 2024.
#
# Using generate_random_tickers, we create unique stocks of random lengths and create stock-year combinations. We then simulate the other financial metrics proportionally based on the revenue. For example, cost of revenue is 40-70% of revenue.
#
# We then verified the data integrity by checking no duplicate stock-year combination exists.

# %%
# Define parameters for simulation
n_desired_rows = 100000  # Target number of unique rows
years = list(range(2000, 2025))  # Expand the range of years (e.g., 2000-2024)
n_unique_stocks_needed = n_desired_rows // len(years) + 1  # Number of unique stocks needed

# %%
# Generate fake stock tickers
def generate_random_tickers(n, length_range=(4, 6)):
    tickers = set()  # Use a set to ensure uniqueness
    while len(tickers) < n:
        length = random.randint(*length_range)  # Random length between 4 and 6
        ticker = ''.join(random.choices(string.ascii_uppercase, k=length))
        tickers.add(ticker)
    return list(tickers)

# Define the number of unique stock tickers needed
n_unique_stocks_needed = n_desired_rows // len(years) + 1

# Generate random stock tickers
base_stocks = generate_random_tickers(n_unique_stocks_needed)

# %%
# Generate all possible stock-year combinations
stock_year_combinations = [(stock, year) for stock in base_stocks for year in years]

# Shuffle the combinations to randomize the order
np.random.seed(42)  # Ensure reproducibility
random.shuffle(stock_year_combinations)

# Select exactly 100,000 rows
stock_year_combinations = stock_year_combinations[:n_desired_rows]

# %%
# Initialize an empty list to store simulated data
simulated_data = []

# Simulate data for unique stock-year combinations
for i, (stock, year) in enumerate(stock_year_combinations):
    # Use previous year's revenue for this stock (if available)
    if i > 0 and simulated_data[-1]['Stock'] == stock:
        previous_revenue = simulated_data[-1]['Revenue']
    else:
        previous_revenue = np.random.randint(1e6, 2.1e9)  # Random initial revenue if no previous data

    # Calculate revenue based on growth
    revenue_growth = np.random.uniform(-0.1, 0.2)  # Random growth rate (-10% to 20%)
    revenue = previous_revenue * (1 + revenue_growth)
    
    # Simulate financial metrics
    cost_of_revenue = revenue * np.random.uniform(0.4, 0.7)
    gross_profit = revenue - cost_of_revenue
    operating_expenses = np.random.uniform(0.2, 0.4) * revenue
    operating_income = gross_profit - operating_expenses
    depreciation_and_amortization = np.random.randint(1e5, 1e7)
    ebitda = operating_income + depreciation_and_amortization
    interest_expense = np.random.randint(1e5, 1e6)
    net_income = operating_income - interest_expense
    net_income_ratio = net_income / revenue if revenue != 0 else 0
    gross_profit_ratio = gross_profit / revenue if revenue != 0 else 0

    # Append to simulated data
    simulated_data.append({
        'Stock': stock,
        'Year': year,
        'Revenue': revenue,
        'Revenue Growth': revenue_growth,
        'Operating Income': operating_income,
        'Net Income': net_income,
        'Net Income Ratio': net_income_ratio,
        'Gross Profit': gross_profit,
        'Gross Profit Ratio': gross_profit_ratio,
        'Operating Expenses': operating_expenses,
        'Cost of Revenue': cost_of_revenue,
        'EBITDA': ebitda,
        'Interest Expense': interest_expense,
        'Depreciation & Amortization': depreciation_and_amortization,
    })

# %%
# Convert to a DataFrame
simulated_df = pd.DataFrame(simulated_data)

# Verify duplicates
duplicates = simulated_df.duplicated(subset=['Stock', 'Year'], keep=False)
print(f"Number of duplicates: {duplicates.sum()}")

# Display the first rows
print(simulated_df.head())
# Out:
# Number of duplicates: 0
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 0    BPZC  2011  1.833317e+09        0.138963      3.465545e+08  3.459331e+08
# 1    BTMV  2005  2.599285e+08        0.037775      7.052226e+07  7.035744e+07
# 2  SSBABI  2004  2.254691e+09        0.116600      2.666813e+08  2.663455e+08
# 3  KTCOVN  2015  5.011669e+08       -0.008727      7.827428e+07  7.767409e+07
# 4   HBGGH  2012  4.910126e+08        0.019958      9.390576e+07  9.374003e+07
#
#    Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 0          0.188692  9.991022e+08            0.544970        6.525477e+08
# 1          0.270680  1.299350e+08            0.499887        5.941274e+07
# 2          0.118130  7.179707e+08            0.318434        4.512894e+08
# 3          0.154986  2.218030e+08            0.442573        1.435287e+08
# 4          0.190912  2.877335e+08            0.586000        1.938277e+08
#
#    Cost of Revenue        EBITDA  Interest Expense  \
# 0     8.342152e+08  3.488890e+08            621430
# 1     1.299935e+08  7.514593e+07            164820
# 2     1.536720e+09  2.668847e+08            335796
# 3     2.793639e+08  8.767993e+07            600186
# 4     2.032790e+08  1.038953e+08            165725
#
#    Depreciation & Amortization
# 0                      2334489
# 1                      4623669
# 2                       203355
# 3                      9405648
# 4                      9989550

# %% [markdown]
# Importantly, we concatenate the simulated_df with the initial df containing the real stocks to generate the base dataset.

# %%
expanded_df = pd.concat([df, simulated_df], ignore_index=True)
# Out:
# C:\Users\tk_ko\AppData\Local\Temp\ipykernel_24240\2238662938.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   expanded_df = pd.concat([df, simulated_df], ignore_index=True)

# %%
expanded_df.to_csv('expanded_dataset_v5.csv', index=False)

# %%
print(f"Expanded dataset has {len(expanded_df)} rows.")
# Out:
# Expanded dataset has 100999 rows.

# %% [markdown]
# ### Partial Dataset

# %% [markdown]
# The partial dataset overlaps with the base dataset, but has missing values in some columns.
#
# The year range is limited to 2022 to 2023.

# %%
# Create a deep copy of expanded_df, with filters by 2022, 2023
partial_df = expanded_df[expanded_df['Year'].isin([2022,2023])].copy()

#Introduce missing data in 'Revenue', 'Net Income' and 'Operating Expenses'
partial_df.loc[partial_df.sample(frac=0.2).index, 'Revenue'] = np.nan #Within revenue, introduce 20% of missing data
partial_df.loc[partial_df.sample(frac=0.1).index, 'Net Income'] = np.nan #Within net income, introduce 10% of missing data
partial_df.loc[partial_df.sample(frac=0.3).index, 'Operating Expenses'] = np.nan #Within operating expenses, introduce 30% of missing data

# %%
# partial_df.to_csv('partial_dataset_v5.csv', index=False)

# %%
partial_df.head()
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 1017  TLSNGU  2023  1.377147e+09        0.166164      3.228263e+08
# 1078    ALAD  2022           NaN        0.125184     -8.221426e+07
# 1088  ZTSXEF  2023  3.194701e+08        0.018995      3.294055e+07
# 1103  BSFLIH  2023  2.243174e+09        0.184940      1.336957e+08
# 1117   XOJED  2022  6.565935e+08        0.037804     -4.209403e+06
#
#         Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 1017  3.225423e+08          0.234210  6.311956e+08            0.458336
# 1078 -8.238490e+07         -0.040235  7.329389e+08            0.357950
# 1088  3.232122e+07          0.101171  1.062017e+08            0.332431
# 1103  1.331177e+08          0.059343  8.575299e+08            0.382284
# 1117 -5.198303e+06         -0.007917  2.280826e+08            0.347373
#
#       Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 1017        3.083693e+08     7.459519e+08  3.283275e+08          284064.0
# 1078                 NaN     1.314665e+09 -7.814426e+07          170640.0
# 1088                 NaN     2.132684e+08  3.994439e+07          619332.0
# 1103                 NaN     1.385644e+09  1.349737e+08          578007.0
# 1117                 NaN     4.285109e+08  4.929404e+06          988900.0
#
#       Depreciation & Amortization
# 1017                    5501218.0
# 1078                    4070001.0
# 1088                    7003836.0
# 1103                    1278049.0
# 1117                    9138807.0

# %% [markdown]
# ### Historical Dataset

# %% [markdown]
# The historical dataset introduces a larger range of years (but randomized), with mismatched data and duplicate records.
#
# Stocks in this dataset are referenced from the stocks in the base dataset.

# %%
historical_data = []
historical_years = range(2010, 2021) # Year 2010 to 2021
historical_stocks = expanded_df['Stock']

# %%
# Function to simulate revenue, with missing and invalid values
def simulate_revenue():
    # 20% chance of missing revenue
    revenue = np.random.randint(1e6, 2.1e9) if np.random.rand() > 0.2 else None
    
    # 5% chance for invalid negative revenue
    if np.random.rand() < 0.05:
        revenue = np.random.randint(-1e9, -1e6)
    return revenue

# %%
# Function to simulate 'Cost of Revenue', allowing for missing or mismatched values
def simulate_cost_of_revenue(revenue):
    if revenue is None or np.random.rand() < 0.1:  # 10% chance of missing value
        return None
    return revenue * np.random.uniform(0.3, 0.8)

# %%
# Function to introduce random mismatches in stock names
def simulate_stock_name(stock):
    if np.random.rand() < 0.05:  # 5% chance for mismatch
        return stock + ' .end'
    return stock

# %%
# Function to simulate random years, including errors outside the range
def simulate_year():
    if np.random.rand() > 0.05:  # 95% chance of random error
        return np.random.randint(2130, 2200)
    return np.random.choice(historical_years)

# %%
# Function to calculate gross profit if valid inputs are provided
def calculate_gross_profit(revenue, cost_of_revenue):
    if revenue is not None and cost_of_revenue is not None:
        return revenue - cost_of_revenue
    return None

# %%
# Simulate 10,000 rows of historical data
for _ in range(10000):
    # Simulate each field using the functions
    stock = simulate_stock_name(np.random.choice(historical_stocks))
    year = simulate_year()
    revenue = simulate_revenue()
    cost_of_revenue = simulate_cost_of_revenue(revenue)
    gross_profit = calculate_gross_profit(revenue, cost_of_revenue)

    historical_data.append({
        'Stock': stock,
        'Year': year,
        'Revenue': revenue,
        'Cost of Revenue': cost_of_revenue,
        'Gross Profit': gross_profit
    })

# %%
historical_df = pd.DataFrame(historical_data)

# %%
# historical_df.to_csv('historical_dataset_v4.csv', index=False)

# %% [markdown]
# ### Sparse Dataset

# %% [markdown]
# Finally, the sparse dataset only contains 100 random stocks, with year and revenue as their only metrics.
#
# Like the Historical dataset, stocks are refrenced from those in the base dataset.
#
# 50% of the revenue column will be empty.

# %%
sparse_data = []
sparse_years = range(2000, 2009)
sparse_stocks = expanded_df['Stock']

# %%
for stock in np.random.choice(sparse_stocks, size=100, replace=False): #Select 100 random stocks
    for year in sparse_years:
        if np.random.rand() > 0.5: #For 50% of the year column, assign a random revenue. The other 50% will be uninitialized
            revenue = np.random.randint(1e6, 2.1e9)
            
            sparse_data.append({
                'Stock': stock,
                'Year': year,
                'Revenue': revenue
            })

# %%
sparse_df = pd.DataFrame(sparse_data)

# %%
# sparse_df.to_csv('sparse_dataset_v4.csv', index=False)

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ### Check whether every stock-year pair is unique

# %%
def check_unique_stock_year_pairs(df, stock_col='Stock', year_col='Year'):
    # Create a combined column to check for duplicates
    unique_combinations = df[[stock_col, year_col]].drop_duplicates()

    # Compare the length of unique combinations with the original DataFrame
    if len(unique_combinations) == len(df):
        print("All stock-year pairs are unique.")
        return True
    else:
        print("There are duplicate stock-year pairs.")
        # Keep no duplicates to ensure only rows with unique Stock-Year pairs remain
        duplicates = df[df.duplicated(subset=[stock_col, year_col], keep=False)]
        print("Duplicate entries:")
        print(duplicates)
        print(duplicates.shape)
        return False

# %%
# 10 duplicate pairs
check_unique_stock_year_pairs(expanded_df)
# Out:
# There are duplicate stock-year pairs.
# Duplicate entries:
#     Stock  Year       Revenue  Revenue Growth  Operating Income   Net Income  \
# 305   TDY  2023  5.635500e+09             NaN      1.046800e+09  885700000.0
# 306   TDY  2023  5.458600e+09             NaN      9.720000e+08  788600000.0
# 420   DPZ  2023  4.479358e+09             NaN      8.195190e+08  519118000.0
# 421   DPZ  2023  4.537158e+09             NaN      7.679250e+08  452263000.0
# 560   KAI  2022  9.047390e+08             NaN      1.712820e+08  120928000.0
# 561   KAI  2022  7.865790e+08             NaN      1.167100e+08   84043000.0
# 670   SNA  2022  4.492800e+09             NaN      1.207200e+09  911700000.0
# 671   SNA  2022  4.252000e+09             NaN      1.123500e+09  820500000.0
# 765  CDNS  2022  3.561718e+09             NaN      1.073686e+09  848952000.0
# 766  CDNS  2022  2.988244e+09             NaN      7.790890e+08  695955000.0
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 305          0.157164  2.439400e+09            0.432863        1.403200e+09
# 306          0.144469  2.330300e+09            0.426904        1.358300e+09
# 420          0.115891  1.727417e+09            0.385639        9.064500e+08
# 421          0.099680  1.648606e+09            0.363357        8.806810e+08
# 560          0.133661  3.895550e+08            0.430572        2.371290e+08
# 561          0.106846  3.373650e+08            0.428902        2.201900e+08
# 670          0.202925  2.181100e+09            0.485466        9.739000e+08
# 671          0.192968  2.110800e+09            0.496425        9.873000e+08
# 765          0.238355  3.190095e+09            0.895662        2.116354e+09
# 766          0.232898  2.681238e+09            0.897262        1.903197e+09
#
#      Cost of Revenue        EBITDA  Interest Expense  \
# 305     3.196100e+09  1.360800e+09        85500000.0
# 306     3.128300e+09  1.335200e+09        89300000.0
# 420     2.751941e+09  9.295550e+08       196475000.0
# 421     2.888552e+09  8.513380e+08       195092000.0
# 560     5.151840e+08  1.877660e+08         6478000.0
# 561     4.492140e+08  1.593540e+08         4821000.0
# 670     2.311700e+09  1.351500e+09        47100000.0
# 671     2.141200e+09  1.249100e+09        53100000.0
# 765     3.716230e+08  1.200385e+09        22934000.0
# 766     3.070060e+08  9.277230e+08        16980000.0
#
#      Depreciation & Amortization
# 305                  316400000.0
# 306                  332200000.0
# 420                   80640000.0
# 421                   80251000.0
# 560                   34936000.0
# 561                   34302000.0
# 670                  100200000.0
# 671                  104800000.0
# 765                  132088000.0
# 766                  142308000.0
# (10, 14)
# False

# %%
check_unique_stock_year_pairs(partial_df)
# Out:
# All stock-year pairs are unique.
# True

# %%
# 298 duplicate pairs
check_unique_stock_year_pairs(historical_df)
# Out:
# There are duplicate stock-year pairs.
# Duplicate entries:
#        Stock  Year       Revenue  Cost of Revenue  Gross Profit
# 21     QCIBQ  2173 -7.091537e+08    -2.220766e+08 -4.870771e+08
# 35    ZDQBNG  2198  1.810861e+09     1.054031e+09  7.568299e+08
# 90    UAHQYG  2161  1.119969e+09     5.023274e+08  6.176421e+08
# 107   IOPWJI  2185           NaN              NaN           NaN
# 112   MNQKWG  2174  2.173614e+07     9.765953e+06  1.197018e+07
# ...      ...   ...           ...              ...           ...
# 9826    GAUD  2195           NaN              NaN           NaN
# 9852    SAAZ  2193  1.757162e+09     1.375122e+09  3.820405e+08
# 9862    SSFY  2199  1.954715e+09     1.181685e+09  7.730297e+08
# 9881  FWNPUT  2194 -1.812004e+08    -7.539939e+07 -1.058010e+08
# 9980    PRCQ  2143  1.402420e+09     9.505610e+08  4.518590e+08
#
# [298 rows x 5 columns]
# (298, 5)
# False

# %%
# 2 duplicate pairs
check_unique_stock_year_pairs(sparse_df)
# Out:
# There are duplicate stock-year pairs.
# Duplicate entries:
#      Stock  Year     Revenue
# 44   INPCQ  2008  1989476413
# 200  INPCQ  2008  1040112774
# (2, 3)
# False

# %% [markdown]
# ### Dropping duplicate stock-year pairs

# %%
def drop_duplicate_stock_year_pairs(df, stock_col='Stock', year_col='Year'):
    print("DataFrame after dropping all duplicates:")
    return df[~df.duplicated(subset=['Stock', 'Year'], keep=False)]

# %%
expanded_df = drop_duplicate_stock_year_pairs(expanded_df)
print(expanded_df)
# Out:
# DataFrame after dropping all duplicates:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        BRK-A  2023  3.644820e+11             NaN      1.231960e+11
# 1        BRK-A  2022  2.341900e+11             NaN     -2.698500e+10
# 2        BRK-A  2021  3.546360e+11             NaN     -8.242500e+10
# 3        BRK-A  2020  2.862560e+11             NaN     -1.135820e+11
# 4        BRK-A  2019  3.272230e+11             NaN     -7.723400e+10
# ...        ...   ...           ...             ...               ...
# 100994  PTLEBY  2005  1.333766e+09       -0.082426      2.334087e+08
# 100995  PGQDKT  2024  1.548388e+09        0.145031      2.106748e+08
# 100996    BPCR  2020  4.912654e+08        0.178375      6.713231e+07
# 100997  FOXTWC  2019  2.127840e+09        0.034832      1.880026e+08
# 100998    VFOK  2021  7.101194e+08        0.051971      1.873849e+08
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       9.622300e+10          0.263999  1.231960e+11            0.338003
# 1      -2.281900e+10         -0.097438  1.098710e+11            0.469153
# 2       8.993700e+10          0.253604  1.337060e+11            0.377023
# 3       4.252100e+10          0.148542  8.953000e+10            0.312762
# 4       8.141700e+10          0.248812  1.248030e+11            0.381400
# ...              ...               ...           ...                 ...
# 100994  2.328940e+08          0.174614  6.811253e+08            0.510678
# 100995  2.098682e+08          0.135540  5.824036e+08            0.376136
# 100996  6.666666e+07          0.135704  2.549765e+08            0.519020
# 100997  1.870805e+08          0.087920  9.650140e+08            0.453518
# 100998  1.866904e+08          0.262900  4.081978e+08            0.574830
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 0             1.985750e+11     2.412860e+11  1.376550e+11      5.003000e+09
# 1             1.423100e+11     1.243190e+11 -1.524900e+10      4.352000e+09
# 2            -4.370610e+11     2.209300e+11  1.265760e+11      4.172000e+09
# 3            -3.998380e+11     1.967260e+11  8.038600e+10      4.083000e+09
# 4            -4.044570e+11     2.024200e+11  1.156410e+11      3.961000e+09
# ...                    ...              ...           ...               ...
# 100994        4.477166e+08     6.526406e+08  2.400571e+08      5.146860e+05
# 100995        3.717289e+08     9.659840e+08  2.154545e+08      8.065550e+05
# 100996        1.878442e+08     2.362889e+08  6.861804e+07      4.656480e+05
# 100997        7.770114e+08     1.162826e+09  1.941805e+08      9.220510e+05
# 100998        2.208130e+08     3.019215e+08  1.891152e+08      6.944930e+05
#
#         Depreciation & Amortization
# 0                      1.248600e+10
# 1                      1.089900e+10
# 2                      1.071800e+10
# 3                      1.059600e+10
# 4                      1.006400e+10
# ...                             ...
# 100994                 6.648408e+06
# 100995                 4.779709e+06
# 100996                 1.485732e+06
# 100997                 6.177922e+06
# 100998                 1.730361e+06
#
# [100989 rows x 14 columns]

# %%
historical_df = drop_duplicate_stock_year_pairs(historical_df)
print(historical_df)
# Out:
# DataFrame after dropping all duplicates:
#        Stock  Year       Revenue  Cost of Revenue  Gross Profit
# 0     IVMAGX  2161           NaN              NaN           NaN
# 1       HIJQ  2149  1.839813e+08     1.345906e+08  4.939068e+07
# 2      WAKFT  2151           NaN              NaN           NaN
# 3       QHIN  2133  1.891520e+09     8.866202e+08  1.004900e+09
# 4     IABVRF  2148  1.850278e+09     8.869205e+08  9.633574e+08
# ...      ...   ...           ...              ...           ...
# 9995    OXVC  2154  8.033017e+08              NaN           NaN
# 9996    JZDY  2142  6.132366e+08              NaN           NaN
# 9997    PDCX  2135  1.120415e+09     7.403297e+08  3.800858e+08
# 9998    YPOT  2182  1.136122e+08     7.777145e+07  3.584073e+07
# 9999  KBNXVP  2160  1.025777e+09     7.303527e+08  2.954241e+08
#
# [9702 rows x 5 columns]

# %%
sparse_df = drop_duplicate_stock_year_pairs(sparse_df)
print(sparse_df)
# Out:
# DataFrame after dropping all duplicates:
#     Stock  Year     Revenue
# 0    OBWA  2000  1709725917
# 1    OBWA  2001   675481498
# 2    OBWA  2002   783243374
# 3    OBWA  2004  1976308486
# 4    OBWA  2005  1756793979
# ..    ...   ...         ...
# 475  RXDK  2003   718562045
# 476  RXDK  2004  1337162477
# 477  RXDK  2005    94388513
# 478  RXDK  2006   743663602
# 479  RXDK  2008    48647460
#
# [478 rows x 3 columns]

# %% [markdown]
# ### Check for duplicates

# %%
# Base dataset
print(f"Duplicate entries (Base Dataset): {expanded_df.duplicated().sum()}")
print(f"{round((expanded_df.duplicated().sum() / partial_df.shape[0]) * 100, 2)}% rows are duplicate.")

# Partial dataset
print(f"Duplicate entries (Partial Dataset): {partial_df.duplicated().sum()}")
print(f"{round((partial_df.duplicated().sum() / partial_df.shape[0]) * 100, 2)}% rows are duplicate.")

# Historical dataset
print(f"Duplicate entries (Historical Dataset): {historical_df.duplicated().sum()}")
print(f"{round((historical_df.duplicated().sum() / historical_df.shape[0]) * 100, 2)}% rows are duplicate.")

# Sparse dataset
print(f"Duplicate entries (Sparse Dataset): {sparse_df.duplicated().sum()}")
print(f"{round((sparse_df.duplicated().sum() / sparse_df.shape[0]) * 100, 2)}% rows are duplicate.")
# Out:
# Duplicate entries (Base Dataset): 0
# 0.0% rows are duplicate.
# Duplicate entries (Partial Dataset): 0
# 0.0% rows are duplicate.
# Duplicate entries (Historical Dataset): 0
# 0.0% rows are duplicate.
# Duplicate entries (Sparse Dataset): 0
# 0.0% rows are duplicate.

# %% [markdown]
# ### Check for inconsistencies

# %% [markdown]
# This function prints the number of unique values per column. From the unique values, we can also tell any inconsistencies such as impossible negatives in revenue that we need to manage.

# %%
# Loop through all columns and print unique values
def no_of_unique_values(df):
    for col in df.columns:
        print(f"Column Name (Base Dataset): {col}")
        print(f"Unique Values: {df[col].unique()}")
        print(f"Number of Unique Values: {df[col].nunique()}")
        print('-' * 60) # To demarcate columns

# %%
no_of_unique_values(expanded_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['BRK-A' 'NVR' 'BKNG' ... 'GAMTND' 'JTLKYV' 'INPCQ']
# Number of Unique Values: 4201
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: ['2023' '2022' '2021' '2020' '2019' '2024' '2018' '2017' '2016' 2011 2005
#  2004 2015 2012 2003 2002 2019 2010 2008 2020 2017 2018 2007 2023 2014
#  2021 2000 2006 2001 2009 2013 2024 2022 2016]
# Number of Unique Values: 34
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [3.64482000e+11 2.34190000e+11 3.54636000e+11 ... 4.91265446e+08
#  2.12784021e+09 7.10119385e+08]
# Number of Unique Values: 100947
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue Growth
# Unique Values: [       nan 0.1389629  0.03777467 ... 0.17837523 0.03483163 0.05197081]
# Number of Unique Values: 100000
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Income
# Unique Values: [ 1.23196000e+11 -2.69850000e+10 -8.24250000e+10 ...  6.71323111e+07
#   1.88002554e+08  1.87384865e+08]
# Number of Unique Values: 100956
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income
# Unique Values: [ 9.62230000e+10 -2.28190000e+10  8.99370000e+10 ...  6.66666631e+07
#   1.87080503e+08  1.86690372e+08]
# Number of Unique Values: 100950
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income Ratio
# Unique Values: [ 0.26399932 -0.09743798  0.2536037  ...  0.13570395  0.08792037
#   0.26289998]
# Number of Unique Values: 100949
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit
# Unique Values: [1.23196000e+11 1.09871000e+11 1.33706000e+11 ... 2.54976513e+08
#  9.65013953e+08 4.08197844e+08]
# Number of Unique Values: 100953
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit Ratio
# Unique Values: [0.33800297 0.46915325 0.3770232  ... 0.51901984 0.45351805 0.57482989]
# Number of Unique Values: 100909
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Expenses
# Unique Values: [ 1.98575000e+11  1.42310000e+11 -4.37061000e+11 ...  1.87844202e+08
#   7.77011400e+08  2.20812979e+08]
# Number of Unique Values: 100958
# ------------------------------------------------------------
# Column Name (Base Dataset): Cost of Revenue
# Unique Values: [2.41286000e+11 1.24319000e+11 2.20930000e+11 ... 2.36288934e+08
#  1.16282626e+09 3.01921540e+08]
# Number of Unique Values: 100911
# ------------------------------------------------------------
# Column Name (Base Dataset): EBITDA
# Unique Values: [ 1.37655000e+11 -1.52490000e+10  1.26576000e+11 ...  6.86180431e+07
#   1.94180476e+08  1.89115226e+08]
# Number of Unique Values: 100939
# ------------------------------------------------------------
# Column Name (Base Dataset): Interest Expense
# Unique Values: [5.00300e+09 4.35200e+09 4.17200e+09 ... 4.65648e+05 9.22051e+05
#  6.94493e+05]
# Number of Unique Values: 95392
# ------------------------------------------------------------
# Column Name (Base Dataset): Depreciation & Amortization
# Unique Values: [1.248600e+10 1.089900e+10 1.071800e+10 ... 1.485732e+06 6.177922e+06
#  1.730361e+06]
# Number of Unique Values: 100445
# ------------------------------------------------------------

# %%
no_of_unique_values(partial_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['TLSNGU' 'ALAD' 'ZTSXEF' ... 'CSVQR' 'GNNM' 'BYKC']
# Number of Unique Values: 4001
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: [2023 2022]
# Number of Unique Values: 2
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [1.37714747e+09            nan 3.19470092e+08 ... 2.82095823e+08
#  6.53232569e+08 1.66379394e+09]
# Number of Unique Values: 6398
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue Growth
# Unique Values: [ 0.16616382  0.12518443  0.01899548 ...  0.18353498 -0.00522837
#  -0.05541769]
# Number of Unique Values: 7997
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Income
# Unique Values: [ 3.22826330e+08 -8.22142569e+07  3.29405494e+07 ...  8.11277342e+07
#   2.77802526e+08  9.51786557e+07]
# Number of Unique Values: 7997
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income
# Unique Values: [ 3.22542266e+08 -8.23848969e+07  3.23212174e+07 ...  6.07363254e+07
#   2.77607129e+08  9.44435167e+07]
# Number of Unique Values: 7197
# ------------------------------------------------------------
# Column Name (Base Dataset): Net Income Ratio
# Unique Values: [ 0.2342104  -0.04023479  0.10117134 ...  0.12301841  0.16685187
#   0.09389908]
# Number of Unique Values: 7997
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit
# Unique Values: [6.31195607e+08 7.32938871e+08 1.06201739e+08 ... 2.68081941e+08
#  6.40833193e+08 3.24666714e+08]
# Number of Unique Values: 7997
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit Ratio
# Unique Values: [0.45833552 0.35794958 0.33243093 ... 0.4103928  0.3851638  0.32279511]
# Number of Unique Values: 7997
# ------------------------------------------------------------
# Column Name (Base Dataset): Operating Expenses
# Unique Values: [3.08369278e+08            nan 6.48981846e+07 ... 1.86954207e+08
#  3.63030666e+08 2.29488059e+08]
# Number of Unique Values: 5598
# ------------------------------------------------------------
# Column Name (Base Dataset): Cost of Revenue
# Unique Values: [7.45951867e+08 1.31466480e+09 2.13268353e+08 ... 3.85150627e+08
#  1.02296075e+09 6.81131390e+08]
# Number of Unique Values: 7997
# ------------------------------------------------------------
# Column Name (Base Dataset): EBITDA
# Unique Values: [ 3.28327548e+08 -7.81442559e+07  3.99443854e+07 ...  9.05970562e+07
#   2.81025075e+08  9.61329877e+07]
# Number of Unique Values: 7997
# ------------------------------------------------------------
# Column Name (Base Dataset): Interest Expense
# Unique Values: [284064. 170640. 619332. ... 768101. 195397. 735139.]
# Number of Unique Values: 7963
# ------------------------------------------------------------
# Column Name (Base Dataset): Depreciation & Amortization
# Unique Values: [5501218. 4070001. 7003836. ... 9469322. 3222549.  954332.]
# Number of Unique Values: 7995
# ------------------------------------------------------------

# %% [markdown]
# Significant inconsistencies in the Historical dataset include:
# 1. Impossible negatives
# 2. Impossible years (e.g. 2177)
# 3. Stock names with '.end'

# %%
no_of_unique_values(historical_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['IVMAGX' 'HIJQ' 'WAKFT' ... 'MAVKN .end' 'KXAKD' 'KPGH .end']
# Number of Unique Values: 4181
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: [2161 2149 2151 2133 2148 2187 2011 2183 2155 2134 2140 2180 2172 2142
#  2164 2136 2144 2163 2165 2170 2135 2182 2158 2153 2154 2012 2198 2190
#  2141 2145 2159 2179 2177 2185 2196 2150 2162 2132 2143 2166 2169 2191
#  2010 2194 2138 2013 2173 2199 2018 2193 2178 2167 2014 2188 2147 2192
#  2137 2186 2168 2181 2197 2156 2152 2020 2176 2157 2195 2146 2131 2184
#  2174 2171 2139 2017 2016 2130 2175 2160 2019 2015 2189]
# Number of Unique Values: 81
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [           nan 1.83981263e+08 1.89151975e+09 ... 1.12041550e+09
#  1.13612172e+08 1.02577676e+09]
# Number of Unique Values: 7886
# ------------------------------------------------------------
# Column Name (Base Dataset): Cost of Revenue
# Unique Values: [           nan 1.34590580e+08 8.86620204e+08 ... 7.40329660e+08
#  7.77714466e+07 7.30352662e+08]
# Number of Unique Values: 7090
# ------------------------------------------------------------
# Column Name (Base Dataset): Gross Profit
# Unique Values: [           nan 4.93906833e+07 1.00489954e+09 ... 3.80085839e+08
#  3.58407254e+07 2.95424096e+08]
# Number of Unique Values: 7090
# ------------------------------------------------------------

# %%
no_of_unique_values(sparse_df)
# Out:
# Column Name (Base Dataset): Stock
# Unique Values: ['OBWA' 'WQCQ' 'DWUEJW' 'KUPZ' 'XGSQ' 'KTZQO' 'IFUPUP' 'KZQQE' 'INPCQ'
#  'UQWMUJ' 'WXINV' 'XCTO' 'WHMRTX' 'SQBVA' 'MPLIF' 'FHZHQ' 'UBFU' 'QOXAP'
#  'ECOLG' 'BYGJ' 'WKJDZN' 'RBLMC' 'FZMC' 'XTHSP' 'EXPWC' 'AATAD' 'MJMFZ'
#  'KNEKVS' 'QZKDW' 'VJPB' 'NGLV' 'GPHJ' 'BPCR' 'SYHQG' 'XNUMQ' 'PDHXAO'
#  'HIMX' 'KEYA' 'KQTXYR' 'WHQKOA' 'GAMTND' 'ONYIVM' 'KELYBC' 'TRHRT'
#  'UQGORK' 'IWZNGS' 'JZHV' 'AWKKL' 'UELONW' 'FFOS' 'EILE' 'BZLFY' 'MDXYBL'
#  'BTMV' 'QOSVLN' 'CPQFGQ' 'XUHOLB' 'RGEBQC' 'AXDPOS' 'BLMPI' 'AFTEH'
#  'MMPGMU' 'LII' 'WZON' 'RYEVSY' 'MMZWN' 'ADPO' 'TVGS' 'WHCV' 'EMHU'
#  'ZKGDWZ' 'LQGH' 'QTVEER' 'MLOR' 'LEODET' 'SSFL' 'YRXYX' 'HBVHWO' 'ZWEBIC'
#  'YGOLQ' 'IVPR' 'ILNAE' 'BVCW' 'FISUI' 'TWRC' 'XXTIXH' 'YIXPOS' 'AQCW'
#  'GXOT' 'TNWI' 'HIJQ' 'YDEGUS' 'OGTRVU' 'HGBQ' 'MVAMHL' 'NAMUF' 'DTWOH'
#  'KXEBOL' 'RXDK']
# Number of Unique Values: 99
# ------------------------------------------------------------
# Column Name (Base Dataset): Year
# Unique Values: [2000 2001 2002 2004 2005 2007 2006 2008 2003]
# Number of Unique Values: 9
# ------------------------------------------------------------
# Column Name (Base Dataset): Revenue
# Unique Values: [1709725917  675481498  783243374 1976308486 1756793979  397468192
#  1362549418  265097662 1846037317 1343986841  384913041 1596005787
#   381864161 1043291256 1022913781 1234841074 1401112566 1225186910
#  1578059062 1350971036 1730117988 1685881717 1421387939  820377024
#  1160778106   54740570  276846282  945778022 1054132024 1347096444
#  2070665171  523434162 1376775734 1263888858 1619816368 1946442977
#   679802333  219641795 1158426525 2058812413  516916861  286020133
#   129321405  453437000  116079836  309054967  201452858 1176257874
#   600790728 1944993806 1111374462  247821051 1868089214   87344967
#  1956797409  124562371 1099988142  387266805 1887428184 1878619426
#  1017626743 1725261935  544778818 1866027211 2039417866  313159323
#  2072915221  155195975 1329539279  952100403  860439989 1410225802
#  1378533295  756332382  127201292 1980529538 1991746817 1383343749
#  1601692196 1127680122 1408082755   91322799  614315123 1694080315
#   119600950  367421743 1528938386 1141868652 1328330807 1349714689
#  1180763523  442755967  496741722  831037260 1607664782  539185345
#  1271341214 1919499390 1956845520  598496624  498703115 1043140781
#   298945269  608655959 1137659796  542529191 1684267140  691347269
#    36173674  306036692  633386664 1533893225 1672109380  288063408
#  1905227831 1236915677  497897606  289753122 1838845801  368122809
#  1776283582 1871503838  392231124  221566951 1414310468  964530739
#  1877133801 1452671131  577145945 1584183404  989567501  598786681
#   388289344   70807885  849375150  998604459 1296761938 1591845255
#   818677477 1049316261 2020225957 1196659758 1534942378 1375595005
#  2071948099  343431088 1760174844  820232425  116883415 2064955253
#  1580863322  508623302 1665304057  365647507  937413614 1887855254
#  1620800200 1218273970  518036710  539305711  587758767 1023056673
#    99039491  817825383 1120349090  115288755   35133604 1686939557
#  2084659728 1462109713 2056428369 1401799467  886330604  426420262
#   693215051 1620679458 1518758789  318654448 1272869128 1429455324
#   363406659  942147788 1889129485  865525753 1114605837  877079472
#  1927726278 1703969077 1004739076  896622544 1415644330 1494454944
#  1614318266 1930049793 1326749828  155177965 1561713471 1716906274
#   996840034  422408904 1425727445 1505547847 1727447893  141198711
#  1310183256  839464191   50139862 1307028224 1929314323 1694897194
#   195599860 1679633397  879769835   97213231  798220369 2073528676
#   480164798 1069911363 1382270611  379313634 1184739911 1524748385
#  1235100537 1140203342  463606683  438480823  262221085 2008284756
#   822984793  710739369  556681625 1414949759 1389671725  176052521
#   622838095 1785660216  766842455 1745552632  904678477 1593063815
#   640665573  398193719 1114702134 1005439243 1450008962 1440708399
#   943400423  829439174 1488872651  744901477 1352905286 1846316431
#  1470646703  149475629  639362416  775358501  233735226 1772774374
#   572493325  405513546   16691412 1752272554 1936943693  217040551
#  1895936436  721347435 1561878908 1026066644  287902780  710269333
#  1312882025  660275228 1731672588  637142265 1603437613 1994791946
#   498185735  736643150 2031174844  197610728 1367092796  174023137
#   925949515 1875991365  303271124 1255433233  525562788 1073985930
#  1957609793  621822848  124583139 1831990372  847959011  710457961
#   994947003  693768340 1768962953 1787109372 1957986031   87186325
#  1851854285  475662061 1138203012 1983610680 1290448782  290263525
#  1155537790  980508826  650262161  361277988 1269103757 1192317719
#   994508800 1897749716 1575571173 1420660796 1162448793 1299626168
#   898484776   25180061  906865678  915955162 1195760470 1790287008
#  2037940158  687771278 1059114658 1300144441  165754307 1036074484
#   620942243 1901629539 1555060397 1321775323 1691247718  613124532
#  1427716005 1466439505  893106967 1585055051 1391405665 1970622521
#  1713180378 1598699597  915255361 1087696809 1888576475 2023468666
#   838276106 2037452571  946216805  837910723 1537611701  451875619
#  2059992981 1768544555 2026007585 1828887684 1542949336    3907402
#  1554317485 1149782952  560877097  840511261 1490364280  959703331
#    86893125 1032334775  630683775 2011739213 1111366640  602399842
#  1552172522  122408818  828244523 1255612029   97886137  239491659
#   710531253 1251805690  405288851 1890604964 1843741876 1190404778
#   797803325 1337453371 1116511359   27456667 1994139868 1273358980
#  1942649676  845220373 1930367541 1074966451   15875620 1499455359
#   904890772   49035241 2030308120  723685146 1767528326  575235274
#   700570652 1823434510  728372863  490920373  799892727  447926414
#  1695995548 1145268230 1864602967  806550856 1493387510  598778187
#  1727818322   58779265 1786854344  741032152 2019129566  358135150
#   955238968 1701161786  207789549  741696325 1861279828 1647991650
#  1740075514 1161437763 1828613009  723574987 1470565611  355376011
#   171258862  209863275 1382439809  428381918  235097680 1623180699
#  1424537299 1745459885  352317620 1695394375  387753860 1951841189
#  1274726621 1427254614  341248112 1190415878  292065648 1906722813
#  1531728566  532136802  927195190 1378452475 1430956265  656635758
#   267279006 1289554115 1055607666 1596137675 1992685598 1009771102
#   806705168 1376999399  541989366 1212543091 2080100988   38609358
#   305341750  736947446  339752694  708128790 1974276894  718562045
#  1337162477   94388513  743663602   48647460]
# Number of Unique Values: 478
# ------------------------------------------------------------

# %% [markdown]
# We also check the dtypes and basic info of each column for any null columns.

# %%
print('Base Dataset')
print(expanded_df.dtypes)
print(expanded_df.info())
print('-' * 60)

print('Partial Dataset')
print(partial_df.dtypes)
print(partial_df.info())
print('-' * 60)

print('Historical Dataset')
print(historical_df.dtypes) 
print(historical_df.info())
print('-' * 60)

print('Sparse Dataset')
print(sparse_df.dtypes)
print(sparse_df.info())
print('-' * 60)
# Out:
# Base Dataset
# Stock                           object
# Year                            object
# Revenue                        float64
# Revenue Growth                 float64
# Operating Income               float64
# Net Income                     float64
# Net Income Ratio               float64
# Gross Profit                   float64
# Gross Profit Ratio             float64
# Operating Expenses             float64
# Cost of Revenue                float64
# EBITDA                         float64
# Interest Expense               float64
# Depreciation & Amortization    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 100989 entries, 0 to 100998
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Stock                        100989 non-null  object
#  1   Year                         100989 non-null  object
#  2   Revenue                      100989 non-null  float64
#  3   Revenue Growth               100000 non-null  float64
#  4   Operating Income             100989 non-null  float64
#  5   Net Income                   100989 non-null  float64
#  6   Net Income Ratio             100989 non-null  float64
#  7   Gross Profit                 100989 non-null  float64
#  8   Gross Profit Ratio           100989 non-null  float64
#  9   Operating Expenses           100989 non-null  float64
#  10  Cost of Revenue              100989 non-null  float64
#  11  EBITDA                       100989 non-null  float64
#  12  Interest Expense             100989 non-null  float64
#  13  Depreciation & Amortization  100989 non-null  float64
# dtypes: float64(12), object(2)
# memory usage: 11.6+ MB
# None
# ------------------------------------------------------------
# Partial Dataset
# Stock                           object
# Year                            object
# Revenue                        float64
# Revenue Growth                 float64
# Operating Income               float64
# Net Income                     float64
# Net Income Ratio               float64
# Gross Profit                   float64
# Gross Profit Ratio             float64
# Operating Expenses             float64
# Cost of Revenue                float64
# EBITDA                         float64
# Interest Expense               float64
# Depreciation & Amortization    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 7997 entries, 1017 to 100973
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Stock                        7997 non-null   object
#  1   Year                         7997 non-null   object
#  2   Revenue                      6398 non-null   float64
#  3   Revenue Growth               7997 non-null   float64
#  4   Operating Income             7997 non-null   float64
#  5   Net Income                   7197 non-null   float64
#  6   Net Income Ratio             7997 non-null   float64
#  7   Gross Profit                 7997 non-null   float64
#  8   Gross Profit Ratio           7997 non-null   float64
#  9   Operating Expenses           5598 non-null   float64
#  10  Cost of Revenue              7997 non-null   float64
#  11  EBITDA                       7997 non-null   float64
#  12  Interest Expense             7997 non-null   float64
#  13  Depreciation & Amortization  7997 non-null   float64
# dtypes: float64(12), object(2)
# memory usage: 1.2+ MB
# None
# ------------------------------------------------------------
# Historical Dataset
# Stock               object
# Year                 int64
# Revenue            float64
# Cost of Revenue    float64
# Gross Profit       float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 9702 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Stock            9702 non-null   object
#  1   Year             9702 non-null   int64
#  2   Revenue          7886 non-null   float64
#  3   Cost of Revenue  7090 non-null   float64
#  4   Gross Profit     7090 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 454.8+ KB
# None
# ------------------------------------------------------------
# Sparse Dataset
# Stock      object
# Year        int64
# Revenue     int64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Index: 478 entries, 0 to 479
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Stock    478 non-null    object
#  1   Year     478 non-null    int64
#  2   Revenue  478 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 14.9+ KB
# None
# ------------------------------------------------------------

# %% [markdown]
# ### Check and filter out impossible years

# %% [markdown]
# This function checks whether years in the 'year' column are greater than a maximum year.
#
# The 'year_column' is a keyword argument that fits the 'year' column. 'max_year' is also a keyword argument that represents the max year.
#
# In this case, we find out whether any column exceeds year 2024.

# %%
def check_years(df, year_column, max_year):
    # Ensure that 'Year' column is numeric
    df[year_column] = pd.to_numeric(df[year_column])
    
    # Flag rows where the year is out of range
    df['is_out_of_range'] = df[year_column] > max_year

    # out_of_range represents years that exceed max_year
    # valid_rows represents years before year max_year
    out_of_range = df[df['is_out_of_range']]
    valid_rows = df[~df['is_out_of_range']]
    
    return {
        "out_of_range": out_of_range,
        "valid_rows": valid_rows,
        "flagged_df": df
    }

# %%
# Base dataset has no impossible years
expanded_df_years = check_years(expanded_df, year_column='Year', max_year=2024)
print("Out-of-range rows:")
print(expanded_df_years["out_of_range"])

print("\nValid rows:")
print(expanded_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(expanded_df_years["flagged_df"])
# Out:
# Out-of-range rows:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, is_out_of_range]
# Index: []
#
# Valid rows:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        BRK-A  2023  3.644820e+11             NaN      1.231960e+11
# 1        BRK-A  2022  2.341900e+11             NaN     -2.698500e+10
# 2        BRK-A  2021  3.546360e+11             NaN     -8.242500e+10
# 3        BRK-A  2020  2.862560e+11             NaN     -1.135820e+11
# 4        BRK-A  2019  3.272230e+11             NaN     -7.723400e+10
# ...        ...   ...           ...             ...               ...
# 100994  PTLEBY  2005  1.333766e+09       -0.082426      2.334087e+08
# 100995  PGQDKT  2024  1.548388e+09        0.145031      2.106748e+08
# 100996    BPCR  2020  4.912654e+08        0.178375      6.713231e+07
# 100997  FOXTWC  2019  2.127840e+09        0.034832      1.880026e+08
# 100998    VFOK  2021  7.101194e+08        0.051971      1.873849e+08
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       9.622300e+10          0.263999  1.231960e+11            0.338003
# 1      -2.281900e+10         -0.097438  1.098710e+11            0.469153
# 2       8.993700e+10          0.253604  1.337060e+11            0.377023
# 3       4.252100e+10          0.148542  8.953000e+10            0.312762
# 4       8.141700e+10          0.248812  1.248030e+11            0.381400
# ...              ...               ...           ...                 ...
# 100994  2.328940e+08          0.174614  6.811253e+08            0.510678
# 100995  2.098682e+08          0.135540  5.824036e+08            0.376136
# 100996  6.666666e+07          0.135704  2.549765e+08            0.519020
# 100997  1.870805e+08          0.087920  9.650140e+08            0.453518
# 100998  1.866904e+08          0.262900  4.081978e+08            0.574830
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 0             1.985750e+11     2.412860e+11  1.376550e+11      5.003000e+09
# 1             1.423100e+11     1.243190e+11 -1.524900e+10      4.352000e+09
# 2            -4.370610e+11     2.209300e+11  1.265760e+11      4.172000e+09
# 3            -3.998380e+11     1.967260e+11  8.038600e+10      4.083000e+09
# 4            -4.044570e+11     2.024200e+11  1.156410e+11      3.961000e+09
# ...                    ...              ...           ...               ...
# 100994        4.477166e+08     6.526406e+08  2.400571e+08      5.146860e+05
# 100995        3.717289e+08     9.659840e+08  2.154545e+08      8.065550e+05
# 100996        1.878442e+08     2.362889e+08  6.861804e+07      4.656480e+05
# 100997        7.770114e+08     1.162826e+09  1.941805e+08      9.220510e+05
# 100998        2.208130e+08     3.019215e+08  1.891152e+08      6.944930e+05
#
#         Depreciation & Amortization  is_out_of_range
# 0                      1.248600e+10            False
# 1                      1.089900e+10            False
# 2                      1.071800e+10            False
# 3                      1.059600e+10            False
# 4                      1.006400e+10            False
# ...                             ...              ...
# 100994                 6.648408e+06            False
# 100995                 4.779709e+06            False
# 100996                 1.485732e+06            False
# 100997                 6.177922e+06            False
# 100998                 1.730361e+06            False
#
# [100989 rows x 15 columns]
#
# Dataframe with flagged column:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0        BRK-A  2023  3.644820e+11             NaN      1.231960e+11
# 1        BRK-A  2022  2.341900e+11             NaN     -2.698500e+10
# 2        BRK-A  2021  3.546360e+11             NaN     -8.242500e+10
# 3        BRK-A  2020  2.862560e+11             NaN     -1.135820e+11
# 4        BRK-A  2019  3.272230e+11             NaN     -7.723400e+10
# ...        ...   ...           ...             ...               ...
# 100994  PTLEBY  2005  1.333766e+09       -0.082426      2.334087e+08
# 100995  PGQDKT  2024  1.548388e+09        0.145031      2.106748e+08
# 100996    BPCR  2020  4.912654e+08        0.178375      6.713231e+07
# 100997  FOXTWC  2019  2.127840e+09        0.034832      1.880026e+08
# 100998    VFOK  2021  7.101194e+08        0.051971      1.873849e+08
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       9.622300e+10          0.263999  1.231960e+11            0.338003
# 1      -2.281900e+10         -0.097438  1.098710e+11            0.469153
# 2       8.993700e+10          0.253604  1.337060e+11            0.377023
# 3       4.252100e+10          0.148542  8.953000e+10            0.312762
# 4       8.141700e+10          0.248812  1.248030e+11            0.381400
# ...              ...               ...           ...                 ...
# 100994  2.328940e+08          0.174614  6.811253e+08            0.510678
# 100995  2.098682e+08          0.135540  5.824036e+08            0.376136
# 100996  6.666666e+07          0.135704  2.549765e+08            0.519020
# 100997  1.870805e+08          0.087920  9.650140e+08            0.453518
# 100998  1.866904e+08          0.262900  4.081978e+08            0.574830
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 0             1.985750e+11     2.412860e+11  1.376550e+11      5.003000e+09
# 1             1.423100e+11     1.243190e+11 -1.524900e+10      4.352000e+09
# 2            -4.370610e+11     2.209300e+11  1.265760e+11      4.172000e+09
# 3            -3.998380e+11     1.967260e+11  8.038600e+10      4.083000e+09
# 4            -4.044570e+11     2.024200e+11  1.156410e+11      3.961000e+09
# ...                    ...              ...           ...               ...
# 100994        4.477166e+08     6.526406e+08  2.400571e+08      5.146860e+05
# 100995        3.717289e+08     9.659840e+08  2.154545e+08      8.065550e+05
# 100996        1.878442e+08     2.362889e+08  6.861804e+07      4.656480e+05
# 100997        7.770114e+08     1.162826e+09  1.941805e+08      9.220510e+05
# 100998        2.208130e+08     3.019215e+08  1.891152e+08      6.944930e+05
#
#         Depreciation & Amortization  is_out_of_range
# 0                      1.248600e+10            False
# 1                      1.089900e+10            False
# 2                      1.071800e+10            False
# 3                      1.059600e+10            False
# 4                      1.006400e+10            False
# ...                             ...              ...
# 100994                 6.648408e+06            False
# 100995                 4.779709e+06            False
# 100996                 1.485732e+06            False
# 100997                 6.177922e+06            False
# 100998                 1.730361e+06            False
#
# [100989 rows x 15 columns]

# %%
# Partial dataset has no impossible years
partial_df_years = check_years(partial_df, year_column='Year', max_year=2024)
print("Out-of-range rows:")
print(partial_df_years["out_of_range"])

print("\nValid rows:")
print(partial_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(partial_df_years["flagged_df"])
# Out:
# Out-of-range rows:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, is_out_of_range]
# Index: []
#
# Valid rows:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 1017    TLSNGU  2023  1.377147e+09        0.166164      3.228263e+08
# 1078      ALAD  2022           NaN        0.125184     -8.221426e+07
# 1088    ZTSXEF  2023  3.194701e+08        0.018995      3.294055e+07
# 1103    BSFLIH  2023  2.243174e+09        0.184940      1.336957e+08
# 1117     XOJED  2022  6.565935e+08        0.037804     -4.209403e+06
# ...        ...   ...           ...             ...               ...
# 100931    SBQP  2023           NaN        0.006929      3.567775e+08
# 100942  AOBPTS  2023           NaN        0.190997      6.115073e+07
# 100945    QCAD  2023  6.532326e+08        0.183535      8.112773e+07
# 100961   VMSUI  2023  1.663794e+09       -0.005228      2.778025e+08
# 100973  XFRGYB  2022           NaN       -0.055418      9.517866e+07
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 1017    3.225423e+08          0.234210  6.311956e+08            0.458336
# 1078   -8.238490e+07         -0.040235  7.329389e+08            0.357950
# 1088    3.232122e+07          0.101171  1.062017e+08            0.332431
# 1103    1.331177e+08          0.059343  8.575299e+08            0.382284
# 1117   -5.198303e+06         -0.007917  2.280826e+08            0.347373
# ...              ...               ...           ...                 ...
# 100931  3.562950e+08          0.231334  8.531026e+08            0.553899
# 100942  6.073633e+07          0.099600  2.548950e+08            0.417998
# 100945           NaN          0.123018  2.680819e+08            0.410393
# 100961  2.776071e+08          0.166852  6.408332e+08            0.385164
# 100973  9.444352e+07          0.093899  3.246667e+08            0.322795
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 1017          3.083693e+08     7.459519e+08  3.283275e+08          284064.0
# 1078                   NaN     1.314665e+09 -7.814426e+07          170640.0
# 1088                   NaN     2.132684e+08  3.994439e+07          619332.0
# 1103                   NaN     1.385644e+09  1.349737e+08          578007.0
# 1117                   NaN     4.285109e+08  4.929404e+06          988900.0
# ...                    ...              ...           ...               ...
# 100931                 NaN     6.870754e+08  3.644203e+08          482545.0
# 100942        1.937443e+08     3.549046e+08  6.768917e+07          414404.0
# 100945        1.869542e+08     3.851506e+08  9.059706e+07          768101.0
# 100961        3.630307e+08     1.022961e+09  2.810251e+08          195397.0
# 100973        2.294881e+08     6.811314e+08  9.613299e+07          735139.0
#
#         Depreciation & Amortization  is_out_of_range
# 1017                      5501218.0            False
# 1078                      4070001.0            False
# 1088                      7003836.0            False
# 1103                      1278049.0            False
# 1117                      9138807.0            False
# ...                             ...              ...
# 100931                    7642717.0            False
# 100942                    6538445.0            False
# 100945                    9469322.0            False
# 100961                    3222549.0            False
# 100973                     954332.0            False
#
# [7997 rows x 15 columns]
#
# Dataframe with flagged column:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 1017    TLSNGU  2023  1.377147e+09        0.166164      3.228263e+08
# 1078      ALAD  2022           NaN        0.125184     -8.221426e+07
# 1088    ZTSXEF  2023  3.194701e+08        0.018995      3.294055e+07
# 1103    BSFLIH  2023  2.243174e+09        0.184940      1.336957e+08
# 1117     XOJED  2022  6.565935e+08        0.037804     -4.209403e+06
# ...        ...   ...           ...             ...               ...
# 100931    SBQP  2023           NaN        0.006929      3.567775e+08
# 100942  AOBPTS  2023           NaN        0.190997      6.115073e+07
# 100945    QCAD  2023  6.532326e+08        0.183535      8.112773e+07
# 100961   VMSUI  2023  1.663794e+09       -0.005228      2.778025e+08
# 100973  XFRGYB  2022           NaN       -0.055418      9.517866e+07
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 1017    3.225423e+08          0.234210  6.311956e+08            0.458336
# 1078   -8.238490e+07         -0.040235  7.329389e+08            0.357950
# 1088    3.232122e+07          0.101171  1.062017e+08            0.332431
# 1103    1.331177e+08          0.059343  8.575299e+08            0.382284
# 1117   -5.198303e+06         -0.007917  2.280826e+08            0.347373
# ...              ...               ...           ...                 ...
# 100931  3.562950e+08          0.231334  8.531026e+08            0.553899
# 100942  6.073633e+07          0.099600  2.548950e+08            0.417998
# 100945           NaN          0.123018  2.680819e+08            0.410393
# 100961  2.776071e+08          0.166852  6.408332e+08            0.385164
# 100973  9.444352e+07          0.093899  3.246667e+08            0.322795
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 1017          3.083693e+08     7.459519e+08  3.283275e+08          284064.0
# 1078                   NaN     1.314665e+09 -7.814426e+07          170640.0
# 1088                   NaN     2.132684e+08  3.994439e+07          619332.0
# 1103                   NaN     1.385644e+09  1.349737e+08          578007.0
# 1117                   NaN     4.285109e+08  4.929404e+06          988900.0
# ...                    ...              ...           ...               ...
# 100931                 NaN     6.870754e+08  3.644203e+08          482545.0
# 100942        1.937443e+08     3.549046e+08  6.768917e+07          414404.0
# 100945        1.869542e+08     3.851506e+08  9.059706e+07          768101.0
# 100961        3.630307e+08     1.022961e+09  2.810251e+08          195397.0
# 100973        2.294881e+08     6.811314e+08  9.613299e+07          735139.0
#
#         Depreciation & Amortization  is_out_of_range
# 1017                      5501218.0            False
# 1078                      4070001.0            False
# 1088                      7003836.0            False
# 1103                      1278049.0            False
# 1117                      9138807.0            False
# ...                             ...              ...
# 100931                    7642717.0            False
# 100942                    6538445.0            False
# 100945                    9469322.0            False
# 100961                    3222549.0            False
# 100973                     954332.0            False
#
# [7997 rows x 15 columns]

# %%
# 9178 rows in Historical dataset are out of range
historical_df_years = check_years(historical_df, year_column='Year', max_year=2024)
print("Out-of-range rows:")
print(historical_df_years["out_of_range"])

print("\nValid rows:")
print(historical_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(historical_df_years["flagged_df"])
# Out:
# Out-of-range rows:
#        Stock  Year       Revenue  Cost of Revenue  Gross Profit  \
# 0     IVMAGX  2161           NaN              NaN           NaN
# 1       HIJQ  2149  1.839813e+08     1.345906e+08  4.939068e+07
# 2      WAKFT  2151           NaN              NaN           NaN
# 3       QHIN  2133  1.891520e+09     8.866202e+08  1.004900e+09
# 4     IABVRF  2148  1.850278e+09     8.869205e+08  9.633574e+08
# ...      ...   ...           ...              ...           ...
# 9995    OXVC  2154  8.033017e+08              NaN           NaN
# 9996    JZDY  2142  6.132366e+08              NaN           NaN
# 9997    PDCX  2135  1.120415e+09     7.403297e+08  3.800858e+08
# 9998    YPOT  2182  1.136122e+08     7.777145e+07  3.584073e+07
# 9999  KBNXVP  2160  1.025777e+09     7.303527e+08  2.954241e+08
#
#       is_out_of_range
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ...               ...
# 9995             True
# 9996             True
# 9997             True
# 9998             True
# 9999             True
#
# [9178 rows x 6 columns]
#
# Valid rows:
#             Stock  Year       Revenue  Cost of Revenue  Gross Profit  \
# 7            SQVE  2011  1.163686e+09     9.083407e+08  2.553451e+08
# 32    JMBXBF .end  2012  1.309424e+09     4.081595e+08  9.012643e+08
# 54         AOSYFW  2010  3.830394e+08     2.430747e+08  1.399647e+08
# 64          HQIMS  2013  5.073700e+08     2.469877e+08  2.603823e+08
# 68    LPFFOX .end  2018           NaN              NaN           NaN
# ...           ...   ...           ...              ...           ...
# 9910        THOVU  2017 -2.360162e+08    -1.547981e+08 -8.121808e+07
# 9913       BCTTEI  2011           NaN              NaN           NaN
# 9926        JLUEY  2016           NaN              NaN           NaN
# 9972         IFKM  2018  6.915114e+08     5.108353e+08  1.806762e+08
# 9975       ESDIUH  2017 -3.638146e+08    -2.547022e+08 -1.091124e+08
#
#       is_out_of_range
# 7               False
# 32              False
# 54              False
# 64              False
# 68              False
# ...               ...
# 9910            False
# 9913            False
# 9926            False
# 9972            False
# 9975            False
#
# [524 rows x 6 columns]
#
# Dataframe with flagged column:
#        Stock  Year       Revenue  Cost of Revenue  Gross Profit  \
# 0     IVMAGX  2161           NaN              NaN           NaN
# 1       HIJQ  2149  1.839813e+08     1.345906e+08  4.939068e+07
# 2      WAKFT  2151           NaN              NaN           NaN
# 3       QHIN  2133  1.891520e+09     8.866202e+08  1.004900e+09
# 4     IABVRF  2148  1.850278e+09     8.869205e+08  9.633574e+08
# ...      ...   ...           ...              ...           ...
# 9995    OXVC  2154  8.033017e+08              NaN           NaN
# 9996    JZDY  2142  6.132366e+08              NaN           NaN
# 9997    PDCX  2135  1.120415e+09     7.403297e+08  3.800858e+08
# 9998    YPOT  2182  1.136122e+08     7.777145e+07  3.584073e+07
# 9999  KBNXVP  2160  1.025777e+09     7.303527e+08  2.954241e+08
#
#       is_out_of_range
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# ...               ...
# 9995             True
# 9996             True
# 9997             True
# 9998             True
# 9999             True
#
# [9702 rows x 6 columns]

# %% [markdown]
# We filter out rows that are out of range, and keep only rows within the valid range of until 2024.
#
# Unique values in the 'Year' column are checked again.

# %%
# Keep only rows that have no impossible years
historical_df = historical_df.loc[historical_df_years['valid_rows'].index]

# %%
historical_df['Year'].unique()
# Out:
# array([2011, 2012, 2010, 2013, 2018, 2014, 2020, 2017, 2016, 2019, 2015],
#       dtype=int64)

# %%
# Sparse dataset has no impossible years
sparse_df_years = check_years(sparse_df, year_column='Year', max_year=2099)
print("Out-of-range rows:")
print(sparse_df_years["out_of_range"])

print("\nValid rows:")
print(sparse_df_years["valid_rows"])

print("\nDataframe with flagged column:")
print(sparse_df_years["flagged_df"])
# Out:
# Out-of-range rows:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, is_out_of_range]
# Index: []
#
# Valid rows:
#     Stock  Year     Revenue  is_out_of_range
# 0    OBWA  2000  1709725917            False
# 1    OBWA  2001   675481498            False
# 2    OBWA  2002   783243374            False
# 3    OBWA  2004  1976308486            False
# 4    OBWA  2005  1756793979            False
# ..    ...   ...         ...              ...
# 475  RXDK  2003   718562045            False
# 476  RXDK  2004  1337162477            False
# 477  RXDK  2005    94388513            False
# 478  RXDK  2006   743663602            False
# 479  RXDK  2008    48647460            False
#
# [478 rows x 4 columns]
#
# Dataframe with flagged column:
#     Stock  Year     Revenue  is_out_of_range
# 0    OBWA  2000  1709725917            False
# 1    OBWA  2001   675481498            False
# 2    OBWA  2002   783243374            False
# 3    OBWA  2004  1976308486            False
# 4    OBWA  2005  1756793979            False
# ..    ...   ...         ...              ...
# 475  RXDK  2003   718562045            False
# 476  RXDK  2004  1337162477            False
# 477  RXDK  2005    94388513            False
# 478  RXDK  2006   743663602            False
# 479  RXDK  2008    48647460            False
#
# [478 rows x 4 columns]

# %% [markdown]
# ### Rename values in 'Stock' column that end with ' .end' in Historical Dataset

# %% [markdown]
# We replace both '.end' and ' .end' at the end of the string using regex.
#
# After that, we print out the stock names to see whether they are all named correctly.

# %%
historical_df['Stock'] = historical_df['Stock'].str.replace(r'\s?\.end$', '', regex=True)

# %%
historical_df['Stock'].unique()
# Out:
# array(['SQVE', 'JMBXBF', 'AOSYFW', 'HQIMS', 'LPFFOX', 'HQCU', 'YLVJB',
#        'SYKZY', 'SCAXI', 'UOSVNX', 'VCXQI', 'SLJLVN', 'ERYZFK', 'PFNWH',
#        'CLAIHO', 'OTUJVZ', 'BTMV', 'PEQY', 'AMEID', 'QCIBQ', 'PZVSHX',
#        'CPCK', 'FFWMSO', 'NIUK', 'GALM', 'GRXYDL', 'SHET', 'SFIV', 'TTTB',
#        'QATG', 'ERZIRJ', 'NDBSR', 'MDTE', 'FSRMGP', 'YQZUN', 'ORAH',
#        'TUTT', 'ZNYWF', 'XEUZ', 'UHDNAN', 'RKMTI', 'DHVAK', 'VCPQBY',
#        'HKEPUZ', 'INRMC', 'AMPO', 'XLZUD', 'CEBIIR', 'VJAF', 'UANYAV',
#        'FYDJQ', 'QCBIW', 'EDIZQ', 'IPUWKK', 'KGEJ', 'JBTS', 'EQREQ',
#        'RLRY', 'NUVPP', 'ZACVOO', 'CBMGBV', 'XDGOZD', 'OFVZT', 'AAZLH',
#        'UZLPI', 'FVMUD', 'IORX', 'XCJMZ', 'AZTQHC', 'XFHP', 'FZMC',
#        'TMHMYR', 'OXDRI', 'PTULN', 'EXLT', 'BYFR', 'KHEBQ', 'VLZBKQ',
#        'YRMTOC', 'LUTNZ', 'KEYA', 'EZAIGH', 'RHGYB', 'UQGORK', 'KKAEMI',
#        'DIJA', 'RSKYN', 'JICHI', 'UQWMUJ', 'AXKU', 'CLDTV', 'LFCFVC',
#        'PNIJNW', 'PPZO', 'YCPX', 'RFYDEH', 'YTXINO', 'GIADHZ', 'MAJKA',
#        'ZYHKFM', 'DMXR', 'UZTZTM', 'YIXV', 'IWXJQ', 'QCJIX', 'NNUPXX',
#        'NADBPE', 'AJZZO', 'PTFPE', 'UIBGA', 'BCDSCO', 'TESU', 'PZUMC',
#        'TTFJLK', 'TBBFSX', 'PGMBY', 'YITM', 'ONST', 'OEIYJ', 'LOCJCF',
#        'HJLC', 'OLXWJ', 'XCPA', 'SKRHFG', 'SHDBKH', 'PPIBDM', 'PXOYQA',
#        'DDNMQ', 'RDIDUL', 'SLGR', 'JPPK', 'NWLWN', 'GPYMJ', 'FGNTG',
#        'AGVVA', 'UMJRKQ', 'QHHY', 'GTTS', 'SOEXCY', 'YMDMPX', 'TNCSBM',
#        'SUNEZ', 'OUEQRW', 'UXVMT', 'DYGLS', 'XOMKY', 'FRVBU', 'PXKM',
#        'QQODP', 'CNUDK', 'PCLU', 'GNXNY', 'MZHV', 'LZJPX', 'DPSTE',
#        'BIZPZI', 'HXLUZ', 'JGGTJU', 'GQCT', 'XZEQDA', 'NABKB', 'DRSSV',
#        'KDBO', 'JBRP', 'TWRC', 'NJBAAS', 'MULF', 'WOKIMM', 'JMOLX',
#        'YJCHEM', 'HTOTBR', 'YJPM', 'JDWD', 'GDAR', 'BSFLIH', 'HNVLET',
#        'LETDZ', 'LEGAJE', 'HEGFOB', 'GZOT', 'FNSDCZ', 'TOIEP', 'DKWYTH',
#        'SFNN', 'SJDATJ', 'PAIM', 'TBDXO', 'HSBJZ', 'CRYWX', 'WHMRTX',
#        'MXKGJ', 'THOVU', 'WOOVP', 'VRLOU', 'WZOLN', 'TIXSRD', 'MYVDR',
#        'CDQB', 'KJOXJW', 'CWOFE', 'CBPVDU', 'WRZUIW', 'JXSOID', 'ZKXEQB',
#        'PFPOUV', 'DHIMFD', 'TZKBTA', 'XVXO', 'GBJNF', 'SQLEV', 'LVQU',
#        'PWHWRE', 'OXPYRO', 'EDXIT', 'XUMLFW', 'WFRBW', 'GCFGVC', 'IHAAJG',
#        'IDGWTF', 'XGCPNB', 'NKXQIG', 'FIIP', 'EWJVXJ', 'GUAV', 'WBJCS',
#        'JCSOTZ', 'IPIWS', 'DIKX', 'SNCZLI', 'ZJGQBC', 'WOJL', 'ULJN',
#        'DGDFS', 'GNRQR', 'CIJJF', 'BPCG', 'WRXVXA', 'XCSAJ', 'KPPKJ',
#        'EFOITF', 'WAWPK', 'NOW', 'CHXZKD', 'WQYMKR', 'KQEBXK', 'WBTGKG',
#        'ADPO', 'VPUAM', 'GXMWZ', 'MDGFC', 'QOTC', 'CRXK', 'ZOPBC', 'NVPH',
#        'XEEEM', 'MILIS', 'UPXN', 'WCEZL', 'HLIG', 'DNPGQJ', 'YJGCG',
#        'PZQH', 'VIIQNM', 'LKES', 'ZCCQTO', 'IJGB', 'VUFOM', 'OMUTNM',
#        'SAWCQE', 'YDEGUS', 'ZBKZ', 'AAHKPV', 'SERL', 'JFCMZ', 'XFLJ',
#        'LXWIDA', 'GHRV', 'ZUFDO', 'GCFY', 'YRQVD', 'MDAP', 'ZKYMZ',
#        'KYYRQB', 'ZNSY', 'AOBPTS', 'TMPU', 'YBTEVU', 'WYVB', 'PVGJ',
#        'HIVVKU', 'EXCVLR', 'AZO', 'PAWKKO', 'FLNM', 'NMCPLP', 'OHTOML',
#        'FZIWD', 'YRTI', 'UEPDDX', 'QHERB', 'XPGBW', 'HIJQ', 'OWHYIG',
#        'YHZZS', 'BDOLZV', 'XJLFN', 'WUUDP', 'UJBU', 'TVIHNW', 'JWOAPT',
#        'PLEFRC', 'OKJX', 'HTINPO', 'EXPWC', 'WHWUNP', 'RYEVSY', 'BMKC',
#        'ZBJZMM', 'AATT', 'NBIAA', 'ZHMUS', 'TWCF', 'JSEOQO', 'XPQQHV',
#        'RCTQG', 'SLLJGP', 'ORHUIF', 'FTON', 'UUUOG', 'UEBBV', 'WJNK',
#        'KTCOVN', 'MPOOA', 'YZOIWT', 'GCGPFU', 'BPEF', 'ZETPM', 'CBLBK',
#        'MQVJ', 'LRDM', 'ABTK', 'MDYW', 'IIRHJ', 'BYKC', 'BH-A', 'SVMCMY',
#        'EFGI', 'XIDHJ', 'QCWDM', 'FEGQX', 'PLHE', 'ZDQBNG', 'MMBFCG',
#        'DORX', 'GGRK', 'OAZP', 'NIVXTX', 'WNKOL', 'YPOT', 'ASLCF', 'IBRS',
#        'UEJM', 'QYMRQ', 'PJAA', 'JDUGTE', 'ROOGX', 'PLCRE', 'YNDWM',
#        'UZWW', 'USFTQ', 'BGOMH', 'WUCSC', 'ZGWX', 'ICIO', 'RYCY', 'CYGSZ',
#        'FRADRS', 'YRCHDB', 'NOJPU', 'SSMJHQ', 'QIHN', 'DRWHJS', 'HIJXTU',
#        'WPCB', 'KFIG', 'AZXJP', 'KMZQ', 'EKUKQN', 'PXD', 'ZVKA', 'TVYD',
#        'GWNI', 'NUISZL', 'JJSWZB', 'EKNAJO', 'ETJLNS', 'QEUAZY', 'JCLLK',
#        'RYVAD', 'CONI', 'FWVPB', 'ELAI', 'LGLM', 'PNSW', 'FGAGG', 'AGLLY',
#        'RTNXE', 'QXLV', 'SJZWFH', 'WRPG', 'CYWQF', 'TGPXT', 'PRMPK',
#        'ROOJW', 'SXJB', 'DMNQU', 'KQOZIS', 'ZSXOZO', 'UJQE', 'TWAD',
#        'QXWWJC', 'TWDALJ', 'TMYJ', 'EEEG', 'WOONCG', 'MMCSK', 'FEMK',
#        'NSOB', 'GRVIVX', 'SZTDLH', 'FZRM', 'SLIXQU', 'DBUJVS', 'BNTS',
#        'XHHL', 'JXUDQW', 'NMLQN', 'VDYD', 'HABZF', 'AKPT', 'LPUZEL',
#        'UBFU', 'WXCAJ', 'KQXKGP', 'JQFR', 'VIWKR', 'KWOA', 'NSEU',
#        'ILTXCY', 'MGNXH', 'KHRILW', 'IAXGNV', 'SAAZ', 'MIBN', 'ZPMCLK',
#        'POYO', 'RBMKA', 'NVUH', 'VJPDI', 'JVSIS', 'IGYCLF', 'ECOLG',
#        'WRGHPO', 'AWKKL', 'PJHRM', 'QOHQOV', 'EGSD', 'YZJB', 'XLDBFU',
#        'TKHQ', 'VCKO', 'BOVDF', 'QQXK', 'LKPK', 'RGXCV', 'YFHQXH',
#        'EDRRGL', 'AHGYQZ', 'USTEDO', 'WRUUVP', 'TJCD', 'DSWQB', 'SUKFG',
#        'BCTTEI', 'OSHREM', 'RWAZG', 'PPZJ', 'BMNXHE', 'ODBTL', 'EIXDK',
#        'ESDIUH', 'HAAZS', 'VQMGN', 'ZWDIJC', 'JLUEY', 'IFKM'],
#       dtype=object)

# %% [markdown]
# ### Check for impossible negative values

# %% [markdown]
# We know that the following columns cannot have negative values:
# **Revenue, Operating Expenses, Cost of Revenue, Interest Expense, Depreciation & Amortization**
#
# We iterate this function over each column to check for any impossible negative values.
#
# We then create a valid_columns list to only keep rows with no impossible negative values.

# %%
def drop_rows_with_negatives(df):
    columns_to_check = ['Revenue', 'Operating Expenses', 'Cost of Revenue', 'Interest Expense', 'Depreciation & Amortization']

    # For each column within columns that are not supposed to have negative values
    for column in columns_to_check:
        if column in df.columns: # Check first if the column exist in the datasset
            # Check for negative values in the column
            has_negative = df[column].lt(0).any()
            if has_negative:
                print(f"Column '{column}' contains negative values.")
            else:
                print(f"Column '{column} does not contain any negative values.'")
        else: # If the column is not present in the dataset, we skip it
            print(f"Column '{column}' is not present in the DataFrame. Skipping.")
            
    # Only keep rows with no impossible negative values
    valid_columns = [col for col in columns_to_check if col in df.columns]
    rows_with_negatives = df[df[valid_columns].lt(0).any(axis=1)]
    return df.drop(rows_with_negatives.index)

# %%
expanded_df = drop_rows_with_negatives(expanded_df)
# Out:
# Column 'Revenue' contains negative values.
# Column 'Operating Expenses' contains negative values.
# Column 'Cost of Revenue' contains negative values.
# Column 'Interest Expense' contains negative values.
# Column 'Depreciation & Amortization' contains negative values.

# %%
partial_df = drop_rows_with_negatives(partial_df)
# Out:
# Column 'Revenue does not contain any negative values.'
# Column 'Operating Expenses does not contain any negative values.'
# Column 'Cost of Revenue does not contain any negative values.'
# Column 'Interest Expense does not contain any negative values.'
# Column 'Depreciation & Amortization does not contain any negative values.'

# %%
historical_df = drop_rows_with_negatives(historical_df)
# Out:
# Column 'Revenue' contains negative values.
# Column 'Operating Expenses' is not present in the DataFrame. Skipping.
# Column 'Cost of Revenue' contains negative values.
# Column 'Interest Expense' is not present in the DataFrame. Skipping.
# Column 'Depreciation & Amortization' is not present in the DataFrame. Skipping.

# %%
sparse_df = drop_rows_with_negatives(sparse_df)
# Out:
# Column 'Revenue does not contain any negative values.'
# Column 'Operating Expenses' is not present in the DataFrame. Skipping.
# Column 'Cost of Revenue' is not present in the DataFrame. Skipping.
# Column 'Interest Expense' is not present in the DataFrame. Skipping.
# Column 'Depreciation & Amortization' is not present in the DataFrame. Skipping.

# %% [markdown]
# ### Dealing with missing values

# %%
# Calculate the percentage of missing values
def missing_values_check(df):
    missing_values = df.isnull().sum()
    percent = (missing_values * 100) / len(df)
    
    # Create a DataFrame to display missing values information
    missing_df = pd.DataFrame({
        'Column': df.columns,
        'No. of Missing Values': missing_values.values,
        'Percentage': percent.values
    }).sort_values(by='Percentage', ascending=False)

    return missing_df

# %%
print(missing_values_check(expanded_df))
print('-'*80)
print(missing_values_check(partial_df))
print('-'*80)
print(missing_values_check(historical_df))
print('-'*80)
print(missing_values_check(sparse_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 3                Revenue Growth                    905    0.896883
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 2                       Revenue                      0    0.000000
# 4              Operating Income                      0    0.000000
# 5                    Net Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000
# --------------------------------------------------------------------------------
#                          Column  No. of Missing Values  Percentage
# 9            Operating Expenses                   2399   29.998750
# 2                       Revenue                   1599   19.994998
# 5                    Net Income                    800   10.003751
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 3                Revenue Growth                      0    0.000000
# 4              Operating Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000
# --------------------------------------------------------------------------------
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    129   26.166329
# 4     Gross Profit                    129   26.166329
# 2          Revenue                     86   17.444219
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000
# --------------------------------------------------------------------------------
#             Column  No. of Missing Values  Percentage
# 0            Stock                      0         0.0
# 1             Year                      0         0.0
# 2          Revenue                      0         0.0
# 3  is_out_of_range                      0         0.0

# %% [markdown]
# The number of missing values in the Partial and Historical dataset hold a significant percentage of the datasets, which affects analysis later on.
#
# We will try to fill in the missing values as best as we can, based on previous year revenues or calculations between columns.

# %% [markdown]
# ### Managing Missing Values

# %% [markdown]
# ### Expanded Dataset: Revenue Growth

# %%
# For each stock, fill in revenue growth NaN based on revenue in the previous year
# Ensure 'Year' column is in integer format
expanded_df['Year'] = expanded_df['Year'].astype(int)

# Sort by stock and year
expanded_df = expanded_df.sort_values(by=['Stock', 'Year'])

# Calculate revenue growth where it is NaN
expanded_df['Revenue Growth'] = expanded_df.groupby('Stock')['Revenue'].apply(
    lambda x: x.pct_change(fill_method=None).fillna(0)
).reset_index(drop=True)

# %%
# Confirm that the only NaN left are stocks with no prior revenues
expanded_df_NaN = expanded_df[expanded_df['Revenue Growth'].isna()]

# %%
expanded_df_NaN
# Out:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 100942  AOBPTS  2023  6.097996e+08             NaN      6.115073e+07
# 100987    BDRE  2003  6.815540e+08             NaN      9.123404e+07
# 100976   BIPOE  2024  2.108123e+09             NaN      5.114961e+08
# 100985   BNDGN  2024  1.789047e+09             NaN      1.230134e+08
# 100996    BPCR  2020  4.912654e+08             NaN      6.713231e+07
# ...        ...   ...           ...             ...               ...
# 100975  YRZOUH  2010  2.193145e+09             NaN      6.433787e+08
# 100948  ZDCJZM  2010  1.406831e+09             NaN      8.421765e+07
# 100912  ZRKOOR  2002  1.161208e+09             NaN      9.529671e+07
# 100920  ZRKOOR  2023  1.037629e+09             NaN      1.823199e+08
# 100943  ZWLMLT  2020  7.871220e+08             NaN      1.108272e+08
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 100942  6.073633e+07          0.099600  2.548950e+08            0.417998
# 100987  9.055099e+07          0.132860  2.525246e+08            0.370513
# 100976  5.111623e+08          0.242473  1.000883e+09            0.474774
# 100985  1.228087e+08          0.068645  6.007443e+08            0.335790
# 100996  6.666666e+07          0.135704  2.549765e+08            0.519020
# ...              ...               ...           ...                 ...
# 100975  6.427152e+08          0.293056  1.254352e+09            0.571942
# 100948  8.370352e+07          0.059498  6.295050e+08            0.447463
# 100912  9.461051e+07          0.081476  5.589661e+08            0.481366
# 100920  1.819399e+08          0.175342  4.993368e+08            0.481229
# 100943  1.098887e+08          0.139608  3.813584e+08            0.484497
#
#         Operating Expenses  Cost of Revenue        EBITDA  Interest Expense  \
# 100942        1.937443e+08     3.549046e+08  6.768917e+07          414404.0
# 100987        1.612906e+08     4.290293e+08  9.950987e+07          683050.0
# 100976        4.893866e+08     1.107240e+09  5.187035e+08          333708.0
# 100985        4.777309e+08     1.188303e+09  1.263938e+08          204687.0
# 100996        1.878442e+08     2.362889e+08  6.861804e+07          465648.0
# ...                    ...              ...           ...               ...
# 100975        6.109732e+08     9.387930e+08  6.486510e+08          663444.0
# 100948        5.452873e+08     7.773265e+08  8.884737e+07          514136.0
# 100912        4.636693e+08     6.022419e+08  1.045150e+08          686195.0
# 100920        3.170169e+08     5.382918e+08  1.918209e+08          379945.0
# 100943        2.705312e+08     4.057636e+08  1.173931e+08          938438.0
#
#         Depreciation & Amortization  is_out_of_range
# 100942                    6538445.0            False
# 100987                    8275823.0            False
# 100976                    7207447.0            False
# 100985                    3380443.0            False
# 100996                    1485732.0            False
# ...                             ...              ...
# 100975                    5272380.0            False
# 100948                    4629713.0            False
# 100912                    9218252.0            False
# 100920                    9501007.0            False
# 100943                    6565926.0            False
#
# [94 rows x 15 columns]

# %% [markdown]
# ### Partial Dataset: Operating Expenses, Revenue, Net Income, Revenue Growth

# %%
partial_df.columns
# Out:
# Index(['Stock', 'Year', 'Revenue', 'Revenue Growth', 'Operating Income',
#        'Net Income', 'Net Income Ratio', 'Gross Profit', 'Gross Profit Ratio',
#        'Operating Expenses', 'Cost of Revenue', 'EBITDA', 'Interest Expense',
#        'Depreciation & Amortization', 'is_out_of_range'],
#       dtype='object')

# %%
partial_df[['Operating Expenses', 'Interest Expense', 'Net Income', 'Revenue Growth']]
# Out:
#         Operating Expenses  Interest Expense    Net Income  Revenue Growth
# 1017          3.083693e+08          284064.0  3.225423e+08        0.166164
# 1078                   NaN          170640.0 -8.238490e+07        0.125184
# 1088                   NaN          619332.0  3.232122e+07        0.018995
# 1103                   NaN          578007.0  1.331177e+08        0.184940
# 1117                   NaN          988900.0 -5.198303e+06        0.037804
# ...                    ...               ...           ...             ...
# 100931                 NaN          482545.0  3.562950e+08        0.006929
# 100942        1.937443e+08          414404.0  6.073633e+07        0.190997
# 100945        1.869542e+08          768101.0           NaN        0.183535
# 100961        3.630307e+08          195397.0  2.776071e+08       -0.005228
# 100973        2.294881e+08          735139.0  9.444352e+07       -0.055418
#
# [7997 rows x 4 columns]

# %% [markdown]
# #### Operating Expenses = Gross Profit - Operating Income

# %%
# Fill NaN in 'Operating Expenses' only if both 'Gross Profit' and 'Operating Income' are available
partial_df['Operating Expenses'] = partial_df.apply(
    lambda row: row['Gross Profit'] - row['Operating Income']
    if pd.isna(row['Operating Expenses']) and pd.notna(row['Gross Profit']) and pd.notna(row['Operating Income'])
    else row['Operating Expenses'], axis=1
)

# %%
partial_df[['Operating Expenses', 'Gross Profit', 'Operating Income']]
# Out:
#         Operating Expenses  Gross Profit  Operating Income
# 1017          3.083693e+08  6.311956e+08      3.228263e+08
# 1078          8.151531e+08  7.329389e+08     -8.221426e+07
# 1088          7.326119e+07  1.062017e+08      3.294055e+07
# 1103          7.238342e+08  8.575299e+08      1.336957e+08
# 1117          2.322920e+08  2.280826e+08     -4.209403e+06
# ...                    ...           ...               ...
# 100931        4.963250e+08  8.531026e+08      3.567775e+08
# 100942        1.937443e+08  2.548950e+08      6.115073e+07
# 100945        1.869542e+08  2.680819e+08      8.112773e+07
# 100961        3.630307e+08  6.408332e+08      2.778025e+08
# 100973        2.294881e+08  3.246667e+08      9.517866e+07
#
# [7997 rows x 3 columns]

# %%
# Check if Operating Expenses still has NaN
if partial_df['Operating Expenses'].isna().any():
    print("Yes, there are still NaN values.")
    print(partial_df[partial_df['Operating Expenses'].isna()])
else:
    print("No more NaN values")
# Out:
# No more NaN values

# %%
print(missing_values_check(partial_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 2                       Revenue                   1599   19.994998
# 5                    Net Income                    800   10.003751
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 3                Revenue Growth                      0    0.000000
# 4              Operating Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000

# %% [markdown]
# #### Net Income = Operating Income - Interest Expense

# %%
# Fill NaN in 'Net Income' only when Operating Income, Interest Expense are available
partial_df['Net Income'] = partial_df.apply(
    lambda row: row['Operating Income'] - row['Interest Expense']
    if pd.isna(row['Net Income']) and pd.notna(row['Operating Income']) and pd.notna(row['Interest Expense'])
    else row['Net Income'],
    axis=1
)

# %%
partial_df[['Net Income', 'Operating Income', 'Interest Expense']]
# Out:
#           Net Income  Operating Income  Interest Expense
# 1017    3.225423e+08      3.228263e+08          284064.0
# 1078   -8.238490e+07     -8.221426e+07          170640.0
# 1088    3.232122e+07      3.294055e+07          619332.0
# 1103    1.331177e+08      1.336957e+08          578007.0
# 1117   -5.198303e+06     -4.209403e+06          988900.0
# ...              ...               ...               ...
# 100931  3.562950e+08      3.567775e+08          482545.0
# 100942  6.073633e+07      6.115073e+07          414404.0
# 100945  8.035963e+07      8.112773e+07          768101.0
# 100961  2.776071e+08      2.778025e+08          195397.0
# 100973  9.444352e+07      9.517866e+07          735139.0
#
# [7997 rows x 3 columns]

# %%
# Check if Net Income still has NaN
if partial_df['Net Income'].isna().any():
    print("Yes, there are still NaN values.")
    print(partial_df[partial_df['Net Income'].isna()])
else:
    print("No more NaN values")
# Out:
# No more NaN values

# %%
print(missing_values_check(partial_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 2                       Revenue                   1599   19.994998
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 3                Revenue Growth                      0    0.000000
# 4              Operating Income                      0    0.000000
# 5                    Net Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000

# %% [markdown]
# #### Revenue = Gross Profit + Cost of Revenue

# %%
# Fill NaN in 'Revenue' only when Gross Profit and Cost of Revenue are available
partial_df['Revenue'] = partial_df.apply(
    lambda row: row['Gross Profit'] + row['Cost of Revenue']
    if pd.isna(row['Revenue']) and pd.notna(row['Gross Profit']) and pd.notna(row['Cost of Revenue'])
    else row['Revenue'],
    axis=1
)

# %%
partial_df[['Revenue', 'Gross Profit', 'Cost of Revenue']]
# Out:
#              Revenue  Gross Profit  Cost of Revenue
# 1017    1.377147e+09  6.311956e+08     7.459519e+08
# 1078    2.047604e+09  7.329389e+08     1.314665e+09
# 1088    3.194701e+08  1.062017e+08     2.132684e+08
# 1103    2.243174e+09  8.575299e+08     1.385644e+09
# 1117    6.565935e+08  2.280826e+08     4.285109e+08
# ...              ...           ...              ...
# 100931  1.540178e+09  8.531026e+08     6.870754e+08
# 100942  6.097996e+08  2.548950e+08     3.549046e+08
# 100945  6.532326e+08  2.680819e+08     3.851506e+08
# 100961  1.663794e+09  6.408332e+08     1.022961e+09
# 100973  1.005798e+09  3.246667e+08     6.811314e+08
#
# [7997 rows x 3 columns]

# %%
# Check if Revenue still has NaN values
if partial_df['Revenue'].isna().any():
    print("Yes, there are still NaN values.")
    print(partial_df[partial_df['Revenue'].isna()])
else:
    print("No more NaN values")
# Out:
# No more NaN values

# %%
print(missing_values_check(partial_df))
# Out:
#                          Column  No. of Missing Values  Percentage
# 3                Revenue Growth                     91    1.124429
# 0                         Stock                      0    0.000000
# 1                          Year                      0    0.000000
# 2                       Revenue                      0    0.000000
# 4              Operating Income                      0    0.000000
# 5                    Net Income                      0    0.000000
# 6              Net Income Ratio                      0    0.000000
# 7                  Gross Profit                      0    0.000000
# 8            Gross Profit Ratio                      0    0.000000
# 9            Operating Expenses                      0    0.000000
# 10              Cost of Revenue                      0    0.000000
# 11                       EBITDA                      0    0.000000
# 12             Interest Expense                      0    0.000000
# 13  Depreciation & Amortization                      0    0.000000
# 14              is_out_of_range                      0    0.000000

# %% [markdown]
# #### Revenue Growth = % Change in Revenue from Previous Year

# %%
# For each stock, fill in revenue growth NaN based on revenue in the previous year
# Ensure 'Year' column is in integer format
partial_df['Year'] = partial_df['Year'].astype(int)

# Sort by stock and year
partial_df = partial_df.sort_values(by=['Stock', 'Year'])

# Calculate revenue growth where it is NaN
partial_df['Revenue Growth'] = partial_df.groupby('Stock')['Revenue'].apply(
    lambda x: x.pct_change().fillna(0)
).reset_index(level=0, drop=True)  # Reset the group index, drop the group level

# %%
partial_df[['Stock', 'Year', 'Revenue', 'Revenue Growth']]
# Out:
#         Stock  Year       Revenue  Revenue Growth
# 60034    AAAR  2022  1.966766e+09        0.000000
# 52351    AAAR  2023  1.511845e+09       -0.231304
# 83513  AAGYLB  2022  2.604578e+07        0.000000
# 88180  AAGYLB  2023  1.729867e+09       65.416389
# 17404  AAHKPV  2022  6.635320e+08        0.000000
# ...       ...   ...           ...             ...
# 52984  ZZNTAM  2023  4.088261e+08        0.062723
# 76589  ZZYCDC  2022  9.501569e+08        0.000000
# 92549  ZZYCDC  2023  2.493206e+09        1.623994
# 70614    ZZZC  2022  2.231377e+07        0.000000
# 38712    ZZZC  2023  1.388236e+09       61.214298
#
# [7997 rows x 4 columns]

# %% [markdown]
# ### Historical Dataset: Gross Profit, Cost of Revenue, Revenue

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    129   26.166329
# 4     Gross Profit                    129   26.166329
# 2          Revenue                     86   17.444219
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000

# %% [markdown]
# #### Gross Profit = Revenue - Cost of Revenue

# %%
# Fill NaN in 'Gross Profit' only when Revenue and Cost of Revenue are available
historical_df['Gross Profit'] = historical_df.apply(
    lambda row: row['Revenue'] - row['Cost of Revenue']
    if pd.isna(row['Gross Profit']) and pd.notna(row['Revenue']) and pd.notna(row['Cost of Revenue'])
    else row['Gross Profit'],
    axis=1
)

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    129   26.166329
# 4     Gross Profit                    129   26.166329
# 2          Revenue                     86   17.444219
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000

# %% [markdown]
# #### Cost of Revenue = Revenue - Gross Profit

# %%
# Fill NaN in 'Cost of Revenue' only when Revenue and Gross Profit are available
historical_df['Cost of Revenue'] = historical_df.apply(
    lambda row: row['Revenue'] - row['Gross Profit']
    if pd.isna(row['Cost of Revenue']) and pd.notna(row['Revenue']) and pd.notna(row['Gross Profit'])
    else row['Cost of Revenue'],
    axis=1
)

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    129   26.166329
# 4     Gross Profit                    129   26.166329
# 2          Revenue                     86   17.444219
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000

# %% [markdown]
# #### Revenue = Cost of Revenue + Gross Profit

# %%
# Fill NaN in 'Revenue' only when Cost of Revenue and Gross Profit are available
historical_df['Revenue'] = historical_df.apply(
    lambda row: row['Cost of Revenue'] + row['Gross Profit']
    if pd.isna(row['Revenue']) and pd.notna(row['Cost of Revenue']) and pd.notna(row['Gross Profit'])
    else row['Revenue'],
    axis=1
)

# %%
print(missing_values_check(historical_df))
# Out:
#             Column  No. of Missing Values  Percentage
# 3  Cost of Revenue                    129   26.166329
# 4     Gross Profit                    129   26.166329
# 2          Revenue                     86   17.444219
# 0            Stock                      0    0.000000
# 1             Year                      0    0.000000
# 5  is_out_of_range                      0    0.000000

# %%
# Check the shape of Historical Dataset
historical_df.shape
# Out:
# (493, 6)

# %%
# Remove rows with no Revenue
historical_df = historical_df.drop(historical_df[historical_df['Revenue'].isna()].index)

# %% [markdown]
# #### Drop helper columns

# %%
expanded_df = expanded_df.drop(columns=['is_out_of_range'])

# %%
partial_df = partial_df.drop(columns=['is_out_of_range'])

# %%
historical_df = historical_df.drop(columns=['is_out_of_range'])

# %%
sparse_df = sparse_df.drop(columns=['is_out_of_range'])

# %% [markdown]
# ### Checking Actual vs Expected value of columns

# %% [markdown]
# For each financial metric, the actual values might not follow the expected values.
#
# For example, if EBITDA = Operating Income - Depreciation & Amortization, the actual value might not follow this formula.
#
# This could be because there are adjustments in real-world reporting or human error from inputting the incorrect value, which can result in them to be there by default.
#
# Depending on how many rows are mismatched for each financial metric, we will decide whether to retain these mismatched rows for analysis later on.

# %% [markdown]
# #### Checking EBITDA (Operating Income - D&A)

# %%
def ebitda_calculation(df):
    # Calculate expected EBITDA
    df['expected_EBITDA'] = df['Operating Income'] + df['Depreciation & Amortization']
    # Compare expected EBITDA with the actual EBITDA, also considering small floating-point differences
    df['EBITDA_match'] = np.isclose(df['expected_EBITDA'], df['EBITDA'])

# %%
ebitda_calculation(expanded_df)

# %%
ebitda_calculation(partial_df)

# %%
# 768 out of 100905 rows in Expanded Dataset still do not match the expected EBITDA formula.
expanded_df[expanded_df['EBITDA_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 553  ABMD  2018  5.937490e+08        0.039003      1.571370e+08  1.121700e+08
# 552  ABMD  2019  7.694320e+08        0.316652      2.248120e+08  2.590160e+08
# 608   ACN  2020  4.432704e+10        0.595719      6.513644e+09  5.107839e+09
# 607   ACN  2021  5.053339e+10       -0.024285      7.621529e+09  5.906809e+09
# 606   ACN  2022  6.159430e+10        0.161534      9.367181e+09  6.877169e+09
# ..    ...   ...           ...             ...               ...           ...
# 483  ZBRA  2019  4.485000e+09        0.062035      6.920000e+08  5.440000e+08
# 482  ZBRA  2020  4.448000e+09       -0.231833      6.510000e+08  5.040000e+08
# 481  ZBRA  2021  5.627000e+09        4.777891      9.790000e+08  8.370000e+08
# 480  ZBRA  2022  5.781000e+09       -0.838209      1.346000e+09  4.630000e+08
# 479  ZBRA  2023  4.584000e+09        1.072314      4.810000e+08  2.960000e+08
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 553          0.188918  4.951680e+08            0.833969        3.380310e+08
# 552          0.336633  6.398650e+08            0.831607        4.150530e+08
# 608          0.115231  1.397616e+10            0.315296        7.462514e+09
# 607          0.116889  1.636413e+10            0.323828        8.742599e+09
# 606          0.111653  1.970154e+10            0.319860        1.033436e+10
# ..                ...           ...                 ...                 ...
# 483          0.121293  2.100000e+09            0.468227        1.376000e+09
# 482          0.113309  2.003000e+09            0.450315        1.318000e+09
# 481          0.148747  2.628000e+09            0.467034        1.617000e+09
# 480          0.080090  2.624000e+09            0.453901        1.688000e+09
# 479          0.064572  2.123000e+09            0.463133        1.642000e+09
#
#      Cost of Revenue        EBITDA  Interest Expense  \
# 553     9.858100e+07  1.644540e+08               0.0
# 552     1.295670e+08  2.307670e+08               0.0
# 608     3.035088e+10  7.986088e+09        33071000.0
# 607     3.416926e+10  7.621529e+09        59492000.0
# 606     4.189277e+10  1.055422e+10        47320000.0
# ..               ...           ...               ...
# 483     2.385000e+09  8.430000e+08        89000000.0
# 482     2.445000e+09  7.360000e+08        76000000.0
# 481     2.999000e+09  1.173000e+09         5000000.0
# 480     3.157000e+09  1.140000e+09        23000000.0
# 479     2.461000e+09  6.520000e+08       133000000.0
#
#      Depreciation & Amortization  expected_EBITDA  EBITDA_match
# 553                 1.100500e+07     1.681420e+08         False
# 552                 1.412100e+07     2.389330e+08         False
# 608                 1.773124e+09     8.286768e+09         False
# 607                 1.891242e+09     9.512771e+09         False
# 606                 1.310738e+09     1.067792e+10         False
# ..                           ...              ...           ...
# 483                 1.750000e+08     8.670000e+08         False
# 482                 1.460000e+08     7.970000e+08         False
# 481                 1.870000e+08     1.166000e+09         False
# 480                 2.040000e+08     1.550000e+09         False
# 479                 1.760000e+08     6.570000e+08         False
#
# [768 rows x 16 columns]

# %%
# All rows in Partial Dataset match the expected EBITDA formula
partial_df[partial_df['EBITDA_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match]
# Index: []

# %% [markdown]
# #### Checking Net Income (Operating Income - Interest Expense)

# %%
def netincome_calculation(df):
    # Calculate expected net income
    df['expected_netincome'] = df['Operating Income'] - df['Interest Expense']
    # Compare expected net income with the actual net income, also considering small floating-point differences
    df['netincome_match'] = np.isclose(df['expected_netincome'], df['Net Income'])

# %%
netincome_calculation(expanded_df)

# %%
netincome_calculation(partial_df)

# %%
# 905 out of 100905 rows in Expanded Dataset still do not match the expected Net Income formula
expanded_df[expanded_df['netincome_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income   Net Income  \
# 553  ABMD  2018  5.937490e+08        0.039003      1.571370e+08  112170000.0
# 552  ABMD  2019  7.694320e+08        0.316652      2.248120e+08  259016000.0
# 551  ABMD  2020  8.408830e+08       -0.234162      2.492190e+08  203009000.0
# 550  ABMD  2021  8.475220e+08        0.000000      2.295570e+08  225525000.0
# 549  ABMD  2022  1.031753e+09        3.131401      3.726920e+08  136505000.0
# ..    ...   ...           ...             ...               ...          ...
# 483  ZBRA  2019  4.485000e+09        0.062035      6.920000e+08  544000000.0
# 482  ZBRA  2020  4.448000e+09       -0.231833      6.510000e+08  504000000.0
# 481  ZBRA  2021  5.627000e+09        4.777891      9.790000e+08  837000000.0
# 480  ZBRA  2022  5.781000e+09       -0.838209      1.346000e+09  463000000.0
# 479  ZBRA  2023  4.584000e+09        1.072314      4.810000e+08  296000000.0
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 553          0.188918  4.951680e+08            0.833969        3.380310e+08
# 552          0.336633  6.398650e+08            0.831607        4.150530e+08
# 551          0.241424  6.895780e+08            0.820064        4.403590e+08
# 550          0.266099  6.856150e+08            0.808964        4.560580e+08
# 549          0.132304  8.435950e+08            0.817633        5.868890e+08
# ..                ...           ...                 ...                 ...
# 483          0.121293  2.100000e+09            0.468227        1.376000e+09
# 482          0.113309  2.003000e+09            0.450315        1.318000e+09
# 481          0.148747  2.628000e+09            0.467034        1.617000e+09
# 480          0.080090  2.624000e+09            0.453901        1.688000e+09
# 479          0.064572  2.123000e+09            0.463133        1.642000e+09
#
#      Cost of Revenue        EBITDA  Interest Expense  \
# 553     9.858100e+07  1.644540e+08               0.0
# 552     1.295670e+08  2.307670e+08               0.0
# 551     1.513050e+08  2.574820e+08               0.0
# 550     1.619070e+08  2.469370e+08               0.0
# 549     1.881580e+08  4.007810e+08        49840000.0
# ..               ...           ...               ...
# 483     2.385000e+09  8.430000e+08        89000000.0
# 482     2.445000e+09  7.360000e+08        76000000.0
# 481     2.999000e+09  1.173000e+09         5000000.0
# 480     3.157000e+09  1.140000e+09        23000000.0
# 479     2.461000e+09  6.520000e+08       133000000.0
#
#      Depreciation & Amortization  expected_EBITDA  EBITDA_match  \
# 553                   11005000.0     1.681420e+08         False
# 552                   14121000.0     2.389330e+08         False
# 551                    8263000.0     2.574820e+08          True
# 550                   17380000.0     2.469370e+08          True
# 549                   28089000.0     4.007810e+08          True
# ..                           ...              ...           ...
# 483                  175000000.0     8.670000e+08         False
# 482                  146000000.0     7.970000e+08         False
# 481                  187000000.0     1.166000e+09         False
# 480                  204000000.0     1.550000e+09         False
# 479                  176000000.0     6.570000e+08         False
#
#      expected_netincome  netincome_match
# 553        1.571370e+08            False
# 552        2.248120e+08            False
# 551        2.492190e+08            False
# 550        2.295570e+08            False
# 549        3.228520e+08            False
# ..                  ...              ...
# 483        6.030000e+08            False
# 482        5.750000e+08            False
# 481        9.740000e+08            False
# 480        1.323000e+09            False
# 479        3.480000e+08            False
#
# [905 rows x 18 columns]

# %%
# All rows in Partial Dataset match the expected Net Income formula
partial_df[partial_df['netincome_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match]
# Index: []

# %% [markdown]
# #### Checking Gross Profit (Revenue - Cost of Revenue)

# %%
def grossprofit_calculation(df):
    # Calculate expected gross profit
    df['expected_grossprofit'] = df['Revenue'] - df['Cost of Revenue']
    
    # Compare expected gross profit with the actual gross profit, considering small floating-point differences
    df['grossprofit_match'] = np.isclose(df['expected_grossprofit'], df['Gross Profit'])

# %%
grossprofit_calculation(expanded_df)

# %%
grossprofit_calculation(partial_df)

# %%
# 5 out of 100905 rows in Expanded Dataset still do not match the expected Gross Profit formula
expanded_df[expanded_df['grossprofit_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 833    CI  2019  1.537430e+11       -0.356192      8.077000e+09  5.104000e+09
# 832    CI  2020  1.605500e+11        3.946164      8.153000e+09  8.458000e+09
# 831    CI  2021  1.742670e+11       -0.255454      7.941000e+09  5.370000e+09
# 830    CI  2022  1.800310e+11       -0.043143      8.450000e+09  6.704000e+09
# 829    CI  2023  1.951870e+11       -0.604405      8.536000e+09  5.164000e+09
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 833          0.033198           0.0            0.799542        1.456660e+11
# 832          0.052673           0.0            0.796297        1.523970e+11
# 831          0.030814           0.0            0.807416        1.663260e+11
# 830          0.037112           0.0            0.821714        1.715810e+11
# 829          0.026457           0.0            0.814491        1.866510e+11
#
#      Cost of Revenue        EBITDA  Interest Expense  \
# 833              0.0  1.091600e+10      1.682000e+09
# 832              0.0  1.447700e+10      1.438000e+09
# 831              0.0  1.041300e+10      1.208000e+09
# 830              0.0  1.290800e+10      1.228000e+09
# 829              0.0  9.574000e+09      1.446000e+09
#
#      Depreciation & Amortization  expected_EBITDA  EBITDA_match  \
# 833                 3.651000e+09     1.172800e+10         False
# 832                 2.802000e+09     1.095500e+10         False
# 831                 2.923000e+09     1.086400e+10         False
# 830                 2.925000e+09     1.137500e+10         False
# 829                 3.035000e+09     1.157100e+10         False
#
#      expected_netincome  netincome_match  expected_grossprofit  \
# 833        6.395000e+09            False          1.537430e+11
# 832        6.715000e+09            False          1.605500e+11
# 831        6.733000e+09            False          1.742670e+11
# 830        7.222000e+09            False          1.800310e+11
# 829        7.090000e+09            False          1.951870e+11
#
#      grossprofit_match
# 833              False
# 832              False
# 831              False
# 830              False
# 829              False

# %%
# All rows in Partial Dataset does not match
partial_df[partial_df['grossprofit_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match]
# Index: []

# %% [markdown]
# #### Checking Net Income Ratio (Net Income / Revenue)

# %%
def netincomeratio_calculation(df):
    # Calculate expected net income ratio
    df['expected_netincome_ratio'] = df['Net Income'] / df['Revenue']
    
    # Handle the case where Revenue is zero to avoid division by zero
    df['expected_netincome_ratio'] = df['expected_netincome_ratio'].where(df['Revenue'] != 0, 0)
    
    # Compare expected net income ratio with the actual net income ratio, considering small floating-point differences
    df['netincomeratio_match'] = np.isclose(df['expected_netincome_ratio'], df['Net Income Ratio'])

# %%
netincomeratio_calculation(expanded_df)

# %%
netincomeratio_calculation(partial_df)

# %%
# 10 rows out of 100905 in Expanded Dataset still do not match the expected Net Income Ratio
expanded_df[expanded_df['netincomeratio_match'] == False]
# Out:
#       Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 91   BAC-PL  2023  9.578700e+10       -0.437592      3.950000e+10
# 832      CI  2020  1.605500e+11        3.946164      8.153000e+09
# 831      CI  2021  1.742670e+11       -0.255454      7.941000e+09
# 830      CI  2022  1.800310e+11       -0.043143      8.450000e+09
# 998     JPM  2020  1.198830e+11       -0.881334      4.175600e+10
# 997     JPM  2021  1.216850e+11       17.462388      6.502400e+10
# 996     JPM  2022  1.286410e+11       -0.929791      5.252300e+10
# 860     ROK  2023  9.058000e+09        0.096858      1.622000e+09
# 941     SAP  2021  2.784000e+10        0.759336      2.885000e+09
# 940     SAP  2022  3.087200e+10       -0.457514      4.672000e+09
#
#        Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 91   2.651500e+10          0.268967  9.578700e+10            1.000000
# 832  8.458000e+09          0.052673  0.000000e+00            0.796297
# 831  5.370000e+09          0.030814  0.000000e+00            0.807416
# 830  6.704000e+09          0.037112  0.000000e+00            0.821714
# 998  2.913100e+10          0.284285  1.198830e+11            1.000000
# 997  4.833400e+10          0.369249  1.216850e+11            1.000000
# 996  3.767600e+10          0.308067  1.286410e+11            1.000000
# 860  1.387400e+09          0.141091  3.717000e+09            0.410355
# 941  5.256000e+09          0.195006  1.989400e+10            0.714583
# 940  2.284000e+09          0.077374  2.193600e+10            0.710547
#
#      Operating Expenses  ...  Interest Expense  Depreciation & Amortization  \
# 91         5.628700e+10  ...      7.333100e+10                 2.057000e+09
# 832        1.523970e+11  ...      1.438000e+09                 2.802000e+09
# 831        1.663260e+11  ...      1.208000e+09                 2.923000e+09
# 830        1.715810e+11  ...      1.228000e+09                 2.925000e+09
# 998        6.665600e+10  ...      9.960000e+09                 8.614000e+09
# 997        7.133600e+10  ...      5.553000e+09                 7.932000e+09
# 996        7.614000e+10  ...      2.609700e+10                 7.051000e+09
# 860        2.023700e+09  ...      1.353000e+08                 2.504000e+08
# 941        1.508300e+10  ...      9.490000e+08                 1.775000e+09
# 940        1.712500e+10  ...      2.205000e+09                 1.569000e+09
#
#      expected_EBITDA  EBITDA_match  expected_netincome  netincome_match  \
# 91      4.155700e+10         False       -3.383100e+10            False
# 832     1.095500e+10         False        6.715000e+09            False
# 831     1.086400e+10         False        6.733000e+09            False
# 830     1.137500e+10         False        7.222000e+09            False
# 998     5.037000e+10          True        3.179600e+10            False
# 997     7.295600e+10          True        5.947100e+10            False
# 996     5.957400e+10          True        2.642600e+10            False
# 860     1.872400e+09         False        1.486700e+09            False
# 941     4.660000e+09         False        1.936000e+09            False
# 940     6.241000e+09         False        2.467000e+09            False
#
#      expected_grossprofit  grossprofit_match  expected_netincome_ratio  \
# 91           9.578700e+10               True                  0.276812
# 832          1.605500e+11              False                  0.052681
# 831          1.742670e+11              False                  0.030815
# 830          1.800310e+11              False                  0.037238
# 998          1.198830e+11               True                  0.242995
# 997          1.216850e+11               True                  0.397206
# 996          1.286410e+11               True                  0.292877
# 860          3.717000e+09               True                  0.153168
# 941          1.989400e+10               True                  0.188793
# 940          2.193600e+10               True                  0.073983
#
#      netincomeratio_match
# 91                  False
# 832                 False
# 831                 False
# 830                 False
# 998                 False
# 997                 False
# 996                 False
# 860                 False
# 941                 False
# 940                 False
#
# [10 rows x 22 columns]

# %%
# All rows in Partial Dataset match the expected Net Income Ratio formula
partial_df[partial_df['netincomeratio_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# #### Checking Gross Profit Ratio (Gross Profit / Revenue)

# %%
def grossprofitratio_calculation(df):
    # Calculate expected gross profit ratio
    df['expected_grossprofit_ratio'] = df['Gross Profit'] / df['Revenue']
    
    # Handle the case where Revenue is zero to avoid division by zero
    df['expected_grossprofit_ratio'] = df['expected_grossprofit_ratio'].where(df['Revenue'] != 0, 0)
    
    # Compare expected gross profit ratio with the actual gross profit ratio, considering small floating-point differences
    df['grossprofitratio_match'] = np.isclose(df['expected_grossprofit_ratio'], df['Gross Profit Ratio'])

# %%
grossprofitratio_calculation(expanded_df)

# %%
grossprofitratio_calculation(partial_df)

# %%
# 15 rows out of 100905 in Expanded Dataset still do not match the expected Gross Profit Ratio
expanded_df[expanded_df['grossprofitratio_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 359  ANTM  2020  1.218670e+11        0.012240      7.711000e+09  4.572000e+09
# 358  ANTM  2021  1.386390e+11        0.040871      8.946000e+09  6.104000e+09
# 357  ANTM  2022  1.565950e+11        0.218883      8.451000e+09  5.894000e+09
# 356  ANTM  2023  1.713400e+11        0.140013      8.745000e+09  5.987000e+09
# 833    CI  2019  1.537430e+11       -0.356192      8.077000e+09  5.104000e+09
# 832    CI  2020  1.605500e+11        3.946164      8.153000e+09  8.458000e+09
# 831    CI  2021  1.742670e+11       -0.255454      7.941000e+09  5.370000e+09
# 830    CI  2022  1.800310e+11       -0.043143      8.450000e+09  6.704000e+09
# 829    CI  2023  1.951870e+11       -0.604405      8.536000e+09  5.164000e+09
# 523   ELV  2020  1.218670e+11        0.263707      7.711000e+09  4.572000e+09
# 522   ELV  2021  1.386390e+11       -0.144525      8.946000e+09  6.104000e+09
# 521   ELV  2022  1.565950e+11       -0.663925      8.451000e+09  5.894000e+09
# 520   ELV  2023  1.713400e+11        0.541258      8.745000e+09  5.987000e+09
# 206    GS  2023  4.625400e+10       -0.843047      1.346000e+10  8.516000e+09
# 995   JPM  2023  1.456700e+11       12.505692      7.054300e+10  4.955200e+10
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 359          0.037516  3.382200e+10            0.000000        2.611100e+10
# 358          0.044028  3.599400e+10            0.000000        2.704800e+10
# 357          0.037638  3.995300e+10            0.000000        3.150200e+10
# 356          0.034942  4.701000e+10            0.899072        3.826500e+10
# 833          0.033198  0.000000e+00            0.799542        1.456660e+11
# 832          0.052673  0.000000e+00            0.796297        1.523970e+11
# 831          0.030814  0.000000e+00            0.807416        1.663260e+11
# 830          0.037112  0.000000e+00            0.821714        1.715810e+11
# 829          0.026457  0.000000e+00            0.814491        1.866510e+11
# 523          0.037516  3.382200e+10            0.000000        2.611100e+10
# 522          0.044028  3.599400e+10            0.000000        2.704800e+10
# 521          0.037638  3.995300e+10            0.000000        3.150200e+10
# 520          0.034942  4.701000e+10            0.899072        3.826500e+10
# 206          0.184114  4.625400e+10            0.642150        3.279400e+10
# 995          0.340166  1.456700e+11            1.063719        7.512700e+10
#
#      ...  expected_EBITDA  EBITDA_match  expected_netincome  netincome_match  \
# 359  ...     8.865000e+09         False        6.927000e+09            False
# 358  ...     1.024800e+10         False        8.148000e+09            False
# 357  ...     1.012600e+10          True        7.600000e+09            False
# 356  ...     1.049000e+10          True        7.715000e+09            False
# 833  ...     1.172800e+10         False        6.395000e+09            False
# 832  ...     1.095500e+10         False        6.715000e+09            False
# 831  ...     1.086400e+10         False        6.733000e+09            False
# 830  ...     1.137500e+10         False        7.222000e+09            False
# 829  ...     1.157100e+10         False        7.090000e+09            False
# 523  ...     8.865000e+09         False        6.927000e+09            False
# 522  ...     1.024800e+10         False        8.148000e+09            False
# 521  ...     1.012600e+10          True        7.600000e+09            False
# 520  ...     1.049000e+10          True        7.715000e+09            False
# 206  ...     1.831600e+10          True       -4.870400e+10            False
# 995  ...     7.805500e+10          True       -1.077800e+10            False
#
#      expected_grossprofit  grossprofit_match  expected_netincome_ratio  \
# 359          3.382200e+10               True                  0.037516
# 358          3.599400e+10               True                  0.044028
# 357          3.995300e+10               True                  0.037638
# 356          4.701000e+10               True                  0.034942
# 833          1.537430e+11              False                  0.033198
# 832          1.605500e+11              False                  0.052681
# 831          1.742670e+11              False                  0.030815
# 830          1.800310e+11              False                  0.037238
# 829          1.951870e+11              False                  0.026457
# 523          3.382200e+10               True                  0.037516
# 522          3.599400e+10               True                  0.044028
# 521          3.995300e+10               True                  0.037638
# 520          4.701000e+10               True                  0.034942
# 206          4.625400e+10               True                  0.184114
# 995          1.456700e+11               True                  0.340166
#
#      netincomeratio_match  expected_grossprofit_ratio  grossprofitratio_match
# 359                  True                    0.277532                   False
# 358                  True                    0.259624                   False
# 357                  True                    0.255136                   False
# 356                  True                    0.274367                   False
# 833                  True                    0.000000                   False
# 832                 False                    0.000000                   False
# 831                 False                    0.000000                   False
# 830                 False                    0.000000                   False
# 829                  True                    0.000000                   False
# 523                  True                    0.277532                   False
# 522                  True                    0.259624                   False
# 521                  True                    0.255136                   False
# 520                  True                    0.274367                   False
# 206                  True                    1.000000                   False
# 995                  True                    1.000000                   False
#
# [15 rows x 24 columns]

# %%
# All rows in Partial Dataset match
partial_df[partial_df['grossprofitratio_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# #### Checking Revenue (Gross Profit + Cost of Revenue)

# %%
def revenue_calculation(df):
    # Calculate expected revenue
    df['expected_revenue'] = df['Gross Profit'] + df['Cost of Revenue']

    # Compare expected revenue with the actual revenue, considering small floating-point differences
    df['revenue_match'] = np.isclose(df['expected_revenue'], df['Revenue'])

# %%
revenue_calculation(expanded_df)

# %%
revenue_calculation(partial_df)

# %%
revenue_calculation(historical_df)

# %%
# 5 out of 100905 rows in Expanded Dataset still do not match
expanded_df[expanded_df['revenue_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 833    CI  2019  1.537430e+11       -0.356192      8.077000e+09  5.104000e+09
# 832    CI  2020  1.605500e+11        3.946164      8.153000e+09  8.458000e+09
# 831    CI  2021  1.742670e+11       -0.255454      7.941000e+09  5.370000e+09
# 830    CI  2022  1.800310e+11       -0.043143      8.450000e+09  6.704000e+09
# 829    CI  2023  1.951870e+11       -0.604405      8.536000e+09  5.164000e+09
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 833          0.033198           0.0            0.799542        1.456660e+11
# 832          0.052673           0.0            0.796297        1.523970e+11
# 831          0.030814           0.0            0.807416        1.663260e+11
# 830          0.037112           0.0            0.821714        1.715810e+11
# 829          0.026457           0.0            0.814491        1.866510e+11
#
#      ...  expected_netincome  netincome_match  expected_grossprofit  \
# 833  ...        6.395000e+09            False          1.537430e+11
# 832  ...        6.715000e+09            False          1.605500e+11
# 831  ...        6.733000e+09            False          1.742670e+11
# 830  ...        7.222000e+09            False          1.800310e+11
# 829  ...        7.090000e+09            False          1.951870e+11
#
#      grossprofit_match  expected_netincome_ratio  netincomeratio_match  \
# 833              False                  0.033198                  True
# 832              False                  0.052681                 False
# 831              False                  0.030815                 False
# 830              False                  0.037238                 False
# 829              False                  0.026457                  True
#
#      expected_grossprofit_ratio  grossprofitratio_match  expected_revenue  \
# 833                         0.0                   False               0.0
# 832                         0.0                   False               0.0
# 831                         0.0                   False               0.0
# 830                         0.0                   False               0.0
# 829                         0.0                   False               0.0
#
#      revenue_match
# 833          False
# 832          False
# 831          False
# 830          False
# 829          False
#
# [5 rows x 26 columns]

# %%
# All rows in Partial Dataset match
partial_df[partial_df['revenue_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_revenue, revenue_match]
# Index: []
#
# [0 rows x 26 columns]

# %%
# 43 out of 407 rows in Historical Dataset still do not match
# But we keep the 43 rows anyway because the mismatch is actually caused by NaN in the other columns
historical_df[historical_df['revenue_match'] == False]
# Out:
#        Stock  Year       Revenue  Cost of Revenue  Gross Profit  \
# 121    YLVJB  2020  1.064303e+09              NaN           NaN
# 228   UOSVNX  2014  1.709739e+09              NaN           NaN
# 1332   OFVZT  2010  4.729678e+08              NaN           NaN
# 1355   AAZLH  2019  1.205587e+09              NaN           NaN
# 1383   UZLPI  2011  1.556445e+07              NaN           NaN
# 1562   OXDRI  2019  1.951711e+09              NaN           NaN
# 1623  YRMTOC  2015  9.860993e+08              NaN           NaN
# 2027   PTFPE  2012  2.757830e+08              NaN           NaN
# 2476  SKRHFG  2012  1.451122e+09              NaN           NaN
# 2509  SHDBKH  2018  4.403560e+08              NaN           NaN
# 2652  RDIDUL  2016  7.339218e+08              NaN           NaN
# 2695   NWLWN  2015  9.683670e+07              NaN           NaN
# 2774    QHHY  2018  2.041293e+09              NaN           NaN
# 3487    GDAR  2015  4.503833e+08              NaN           NaN
# 3764   HSBJZ  2012  1.257612e+09              NaN           NaN
# 4322   SQLEV  2016  1.533493e+09              NaN           NaN
# 4520  EWJVXJ  2020  4.681619e+08              NaN           NaN
# 4841   XCSAJ  2017  1.569936e+09              NaN           NaN
# 4923  CHXZKD  2016  1.783658e+09              NaN           NaN
# 4938  KQEBXK  2013  1.072184e+09              NaN           NaN
# 5259  ZCCQTO  2020  4.506711e+08              NaN           NaN
# 5445    ZBKZ  2015  5.619353e+08              NaN           NaN
# 5446  AAHKPV  2012  3.417373e+08              NaN           NaN
# 5533    GHRV  2015  6.614241e+08              NaN           NaN
# 5895  UEPDDX  2018  1.264402e+09              NaN           NaN
# 5901   QHERB  2012  1.166230e+09              NaN           NaN
# 6170    UJBU  2013  2.919337e+08              NaN           NaN
# 6599  JSEOQO  2016  1.648920e+09              NaN           NaN
# 6637  ORHUIF  2010  1.131601e+09              NaN           NaN
# 6706    WJNK  2011  1.211729e+09              NaN           NaN
# 7203  NIVXTX  2013  1.084515e+08              NaN           NaN
# 7490   YNDWM  2013  1.965671e+09              NaN           NaN
# 7768    QIHN  2011  2.000997e+09              NaN           NaN
# 7816    KMZQ  2014  1.459759e+09              NaN           NaN
# 8062    LGLM  2018  3.366382e+08              NaN           NaN
# 8270   CYWQF  2015  1.914502e+09              NaN           NaN
# 8284   PRMPK  2018  1.076601e+09              NaN           NaN
# 8731    VDYD  2019  1.298809e+09              NaN           NaN
# 8835  KQXKGP  2020  2.369687e+08              NaN           NaN
# 9315  QOHQOV  2010  9.337662e+08              NaN           NaN
# 9546  YFHQXH  2019  1.464466e+09              NaN           NaN
# 9564  EDRRGL  2017  6.847016e+08              NaN           NaN
# 9774   ODBTL  2013  8.838695e+08              NaN           NaN
#
#       expected_revenue  revenue_match
# 121                NaN          False
# 228                NaN          False
# 1332               NaN          False
# 1355               NaN          False
# 1383               NaN          False
# 1562               NaN          False
# 1623               NaN          False
# 2027               NaN          False
# 2476               NaN          False
# 2509               NaN          False
# 2652               NaN          False
# 2695               NaN          False
# 2774               NaN          False
# 3487               NaN          False
# 3764               NaN          False
# 4322               NaN          False
# 4520               NaN          False
# 4841               NaN          False
# 4923               NaN          False
# 4938               NaN          False
# 5259               NaN          False
# 5445               NaN          False
# 5446               NaN          False
# 5533               NaN          False
# 5895               NaN          False
# 5901               NaN          False
# 6170               NaN          False
# 6599               NaN          False
# 6637               NaN          False
# 6706               NaN          False
# 7203               NaN          False
# 7490               NaN          False
# 7768               NaN          False
# 7816               NaN          False
# 8062               NaN          False
# 8270               NaN          False
# 8284               NaN          False
# 8731               NaN          False
# 8835               NaN          False
# 9315               NaN          False
# 9546               NaN          False
# 9564               NaN          False
# 9774               NaN          False

# %% [markdown]
# #### Checking Revenue Growth (% Change in Revenue from Previous Year)

# %%
def revenuegrowth_calculation(df):
    # Sort Stock and Year first
    df = df.sort_values(by=['Stock', 'Year'])
    
    # Calculate expected revenue growth
    df['expected_revenuegrowth'] = df.groupby('Stock')['Revenue'].pct_change()

    # Fill NaN values in expected_revenuegrowth (e.g., first year or missing data)
    df['expected_revenuegrowth'] = df['expected_revenuegrowth'].fillna(0)

    # Compare expected revenue growth with the actual revenue growth, considering small floating-point differences
    df['revenuegrowth_match'] = np.isclose(df['expected_revenuegrowth'], df['Revenue Growth'], atol=1e-2)

    return df

# %%
expanded_df = revenuegrowth_calculation(expanded_df)

# %%
partial_df = revenuegrowth_calculation(partial_df)

# %%
# 100042 out of 100905 rows in Expanded Dataset still do not match the expected Revenue Growth
expanded_df[expanded_df['revenuegrowth_match'] == False]
# Out:
#       Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 74474  AAAR  2000  1.226394e+09        0.515833      3.822607e+08
# 30360  AAAR  2001  1.363043e+09        0.251834      2.826937e+08
# 57233  AAAR  2002  9.680363e+08        1.469854      1.493846e+08
# 38752  AAAR  2003  7.725786e+08        0.026633      8.830040e+07
# 87263  AAAR  2004  9.481924e+07        2.047161      1.385745e+07
# ...     ...   ...           ...             ...               ...
# 25480  ZZZC  2020  2.068409e+09        0.236733      6.084053e+08
# 51748  ZZZC  2021  1.044180e+09        4.249838      1.926045e+08
# 70614  ZZZC  2022  2.231377e+07        0.000000      6.756885e+06
# 38712  ZZZC  2023  1.388236e+09        0.635764      2.644288e+08
# 33732  ZZZC  2024  1.225857e+09        0.016966      3.342184e+08
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 74474  3.821538e+08          0.311608  7.326731e+08            0.597421
# 30360  2.823476e+08          0.207145  5.723752e+08            0.419924
# 57233  1.489654e+08          0.153884  4.224707e+08            0.436420
# 38752  8.753229e+07          0.113299  3.959663e+08            0.512526
# 87263  1.312690e+07          0.138441  4.645290e+07            0.489910
# ...             ...               ...           ...                 ...
# 25480  6.074186e+08          0.293665  1.172125e+09            0.566679
# 51748  1.923814e+08          0.184242  4.346634e+08            0.416272
# 70614  5.839832e+06          0.261714  1.311786e+07            0.587882
# 38712  2.641767e+08          0.190297  6.771341e+08            0.487766
# 33732  3.333005e+08          0.271892  6.954862e+08            0.567347
#
#        Operating Expenses  ...  expected_grossprofit  grossprofit_match  \
# 74474        3.504124e+08  ...          7.326731e+08               True
# 30360        2.896814e+08  ...          5.723752e+08               True
# 57233        2.730861e+08  ...          4.224707e+08               True
# 38752        3.076659e+08  ...          3.959663e+08               True
# 87263        3.259545e+07  ...          4.645290e+07               True
# ...                   ...  ...                   ...                ...
# 25480        5.637193e+08  ...          1.172125e+09               True
# 51748        2.420589e+08  ...          4.346634e+08               True
# 70614        6.360976e+06  ...          1.311786e+07               True
# 38712        4.127053e+08  ...          6.771341e+08               True
# 33732        3.612678e+08  ...          6.954862e+08               True
#
#        expected_netincome_ratio  netincomeratio_match  \
# 74474                  0.311608                  True
# 30360                  0.207145                  True
# 57233                  0.153884                  True
# 38752                  0.113299                  True
# 87263                  0.138441                  True
# ...                         ...                   ...
# 25480                  0.293665                  True
# 51748                  0.184242                  True
# 70614                  0.261714                  True
# 38712                  0.190297                  True
# 33732                  0.271892                  True
#
#        expected_grossprofit_ratio  grossprofitratio_match  expected_revenue  \
# 74474                    0.597421                    True      1.226394e+09
# 30360                    0.419924                    True      1.363043e+09
# 57233                    0.436420                    True      9.680363e+08
# 38752                    0.512526                    True      7.725786e+08
# 87263                    0.489910                    True      9.481924e+07
# ...                           ...                     ...               ...
# 25480                    0.566679                    True      2.068409e+09
# 51748                    0.416272                    True      1.044180e+09
# 70614                    0.587882                    True      2.231377e+07
# 38712                    0.487766                    True      1.388236e+09
# 33732                    0.567347                    True      1.225857e+09
#
#        revenue_match  expected_revenuegrowth  revenuegrowth_match
# 74474           True                0.000000                False
# 30360           True                0.111424                False
# 57233           True               -0.289798                False
# 38752           True               -0.201912                False
# 87263           True               -0.877269                False
# ...              ...                     ...                  ...
# 25480           True                0.876464                False
# 51748           True               -0.495177                False
# 70614           True               -0.978630                False
# 38712           True               61.214298                False
# 33732           True               -0.116968                False
#
# [100042 rows x 28 columns]

# %%
# We keep these rows but replace the original Revenue Growth with the expected numbers
expanded_df['Revenue Growth'] = expanded_df['expected_revenuegrowth']

# %%
# All rows in Partial Dataset match
partial_df[partial_df['revenuegrowth_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# #### Checking Cost of Revenue (Revenue - Gross Profit)

# %%
def costofrevenue_calculation(df):
    # Calculate expected cost of revenue
    df['expected_costofrevenue'] = df['Revenue'] - df['Gross Profit']

    # Compare expected cost of revenue with the actual cost of revenue, considering small floating-point differences
    df['costofrevenue_match'] = np.isclose(df['expected_costofrevenue'], df['Cost of Revenue'])

# %%
costofrevenue_calculation(expanded_df)

# %%
costofrevenue_calculation(partial_df)

# %%
# 5 out of 100905 rows in Expanded Dataset still do not match
expanded_df[expanded_df['costofrevenue_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 833    CI  2019  1.537430e+11        0.000000      8.077000e+09  5.104000e+09
# 832    CI  2020  1.605500e+11        0.044275      8.153000e+09  8.458000e+09
# 831    CI  2021  1.742670e+11        0.085438      7.941000e+09  5.370000e+09
# 830    CI  2022  1.800310e+11        0.033076      8.450000e+09  6.704000e+09
# 829    CI  2023  1.951870e+11        0.084186      8.536000e+09  5.164000e+09
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 833          0.033198           0.0            0.799542        1.456660e+11
# 832          0.052673           0.0            0.796297        1.523970e+11
# 831          0.030814           0.0            0.807416        1.663260e+11
# 830          0.037112           0.0            0.821714        1.715810e+11
# 829          0.026457           0.0            0.814491        1.866510e+11
#
#      ...  expected_netincome_ratio  netincomeratio_match  \
# 833  ...                  0.033198                  True
# 832  ...                  0.052681                 False
# 831  ...                  0.030815                 False
# 830  ...                  0.037238                 False
# 829  ...                  0.026457                  True
#
#      expected_grossprofit_ratio  grossprofitratio_match  expected_revenue  \
# 833                         0.0                   False               0.0
# 832                         0.0                   False               0.0
# 831                         0.0                   False               0.0
# 830                         0.0                   False               0.0
# 829                         0.0                   False               0.0
#
#      revenue_match  expected_revenuegrowth  revenuegrowth_match  \
# 833          False                0.000000                False
# 832          False                0.044275                False
# 831          False                0.085438                False
# 830          False                0.033076                False
# 829          False                0.084186                False
#
#      expected_costofrevenue  costofrevenue_match
# 833            1.537430e+11                False
# 832            1.605500e+11                False
# 831            1.742670e+11                False
# 830            1.800310e+11                False
# 829            1.951870e+11                False
#
# [5 rows x 30 columns]

# %%
# All rows in Partial Dataset match
partial_df[partial_df['costofrevenue_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match, expected_costofrevenue, costofrevenue_match]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# #### Checking Operating Income (Gross Profit - Operating Expense)

# %%
def operatingincome_calculation(df):
    # Calculate expected operating income
    df['expected_operatingincome'] = df['Gross Profit'] - df['Operating Expenses']
    
    # Compare expected operating income with the actual operating income, considering small floating-point differences
    df['operatingincome_match'] = np.isclose(df['expected_operatingincome'], df['Operating Income'])

# %%
operatingincome_calculation(expanded_df)

# %%
operatingincome_calculation(partial_df)

# %%
# 440 out of 100905 rows in Expanded Dataset still do not match
expanded_df[expanded_df['operatingincome_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 549  ABMD  2022  1.031753e+09        0.217376      3.726920e+08  1.365050e+08
# 824   ADP  2024  1.920260e+10        0.066089      4.977200e+09  3.752000e+09
# 813  ADSK  2020  3.274300e+09        0.000000      3.430000e+08  2.145000e+08
# 809  ADSK  2024  5.440000e+09        0.086913      1.128000e+09  9.060000e+08
# 883   AJG  2019  7.195000e+09        0.000000      8.365000e+08  6.688000e+08
# ..    ...   ...           ...             ...               ...           ...
# 775   WTW  2022  8.866000e+09       -0.014670      1.178000e+09  1.009000e+09
# 483  ZBRA  2019  4.485000e+09        0.000000      6.920000e+08  5.440000e+08
# 482  ZBRA  2020  4.448000e+09       -0.008250      6.510000e+08  5.040000e+08
# 481  ZBRA  2021  5.627000e+09        0.265063      9.790000e+08  8.370000e+08
# 480  ZBRA  2022  5.781000e+09        0.027368      1.346000e+09  4.630000e+08
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 549          0.132304  8.435950e+08            0.817633        5.868890e+08
# 824          0.195390  8.725900e+09            0.454412        4.204400e+09
# 813          0.065510  2.949400e+09            0.900773        2.605900e+09
# 809          0.166544  4.929000e+09            0.906066        3.816000e+09
# 883          0.092953  2.364100e+09            0.328575        1.542900e+09
# ..                ...           ...                 ...                 ...
# 775          0.113806  3.620000e+09            0.408301        2.343000e+09
# 483          0.121293  2.100000e+09            0.468227        1.376000e+09
# 482          0.113309  2.003000e+09            0.450315        1.318000e+09
# 481          0.148747  2.628000e+09            0.467034        1.617000e+09
# 480          0.080090  2.624000e+09            0.453901        1.688000e+09
#
#      ...  expected_grossprofit_ratio  grossprofitratio_match  \
# 549  ...                    0.817633                    True
# 824  ...                    0.454412                    True
# 813  ...                    0.900773                    True
# 809  ...                    0.906066                    True
# 883  ...                    0.328575                    True
# ..   ...                         ...                     ...
# 775  ...                    0.408301                    True
# 483  ...                    0.468227                    True
# 482  ...                    0.450315                    True
# 481  ...                    0.467034                    True
# 480  ...                    0.453901                    True
#
#      expected_revenue  revenue_match  expected_revenuegrowth  \
# 549      1.031753e+09           True                0.217376
# 824      1.920260e+10           True                0.066089
# 813      3.274300e+09           True                0.000000
# 809      5.440000e+09           True                0.086913
# 883      7.195000e+09           True                0.000000
# ..                ...            ...                     ...
# 775      8.866000e+09           True               -0.014670
# 483      4.485000e+09           True                0.000000
# 482      4.448000e+09           True               -0.008250
# 481      5.627000e+09           True                0.265063
# 480      5.781000e+09           True                0.027368
#
#      revenuegrowth_match  expected_costofrevenue  costofrevenue_match  \
# 549                False            1.881580e+08                 True
# 824                False            1.047670e+10                 True
# 813                False            3.249000e+08                 True
# 809                False            5.110000e+08                 True
# 883                False            4.830900e+09                 True
# ..                   ...                     ...                  ...
# 775                False            5.246000e+09                 True
# 483                False            2.385000e+09                 True
# 482                False            2.445000e+09                 True
# 481                False            2.999000e+09                 True
# 480                False            3.157000e+09                 True
#
#      expected_operatingincome  operatingincome_match
# 549              2.567060e+08                  False
# 824              4.521500e+09                  False
# 813              3.435000e+08                  False
# 809              1.113000e+09                  False
# 883              8.212000e+08                  False
# ..                        ...                    ...
# 775              1.277000e+09                  False
# 483              7.240000e+08                  False
# 482              6.850000e+08                  False
# 481              1.011000e+09                  False
# 480              9.360000e+08                  False
#
# [440 rows x 32 columns]

# %%
# All rows in Partial Dataset match
partial_df[partial_df['operatingincome_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match, expected_costofrevenue, costofrevenue_match, expected_operatingincome, operatingincome_match]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# #### Checking Operating Expenses (Gross Profit - Operating Income)

# %%
def operatingexpenses_calculation(df):
    # Calculate expected operating expenses
    df['expected_operatingexpenses'] = df['Gross Profit'] - df['Operating Income']
    
    # Compare expected operating expenses with the actual operating expense, considering small floating-point differences
    df['operatingexpenses_match'] = np.isclose(df['expected_operatingexpenses'], df['Operating Expenses'])

# %%
operatingexpenses_calculation(expanded_df)

# %%
operatingexpenses_calculation(partial_df)

# %%
# 440 out of 100905 in Expanded Dataset still do not match the expected Operating Expenses
expanded_df[expanded_df['operatingexpenses_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 549  ABMD  2022  1.031753e+09        0.217376      3.726920e+08  1.365050e+08
# 824   ADP  2024  1.920260e+10        0.066089      4.977200e+09  3.752000e+09
# 813  ADSK  2020  3.274300e+09        0.000000      3.430000e+08  2.145000e+08
# 809  ADSK  2024  5.440000e+09        0.086913      1.128000e+09  9.060000e+08
# 883   AJG  2019  7.195000e+09        0.000000      8.365000e+08  6.688000e+08
# ..    ...   ...           ...             ...               ...           ...
# 775   WTW  2022  8.866000e+09       -0.014670      1.178000e+09  1.009000e+09
# 483  ZBRA  2019  4.485000e+09        0.000000      6.920000e+08  5.440000e+08
# 482  ZBRA  2020  4.448000e+09       -0.008250      6.510000e+08  5.040000e+08
# 481  ZBRA  2021  5.627000e+09        0.265063      9.790000e+08  8.370000e+08
# 480  ZBRA  2022  5.781000e+09        0.027368      1.346000e+09  4.630000e+08
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 549          0.132304  8.435950e+08            0.817633        5.868890e+08
# 824          0.195390  8.725900e+09            0.454412        4.204400e+09
# 813          0.065510  2.949400e+09            0.900773        2.605900e+09
# 809          0.166544  4.929000e+09            0.906066        3.816000e+09
# 883          0.092953  2.364100e+09            0.328575        1.542900e+09
# ..                ...           ...                 ...                 ...
# 775          0.113806  3.620000e+09            0.408301        2.343000e+09
# 483          0.121293  2.100000e+09            0.468227        1.376000e+09
# 482          0.113309  2.003000e+09            0.450315        1.318000e+09
# 481          0.148747  2.628000e+09            0.467034        1.617000e+09
# 480          0.080090  2.624000e+09            0.453901        1.688000e+09
#
#      ...  expected_revenue  revenue_match  expected_revenuegrowth  \
# 549  ...      1.031753e+09           True                0.217376
# 824  ...      1.920260e+10           True                0.066089
# 813  ...      3.274300e+09           True                0.000000
# 809  ...      5.440000e+09           True                0.086913
# 883  ...      7.195000e+09           True                0.000000
# ..   ...               ...            ...                     ...
# 775  ...      8.866000e+09           True               -0.014670
# 483  ...      4.485000e+09           True                0.000000
# 482  ...      4.448000e+09           True               -0.008250
# 481  ...      5.627000e+09           True                0.265063
# 480  ...      5.781000e+09           True                0.027368
#
#      revenuegrowth_match  expected_costofrevenue  costofrevenue_match  \
# 549                False            1.881580e+08                 True
# 824                False            1.047670e+10                 True
# 813                False            3.249000e+08                 True
# 809                False            5.110000e+08                 True
# 883                False            4.830900e+09                 True
# ..                   ...                     ...                  ...
# 775                False            5.246000e+09                 True
# 483                False            2.385000e+09                 True
# 482                False            2.445000e+09                 True
# 481                False            2.999000e+09                 True
# 480                False            3.157000e+09                 True
#
#      expected_operatingincome  operatingincome_match  \
# 549              2.567060e+08                  False
# 824              4.521500e+09                  False
# 813              3.435000e+08                  False
# 809              1.113000e+09                  False
# 883              8.212000e+08                  False
# ..                        ...                    ...
# 775              1.277000e+09                  False
# 483              7.240000e+08                  False
# 482              6.850000e+08                  False
# 481              1.011000e+09                  False
# 480              9.360000e+08                  False
#
#      expected_operatingexpenses  operatingexpenses_match
# 549                4.709030e+08                    False
# 824                3.748700e+09                    False
# 813                2.606400e+09                    False
# 809                3.801000e+09                    False
# 883                1.527600e+09                    False
# ..                          ...                      ...
# 775                2.442000e+09                    False
# 483                1.408000e+09                    False
# 482                1.352000e+09                    False
# 481                1.649000e+09                    False
# 480                1.278000e+09                    False
#
# [440 rows x 34 columns]

# %%
# All rows in Partial Dataset match
partial_df[partial_df['operatingexpenses_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match, expected_costofrevenue, costofrevenue_match, expected_operatingincome, operatingincome_match, expected_operatingexpenses, operatingexpenses_match]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# #### Checking Depreciation & Amortization (EBITDA - Operating Income)

# %%
def depreciationamortization_calculation(df):
    # Calculate expected D&A
    df['expected_depreciationamortization'] = df['EBITDA'] - df['Operating Income']
    
    # Compare expected D&A with the actual D&A, considering small floating-point differences
    df['depreciationamortization_match'] = np.isclose(df['expected_depreciationamortization'], df['Depreciation & Amortization'])

# %%
depreciationamortization_calculation(expanded_df)

# %%
depreciationamortization_calculation(partial_df)

# %%
# 768 rows out of 100905 in Expanded Dataset still do not match the expected D&A
expanded_df[expanded_df['depreciationamortization_match'] == False]
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income    Net Income  \
# 553  ABMD  2018  5.937490e+08        0.000000      1.571370e+08  1.121700e+08
# 552  ABMD  2019  7.694320e+08        0.295888      2.248120e+08  2.590160e+08
# 608   ACN  2020  4.432704e+10        0.000000      6.513644e+09  5.107839e+09
# 607   ACN  2021  5.053339e+10        0.140013      7.621529e+09  5.906809e+09
# 606   ACN  2022  6.159430e+10        0.218883      9.367181e+09  6.877169e+09
# ..    ...   ...           ...             ...               ...           ...
# 483  ZBRA  2019  4.485000e+09        0.000000      6.920000e+08  5.440000e+08
# 482  ZBRA  2020  4.448000e+09       -0.008250      6.510000e+08  5.040000e+08
# 481  ZBRA  2021  5.627000e+09        0.265063      9.790000e+08  8.370000e+08
# 480  ZBRA  2022  5.781000e+09        0.027368      1.346000e+09  4.630000e+08
# 479  ZBRA  2023  4.584000e+09       -0.207058      4.810000e+08  2.960000e+08
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 553          0.188918  4.951680e+08            0.833969        3.380310e+08
# 552          0.336633  6.398650e+08            0.831607        4.150530e+08
# 608          0.115231  1.397616e+10            0.315296        7.462514e+09
# 607          0.116889  1.636413e+10            0.323828        8.742599e+09
# 606          0.111653  1.970154e+10            0.319860        1.033436e+10
# ..                ...           ...                 ...                 ...
# 483          0.121293  2.100000e+09            0.468227        1.376000e+09
# 482          0.113309  2.003000e+09            0.450315        1.318000e+09
# 481          0.148747  2.628000e+09            0.467034        1.617000e+09
# 480          0.080090  2.624000e+09            0.453901        1.688000e+09
# 479          0.064572  2.123000e+09            0.463133        1.642000e+09
#
#      ...  expected_revenuegrowth  revenuegrowth_match  expected_costofrevenue  \
# 553  ...                0.000000                False            9.858100e+07
# 552  ...                0.295888                False            1.295670e+08
# 608  ...                0.000000                False            3.035088e+10
# 607  ...                0.140013                False            3.416926e+10
# 606  ...                0.218883                False            4.189277e+10
# ..   ...                     ...                  ...                     ...
# 483  ...                0.000000                False            2.385000e+09
# 482  ...               -0.008250                False            2.445000e+09
# 481  ...                0.265063                False            2.999000e+09
# 480  ...                0.027368                False            3.157000e+09
# 479  ...               -0.207058                False            2.461000e+09
#
#      costofrevenue_match  expected_operatingincome  operatingincome_match  \
# 553                 True              1.571370e+08                   True
# 552                 True              2.248120e+08                   True
# 608                 True              6.513644e+09                   True
# 607                 True              7.621529e+09                   True
# 606                 True              9.367181e+09                   True
# ..                   ...                       ...                    ...
# 483                 True              7.240000e+08                  False
# 482                 True              6.850000e+08                  False
# 481                 True              1.011000e+09                  False
# 480                 True              9.360000e+08                  False
# 479                 True              4.810000e+08                   True
#
#      expected_operatingexpenses  operatingexpenses_match  \
# 553                3.380310e+08                     True
# 552                4.150530e+08                     True
# 608                7.462514e+09                     True
# 607                8.742599e+09                     True
# 606                1.033436e+10                     True
# ..                          ...                      ...
# 483                1.408000e+09                    False
# 482                1.352000e+09                    False
# 481                1.649000e+09                    False
# 480                1.278000e+09                    False
# 479                1.642000e+09                     True
#
#      expected_depreciationamortization  depreciationamortization_match
# 553                       7.317000e+06                           False
# 552                       5.955000e+06                           False
# 608                       1.472444e+09                           False
# 607                       0.000000e+00                           False
# 606                       1.187044e+09                           False
# ..                                 ...                             ...
# 483                       1.510000e+08                           False
# 482                       8.500000e+07                           False
# 481                       1.940000e+08                           False
# 480                      -2.060000e+08                           False
# 479                       1.710000e+08                           False
#
# [768 rows x 36 columns]

# %%
# All rows in Partial Dataset match
partial_df[partial_df['depreciationamortization_match'] == False]
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match, expected_costofrevenue, costofrevenue_match, expected_operatingincome, operatingincome_match, expected_operatingexpenses, operatingexpenses_match, expected_depreciationamortization, depreciationamortization_match]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# #### Dropping rows with 'False' in any of Match columns

# %%
# Expanded Dataset - All match columns except for expected revenue growth match
expanded_df_match_columns = [col for col in expanded_df.columns if 'match' in col and col != 'revenuegrowth_match']

# Filter rows where any of the match columns have False values - 905 rows
expanded_df_rows_with_false = expanded_df[~expanded_df[expanded_df_match_columns].all(axis=1)]

expanded_df_rows_with_false
# Out:
#     Stock  Year       Revenue  Revenue Growth  Operating Income   Net Income  \
# 553  ABMD  2018  5.937490e+08        0.000000      1.571370e+08  112170000.0
# 552  ABMD  2019  7.694320e+08        0.295888      2.248120e+08  259016000.0
# 551  ABMD  2020  8.408830e+08        0.092862      2.492190e+08  203009000.0
# 550  ABMD  2021  8.475220e+08        0.007895      2.295570e+08  225525000.0
# 549  ABMD  2022  1.031753e+09        0.217376      3.726920e+08  136505000.0
# ..    ...   ...           ...             ...               ...          ...
# 483  ZBRA  2019  4.485000e+09        0.000000      6.920000e+08  544000000.0
# 482  ZBRA  2020  4.448000e+09       -0.008250      6.510000e+08  504000000.0
# 481  ZBRA  2021  5.627000e+09        0.265063      9.790000e+08  837000000.0
# 480  ZBRA  2022  5.781000e+09        0.027368      1.346000e+09  463000000.0
# 479  ZBRA  2023  4.584000e+09       -0.207058      4.810000e+08  296000000.0
#
#      Net Income Ratio  Gross Profit  Gross Profit Ratio  Operating Expenses  \
# 553          0.188918  4.951680e+08            0.833969        3.380310e+08
# 552          0.336633  6.398650e+08            0.831607        4.150530e+08
# 551          0.241424  6.895780e+08            0.820064        4.403590e+08
# 550          0.266099  6.856150e+08            0.808964        4.560580e+08
# 549          0.132304  8.435950e+08            0.817633        5.868890e+08
# ..                ...           ...                 ...                 ...
# 483          0.121293  2.100000e+09            0.468227        1.376000e+09
# 482          0.113309  2.003000e+09            0.450315        1.318000e+09
# 481          0.148747  2.628000e+09            0.467034        1.617000e+09
# 480          0.080090  2.624000e+09            0.453901        1.688000e+09
# 479          0.064572  2.123000e+09            0.463133        1.642000e+09
#
#      ...  expected_revenuegrowth  revenuegrowth_match  expected_costofrevenue  \
# 553  ...                0.000000                False            9.858100e+07
# 552  ...                0.295888                False            1.295670e+08
# 551  ...                0.092862                False            1.513050e+08
# 550  ...                0.007895                 True            1.619070e+08
# 549  ...                0.217376                False            1.881580e+08
# ..   ...                     ...                  ...                     ...
# 483  ...                0.000000                False            2.385000e+09
# 482  ...               -0.008250                False            2.445000e+09
# 481  ...                0.265063                False            2.999000e+09
# 480  ...                0.027368                False            3.157000e+09
# 479  ...               -0.207058                False            2.461000e+09
#
#      costofrevenue_match  expected_operatingincome  operatingincome_match  \
# 553                 True              1.571370e+08                   True
# 552                 True              2.248120e+08                   True
# 551                 True              2.492190e+08                   True
# 550                 True              2.295570e+08                   True
# 549                 True              2.567060e+08                  False
# ..                   ...                       ...                    ...
# 483                 True              7.240000e+08                  False
# 482                 True              6.850000e+08                  False
# 481                 True              1.011000e+09                  False
# 480                 True              9.360000e+08                  False
# 479                 True              4.810000e+08                   True
#
#      expected_operatingexpenses  operatingexpenses_match  \
# 553                3.380310e+08                     True
# 552                4.150530e+08                     True
# 551                4.403590e+08                     True
# 550                4.560580e+08                     True
# 549                4.709030e+08                    False
# ..                          ...                      ...
# 483                1.408000e+09                    False
# 482                1.352000e+09                    False
# 481                1.649000e+09                    False
# 480                1.278000e+09                    False
# 479                1.642000e+09                     True
#
#      expected_depreciationamortization  depreciationamortization_match
# 553                          7317000.0                           False
# 552                          5955000.0                           False
# 551                          8263000.0                            True
# 550                         17380000.0                            True
# 549                         28089000.0                            True
# ..                                 ...                             ...
# 483                        151000000.0                           False
# 482                         85000000.0                           False
# 481                        194000000.0                           False
# 480                       -206000000.0                           False
# 479                        171000000.0                           False
#
# [905 rows x 36 columns]

# %% [markdown]
# Upon closer inspection, most of the stocks with mismatched values are from the real stocks called using the Financial Modelling Prep API. This could be a reflection of the actual values using different real-world calculations than the assumptions we are using (e.g. Operating Expenses = Gross Profit - Operating Income).
#
# We do not drop these rows.

# %%
expanded_df_rows_with_false['Stock'].unique()
# Out:
# array(['ABMD', 'ACN', 'ADBE', 'ADP', 'ADSK', 'AJG', 'ALNY', 'AMGN', 'AMP',
#        'ANSS', 'ANTM', 'AON', 'APD', 'APP', 'ARGX', 'ASML', 'ASR', 'ATRI',
#        'AVGOP', 'AXON', 'AXP', 'AYI', 'AZO', 'BAC-PL', 'BH-A', 'BIO',
#        'BIO-B', 'BKNG', 'BLD', 'BLK', 'BRK-A', 'BRK-B', 'BURL', 'CABO',
#        'CACC', 'CACI', 'CASY', 'CAT', 'CB', 'CDNS', 'CEG', 'CHE', 'CHTR',
#        'CI', 'CMI', 'COIN', 'COKE', 'COST', 'CPAY', 'CRM', 'CRWD', 'CSL',
#        'CSWI', 'CVCO', 'CW', 'CYBR', 'DDS', 'DE', 'DHR-PA', 'DHR-PB',
#        'DJCO', 'DPZ', 'DUOL', 'EFX', 'ELV', 'EME', 'EQIX', 'ERIE', 'ESLT',
#        'ESS', 'ETN', 'EVR', 'FCNCA', 'FDS', 'FDX', 'FFIV', 'FICO', 'FIX',
#        'FLT', 'FLUT', 'FTV-PA', 'GD', 'GEV', 'GHC', 'GPI', 'GS', 'GWW',
#        'HCA', 'HD', 'HUBB', 'HUBS', 'HUM', 'IDXX', 'IESC', 'INTU', 'ISRG',
#        'IT', 'JLL', 'JPM', 'KAI', 'KLAC', 'KNSL', 'KRTX', 'KSU', 'LAD',
#        'LII', 'LIN', 'LLY', 'LMT', 'LPLA', 'LULU', 'MA', 'MANH', 'MAR',
#        'MCD', 'MCK', 'MCO', 'MDGL', 'MEDP', 'MELI', 'META', 'MKL', 'MLM',
#        'MOH', 'MORN', 'MPWR', 'MSCI', 'MSFT', 'MSI', 'MSTR', 'MTD',
#        'MUSA', 'NEU', 'NFLX', 'NOC', 'NOW', 'NVR', 'NWLI', 'ORLY', 'PEN',
#        'PH', 'PIPR', 'PODD', 'POOL', 'POWL', 'PRI', 'PSA', 'PWR', 'PXD',
#        'RACE', 'RBC', 'REGN', 'RH', 'ROK', 'ROP', 'RS', 'SAIA', 'SAP',
#        'SEB', 'SHW', 'SNA', 'SNPS', 'SPGI', 'SPOT', 'STZ-B', 'SWAV',
#        'SYK', 'TDG', 'TDY', 'TMO', 'TPL', 'TSLA', 'TT', 'TYL', 'UI',
#        'ULTA', 'UNH', 'URI', 'USB-PA', 'UTHR', 'V', 'VMC', 'VMI', 'VRSK',
#        'VRTX', 'WAT', 'WFC-PL', 'WINA', 'WING', 'WIRE', 'WSO', 'WSO-B',
#        'WST', 'WTM', 'WTW', 'ZBRA'], dtype=object)

# %%
# expanded_df.to_csv('expanded_df_v6.csv', index=False)
# partial_df.to_csv('partial_df_v6.csv', index=False)
# historical_df.to_csv('historical_df_v5.csv', index=False)
# sparse_df.to_csv('sparse_df_v5.csv', index=False)

# %%
expanded_df.shape
# Out:
# (100905, 36)

# %%
partial_df.shape
# Out:
# (7997, 36)

# %%
historical_df.shape
# Out:
# (407, 7)

# %%
sparse_df.shape
# Out:
# (478, 3)

# %% [markdown]
# # 4. Merge all datasets into one

# %% [markdown]
# Now that the datasets have been cleaned, we merge all 4 datasets into one.
#
# We use concat to join since the datasets have the same structure, and we only want to combine rows.

# %%
merged_df = pd.concat([expanded_df, partial_df], axis=0, ignore_index=True).drop_duplicates()

# %%
merged_df = pd.concat([merged_df, historical_df, sparse_df], axis=0, ignore_index=True).drop_duplicates()

# %%
merged_df
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0       AAAR  2000  1.226394e+09        0.000000      3.822607e+08
# 1       AAAR  2001  1.363043e+09        0.111424      2.826937e+08
# 2       AAAR  2002  9.680363e+08       -0.289798      1.493846e+08
# 3       AAAR  2003  7.725786e+08       -0.201912      8.830040e+07
# 4       AAAR  2004  9.481924e+07       -0.877269      1.385745e+07
# ...      ...   ...           ...             ...               ...
# 109750  RXDK  2003  7.185620e+08             NaN               NaN
# 109751  RXDK  2004  1.337162e+09             NaN               NaN
# 109752  RXDK  2005  9.438851e+07             NaN               NaN
# 109753  RXDK  2006  7.436636e+08             NaN               NaN
# 109754  RXDK  2008  4.864746e+07             NaN               NaN
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       3.821538e+08          0.311608  7.326731e+08            0.597421
# 1       2.823476e+08          0.207145  5.723752e+08            0.419924
# 2       1.489654e+08          0.153884  4.224707e+08            0.436420
# 3       8.753229e+07          0.113299  3.959663e+08            0.512526
# 4       1.312690e+07          0.138441  4.645290e+07            0.489910
# ...              ...               ...           ...                 ...
# 109750           NaN               NaN           NaN                 NaN
# 109751           NaN               NaN           NaN                 NaN
# 109752           NaN               NaN           NaN                 NaN
# 109753           NaN               NaN           NaN                 NaN
# 109754           NaN               NaN           NaN                 NaN
#
#         Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 0             3.504124e+08  ...                0.000000                False
# 1             2.896814e+08  ...                0.111424                False
# 2             2.730861e+08  ...               -0.289798                False
# 3             3.076659e+08  ...               -0.201912                False
# 4             3.259545e+07  ...               -0.877269                False
# ...                    ...  ...                     ...                  ...
# 109750                 NaN  ...                     NaN                  NaN
# 109751                 NaN  ...                     NaN                  NaN
# 109752                 NaN  ...                     NaN                  NaN
# 109753                 NaN  ...                     NaN                  NaN
# 109754                 NaN  ...                     NaN                  NaN
#
#         expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 0                 4.937207e+08                 True              3.822607e+08
# 1                 7.906683e+08                 True              2.826937e+08
# 2                 5.455656e+08                 True              1.493846e+08
# 3                 3.766123e+08                 True              8.830040e+07
# 4                 4.836634e+07                 True              1.385745e+07
# ...                        ...                  ...                       ...
# 109750                     NaN                  NaN                       NaN
# 109751                     NaN                  NaN                       NaN
# 109752                     NaN                  NaN                       NaN
# 109753                     NaN                  NaN                       NaN
# 109754                     NaN                  NaN                       NaN
#
#        operatingincome_match  expected_operatingexpenses  \
# 0                       True                3.504124e+08
# 1                       True                2.896814e+08
# 2                       True                2.730861e+08
# 3                       True                3.076659e+08
# 4                       True                3.259545e+07
# ...                      ...                         ...
# 109750                   NaN                         NaN
# 109751                   NaN                         NaN
# 109752                   NaN                         NaN
# 109753                   NaN                         NaN
# 109754                   NaN                         NaN
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 0                         True                          1056139.0
# 1                         True                          7333540.0
# 2                         True                          3297207.0
# 3                         True                          4757430.0
# 4                         True                           569588.0
# ...                        ...                                ...
# 109750                     NaN                                NaN
# 109751                     NaN                                NaN
# 109752                     NaN                                NaN
# 109753                     NaN                                NaN
# 109754                     NaN                                NaN
#
#        depreciationamortization_match
# 0                                True
# 1                                True
# 2                                True
# 3                                True
# 4                                True
# ...                               ...
# 109750                            NaN
# 109751                            NaN
# 109752                            NaN
# 109753                            NaN
# 109754                            NaN
#
# [109755 rows x 36 columns]

# %% [markdown]
# #### Checking Merged Dataset

# %%
# Checking shape of merged dataset
merged_df.shape
# Out:
# (109755, 36)

# %%
# Ensure no more duplicate rows
duplicate_rows = merged_df[merged_df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Stock, Year, Revenue, Revenue Growth, Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses, Cost of Revenue, EBITDA, Interest Expense, Depreciation & Amortization, expected_EBITDA, EBITDA_match, expected_netincome, netincome_match, expected_grossprofit, grossprofit_match, expected_netincome_ratio, netincomeratio_match, expected_grossprofit_ratio, grossprofitratio_match, expected_revenue, revenue_match, expected_revenuegrowth, revenuegrowth_match, expected_costofrevenue, costofrevenue_match, expected_operatingincome, operatingincome_match, expected_operatingexpenses, operatingexpenses_match, expected_depreciationamortization, depreciationamortization_match]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# There will be NaN values from merging other datasets.
#
# We need to ensure that there are no completely null rows.

# %%
merged_df = merged_df.dropna(how='all')

if merged_df.isnull().all(axis=1).any():
    print("There are rows where all values are null.")
else:
    print("No completely null rows.")
# Out:
# No completely null rows.

# %%
# Check data types
merged_df.dtypes
# Out:
# Stock                                 object
# Year                                   int64
# Revenue                              float64
# Revenue Growth                       float64
# Operating Income                     float64
# Net Income                           float64
# Net Income Ratio                     float64
# Gross Profit                         float64
# Gross Profit Ratio                   float64
# Operating Expenses                   float64
# Cost of Revenue                      float64
# EBITDA                               float64
# Interest Expense                     float64
# Depreciation & Amortization          float64
# expected_EBITDA                      float64
# EBITDA_match                          object
# expected_netincome                   float64
# netincome_match                       object
# expected_grossprofit                 float64
# grossprofit_match                     object
# expected_netincome_ratio             float64
# netincomeratio_match                  object
# expected_grossprofit_ratio           float64
# grossprofitratio_match                object
# expected_revenue                     float64
# revenue_match                         object
# expected_revenuegrowth               float64
# revenuegrowth_match                   object
# expected_costofrevenue               float64
# costofrevenue_match                   object
# expected_operatingincome             float64
# operatingincome_match                 object
# expected_operatingexpenses           float64
# operatingexpenses_match               object
# expected_depreciationamortization    float64
# depreciationamortization_match        object
# dtype: object

# %%
# Summary of merged dataset
merged_df.describe()
# Out:
#                 Year       Revenue  Revenue Growth  Operating Income  \
# count  109755.000000  1.097550e+05    1.088700e+05      1.088700e+05
# mean     2012.814879  1.288052e+09             inf      2.009616e+08
# std         7.472332  5.174509e+09             NaN      1.310842e+09
# min      2000.000000  0.000000e+00   -9.995006e-01     -2.698500e+10
# 25%      2006.000000  5.491529e+08   -4.575421e-01      3.737903e+07
# 50%      2013.000000  1.096443e+09    0.000000e+00      1.243181e+08
# 75%      2020.000000  1.647164e+09    8.511327e-01      2.595346e+08
# max      2024.000000  3.675330e+11             inf      1.372360e+11
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# count  1.088700e+05     108870.000000  1.092340e+05       108870.000000
# mean   1.892545e+08          0.141341  5.759100e+08            0.450374
# std    9.208276e+08          2.015173  2.381924e+09            0.091703
# min   -2.281900e+10       -663.119266 -2.590780e+08           -5.776780
# 25%    3.674602e+07          0.071269  2.385803e+08            0.375018
# 50%    1.236149e+08          0.148225  4.748697e+08            0.449813
# 75%    2.586185e+08          0.225067  7.216252e+08            0.525462
# max    9.622300e+10          2.285934  1.934050e+11            1.063719
#
#        Operating Expenses  Cost of Revenue  ...  expected_netincome  \
# count        1.088700e+05     1.092340e+05  ...        1.088700e+05
# mean         3.954685e+08     7.052640e+08  ...        1.947034e+08
# std          2.372917e+09     3.403115e+09  ...        1.238412e+09
# min          0.000000e+00     0.000000e+00  ...       -4.870400e+10
# 25%          1.584169e+08     2.933376e+08  ...        3.675283e+07
# 50%          3.167506e+08     5.877981e+08  ...        1.236698e+08
# 75%          4.812132e+08     8.848713e+08  ...        2.588521e+08
# max          2.647660e+11     2.963670e+11  ...        1.360510e+11
#
#        expected_grossprofit  expected_netincome_ratio  \
# count          1.088700e+05             108870.000000
# mean           5.842560e+08                  0.141340
# std            2.657713e+09                  2.015173
# min           -2.590780e+08               -663.119266
# 25%            2.388123e+08                  0.071269
# 50%            4.751024e+08                  0.148230
# 75%            7.217758e+08                  0.225067
# max            1.951870e+11                  2.285934
#
#        expected_grossprofit_ratio  expected_revenue  expected_revenuegrowth  \
# count               108870.000000      1.092340e+05            1.088700e+05
# mean                     0.450343      1.281174e+09                     inf
# std                      0.091664      5.054281e+09                     NaN
# min                     -5.776780      0.000000e+00           -9.995006e-01
# 25%                      0.374998      5.491039e+08           -4.575421e-01
# 50%                      0.449782      1.096249e+09            0.000000e+00
# 75%                      0.525440      1.647294e+09            8.511327e-01
# max                      1.000000      3.675330e+11                     inf
#
#        expected_costofrevenue  expected_operatingincome  \
# count            1.088700e+05              1.088700e+05
# mean             7.136331e+08              1.808535e+08
# std              3.603966e+09              1.661071e+09
# min              0.000000e+00             -1.866510e+11
# 25%              2.935935e+08              3.723837e+07
# 50%              5.879782e+08              1.240990e+08
# 75%              8.851731e+08              2.592215e+08
# max              2.963670e+11              1.372360e+11
#
#        expected_operatingexpenses  expected_depreciationamortization
# count                1.088700e+05                       1.088700e+05
# mean                 3.753603e+08                       1.288811e+07
# std                  1.375360e+09                       3.238651e+08
# min                 -2.925400e+10                      -5.257200e+10
# 25%                  1.583538e+08                       2.608643e+06
# 50%                  3.166551e+08                       5.090860e+06
# 75%                  4.810556e+08                       7.583524e+06
# max                  1.404470e+11                       2.469300e+10
#
# [8 rows x 24 columns]

# %% [markdown]
# **Year**:
#
# Min year is 2000, Max year is 2024. Median year is 2013. The mean year 2012 suggests a midpoint near the median, indicating that the years are evenly distributed and not heavily skewed.
#
# **Revenue Growth**:
#
# Need to explore Mean and Max Revenue Growth (inf) as it might represent outliers.
#
# **Operating Income, Net Income, Net Income Ratio, Gross Profit, Gross Profit Ratio, Operating Expenses**:
#
# The negative min values may need to be investigated for accuracy or treated by replacing or refining.
#
# **Cost of Revenue**:
#
# The large standard deviation (3.403115e+09) suggests outliers or extreme cases.

# %%
# 9564 rows still have rows with impossible negative values
negative_rows = merged_df[
    (merged_df[['Operating Income', 'Net Income', 'Net Income Ratio', 
                'Gross Profit', 'Gross Profit Ratio', 'Operating Expenses']] < 0).any(axis=1)
]

print(negative_rows)
# Out:
#          Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 5         AAAR  2005  6.050416e+08        5.381000     -2.464341e+07
# 38      AAGYLB  2013  8.312850e+08       -0.598627     -1.380779e+07
# 39      AAGYLB  2014  4.357647e+08       -0.475794     -1.429305e+07
# 54      AAHKPV  2004  7.513738e+08       -0.480948     -5.106996e+06
# 58      AAHKPV  2008  2.082850e+09        1.786350     -1.037638e+08
# ...        ...   ...           ...             ...               ...
# 108783  ZTASWV  2023  2.625965e+08       -0.787795     -1.001228e+07
# 108805   ZVHCG  2023  1.266791e+09        0.193511     -1.083619e+08
# 108819  ZWDIJC  2023  1.357441e+09       -0.154495     -6.649307e+06
# 108830  ZXBJSE  2022  3.820760e+08        0.000000     -2.639081e+07
# 108837  ZXKILH  2023  1.437732e+09       -0.192163     -8.332478e+07
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 5      -2.535253e+07         -0.041902  1.957464e+08            0.323525
# 38     -1.476732e+07         -0.017764  2.661671e+08            0.320188
# 39     -1.524896e+07         -0.034994  1.534762e+08            0.352200
# 54     -5.768982e+06         -0.007678  2.708450e+08            0.360466
# 58     -1.044112e+08         -0.050129  7.196320e+08            0.345503
# ...              ...               ...           ...                 ...
# 108783 -1.042020e+07         -0.039681  8.012355e+07            0.305120
# 108805 -1.086421e+08         -0.085762  3.928688e+08            0.310129
# 108819 -6.977551e+06         -0.005140  4.335863e+08            0.319414
# 108830 -2.663411e+07         -0.069709  1.209709e+08            0.316615
# 108837 -8.345763e+07         -0.058048  4.601249e+08            0.320035
#
#         Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 5             2.203898e+08  ...                5.381000                False
# 38            2.799749e+08  ...               -0.598627                False
# 39            1.677692e+08  ...               -0.475794                False
# 54            2.759520e+08  ...               -0.480948                False
# 58            8.233958e+08  ...                1.786350                False
# ...                    ...  ...                     ...                  ...
# 108783        9.013583e+07  ...               -0.787795                 True
# 108805        5.012307e+08  ...                0.193511                 True
# 108819        4.402356e+08  ...               -0.154495                 True
# 108830        1.473617e+08  ...                0.000000                 True
# 108837        5.434497e+08  ...               -0.192163                 True
#
#         expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 5                 4.092952e+08                 True             -2.464341e+07
# 38                5.651179e+08                 True             -1.380779e+07
# 39                2.822885e+08                 True             -1.429305e+07
# 54                4.805288e+08                 True             -5.106996e+06
# 58                1.363218e+09                 True             -1.037638e+08
# ...                        ...                  ...                       ...
# 108783            1.824730e+08                 True             -1.001228e+07
# 108805            8.739221e+08                 True             -1.083619e+08
# 108819            9.238552e+08                 True             -6.649307e+06
# 108830            2.611050e+08                 True             -2.639081e+07
# 108837            9.776070e+08                 True             -8.332478e+07
#
#        operatingincome_match  expected_operatingexpenses  \
# 5                       True                2.203898e+08
# 38                      True                2.799749e+08
# 39                      True                1.677692e+08
# 54                      True                2.759520e+08
# 58                      True                8.233958e+08
# ...                      ...                         ...
# 108783                  True                9.013583e+07
# 108805                  True                5.012307e+08
# 108819                  True                4.402356e+08
# 108830                  True                1.473617e+08
# 108837                  True                5.434497e+08
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 5                         True                          8278723.0
# 38                        True                          5678449.0
# 39                        True                          7754165.0
# 54                        True                          1157469.0
# 58                        True                          3236655.0
# ...                        ...                                ...
# 108783                    True                          7990217.0
# 108805                    True                          2524636.0
# 108819                    True                          5637478.0
# 108830                    True                          2015209.0
# 108837                    True                          2010534.0
#
#        depreciationamortization_match
# 5                                True
# 38                               True
# 39                               True
# 54                               True
# 58                               True
# ...                               ...
# 108783                           True
# 108805                           True
# 108819                           True
# 108830                           True
# 108837                           True
#
# [9564 rows x 36 columns]

# %%
# Remove rows with impossible negative values
merged_df = merged_df[~(
    (merged_df[['Operating Income', 'Net Income', 'Net Income Ratio', 
                'Gross Profit', 'Gross Profit Ratio', 'Operating Expenses']] < 0).any(axis=1)
)]

# %%
merged_df
# Out:
#        Stock  Year       Revenue  Revenue Growth  Operating Income  \
# 0       AAAR  2000  1.226394e+09        0.000000      3.822607e+08
# 1       AAAR  2001  1.363043e+09        0.111424      2.826937e+08
# 2       AAAR  2002  9.680363e+08       -0.289798      1.493846e+08
# 3       AAAR  2003  7.725786e+08       -0.201912      8.830040e+07
# 4       AAAR  2004  9.481924e+07       -0.877269      1.385745e+07
# ...      ...   ...           ...             ...               ...
# 109750  RXDK  2003  7.185620e+08             NaN               NaN
# 109751  RXDK  2004  1.337162e+09             NaN               NaN
# 109752  RXDK  2005  9.438851e+07             NaN               NaN
# 109753  RXDK  2006  7.436636e+08             NaN               NaN
# 109754  RXDK  2008  4.864746e+07             NaN               NaN
#
#           Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# 0       3.821538e+08          0.311608  7.326731e+08            0.597421
# 1       2.823476e+08          0.207145  5.723752e+08            0.419924
# 2       1.489654e+08          0.153884  4.224707e+08            0.436420
# 3       8.753229e+07          0.113299  3.959663e+08            0.512526
# 4       1.312690e+07          0.138441  4.645290e+07            0.489910
# ...              ...               ...           ...                 ...
# 109750           NaN               NaN           NaN                 NaN
# 109751           NaN               NaN           NaN                 NaN
# 109752           NaN               NaN           NaN                 NaN
# 109753           NaN               NaN           NaN                 NaN
# 109754           NaN               NaN           NaN                 NaN
#
#         Operating Expenses  ...  expected_revenuegrowth  revenuegrowth_match  \
# 0             3.504124e+08  ...                0.000000                False
# 1             2.896814e+08  ...                0.111424                False
# 2             2.730861e+08  ...               -0.289798                False
# 3             3.076659e+08  ...               -0.201912                False
# 4             3.259545e+07  ...               -0.877269                False
# ...                    ...  ...                     ...                  ...
# 109750                 NaN  ...                     NaN                  NaN
# 109751                 NaN  ...                     NaN                  NaN
# 109752                 NaN  ...                     NaN                  NaN
# 109753                 NaN  ...                     NaN                  NaN
# 109754                 NaN  ...                     NaN                  NaN
#
#         expected_costofrevenue  costofrevenue_match  expected_operatingincome  \
# 0                 4.937207e+08                 True              3.822607e+08
# 1                 7.906683e+08                 True              2.826937e+08
# 2                 5.455656e+08                 True              1.493846e+08
# 3                 3.766123e+08                 True              8.830040e+07
# 4                 4.836634e+07                 True              1.385745e+07
# ...                        ...                  ...                       ...
# 109750                     NaN                  NaN                       NaN
# 109751                     NaN                  NaN                       NaN
# 109752                     NaN                  NaN                       NaN
# 109753                     NaN                  NaN                       NaN
# 109754                     NaN                  NaN                       NaN
#
#        operatingincome_match  expected_operatingexpenses  \
# 0                       True                3.504124e+08
# 1                       True                2.896814e+08
# 2                       True                2.730861e+08
# 3                       True                3.076659e+08
# 4                       True                3.259545e+07
# ...                      ...                         ...
# 109750                   NaN                         NaN
# 109751                   NaN                         NaN
# 109752                   NaN                         NaN
# 109753                   NaN                         NaN
# 109754                   NaN                         NaN
#
#        operatingexpenses_match  expected_depreciationamortization  \
# 0                         True                          1056139.0
# 1                         True                          7333540.0
# 2                         True                          3297207.0
# 3                         True                          4757430.0
# 4                         True                           569588.0
# ...                        ...                                ...
# 109750                     NaN                                NaN
# 109751                     NaN                                NaN
# 109752                     NaN                                NaN
# 109753                     NaN                                NaN
# 109754                     NaN                                NaN
#
#        depreciationamortization_match
# 0                                True
# 1                                True
# 2                                True
# 3                                True
# 4                                True
# ...                               ...
# 109750                            NaN
# 109751                            NaN
# 109752                            NaN
# 109753                            NaN
# 109754                            NaN
#
# [100191 rows x 36 columns]

# %%
merged_df.describe()
# Out:
#                 Year       Revenue  Revenue Growth  Operating Income  \
# count  100191.000000  1.001910e+05    99306.000000      9.930600e+04
# mean     2012.816061  1.298722e+09        2.834273      2.236583e+08
# std         7.475134  5.217603e+09       28.277972      1.362351e+09
# min      2000.000000  6.993100e+04       -0.999084      1.326189e+05
# 25%      2006.000000  5.564988e+08       -0.451841      5.690216e+07
# 50%      2013.000000  1.100775e+09        0.000000      1.435339e+08
# 75%      2020.000000  1.648227e+09        0.853648      2.765742e+08
# max      2024.000000  3.675330e+11     1889.754699      1.372360e+11
#
#          Net Income  Net Income Ratio  Gross Profit  Gross Profit Ratio  \
# count  9.930600e+04      99306.000000  9.967000e+04        99306.000000
# mean   2.116830e+08          0.165789  5.931207e+08            0.461391
# std    9.551527e+08          0.092602  2.401746e+09            0.084817
# min    4.415663e+02          0.000002  0.000000e+00            0.000000
# 25%    5.630877e+07          0.092684  2.487228e+08            0.394067
# 50%    1.429354e+08          0.161458  4.894837e+08            0.463116
# 75%    2.756703e+08          0.232938  7.429406e+08            0.531942
# max    9.622300e+10          2.285934  1.934050e+11            1.063719
#
#        Operating Expenses  Cost of Revenue  ...  expected_netincome  \
# count        9.930600e+04     9.967000e+04  ...        9.930600e+04
# mean         3.907715e+08     6.981188e+08  ...        2.170116e+08
# std          2.292548e+09     3.437781e+09  ...        1.286195e+09
# min          0.000000e+00     0.000000e+00  ...       -4.870400e+10
# 25%          1.571172e+08     2.918484e+08  ...        5.629911e+07
# 50%          3.113996e+08     5.802615e+08  ...        1.429635e+08
# 75%          4.716377e+08     8.689813e+08  ...        2.758780e+08
# max          2.429500e+11     2.963670e+11  ...        1.360510e+11
#
#        expected_grossprofit  expected_netincome_ratio  \
# count          9.930600e+04              99306.000000
# mean           6.023336e+08                  0.165789
# std            2.700396e+09                  0.092602
# min            0.000000e+00                  0.000002
# 25%            2.488819e+08                  0.092684
# 50%            4.897798e+08                  0.161458
# 75%            7.431881e+08                  0.232938
# max            1.951870e+11                  2.285934
#
#        expected_grossprofit_ratio  expected_revenue  expected_revenuegrowth  \
# count                99306.000000      9.967000e+04            99306.000000
# mean                     0.461357      1.291240e+09                2.834273
# std                      0.084775      5.087051e+09               28.277972
# min                      0.000000      0.000000e+00               -0.999084
# 25%                      0.394047      5.563198e+08               -0.451841
# 50%                      0.463088      1.100655e+09                0.000000
# 75%                      0.531917      1.648433e+09                0.853648
# max                      1.000000      3.675330e+11             1889.754699
#
#        expected_costofrevenue  expected_operatingincome  \
# count            9.930600e+04              9.930600e+04
# mean             7.072677e+08              2.028640e+08
# std              3.655443e+09              1.712221e+09
# min              0.000000e+00             -1.866510e+11
# 25%              2.922159e+08              5.676511e+07
# 50%              5.804474e+08              1.433968e+08
# 75%              8.691021e+08              2.762493e+08
# max              2.963670e+11              1.372360e+11
#
#        expected_operatingexpenses  expected_depreciationamortization
# count                9.930600e+04                       9.930600e+04
# mean                 3.699772e+08                       1.397491e+07
# std                  1.295191e+09                       2.880655e+08
# min                 -2.925400e+10                      -3.483200e+10
# 25%                  1.570542e+08                       2.609362e+06
# 50%                  3.112744e+08                       5.096295e+06
# 75%                  4.715306e+08                       7.587542e+06
# max                  8.917300e+10                       2.469300e+10
#
# [8 rows x 24 columns]

# %%
# merged_df.to_csv('merged_df_v4.csv', index=False)
